# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
from torch.utils.data import Dataset, DataLoader
from torch import nn
from torch.nn.functional import relu
import torch.nn.functional as F
from scipy.io import loadmat
import os
from os import listdir
import pandas as pd
from skimage import io
from PIL import Image
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pickle

from utils_v2 import *
# from models import *

# %% [markdown]
# #### Goose 1st and 2nd series

# %%
val_dates = ['180409', '180412', '180414']
test_dates = ['180411', '180413']
bad_dates = []
load_path = '/home/bijanadmin/Desktop/Goose_data/data_Goose_all_2/'
# test_imbalance(load_path, val_dates, test_dates, bad_dates, test_train=True)

# %%
CH = 'all'
device = torch.device('cuda')

train_files, val_files, test_files = create_files(load_path, val_dates, test_dates, bad_dates)
train_loader, val_loader, test_loader = create_dataloaders(train_files, val_files, test_files, load_path, batch_size=128)

# %%
for batch_idx, (data, label, date, rec, time) in enumerate(train_loader): # check shapes
    print(data.shape)
    print(label.shape)
    print(len(date))
    print(len(rec))
    print(len(time))
    break
# Out:
# torch.Size([128, 62, 100, 10])
# torch.Size([128, 1])
# 128
# 128
# 128

# %%
# movement labelled 0; non-movement labelled 1
for batch_idx, (data, label, date, rec, time) in enumerate(train_loader):
    for i in range(128):
        print('date:{}, rec:{}, time:{}, label:{}'.format(date[i], rec[i], time[i], label[i][0].numpy()))
        if label[i][0].numpy() == 0.0:
            data_sub = data[i][0]
            plt.yticks(ticks=[0, 20, 40, 60, 80, 99], labels=[round(np.logspace(0, 2.45, 100)[i]) for i in [0, 20, 40, 60, 80, 99]])
            plt.xticks(ticks=[0, 9], labels=[1, 10])
            plt.imshow(data_sub)
            plt.clim(-1.5, 1.5)
            plt.colorbar()
            plt.show()
    break
# Out:
# date:180324, rec:004, time:4489.0, label:1.0
# date:180324, rec:009, time:740.0, label:0.0
# date:180331, rec:001, time:2340.0, label:0.0
# date:180327, rec:007, time:5001.0, label:0.0
# date:180322, rec:003, time:4499.0, label:1.0
# date:180324, rec:001, time:1482.0, label:1.0
# date:180324, rec:008, time:3237.0, label:1.0
# date:180330, rec:009, time:4051.0, label:0.0
# date:180327, rec:007, time:4671.0, label:0.0
# date:180325, rec:002, time:6165.0, label:1.0
# date:180324, rec:009, time:1682.0, label:1.0
# date:180325, rec:001, time:6460.0, label:1.0
# date:180323, rec:004, time:6511.0, label:1.0
# date:180327, rec:008, time:220.0, label:0.0
# date:180327, rec:008, time:4923.0, label:0.0
# date:180325, rec:004, time:7070.0, label:1.0
# date:180325, rec:004, time:457.0, label:1.0
# date:180327, rec:008, time:4603.0, label:0.0
# date:180324, rec:003, time:5077.0, label:1.0
# date:180330, rec:001, time:5679.0, label:1.0
# date:180324, rec:004, time:6472.0, label:1.0
# date:180322, rec:003, time:5936.0, label:1.0
# date:180331, rec:007, time:6668.0, label:0.0
# date:180324, rec:004, time:2099.0, label:1.0
# date:180324, rec:001, time:7147.0, label:1.0
# date:180325, rec:002, time:5925.0, label:1.0
# date:180401, rec:001, time:3826.0, label:1.0
# date:180327, rec:007, time:1820.0, label:0.0
# date:180401, rec:001, time:730.0, label:0.0
# date:180410, rec:006, time:4339.0, label:1.0
# date:180331, rec:007, time:2477.0, label:0.0
# date:180330, rec:008, time:1341.0, label:0.0
# date:180325, rec:002, time:5258.0, label:1.0
# date:180329, rec:002, time:3422.0, label:1.0
# date:180324, rec:001, time:928.0, label:0.0
# date:180330, rec:007, time:6208.0, label:1.0
# date:180323, rec:004, time:4319.0, label:1.0
# date:180401, rec:001, time:1170.0, label:0.0
# date:180325, rec:001, time:1120.0, label:0.0
# date:180324, rec:008, time:1571.0, label:0.0
# date:180331, rec:004, time:359.0, label:1.0
# date:180323, rec:002, time:530.0, label:1.0
# date:180410, rec:006, time:110.0, label:1.0
# date:180330, rec:009, time:3991.0, label:0.0
# date:180331, rec:003, time:3298.0, label:1.0
# date:180330, rec:008, time:5935.0, label:0.0
# date:180401, rec:001, time:1710.0, label:0.0
# date:180325, rec:009, time:1050.0, label:0.0
# date:180325, rec:001, time:1050.0, label:0.0
# date:180325, rec:006, time:471.0, label:1.0
# date:180327, rec:007, time:2480.0, label:0.0
# date:180327, rec:008, time:2162.0, label:0.0
# date:180329, rec:001, time:270.0, label:0.0
# date:180323, rec:003, time:3491.0, label:1.0
# date:180330, rec:006, time:4462.0, label:1.0
# date:180401, rec:001, time:4517.0, label:1.0
# date:180325, rec:005, time:4059.0, label:1.0
# date:180330, rec:001, time:6546.0, label:1.0
# date:180324, rec:004, time:6893.0, label:1.0
# date:180330, rec:008, time:2796.0, label:0.0
# date:180330, rec:006, time:4702.0, label:1.0
# date:180325, rec:009, time:2130.0, label:0.0
# date:180330, rec:004, time:1097.0, label:1.0
# date:180325, rec:001, time:1710.0, label:0.0
# date:180324, rec:008, time:5674.0, label:0.0
# date:180331, rec:007, time:5167.0, label:0.0
# date:180327, rec:001, time:1690.0, label:0.0
# date:180331, rec:001, time:2110.0, label:0.0
# date:180401, rec:001, time:5367.0, label:0.0
# date:180330, rec:008, time:2286.0, label:0.0
# date:180326, rec:004, time:4187.0, label:1.0
# date:180325, rec:006, time:441.0, label:1.0
# date:180325, rec:005, time:1564.0, label:1.0
# date:180330, rec:001, time:6105.0, label:1.0
# date:180327, rec:002, time:2070.0, label:1.0
# date:180330, rec:008, time:4327.0, label:0.0
# date:180325, rec:005, time:5307.0, label:1.0
# date:180324, rec:001, time:868.0, label:0.0
# date:180401, rec:001, time:1710.0, label:0.0
# date:180324, rec:006, time:1072.0, label:1.0
# date:180327, rec:008, time:3202.0, label:0.0
# date:180325, rec:007, time:1973.0, label:1.0
# date:180327, rec:002, time:6885.0, label:1.0
# date:180330, rec:005, time:3286.0, label:1.0
# date:180329, rec:001, time:1480.0, label:0.0
# date:180323, rec:004, time:4339.0, label:1.0
# date:180324, rec:008, time:5063.0, label:0.0
# date:180327, rec:004, time:6553.0, label:1.0
# date:180324, rec:009, time:150.0, label:0.0
# date:180329, rec:006, time:5221.0, label:1.0
# date:180326, rec:004, time:2039.0, label:1.0
# date:180330, rec:007, time:2918.0, label:1.0
# date:180330, rec:009, time:1924.0, label:0.0
# date:180327, rec:001, time:5684.0, label:1.0
# date:180325, rec:004, time:6597.0, label:1.0
# date:180410, rec:005, time:3054.0, label:1.0
# date:180324, rec:008, time:3423.0, label:0.0
# date:180331, rec:005, time:6829.0, label:1.0
# date:180330, rec:008, time:3666.0, label:0.0
# date:180327, rec:007, time:4681.0, label:0.0
# date:180410, rec:005, time:4452.0, label:1.0
# date:180329, rec:004, time:5421.0, label:1.0
# date:180327, rec:004, time:3555.0, label:1.0
# date:180330, rec:006, time:4672.0, label:1.0
# date:180325, rec:003, time:6527.0, label:1.0
# date:180327, rec:008, time:2232.0, label:0.0
# date:180325, rec:009, time:1740.0, label:0.0
# date:180325, rec:001, time:1130.0, label:0.0
# date:180401, rec:001, time:2179.0, label:1.0
# date:180329, rec:002, time:5005.0, label:1.0
# date:180324, rec:006, time:682.0, label:1.0
# date:180324, rec:001, time:1106.0, label:1.0
# date:180329, rec:006, time:624.0, label:1.0
# date:180331, rec:001, time:5517.0, label:1.0
# date:180410, rec:006, time:5892.0, label:0.0
# date:180326, rec:004, time:2609.0, label:1.0
# date:180325, rec:001, time:2100.0, label:0.0
# date:180324, rec:006, time:150.0, label:1.0
# date:180329, rec:006, time:6714.0, label:1.0
# date:180331, rec:007, time:4357.0, label:0.0
# date:180331, rec:007, time:2206.0, label:1.0
# date:180329, rec:001, time:1150.0, label:0.0
# date:180410, rec:003, time:2690.0, label:1.0
# date:180410, rec:003, time:3918.0, label:1.0
# date:180325, rec:003, time:5002.0, label:1.0
# date:180329, rec:001, time:720.0, label:0.0
# date:180330, rec:008, time:6455.0, label:0.0
# date:180329, rec:006, time:4727.0, label:0.0

# %%
class CNN(nn.Module):
    def __init__(self,p_dropout):
        super(CNN,self).__init__()
    
        # convolutional layer (sees 1x100x10 image tensor)
        self.conv1 = nn.Conv2d(in_channels=62, out_channels=2,kernel_size=(3,3),stride=(1,1),padding=(1,1))
        # convolutional layer (sees 2x50x5 tensor)
        self.conv2 = nn.Conv2d(in_channels=2, out_channels=4,kernel_size=(3,3),stride=(1,1),padding=(1,1))
        # sees a layer 4x25x2
        self.fc1 = nn.Linear(4*25*2,1)
        
        # Max pooling
        self.pool = nn.MaxPool2d(2,2)
        # dropout layer 
        self.dropout = nn.Dropout(p_dropout)
         # batch normalization 
        self.bn1 = nn.BatchNorm2d(2)
        self.bn2 = nn.BatchNorm2d(4)
      
    def forward(self,x):
        
        x = x.float()
        
        conv_x1 = self.conv1(x)
        x = self.pool(F.relu(self.bn1(conv_x1))) # Convolution 1:

        conv_x2 = self.conv2(x)
        x = self.pool(F.relu(self.bn2(conv_x2))) # Convolution 2:

        x = x.view(x.shape[0],-1) # flatten image input
        
        x = self.dropout(x) # dropout
        x = self.fc1(x) # Fully connected layer
        
        return x, conv_x1, conv_x2

# %%
learning_rate = 0.001
tol = 0.01
p_dropout = 0.4

num_epochs = 51
model_name = 'CNN'
model_type = 'LR'
alpha = 0
loss_type = 'bce'
reg_type = 'none'
series = '1st_and_2nd'

model = CNN(p_dropout).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)
criterion = nn.BCELoss(reduction='mean')
model
# Out:
# CNN(
#   (conv1): Conv2d(62, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(2, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (fc1): Linear(in_features=200, out_features=1, bias=True)
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dropout): Dropout(p=0.4, inplace=False)
#   (bn1): BatchNorm2d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn2): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )

# %%
(data, labels, _, _, _) = next(iter(train_loader))
data = data.to(device)
output, conv1, conv2 = model(data)
output.shape
criterion
# Out:
# BCELoss()

# %%
epochs, training_losses, training_acc, val_losses, validation_acc = [], [], [], [], []

for epoch in range(num_epochs):
    train_loss, train_acc, conv1, conv2 = train(model, optimizer, criterion, train_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
    print('Train loss for epoch {}: {}'.format(epoch, train_loss))
    val_loss, val_acc = evaluate(model, optimizer, criterion, val_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
    print('Val loss for epoch {}: {}'.format(epoch, val_loss))
    epochs.append(epoch)
    training_losses.append(train_loss)
    training_acc.append(train_acc)
    val_losses.append(val_loss)
    validation_acc.append(val_acc)
    if val_loss <= min(val_losses):
        best_epoch = epoch
        print(epoch)
        path = '/home/bijanadmin/Desktop/Goose_data/model/CNN_10_sec_window'
        torch.save(model.state_dict(), '{}/CNN_CH{}_LOSS{}_DROPOUT{}{}_EPOCH{}_MODEL_{}_SERIES_{}.pt'.format(path, CH, loss_type, p_dropout, alpha, epoch,model_name,series))
        torch.save(conv1,'{}/conv_layer_1_CH{}_LOSS{}_DROPOUT{}{}_EPOCH{}_MODEL_{}_SERIES_{}.pt'.format(path, CH, loss_type, p_dropout, alpha, epoch,model_name,series))
        torch.save(conv2,'{}/conv_layer_2_CH{}_LOSS{}_DROPOUT{}{}_EPOCH{}_MODEL_{}_SERIES_{}.pt'.format(path, CH, loss_type, p_dropout, alpha, epoch,model_name,series))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-10-7df1928d022d> in <module>
#       2
#       3 for epoch in range(num_epochs):
# ----> 4     train_loss, train_acc, conv1, conv2 = train(model, optimizer, criterion, train_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
#       5     print('Train loss for epoch {}: {}'.format(epoch, train_loss))
#       6     val_loss, val_acc = evaluate(model, optimizer, criterion, val_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
#
# /mnt/pesaranlab/People/Capstone_students/Gino/Sleeping-Monkeys/codes/utils_v2.py in train(model, optimizer, criterion, loader, alpha, timewindow, model_type, loss_type, reg_type, collect_result, device)
#     207
#     208     for batch_idx, (data, labels, _, _, _) in enumerate(loader):
# --> 209         data = data.to(device).float()
#     210         labels = labels.to(device).float()
#     211
#
# RuntimeError: CUDA out of memory. Tried to allocate 32.00 MiB (GPU 0; 10.91 GiB total capacity; 156.84 MiB already allocated; 43.88 MiB free; 162.00 MiB reserved in total by PyTorch)

# %%
# =============================================================================
#  FILTERS CNN
# =============================================================================
filter1 = 2
filter2 = 4
dir_frequency = 'frequency_0_60'
dir_filters = '/filters_2_4_8'
dir_tapers = '/tapers_1_2'


for i in range(filter1):
    fig, ax = plt.subplots()
    ax.set_title('Filter {} - conv layer 1'.format(i+1),fontsize=14)
    img1 = ax.imshow(torch.detach(conv1[1,i,:,:]).cpu().numpy(),origin='lower')
    fig.colorbar(img1, ax=ax,orientation="vertical")
#     ax.set_aspect('auto')
    plt.show()
#     fig.savefig('Plots/Ch_{}/random_N_015_W_25_dn_018/'.format(Ch)+dir_frequency + dir_tapers + dir_filters +'/CNN_100rand_f_{}_{}_Filter_{}_conv1_2x{}x{}_filters_size_47_30.png'.format(fmin,fmax,i+1,filter1,filter2),bbox_inches='tight')
#     plt.close(fig)
   
    
for i in range(filter2):
    fig, ax = plt.subplots()
    ax.set_title('Filter {} - conv layer 2'.format(i+1),fontsize=14)
    img1 = ax.imshow(torch.detach(conv2[1,i,:,:]).cpu().numpy(),origin='lower')
    fig.colorbar(img1, ax=ax,orientation="vertical")
    plt.show()
    
#     fig.savefig('Plots/Ch_{}/random_N_015_W_25_dn_018/'.format(Ch)+ dir_frequency + dir_tapers + dir_filters +'/CNN_100rand_f_{}_{}_Filter_{}_conv2_2x{}x{}_filters_size_47_30.png'.format(fmin,fmax,i+1,filter1,filter2),bbox_inches='tight')
#     plt.close(fig)
