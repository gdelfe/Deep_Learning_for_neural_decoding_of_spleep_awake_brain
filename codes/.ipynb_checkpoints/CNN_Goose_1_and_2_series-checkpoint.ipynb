# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
from torch.utils.data import Dataset, DataLoader
from torch import nn
from torch.nn.functional import relu
import torch.nn.functional as F
from scipy.io import loadmat
import os
from os import listdir
import pandas as pd
from skimage import io
from PIL import Image
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pickle

from utils_v2 import *
# from models import *

# %% [markdown]
# #### Goose 1st and 2nd series

# %%
val_dates = ['180409', '180412', '180414']
test_dates = ['180411', '180413']
bad_dates = []
load_path = '/home/bijanadmin/Desktop/Goose_data/data_Goose_all_2/'
# test_imbalance(load_path, val_dates, test_dates, bad_dates, test_train=True)

# %%
CH = 'all'
device = torch.device('cuda')

train_files, val_files, test_files = create_files(load_path, val_dates, test_dates, bad_dates)
train_loader, val_loader, test_loader = create_dataloaders(train_files, val_files, test_files, load_path, batch_size=128)

# %%
for batch_idx, (data, label, date, rec, time) in enumerate(train_loader): # check shapes
    print(data.shape)
    print(label.shape)
    print(len(date))
    print(len(rec))
    print(len(time))
    break
# Out:
# torch.Size([128, 62, 100, 10])
# torch.Size([128, 1])
# 128
# 128
# 128

# %%
# movement labelled 0; non-movement labelled 1
for batch_idx, (data, label, date, rec, time) in enumerate(train_loader):
    for i in range(128):
        print('date:{}, rec:{}, time:{}, label:{}'.format(date[i], rec[i], time[i], label[i][0].numpy()))
        if label[i][0].numpy() == 0.0:
            data_sub = data[i][0]
            plt.yticks(ticks=[0, 20, 40, 60, 80, 99], labels=[round(np.logspace(0, 2.45, 100)[i]) for i in [0, 20, 40, 60, 80, 99]])
            plt.xticks(ticks=[0, 9], labels=[1, 10])
            plt.imshow(data_sub)
            plt.clim(-1.5, 1.5)
            plt.colorbar()
            plt.show()
    break
# Out:
# date:180331, rec:007, time:6858.0, label:0.0
# date:180329, rec:006, time:3749.0, label:1.0
# date:180330, rec:006, time:140.0, label:1.0
# date:180327, rec:008, time:5663.0, label:0.0
# date:180325, rec:006, time:4465.0, label:1.0
# date:180331, rec:007, time:5388.0, label:0.0
# date:180330, rec:009, time:6601.0, label:0.0
# date:180325, rec:004, time:4604.0, label:1.0
# date:180327, rec:008, time:5813.0, label:0.0
# date:180331, rec:004, time:3171.0, label:1.0
# date:180329, rec:001, time:260.0, label:0.0
# date:180401, rec:003, time:1150.0, label:1.0
# date:180410, rec:005, time:1818.0, label:0.0
# date:180324, rec:001, time:5574.0, label:1.0
# date:180327, rec:007, time:5171.0, label:0.0
# date:180330, rec:009, time:2174.0, label:0.0
# date:180330, rec:008, time:981.0, label:0.0
# date:180331, rec:007, time:1920.0, label:1.0
# date:180327, rec:007, time:2290.0, label:0.0
# date:180324, rec:006, time:6883.0, label:0.0
# date:180330, rec:008, time:461.0, label:0.0
# date:180327, rec:001, time:6942.0, label:0.0
# date:180323, rec:007, time:4722.0, label:0.0
# date:180325, rec:001, time:1700.0, label:0.0
# date:180331, rec:004, time:6964.0, label:1.0
# date:180330, rec:003, time:6453.0, label:1.0
# date:180330, rec:003, time:2468.0, label:1.0
# date:180326, rec:004, time:108.0, label:1.0
# date:180327, rec:005, time:3870.0, label:1.0
# date:180324, rec:003, time:1719.0, label:1.0
# date:180331, rec:007, time:5998.0, label:0.0
# date:180327, rec:008, time:3332.0, label:0.0
# date:180331, rec:001, time:1780.0, label:0.0
# date:180327, rec:007, time:1600.0, label:0.0
# date:180325, rec:001, time:320.0, label:0.0
# date:180330, rec:009, time:4891.0, label:0.0
# date:180324, rec:008, time:50.0, label:0.0
# date:180324, rec:008, time:5954.0, label:0.0
# date:180325, rec:001, time:1630.0, label:0.0
# date:180330, rec:008, time:901.0, label:0.0
# date:180327, rec:007, time:4781.0, label:0.0
# date:180325, rec:005, time:1164.0, label:1.0
# date:180410, rec:002, time:20.0, label:1.0
# date:180325, rec:009, time:6470.0, label:0.0
# date:180324, rec:005, time:2944.0, label:1.0
# date:180327, rec:002, time:1660.0, label:1.0
# date:180330, rec:008, time:1551.0, label:0.0
# date:180331, rec:007, time:2947.0, label:0.0
# date:180327, rec:008, time:4623.0, label:0.0
# date:180327, rec:008, time:190.0, label:0.0
# date:180323, rec:007, time:6371.0, label:0.0
# date:180410, rec:003, time:2360.0, label:1.0
# date:180322, rec:007, time:4850.0, label:0.0
# date:180325, rec:009, time:2400.0, label:0.0
# date:180322, rec:003, time:6806.0, label:1.0
# date:180410, rec:003, time:4428.0, label:1.0
# date:180325, rec:002, time:5378.0, label:1.0
# date:180331, rec:007, time:2997.0, label:0.0
# date:180330, rec:008, time:6545.0, label:0.0
# date:180325, rec:004, time:4534.0, label:1.0
# date:180325, rec:002, time:4588.0, label:1.0
# date:180324, rec:004, time:5409.0, label:1.0
# date:180327, rec:004, time:2644.0, label:0.0
# date:180327, rec:007, time:2740.0, label:0.0
# date:180327, rec:008, time:1872.0, label:0.0
# date:180331, rec:001, time:880.0, label:0.0
# date:180324, rec:008, time:6624.0, label:0.0
# date:180327, rec:005, time:3860.0, label:1.0
# date:180327, rec:005, time:750.0, label:1.0
# date:180324, rec:003, time:380.0, label:1.0
# date:180331, rec:003, time:4878.0, label:1.0
# date:180410, rec:006, time:1606.0, label:1.0
# date:180327, rec:008, time:2762.0, label:0.0
# date:180325, rec:005, time:4276.0, label:0.0
# date:180410, rec:005, time:6979.0, label:1.0
# date:180410, rec:006, time:4829.0, label:1.0
# date:180323, rec:002, time:1707.0, label:1.0
# date:180324, rec:006, time:3079.0, label:1.0
# date:180323, rec:001, time:900.0, label:0.0
# date:180322, rec:007, time:4520.0, label:0.0
# date:180330, rec:007, time:1832.0, label:1.0
# date:180323, rec:002, time:4246.0, label:1.0
# date:180330, rec:009, time:5461.0, label:0.0
# date:180323, rec:002, time:540.0, label:1.0
# date:180330, rec:004, time:4137.0, label:1.0
# date:180325, rec:006, time:3763.0, label:1.0
# date:180322, rec:004, time:203.0, label:0.0
# date:180326, rec:003, time:6093.0, label:1.0
# date:180330, rec:008, time:501.0, label:0.0
# date:180322, rec:002, time:5204.0, label:1.0
# date:180410, rec:004, time:2198.0, label:1.0
# date:180325, rec:004, time:4554.0, label:1.0
# date:180327, rec:008, time:3972.0, label:0.0
# date:180323, rec:002, time:2976.0, label:1.0
# date:180401, rec:001, time:4537.0, label:1.0
# date:180325, rec:009, time:1580.0, label:0.0
# date:180327, rec:001, time:1340.0, label:0.0
# date:180327, rec:005, time:1430.0, label:1.0
# date:180323, rec:007, time:5581.0, label:0.0
# date:180401, rec:001, time:770.0, label:0.0
# date:180324, rec:006, time:3019.0, label:1.0
# date:180325, rec:004, time:643.0, label:1.0
# date:180331, rec:007, time:3587.0, label:0.0
# date:180331, rec:007, time:5267.0, label:0.0
# date:180330, rec:009, time:6401.0, label:0.0
# date:180325, rec:007, time:6283.0, label:0.0
# date:180324, rec:006, time:462.0, label:1.0
# date:180325, rec:002, time:6569.0, label:1.0
# date:180330, rec:007, time:4190.0, label:1.0
# date:180401, rec:002, time:2736.0, label:1.0
# date:180325, rec:009, time:1690.0, label:0.0
# date:180322, rec:007, time:1807.0, label:0.0
# date:180327, rec:002, time:3110.0, label:1.0
# date:180325, rec:001, time:660.0, label:0.0
# date:180327, rec:004, time:2274.0, label:0.0
# date:180330, rec:001, time:2126.0, label:1.0
# date:180330, rec:006, time:2832.0, label:1.0
# date:180324, rec:001, time:300.0, label:0.0
# date:180324, rec:001, time:3785.0, label:1.0
# date:180325, rec:003, time:2836.0, label:1.0
# date:180327, rec:007, time:5741.0, label:0.0
# date:180327, rec:002, time:3921.0, label:0.0
# date:180330, rec:009, time:388.0, label:0.0
# date:180410, rec:004, time:6402.0, label:1.0
# date:180327, rec:008, time:5143.0, label:0.0
# date:180324, rec:003, time:510.0, label:1.0
# date:180401, rec:001, time:760.0, label:0.0
# date:180325, rec:007, time:4803.0, label:0.0

# %%
class CNN(nn.Module):
    def __init__(self,p_dropout):
        super(CNN,self).__init__()
    
        # convolutional layer (sees 1x100x10 image tensor)
        self.conv1 = nn.Conv2d(in_channels=62, out_channels=2,kernel_size=(3,3),stride=(1,1),padding=(1,1))
        # convolutional layer (sees 2x50x5 tensor)
        self.conv2 = nn.Conv2d(in_channels=2, out_channels=4,kernel_size=(3,3),stride=(1,1),padding=(1,1))
        # sees a layer 4x25x2
        self.fc1 = nn.Linear(4*25*2,1)
        
        # Max pooling
        self.pool = nn.MaxPool2d(2,2)
        # dropout layer 
        self.dropout = nn.Dropout(p_dropout)
         # batch normalization 
        self.bn1 = nn.BatchNorm2d(2)
        self.bn2 = nn.BatchNorm2d(4)
      
    def forward(self,x):
        
        x = x.float()
        
        conv_x1 = self.conv1(x)
        x = self.pool(F.relu(self.bn1(conv_x1))) # Convolution 1:

        conv_x2 = self.conv2(x)
        x = self.pool(F.relu(self.bn2(conv_x2))) # Convolution 2:

        x = x.view(x.shape[0],-1) # flatten image input
        
        x = self.dropout(x) # dropout
        x = self.fc1(x) # Fully connected layer
        
        return x, conv_x1, conv_x2

# %%
learning_rate = 0.001
tol = 0.01
p_dropout = 0.2

num_epochs = 51
model_name = 'CNN'
model_type = 'LR'
alpha = 0
loss_type = 'bce'
reg_type = 'none'
series = '1st_and_2nd'

model = CNN(p_dropout).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)
criterion = nn.BCELoss(reduction='mean')
model
# Out:
# CNN(
#   (conv1): Conv2d(62, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(2, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (fc1): Linear(in_features=200, out_features=1, bias=True)
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dropout): Dropout(p=0.2, inplace=False)
#   (bn1): BatchNorm2d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn2): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )

# %%
(data, labels, _, _, _) = next(iter(train_loader))
data = data.to(device)
output, conv1, conv2 = model(data)
output.shape
criterion
# Out:
# BCELoss()

# %%
epochs, training_losses, training_acc, val_losses, validation_acc = [], [], [], [], []

for epoch in range(num_epochs):
    train_loss, train_acc, conv1, conv2 = train(model, optimizer, criterion, train_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
    print('Train loss for epoch {}: {}'.format(epoch, train_loss))
    val_loss, val_acc = evaluate(model, optimizer, criterion, val_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
    print('Val loss for epoch {}: {}'.format(epoch, val_loss))
    epochs.append(epoch)
    training_losses.append(train_loss)
    training_acc.append(train_acc)
    val_losses.append(val_loss)
    validation_acc.append(val_acc)
    if val_loss <= min(val_losses):
        best_epoch = epoch
        print(epoch)
        path = '/home/bijanadmin/Desktop/Goose_data/model/CNN_10_sec_window'
        torch.save(model.state_dict(), '{}/CNN_CH{}_LOSS{}_DROPOUT{}{}_EPOCH{}_MODEL_{}_SERIES_{}.pt'.format(path, CH, loss_type, p_dropout, alpha, epoch,model_name,series))
        torch.save(conv1,'{}/conv_layer_1_CH{}_LOSS{}_DROPOUT{}{}_EPOCH{}_MODEL_{}_SERIES_{}.pt'.format(path, CH, loss_type, p_dropout, alpha, epoch,model_name,series))
        torch.save(conv2,'{}/conv_layer_2_CH{}_LOSS{}_DROPOUT{}{}_EPOCH{}_MODEL_{}_SERIES_{}.pt'.format(path, CH, loss_type, p_dropout, alpha, epoch,model_name,series))
# Out:
# Train loss for epoch 0: 0.0024838163517415524
# Val loss for epoch 0: 0.0014206406194716692
# 0
# Train loss for epoch 1: 0.0018356333021074533
# Val loss for epoch 1: 0.0013988628052175045
# 1

# %%
# =============================================================================
#  FILTERS CNN
# =============================================================================
filter1 = 2
filter2 = 4
dir_frequency = 'frequency_0_60'
dir_filters = '/filters_2_4_8'
dir_tapers = '/tapers_1_2'


for i in range(filter1):
    fig, ax = plt.subplots()
    ax.set_title('Filter {} - conv layer 1'.format(i+1),fontsize=14)
    img1 = ax.imshow(torch.detach(conv1[1,i,:,:]).cpu().numpy(),origin='lower')
    fig.colorbar(img1, ax=ax,orientation="vertical")
#     ax.set_aspect('auto')
    plt.show()
#     fig.savefig('Plots/Ch_{}/random_N_015_W_25_dn_018/'.format(Ch)+dir_frequency + dir_tapers + dir_filters +'/CNN_100rand_f_{}_{}_Filter_{}_conv1_2x{}x{}_filters_size_47_30.png'.format(fmin,fmax,i+1,filter1,filter2),bbox_inches='tight')
#     plt.close(fig)
   
    
for i in range(filter2):
    fig, ax = plt.subplots()
    ax.set_title('Filter {} - conv layer 2'.format(i+1),fontsize=14)
    img1 = ax.imshow(torch.detach(conv2[1,i,:,:]).cpu().numpy(),origin='lower')
    fig.colorbar(img1, ax=ax,orientation="vertical")
    plt.show()
    
#     fig.savefig('Plots/Ch_{}/random_N_015_W_25_dn_018/'.format(Ch)+ dir_frequency + dir_tapers + dir_filters +'/CNN_100rand_f_{}_{}_Filter_{}_conv2_2x{}x{}_filters_size_47_30.png'.format(fmin,fmax,i+1,filter1,filter2),bbox_inches='tight')
#     plt.close(fig)
