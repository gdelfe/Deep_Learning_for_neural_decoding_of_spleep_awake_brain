# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
from torch.utils.data import Dataset, DataLoader
from torch import nn
from torch.nn.functional import relu
from scipy.io import loadmat
import os
from os import listdir
import pandas as pd
from skimage import io
from PIL import Image
from sklearn.metrics import confusion_matrix
import seaborn as sn

from utils import *

# %%
train_loader, val_loader, test_loader = create_dataloaders(batch_size=128, version='_Goose_1st')

# %%
len(train_loader), len(val_loader), len(test_loader)
# Out:
# (142, 24, 60)

# %%
for batch_idx, (data, labels, date, rec, time) in enumerate(train_loader):
    print(data.shape)
    print(labels.shape)
    print(len(date))
    print(len(rec))
    print(len(time))
    break
# Out:
# torch.Size([128, 62, 100, 10])
# torch.Size([128, 1])
# 128
# 128
# 128

# %%
for batch_idx, (data, label, date, rec, time) in enumerate(train_loader):
    for i in range(128):
        print('date:{}, rec:{}, time:{}'.format(date[i], rec[i], time[i]))
        data_sub = data[i][0]
        plt.imshow(data_sub)
        plt.title(label[i][0].numpy())
        plt.show()
    break
# Out:
# date:180325, rec:004, time:2880.0
# date:180326, rec:004, time:3958.0
# date:180322, rec:003, time:483.0
# date:180327, rec:002, time:2630.0
# date:180327, rec:002, time:2090.0
# date:180327, rec:008, time:530.0
# date:180325, rec:002, time:1972.0
# date:180326, rec:003, time:6133.0
# date:180327, rec:007, time:4411.0
# date:180326, rec:003, time:3814.0
# date:180401, rec:001, time:2229.0
# date:180327, rec:006, time:260.0
# date:180325, rec:002, time:600.0
# date:180327, rec:006, time:6211.0
# date:180327, rec:001, time:4691.0
# date:180327, rec:008, time:5643.0
# date:180322, rec:002, time:6965.0
# date:180325, rec:002, time:5078.0
# date:180323, rec:007, time:7191.0
# date:180327, rec:008, time:5693.0
# date:180323, rec:004, time:3563.0
# date:180327, rec:002, time:5174.0
# date:180325, rec:007, time:1284.0
# date:180322, rec:005, time:848.0
# date:180325, rec:004, time:3450.0
# date:180323, rec:002, time:6116.0
# date:180325, rec:007, time:1414.0
# date:180327, rec:007, time:1930.0
# date:180324, rec:004, time:5199.0
# date:180323, rec:003, time:220.0
# date:180324, rec:009, time:700.0
# date:180327, rec:002, time:2170.0
# date:180324, rec:003, time:1206.0
# date:180325, rec:003, time:180.0
# date:180326, rec:004, time:6422.0
# date:180327, rec:008, time:4022.0
# date:180325, rec:005, time:2666.0
# date:180326, rec:004, time:7080.0
# date:180322, rec:004, time:6476.0
# date:180327, rec:005, time:6218.0
# date:180324, rec:006, time:3209.0
# date:180323, rec:002, time:5625.0
# date:180327, rec:004, time:6661.0
# date:180327, rec:006, time:950.0
# date:180324, rec:003, time:490.0
# date:180325, rec:003, time:2525.0
# date:180325, rec:001, time:10.0
# date:180326, rec:003, time:110.0
# date:180325, rec:003, time:3352.0
# date:180325, rec:003, time:3803.0
# date:180322, rec:007, time:1577.0
# date:180322, rec:002, time:4829.0
# date:180323, rec:001, time:6983.0
# date:180326, rec:004, time:1070.0
# date:180326, rec:003, time:809.0
# date:180327, rec:008, time:6149.0
# date:180324, rec:001, time:7147.0
# date:180322, rec:005, time:3231.0
# date:180324, rec:004, time:5339.0
# date:180327, rec:007, time:527.0
# date:180326, rec:003, time:3824.0
# date:180326, rec:004, time:373.0
# date:180324, rec:005, time:2540.0
# date:180401, rec:003, time:2677.0
# date:180322, rec:003, time:703.0
# date:180323, rec:002, time:1287.0
# date:180324, rec:003, time:1599.0
# date:180401, rec:002, time:3606.0
# date:180322, rec:003, time:1423.0
# date:180325, rec:001, time:7011.0
# date:180325, rec:001, time:4786.0
# date:180327, rec:006, time:4117.0
# date:180325, rec:005, time:654.0
# date:180325, rec:003, time:3833.0
# date:180325, rec:004, time:3210.0
# date:180401, rec:003, time:3777.0
# date:180325, rec:006, time:779.0
# date:180327, rec:001, time:5354.0
# date:180326, rec:004, time:2339.0
# date:180325, rec:004, time:4120.0
# date:180322, rec:005, time:2432.0
# date:180324, rec:008, time:251.0
# date:180327, rec:005, time:7175.0
# date:180327, rec:002, time:2150.0
# date:180322, rec:004, time:6776.0
# date:180327, rec:005, time:2860.0
# date:180322, rec:001, time:210.0
# date:180323, rec:002, time:790.0
# date:180327, rec:007, time:5041.0
# date:180325, rec:003, time:3843.0
# date:180327, rec:004, time:4714.0
# date:180325, rec:004, time:1478.0
# date:180401, rec:003, time:7088.0
# date:180324, rec:005, time:320.0
# date:180327, rec:001, time:40.0
# date:180325, rec:009, time:4006.0
# date:180323, rec:002, time:7178.0
# date:180325, rec:009, time:3686.0
# date:180327, rec:004, time:5434.0
# date:180325, rec:003, time:4298.0
# date:180322, rec:003, time:3498.0
# date:180325, rec:003, time:6207.0
# date:180327, rec:005, time:2163.0
# date:180324, rec:004, time:2149.0
# date:180324, rec:003, time:4315.0
# date:180323, rec:003, time:4477.0
# date:180325, rec:005, time:1244.0
# date:180326, rec:003, time:4364.0
# date:180322, rec:003, time:7096.0
# date:180323, rec:005, time:2297.0
# date:180327, rec:005, time:100.0
# date:180325, rec:009, time:1020.0
# date:180323, rec:002, time:5105.0
# date:180401, rec:001, time:3163.0
# date:180327, rec:007, time:3990.0
# date:180324, rec:006, time:5763.0
# date:180327, rec:006, time:3696.0
# date:180325, rec:001, time:4906.0
# date:180322, rec:002, time:3709.0
# date:180325, rec:005, time:4643.0
# date:180325, rec:007, time:3116.0
# date:180322, rec:007, time:49.0
# date:180325, rec:009, time:450.0
# date:180325, rec:007, time:2586.0
# date:180325, rec:005, time:5417.0
# date:180327, rec:005, time:4604.0
# date:180325, rec:009, time:4839.0
# date:180327, rec:006, time:2388.0

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)

tol = 0.01
learning_rate = 0.001
num_epochs = 50
l2 = 0
alpha = 0
CH = 'all'

model = LogReg().to(device)
criterion = nn.BCELoss()
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)
# Out:
# cuda

# %%
epochs = []
training_losses = []
training_acc = []
val_losses = []
validation_acc = []

train_predictions = []
validation_predictions = []
train_preds_probs = []
validation_preds_probs = []
train_labels = []
validation_labels = []

for epoch in range(num_epochs):
    avg_train_loss, train_acc, train_preds, train_preds_probs, train_labs = train(model, criterion, optimizer, train_loader, epoch, alpha=alpha)
    print('Train loss for epoch {}: {}'.format(epoch, avg_train_loss))
    val_loss, val_acc, val_preds, val_preds_probs, val_labels = test(model, criterion, optimizer, val_loader)
    print('Val loss for epoch {}: {}'.format(epoch, val_loss))
    if val_losses:
        if val_loss < min(val_losses):
            print(epoch)
            path = '/mnt/pesaranlab/People/Capstone_students/Yue/model_Goose_1st'
            torch.save(model.state_dict(), '{}/lr_CH{}_reg{}_alpha{}_epoch{}.pt'.format(path, CH, l2, alpha, epoch))
    epochs.append(epoch)
    training_losses.append(avg_train_loss)
    training_acc.append(train_acc)
    val_losses.append(val_loss)
    validation_acc.append(val_acc)
    
    train_predictions.append(train_preds)
    train_labels.append(train_labs)
    train_preds_probs.append(train_preds_probs)
    validation_predictions.append(val_preds)
    validation_labels.append(val_labels)
    validation_preds_probs.append(val_preds_probs)
    
    if avg_train_loss < tol:
        break
# Out:
# Train loss for epoch 0: 0.6718981266021729
# Val loss for epoch 0: 0.7807711362838745
# Train loss for epoch 1: 0.5345409512519836
# Val loss for epoch 1: 0.658898115158081
# 1
# Train loss for epoch 2: 0.5689313411712646
# Val loss for epoch 2: 0.6782695651054382
# Train loss for epoch 3: 0.5448428392410278
# Val loss for epoch 3: 0.4777117967605591
# 3
# Train loss for epoch 4: 0.451606810092926
# Val loss for epoch 4: 0.5985017418861389
# Train loss for epoch 5: 0.4140597879886627
# Val loss for epoch 5: 0.6006309986114502
# Train loss for epoch 6: 0.3838578760623932
# Val loss for epoch 6: 0.5181984305381775
# Train loss for epoch 7: 0.41318196058273315
# Val loss for epoch 7: 0.640994668006897
# Train loss for epoch 8: 0.41466253995895386
# Val loss for epoch 8: 0.815771758556366
# Train loss for epoch 9: 0.4219949245452881
# Val loss for epoch 9: 0.5779106020927429
# Train loss for epoch 10: 0.35185492038726807
# Val loss for epoch 10: 0.45734453201293945
# 10
# Train loss for epoch 11: 0.33620762825012207
# Val loss for epoch 11: 0.5078771710395813
# Train loss for epoch 12: 0.35081303119659424
# Val loss for epoch 12: 0.5255242586135864
# Train loss for epoch 13: 0.33591964840888977
# Val loss for epoch 13: 0.6057406663894653
# Train loss for epoch 14: 0.35611963272094727
# Val loss for epoch 14: 0.9053153395652771
# Train loss for epoch 15: 0.325103759765625
# Val loss for epoch 15: 0.5304102301597595
# Train loss for epoch 16: 0.33202359080314636
# Val loss for epoch 16: 0.6221213936805725
# Train loss for epoch 17: 0.3752942979335785
# Val loss for epoch 17: 0.8239171504974365
# Train loss for epoch 18: 0.3793739974498749
# Val loss for epoch 18: 0.4452309012413025
# 18
# Train loss for epoch 19: 0.2748059928417206
# Val loss for epoch 19: 0.5173091888427734
# Train loss for epoch 20: 0.3715921938419342
# Val loss for epoch 20: 0.5306869745254517
# Train loss for epoch 21: 0.3062349855899811
# Val loss for epoch 21: 0.6682496070861816
# Train loss for epoch 22: 0.2954811155796051
# Val loss for epoch 22: 0.8672566413879395
# Train loss for epoch 23: 0.25052887201309204
# Val loss for epoch 23: 0.4503067135810852
# Train loss for epoch 24: 0.26854291558265686
# Val loss for epoch 24: 0.6635257601737976
# Train loss for epoch 25: 0.26973757147789
# Val loss for epoch 25: 0.5665119290351868
# Train loss for epoch 26: 0.24319836497306824
# Val loss for epoch 26: 0.762666642665863
# Train loss for epoch 27: 0.3160925507545471
# Val loss for epoch 27: 0.7201907634735107
# Train loss for epoch 28: 0.23463770747184753
# Val loss for epoch 28: 0.723179817199707
# Train loss for epoch 29: 0.2781258225440979
# Val loss for epoch 29: 1.6582691669464111
# Train loss for epoch 30: 0.3203166425228119
# Val loss for epoch 30: 0.5924211740493774
# Train loss for epoch 31: 0.23828470706939697
# Val loss for epoch 31: 0.6119174361228943
# Train loss for epoch 32: 0.24912331998348236
# Val loss for epoch 32: 0.519689679145813
# Train loss for epoch 33: 0.2489473521709442
# Val loss for epoch 33: 0.6298701763153076
# Train loss for epoch 34: 0.2577078938484192
# Val loss for epoch 34: 0.44880640506744385
# Train loss for epoch 35: 0.22523368895053864
# Val loss for epoch 35: 0.5184214115142822
# Train loss for epoch 36: 0.21816247701644897
# Val loss for epoch 36: 0.49167537689208984
# Train loss for epoch 37: 0.20556840300559998
# Val loss for epoch 37: 0.5202414989471436
# Train loss for epoch 38: 0.19510872662067413
# Val loss for epoch 38: 1.1812005043029785
# Train loss for epoch 39: 0.24704821407794952
# Val loss for epoch 39: 0.6171888113021851
# Train loss for epoch 40: 0.22359232604503632
# Val loss for epoch 40: 0.5576750040054321
# Train loss for epoch 41: 0.22213654220104218
# Val loss for epoch 41: 0.659963846206665
# Train loss for epoch 42: 0.2742878198623657
# Val loss for epoch 42: 0.6403404474258423
# Train loss for epoch 43: 0.2451646775007248
# Val loss for epoch 43: 0.706640899181366
# Train loss for epoch 44: 0.19514058530330658
# Val loss for epoch 44: 0.5119709372520447
# Train loss for epoch 45: 0.19596146047115326
# Val loss for epoch 45: 0.6183211207389832
# Train loss for epoch 46: 0.21727178990840912
# Val loss for epoch 46: 0.667793869972229
# Train loss for epoch 47: 0.30224350094795227
# Val loss for epoch 47: 0.7318417429924011
# Train loss for epoch 48: 0.20142501592636108
# Val loss for epoch 48: 0.5939346551895142
# Train loss for epoch 49: 0.16112501919269562
# Val loss for epoch 49: 0.5243672132492065
# Train loss for epoch 50: 0.20579902827739716
# Val loss for epoch 50: 0.5896785259246826

# %%
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.title("LR", fontsize = 15)
plt.plot(training_losses[:51],linewidth = 1.5,label = 'train')
plt.plot(val_losses[:51],linewidth = 1.5,label = 'valid')
plt.xlabel("Epoch",fontsize = 15)
plt.ylabel("Loss", fontsize = 15)
plt.legend()
plt.subplot(1,2,2)
plt.title("LR", fontsize = 15)
plt.plot(training_acc[:51],linewidth = 1.5,label = 'train')
plt.plot(validation_acc[:51],linewidth = 1.5,label = 'valid')
plt.xlabel("Epoch",fontsize = 15)
plt.ylabel("Accuracy", fontsize = 15)
plt.legend()
plt.show()

# %%
model = LogReg().to(device)
path = '/mnt/pesaranlab/People/Capstone_students/Yue/model_Goose_1st'
model.load_state_dict(torch.load('{}/lr_CH{}_reg{}_alpha{}_epoch18.pt'.format(path, CH, l2, alpha)))
weights = model.linear.weight.view(62, 100, 10)
plt.figure(figsize=(15,8))
for i in range(62):
    weights_sub = weights[i].detach().cpu()
    plt.subplot(2,31,i+1)
    plt.axis('off')
    plt.imshow(weights_sub)
    # plt.clim(-0.03, 0.03)
plt.show()

# %%
test_loss, test_acc, test_preds, test_preds_probs, test_labels, cases_wrong_1 = test(model, criterion, optimizer, test_loader, mode='test')
print('test loss:{} accuracy:{}'.format(test_loss, test_acc))
# Out:
# test loss:0.38072946667671204 accuracy:0.8793012175754368

# %%
np.mean(np.concatenate(test_labels))
# Out:
# 0.7769984

# %%
predictions_test = np.concatenate(test_preds)
labels_test = np.concatenate(test_labels)

df_test = pd.DataFrame({'predictions': predictions_test, 'labels': labels_test})

cm_test = confusion_matrix(labels_test, predictions_test)
ax = plt.axes()
sn.heatmap(cm_test, annot = True, fmt = "d", ax = ax, center=3000)
ax.set_title('Test Confusion Matrix')
ax.set_xlabel('Predicted Label')
ax.set_ylabel('True Label')
plt.show()

# %%
idx = 0
print('date:{}, rec:{}, time:{}, label:{}'.format(cases_wrong_1[0][0], cases_wrong_1[0][1], cases_wrong_1[0][1], cases_wrong_1[0][3]))
print('Original data 62 CH')
plt.figure(figsize=(15,8))
for i in range(62):
    weights_sub = cases_wrong_1[0][-1][i]
    plt.subplot(2,31,i+1)
    plt.axis('off')
    plt.imshow(weights_sub)
    # plt.clim(-0.03, 0.03)
plt.show()
# Out:
# date:180330, rec:003, time:003, label:1.0
# Original data 62 CH

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)

tol = 0.01
learning_rate = 0.001
num_epochs = 51
l2 = 0.1
alpha = 0
CH = 'all'

model = LogReg().to(device)
criterion = nn.BCELoss()
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate, weight_decay=l2)
# Out:
# cuda

# %%
epochs = []
training_losses = []
training_acc = []
val_losses = []
validation_acc = []

train_predictions = []
validation_predictions = []
train_preds_probs = []
validation_preds_probs = []
train_labels = []
validation_labels = []

for epoch in range(num_epochs):
    avg_train_loss, train_acc, train_preds, train_preds_probs, train_labs = train(model, criterion, optimizer, train_loader, epoch, alpha=alpha)
    print('Train loss for epoch {}: {}'.format(epoch, avg_train_loss))
    val_loss, val_acc, val_preds, val_preds_probs, val_labels = test(model, criterion, optimizer, val_loader)
    print('Val loss for epoch {}: {}'.format(epoch, val_loss))
    if val_losses:
        if val_loss < min(val_losses):
            print(epoch)
            path = '/mnt/pesaranlab/People/Capstone_students/Yue/model_Goose_1st'
            torch.save(model.state_dict(), '{}/lr_CH{}_reg{}_alpha{}_epoch{}.pt'.format(path, CH, l2, alpha, epoch))
    epochs.append(epoch)
    training_losses.append(avg_train_loss)
    training_acc.append(train_acc)
    val_losses.append(val_loss)
    validation_acc.append(val_acc)
    
    train_predictions.append(train_preds)
    train_labels.append(train_labs)
    train_preds_probs.append(train_preds_probs)
    validation_predictions.append(val_preds)
    validation_labels.append(val_labels)
    validation_preds_probs.append(val_preds_probs)
    
    if avg_train_loss < tol:
        break
# Out:
# Train loss for epoch 0: 0.8737578392028809
# Val loss for epoch 0: 0.6137925386428833
# Train loss for epoch 1: 0.5128371119499207
# Val loss for epoch 1: 0.5204573273658752
# 1
# Train loss for epoch 2: 0.5710514187812805
# Val loss for epoch 2: 0.6491480469703674
# Train loss for epoch 3: 0.4860241115093231
# Val loss for epoch 3: 0.7129786014556885
# Train loss for epoch 4: 0.6372783780097961
# Val loss for epoch 4: 0.6909440755844116
# Train loss for epoch 5: 0.4850507378578186
# Val loss for epoch 5: 0.671325147151947
# Train loss for epoch 6: 0.5068501830101013
# Val loss for epoch 6: 0.9042603373527527
# Train loss for epoch 7: 0.5292824506759644
# Val loss for epoch 7: 1.1947886943817139
# Train loss for epoch 8: 0.4867381751537323
# Val loss for epoch 8: 0.7399414777755737
# Train loss for epoch 9: 0.48878371715545654
# Val loss for epoch 9: 0.7402666807174683
# Train loss for epoch 10: 0.4718514382839203
# Val loss for epoch 10: 0.3935666084289551
# 10
# Train loss for epoch 11: 0.40185797214508057
# Val loss for epoch 11: 0.5041972994804382
# Train loss for epoch 12: 0.5681512355804443
# Val loss for epoch 12: 0.5756700038909912
# Train loss for epoch 13: 0.5126834511756897
# Val loss for epoch 13: 0.37003403902053833
# 13
# Train loss for epoch 14: 0.4813953936100006
# Val loss for epoch 14: 0.662082850933075
# Train loss for epoch 15: 0.4575105607509613
# Val loss for epoch 15: 0.4171990156173706
# Train loss for epoch 16: 0.43699130415916443
# Val loss for epoch 16: 1.1269118785858154
# Train loss for epoch 17: 0.5378261804580688
# Val loss for epoch 17: 0.47356852889060974
# Train loss for epoch 18: 0.41055533289909363
# Val loss for epoch 18: 0.5557878017425537
# Train loss for epoch 19: 0.465361624956131
# Val loss for epoch 19: 0.45340293645858765
# Train loss for epoch 20: 0.4895060360431671
# Val loss for epoch 20: 0.3771209120750427
# Train loss for epoch 21: 0.44239553809165955
# Val loss for epoch 21: 0.36758872866630554
# 21
# Train loss for epoch 22: 0.43860822916030884
# Val loss for epoch 22: 0.46012434363365173
# Train loss for epoch 23: 0.45754578709602356
# Val loss for epoch 23: 0.566464900970459
# Train loss for epoch 24: 0.4710923135280609
# Val loss for epoch 24: 0.4707796573638916
# Train loss for epoch 25: 0.45328444242477417
# Val loss for epoch 25: 0.343406081199646
# 25
# Train loss for epoch 26: 0.4862934648990631
# Val loss for epoch 26: 0.45530959963798523
# Train loss for epoch 27: 0.4303083121776581
# Val loss for epoch 27: 0.5904320478439331
# Train loss for epoch 28: 0.46962985396385193
# Val loss for epoch 28: 0.6689720153808594
# Train loss for epoch 29: 0.4872557818889618
# Val loss for epoch 29: 0.6869685053825378
# Train loss for epoch 30: 0.5156667828559875
# Val loss for epoch 30: 0.5434844493865967
# Train loss for epoch 31: 0.45425042510032654
# Val loss for epoch 31: 0.520743727684021
# Train loss for epoch 32: 0.4209485352039337
# Val loss for epoch 32: 0.32710888981819153
# 32
# Train loss for epoch 33: 0.44964414834976196
# Val loss for epoch 33: 0.5560399293899536
# Train loss for epoch 34: 0.4929080307483673
# Val loss for epoch 34: 0.44716498255729675
# Train loss for epoch 35: 0.5436439514160156
# Val loss for epoch 35: 0.5031790733337402
# Train loss for epoch 36: 0.4594431519508362
# Val loss for epoch 36: 0.6378870010375977
# Train loss for epoch 37: 0.5352036356925964
# Val loss for epoch 37: 0.48126107454299927
# Train loss for epoch 38: 0.4782605767250061
# Val loss for epoch 38: 0.4846913814544678
# Train loss for epoch 39: 0.441288024187088
# Val loss for epoch 39: 0.6623708009719849
# Train loss for epoch 40: 0.4561806619167328
# Val loss for epoch 40: 0.6434953212738037
# Train loss for epoch 41: 0.4596356451511383
# Val loss for epoch 41: 0.5921002626419067
# Train loss for epoch 42: 0.49130967259407043
# Val loss for epoch 42: 0.6320044994354248
# Train loss for epoch 43: 0.6870830059051514
# Val loss for epoch 43: 1.3668497800827026
# Train loss for epoch 44: 0.45467624068260193
# Val loss for epoch 44: 0.46421921253204346
# Train loss for epoch 45: 0.40206924080848694
# Val loss for epoch 45: 0.4567517936229706
# Train loss for epoch 46: 0.4206865131855011
# Val loss for epoch 46: 0.6040958166122437
# Train loss for epoch 47: 0.5048773288726807
# Val loss for epoch 47: 0.39613077044487
# Train loss for epoch 48: 0.45032134652137756
# Val loss for epoch 48: 0.5219416618347168
# Train loss for epoch 49: 0.4754464626312256
# Val loss for epoch 49: 0.4207470118999481
# Train loss for epoch 50: 0.5712101459503174
# Val loss for epoch 50: 0.37349459528923035

# %%
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.title("LR", fontsize = 15)
plt.plot(training_losses[:51],linewidth = 1.5,label = 'train')
plt.plot(val_losses[:51],linewidth = 1.5,label = 'valid')
plt.xlabel("Epoch",fontsize = 15)
plt.ylabel("Loss", fontsize = 15)
plt.legend()
plt.subplot(1,2,2)
plt.title("LR", fontsize = 15)
plt.plot(training_acc[:51],linewidth = 1.5,label = 'train')
plt.plot(validation_acc[:51],linewidth = 1.5,label = 'valid')
plt.xlabel("Epoch",fontsize = 15)
plt.ylabel("Accuracy", fontsize = 15)
plt.legend()
plt.show()

# %%
model = LogReg().to(device)
path = '/mnt/pesaranlab/People/Capstone_students/Yue/model_Goose_1st'
model.load_state_dict(torch.load('{}/lr_CH{}_reg{}_alpha{}_epoch32.pt'.format(path, CH, l2, alpha)))
weights = model.linear.weight.view(62, 100, 10)
plt.figure(figsize=(15,8))
for i in range(62):
    weights_sub = weights[i].detach().cpu()
    plt.subplot(2,31,i+1)
    plt.axis('off')
    plt.imshow(weights_sub)
    # plt.clim(-0.03, 0.03)
plt.show()

# %%
test_loss, test_acc, test_preds, test_preds_probs, test_labels, cases_wrong_2 = test(model, criterion, optimizer, test_loader, mode='test')
print('test loss:{} accuracy:{}'.format(test_loss, test_acc))
# Out:
# test loss:0.4904329776763916 accuracy:0.8227898358920064

# %%
np.mean(np.concatenate(test_labels))
# Out:
# 0.7769984

# %%
predictions_test = np.concatenate(test_preds)
labels_test = np.concatenate(test_labels)

df_test = pd.DataFrame({'predictions': predictions_test, 'labels': labels_test})

cm_test = confusion_matrix(labels_test, predictions_test)
ax = plt.axes()
sn.heatmap(cm_test, annot = True, fmt = "d", ax = ax, center=3000)
ax.set_title('Test Confusion Matrix')
ax.set_xlabel('Predicted Label')
ax.set_ylabel('True Label')
plt.show()

# %%
idx = 0
print('date:{}, rec:{}, time:{}, label:{}'.format(cases_wrong_2[0][0], cases_wrong_2[0][1], cases_wrong_2[0][1], cases_wrong_2[0][3]))
print('Original data 62 CH')
plt.figure(figsize=(15,8))
for i in range(62):
    weights_sub = cases_wrong_2[0][-1][i]
    plt.subplot(2,31,i+1)
    plt.axis('off')
    plt.imshow(weights_sub)
    # plt.clim(-0.03, 0.03)
plt.show()
# Out:
# date:180330, rec:007, time:007, label:1.0
# Original data 62 CH
