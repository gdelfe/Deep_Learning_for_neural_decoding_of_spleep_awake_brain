# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn 
import torch.nn.functional as F
from scipy.io import loadmat
import os
from os import listdir
import pandas as pd
from skimage import io
from PIL import Image
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pickle

from utils import *

# %% [markdown]
# ### Below are results from Goose_1st_1

# %%
#selected subset of dates. 
val_dates = ['180328','180329']
test_dates = ['180330','180331']
load_path = '/home/bijanadmin/Desktop/Goose_data/data_Goose_all_2/'

train_files, val_files, test_files = create_files(load_path, val_dates, test_dates)
train_loader, val_loader, test_loader = create_dataloaders(train_files, val_files, test_files,load_path, batch_size=256)

# %%
len(train_loader), len(val_loader), len(test_loader)
# Out:
# (223, 11, 25)

# %%
class MLP(nn.Module):
    def __init__(self, input_dim=100*10*62, output_dim=1):
        super(MLP, self).__init__()
        self.linear1 = nn.Linear(input_dim, 256)
        self.linear2 = nn.Linear(256, output_dim)
        
    def forward(self, x):
        x = x.reshape([x.shape[0], 1, -1]).float()
        x1 = F.relu(self.linear1(x))
        outputs = self.linear2(x1)
        return outputs

# %%
device = torch.device('cuda')

tol = 0.01
learning_rate = 0.001
num_epochs = 51
alpha = 0
model_type = 'MLP'
loss_type = 'bce'
reg_type = 'none'
CH = 'all'

model = MLP().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)

# %%
epochs, training_losses, training_acc, val_losses, validation_acc = [], [], [], [], []

for epoch in range(num_epochs):
    train_loss, train_acc = train(model, optimizer, train_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
    print('Train loss for epoch {}: {}'.format(epoch, train_loss))
    val_loss, val_acc = evaluate(model, optimizer, val_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
    print('Val loss for epoch {}: {}'.format(epoch, val_loss))
    if val_losses:
        if val_loss < min(val_losses):
            best_epoch = epoch
            print(epoch)
            path = '/mnt/pesaranlab/People/Capstone_students/Yue/model/model_Goose_1st_1_upsample'
            torch.save(model.state_dict(), '{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, epoch))
    epochs.append(epoch)
    training_losses.append(train_loss)
    training_acc.append(train_acc)
    val_losses.append(val_loss)
    validation_acc.append(val_acc)
    
    if train_loss < tol:
        break
# Out:
# Train loss for epoch 0: 5.637181758880615
# Val loss for epoch 0: 1.0339089632034302
# Train loss for epoch 1: 1.528361439704895
# Val loss for epoch 1: 0.634041965007782
# 1
# Train loss for epoch 2: 0.38548359274864197
# Val loss for epoch 2: 0.4849734306335449
# 2
# Train loss for epoch 3: 0.18208247423171997
# Val loss for epoch 3: 0.4101341664791107
# 3
# Train loss for epoch 4: 0.13340263068675995
# Val loss for epoch 4: 0.3668285310268402
# 4
# Train loss for epoch 5: 0.10207942128181458
# Val loss for epoch 5: 0.34699487686157227
# 5
# Train loss for epoch 6: 0.11003502458333969
# Val loss for epoch 6: 0.45482730865478516
# Train loss for epoch 7: 0.08611515164375305
# Val loss for epoch 7: 0.33059871196746826
# 7
# Train loss for epoch 8: 0.08065655827522278
# Val loss for epoch 8: 0.595654308795929
# Train loss for epoch 9: 0.08533122390508652
# Val loss for epoch 9: 0.8833327889442444
# Train loss for epoch 10: 0.09560886770486832
# Val loss for epoch 10: 1.0663920640945435
# Train loss for epoch 11: 0.08987785130739212
# Val loss for epoch 11: 1.154322862625122
# Train loss for epoch 12: 0.10477087646722794
# Val loss for epoch 12: 0.8067134618759155
# Train loss for epoch 13: 0.09643761068582535
# Val loss for epoch 13: 0.695650577545166
# Train loss for epoch 14: 0.0618373341858387
# Val loss for epoch 14: 1.0315678119659424
# Train loss for epoch 15: 0.17053893208503723
# Val loss for epoch 15: 0.8973906636238098
# Train loss for epoch 16: 0.5699621438980103
# Val loss for epoch 16: 2.2124905586242676
# Train loss for epoch 17: 0.15416523814201355
# Val loss for epoch 17: 1.3912367820739746
# Train loss for epoch 18: 0.11232960224151611
# Val loss for epoch 18: 1.2690556049346924
# Train loss for epoch 19: 0.08730782568454742
# Val loss for epoch 19: 1.334121584892273
# Train loss for epoch 20: 0.054209738969802856
# Val loss for epoch 20: 1.3644225597381592
# Train loss for epoch 21: 0.11001352965831757
# Val loss for epoch 21: 1.2779344320297241
# Train loss for epoch 22: 0.06702224910259247
# Val loss for epoch 22: 2.4487056732177734
# Train loss for epoch 23: 0.0647624284029007
# Val loss for epoch 23: 2.1272854804992676
# Train loss for epoch 24: 0.10481012612581253
# Val loss for epoch 24: 1.7509183883666992
# Train loss for epoch 25: 0.11166171729564667
# Val loss for epoch 25: 2.25872540473938
# Train loss for epoch 26: 0.1625881940126419
# Val loss for epoch 26: 2.106227159500122
# Train loss for epoch 27: 0.10066591948270798
# Val loss for epoch 27: 1.927919626235962
# Train loss for epoch 28: 0.0575074627995491
# Val loss for epoch 28: 2.8474457263946533
# Train loss for epoch 29: 0.03834957256913185
# Val loss for epoch 29: 2.141218900680542
# Train loss for epoch 30: 0.16926072537899017
# Val loss for epoch 30: 2.2630410194396973
# Train loss for epoch 31: 0.15832021832466125
# Val loss for epoch 31: 2.822848320007324
# Train loss for epoch 32: 0.1284792125225067
# Val loss for epoch 32: 2.4703123569488525
# Train loss for epoch 33: 0.10028437525033951
# Val loss for epoch 33: 2.6753616333007812
# Train loss for epoch 34: 0.05181137099862099
# Val loss for epoch 34: 3.6914069652557373
# Train loss for epoch 35: 0.10738218575716019
# Val loss for epoch 35: 2.265660047531128
# Train loss for epoch 36: 0.17136508226394653
# Val loss for epoch 36: 4.886033058166504
# Train loss for epoch 37: 0.13290494680404663
# Val loss for epoch 37: 2.6410465240478516
# Train loss for epoch 38: 0.2297487109899521
# Val loss for epoch 38: 2.2408194541931152
# Train loss for epoch 39: 0.11787569522857666
# Val loss for epoch 39: 2.4536335468292236
# Train loss for epoch 40: 0.18131527304649353
# Val loss for epoch 40: 3.3098502159118652
# Train loss for epoch 41: 0.1736399382352829
# Val loss for epoch 41: 2.9863173961639404
# Train loss for epoch 42: 0.1413750797510147
# Val loss for epoch 42: 2.6185808181762695
# Train loss for epoch 43: 0.07742781192064285
# Val loss for epoch 43: 2.919753313064575
# Train loss for epoch 44: 0.04345070198178291
# Val loss for epoch 44: 2.602369785308838
# Train loss for epoch 45: 0.11770866811275482
# Val loss for epoch 45: 2.97806453704834
# Train loss for epoch 46: 0.1344359964132309
# Val loss for epoch 46: 3.488818883895874
# Train loss for epoch 47: 0.13729403913021088
# Val loss for epoch 47: 3.7128143310546875
# Train loss for epoch 48: 0.16149450838565826

# %%
plot_loss_acc(training_losses, val_losses, training_acc, validation_acc, model_type)

# %%
model = MLP().to(device)
path = '/mnt/pesaranlab/People/Capstone_students/Yue/model/model_Goose_1st_1_upsample'
model.load_state_dict(torch.load('{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, best_epoch)))
# Out:
# <All keys matched successfully>

# %%
test_loss, test_acc, test_preds, test_preds_probs, test_labels, cases_wrong_0 = evaluate(model, optimizer, test_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=True, device=device)
print('test loss:{} accuracy:{}'.format(test_loss, test_acc))
# Out:
# test loss:0.48869988322257996 accuracy:0.936

# %%
path_wrong = '/mnt/pesaranlab/People/Capstone_students/Yue/wrong_pred'
pickle.dump(cases_wrong_0, open('{}/{}_CH{}_LOSS{}_REG{}{}.pt'.format(path_wrong, model_type, CH, loss_type, reg_type, alpha), 'wb'))

# %%
predictions_test = np.concatenate(test_preds)
labels_test = np.concatenate(test_labels)

df_test = pd.DataFrame({'predictions': predictions_test, 'labels': labels_test})

cm_test = confusion_matrix(labels_test, predictions_test)
ax = plt.axes()
sn.heatmap(cm_test, annot = True, fmt = "d", ax = ax, center=2000)
ax.set_title('Test Confusion Matrix')
ax.set_xlabel('Predicted Label')
ax.set_ylabel('True Label')
plt.show()

# %% [markdown]
# ### Goose_all_2 Results with different dropout

# %%
len(train_loader), len(val_loader), len(test_loader)
# Out:
# (223, 11, 25)

# %%
class MLP(nn.Module):
    def __init__(self, input_dim=100*10*62, output_dim=1, dropout = 0.5):
        super(MLP, self).__init__()
        self.linear1 = nn.Linear(input_dim, 256)
        self.linear2 = nn.Linear(256, output_dim)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, x):
        x = x.reshape([x.shape[0], 1, -1]).float()
        x1 = self.relu(self.linear1(x))
        outputs = self.linear2(x1)
        return outputs

# %%
device = torch.device('cuda')

tol = 0.01
learning_rate = 0.001
num_epochs = 51
alpha = 0
model_type = 'MLP'
loss_type = 'bce'
reg_type = 'none'
CH = 'all'
dropout_all = [0.1,0.3,0.5,0.7,1]
model_saving_path = '/mnt/pesaranlab/People/Capstone_students/Yue/model/model_Goose_all_2_MLP'

# %%
for d in range(0,len(dropout_all)):
    dropout = dropout_all[d]
    model = MLP(dropout = dropout).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)
    epochs, training_losses, training_acc, val_losses, validation_acc = [], [], [], [], []

    for epoch in range(num_epochs):
        train_loss, train_acc = train(model, optimizer, train_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
        print('Train loss for epoch {}: {}'.format(epoch, train_loss))
        val_loss, val_acc = evaluate(model, optimizer, val_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
        print('Val loss for epoch {}: {}'.format(epoch, val_loss))
        epochs.append(epoch)
        training_losses.append(train_loss)
        training_acc.append(train_acc)
        val_losses.append(val_loss)
        validation_acc.append(val_acc)
        if val_loss <= min(val_losses):
            best_epoch = epoch
            print(epoch)
            path = model_saving_path
            torch.save(model.state_dict(), '{}/{}_CH{}_LOSS{}_REG{}{}_DO{}_EPOCH{}.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, dropout, epoch))
    plot_loss_acc(training_losses, val_losses, training_acc, validation_acc, model_type)
# Out:
# Train loss for epoch 0: 2.813000440597534
# Val loss for epoch 0: 0.19934920966625214
# 0
# Train loss for epoch 1: 0.10905864089727402
# Val loss for epoch 1: 0.14178207516670227
# 1
# Train loss for epoch 2: 0.10094005614519119
# Val loss for epoch 2: 0.130327969789505
# 2
# Train loss for epoch 3: 0.06226356700062752
# Val loss for epoch 3: 0.15722838044166565
# Train loss for epoch 4: 0.06922503560781479
# Val loss for epoch 4: 0.13792605698108673
# Train loss for epoch 5: 0.04264220595359802
# Val loss for epoch 5: 0.16104404628276825
# Train loss for epoch 6: 0.044346071779727936
# Val loss for epoch 6: 0.17354579269886017
# Train loss for epoch 7: 0.0276593379676342
# Val loss for epoch 7: 0.27059435844421387
# Train loss for epoch 8: 0.10733752697706223
# Val loss for epoch 8: 0.40677398443222046
# Train loss for epoch 9: 0.04044719412922859
# Val loss for epoch 9: 0.2639794945716858
# Train loss for epoch 10: 0.059569478034973145
# Val loss for epoch 10: 0.24441678822040558
# Train loss for epoch 11: 0.020133275538682938
# Val loss for epoch 11: 0.21084155142307281
# Train loss for epoch 12: 0.03310558572411537
# Val loss for epoch 12: 0.41620513796806335
# Train loss for epoch 13: 0.04414726048707962
# Val loss for epoch 13: 0.5156299471855164
# Train loss for epoch 14: 0.04025121033191681
# Val loss for epoch 14: 0.6712030172348022
# Train loss for epoch 15: 0.04053542762994766
# Val loss for epoch 15: 0.4125206768512726
# Train loss for epoch 16: 0.036336060613393784
# Val loss for epoch 16: 0.5295251607894897
# Train loss for epoch 17: 0.07257506996393204
# Val loss for epoch 17: 0.7991920113563538
# Train loss for epoch 18: 0.08636949956417084
# Val loss for epoch 18: 0.5082871317863464
# Train loss for epoch 19: 0.05424811691045761
# Val loss for epoch 19: 0.7695973515510559
# Train loss for epoch 20: 0.02834385074675083
# Val loss for epoch 20: 0.3749953806400299
# Train loss for epoch 21: 0.025482991710305214
# Val loss for epoch 21: 0.4880245327949524
# Train loss for epoch 22: 0.017073774710297585
# Val loss for epoch 22: 0.9211373925209045
# Train loss for epoch 23: 0.06748924404382706
# Val loss for epoch 23: 0.46360865235328674
# Train loss for epoch 24: 0.03558710217475891
# Val loss for epoch 24: 0.5274373888969421
# Train loss for epoch 25: 0.021214302629232407
# Val loss for epoch 25: 0.6027650833129883
# Train loss for epoch 26: 0.051555268466472626
# Val loss for epoch 26: 1.047309160232544
# Train loss for epoch 27: 0.05877918377518654
# Val loss for epoch 27: 0.7031202912330627
# Train loss for epoch 28: 0.050707653164863586
# Val loss for epoch 28: 0.8616754412651062
# Train loss for epoch 29: 0.05095173045992851
# Val loss for epoch 29: 0.7958046793937683
# Train loss for epoch 30: 0.046387117356061935
# Val loss for epoch 30: 0.7778194546699524
# Train loss for epoch 31: 0.06811070442199707
# Val loss for epoch 31: 1.9054397344589233
# Train loss for epoch 32: 0.0119841443374753
# Val loss for epoch 32: 0.8669057488441467
# Train loss for epoch 33: 0.019130097702145576
# Val loss for epoch 33: 1.074391484260559
# Train loss for epoch 34: 0.03183010593056679
# Val loss for epoch 34: 0.8028606176376343
# Train loss for epoch 35: 0.02313036099076271
# Val loss for epoch 35: 1.0587021112442017
# Train loss for epoch 36: 0.025755049660801888
# Val loss for epoch 36: 0.8351032137870789
# Train loss for epoch 37: 0.04393233358860016
# Val loss for epoch 37: 1.1825913190841675
# Train loss for epoch 38: 0.25762882828712463
# Val loss for epoch 38: 0.7632273435592651
# Train loss for epoch 39: 0.14664682745933533
# Val loss for epoch 39: 1.2872940301895142
# Train loss for epoch 40: 0.02177044004201889
# Val loss for epoch 40: 1.1192975044250488
# Train loss for epoch 41: 0.019810959696769714
# Val loss for epoch 41: 1.0570160150527954
# Train loss for epoch 42: 0.07066202908754349
# Val loss for epoch 42: 1.090795636177063
# Train loss for epoch 43: 0.039090655744075775
# Val loss for epoch 43: 0.9536212682723999
# Train loss for epoch 44: 0.0422542504966259
# Val loss for epoch 44: 1.0411113500595093
# Train loss for epoch 45: 0.10644225031137466
# Val loss for epoch 45: 1.4315497875213623
# Train loss for epoch 46: 0.05419349670410156
# Val loss for epoch 46: 1.4306577444076538
# Train loss for epoch 47: 0.050537120550870895
# Val loss for epoch 47: 1.4767810106277466
# Train loss for epoch 48: 0.04047339782118797
# Val loss for epoch 48: 1.536482572555542
# Train loss for epoch 49: 0.03229610249400139
# Val loss for epoch 49: 1.136692762374878
# Train loss for epoch 50: 0.054076917469501495
# Val loss for epoch 50: 0.8276848196983337
# Train loss for epoch 0: 4.240124702453613
# Val loss for epoch 0: 0.41496479511260986
# 0
# Train loss for epoch 1: 0.358806848526001
# Val loss for epoch 1: 0.2985121011734009
# 1
# Train loss for epoch 2: 0.08375247567892075
# Val loss for epoch 2: 0.221844881772995
# 2
# Train loss for epoch 3: 0.0659174993634224
# Val loss for epoch 3: 0.15630315244197845
# 3
# Train loss for epoch 4: 0.04375474527478218
# Val loss for epoch 4: 0.178855299949646
# Train loss for epoch 5: 0.04404217749834061
# Val loss for epoch 5: 0.2715151309967041
# Train loss for epoch 6: 0.03814706951379776
# Val loss for epoch 6: 0.3472265303134918
# Train loss for epoch 7: 0.06255257874727249
# Val loss for epoch 7: 0.25650107860565186
# Train loss for epoch 8: 0.02814452536404133
# Val loss for epoch 8: 0.27019843459129333
# Train loss for epoch 9: 0.023943081498146057
# Val loss for epoch 9: 0.27907148003578186
# Train loss for epoch 10: 0.04243485629558563
# Val loss for epoch 10: 0.5009092688560486
# Train loss for epoch 11: 0.0880875363945961
# Val loss for epoch 11: 0.5138593912124634
# Train loss for epoch 12: 0.046322379261255264
# Val loss for epoch 12: 0.3684116005897522
# Train loss for epoch 13: 0.014404679648578167
# Val loss for epoch 13: 0.42780449986457825
# Train loss for epoch 14: 0.019129501655697823
# Val loss for epoch 14: 0.4375072419643402
# Train loss for epoch 15: 0.04504545032978058
# Val loss for epoch 15: 0.3532950282096863
# Train loss for epoch 16: 0.08194991201162338
# Val loss for epoch 16: 0.3983381390571594
# Train loss for epoch 17: 0.046779077500104904
# Val loss for epoch 17: 0.33706656098365784
# Train loss for epoch 18: 0.04942340776324272
# Val loss for epoch 18: 0.7261940240859985
# Train loss for epoch 19: 0.01690591871738434
# Val loss for epoch 19: 0.378605455160141
# Train loss for epoch 20: 0.016812466084957123
# Val loss for epoch 20: 0.5707582831382751
# Train loss for epoch 21: 0.030118094757199287
# Val loss for epoch 21: 0.8044629693031311
# Train loss for epoch 22: 0.11697331815958023
# Val loss for epoch 22: 0.9194588661193848
# Train loss for epoch 23: 0.05221102014183998
# Val loss for epoch 23: 0.839343249797821
# Train loss for epoch 24: 0.019703438505530357
# Val loss for epoch 24: 0.8640109896659851
# Train loss for epoch 25: 0.024274637922644615
# Val loss for epoch 25: 0.5855580568313599
# Train loss for epoch 26: 0.1035449430346489
# Val loss for epoch 26: 0.7634601593017578
# Train loss for epoch 27: 0.09911201149225235
# Val loss for epoch 27: 1.0179585218429565
# Train loss for epoch 28: 0.04982101544737816
# Val loss for epoch 28: 0.8231644034385681
# Train loss for epoch 29: 0.03360596299171448
# Val loss for epoch 29: 1.0355943441390991
# Train loss for epoch 30: 0.007590449880808592
# Val loss for epoch 30: 0.9383620023727417
# Train loss for epoch 31: 0.03782166540622711
# Val loss for epoch 31: 1.9838883876800537
# Train loss for epoch 32: 0.04338508099317551
# Val loss for epoch 32: 0.7063487768173218
# Train loss for epoch 33: 0.052704960107803345
# Val loss for epoch 33: 0.6918519735336304
# Train loss for epoch 34: 0.1000852882862091
# Val loss for epoch 34: 0.981421172618866
# Train loss for epoch 35: 0.07573968172073364
# Val loss for epoch 35: 1.7745308876037598
# Train loss for epoch 36: 0.08289586007595062
# Val loss for epoch 36: 1.6093170642852783
# Train loss for epoch 37: 0.0945136621594429
# Val loss for epoch 37: 0.8761206865310669
# Train loss for epoch 38: 0.05038844794034958
# Val loss for epoch 38: 0.9027001857757568
# Train loss for epoch 39: 0.04794006422162056
# Val loss for epoch 39: 1.146518349647522
# Train loss for epoch 40: 0.045477285981178284
# Val loss for epoch 40: 0.8606114387512207
# Train loss for epoch 41: 0.046539440751075745
# Val loss for epoch 41: 1.0356751680374146
# Train loss for epoch 42: 0.0327545590698719
# Val loss for epoch 42: 1.292313575744629
# Train loss for epoch 43: 0.04826029762625694
# Val loss for epoch 43: 1.3030548095703125
# Train loss for epoch 44: 0.07788816094398499
# Val loss for epoch 44: 1.1073505878448486
# Train loss for epoch 45: 0.05397318676114082
# Val loss for epoch 45: 1.2669731378555298
# Train loss for epoch 46: 0.04355558380484581
# Val loss for epoch 46: 1.1914397478103638
# Train loss for epoch 47: 0.017406025901436806
# Val loss for epoch 47: 1.039067029953003
# Train loss for epoch 48: 0.06525551527738571
# Val loss for epoch 48: 1.0461642742156982
# Train loss for epoch 49: 0.16353864967823029
# Val loss for epoch 49: 1.3444697856903076
# Train loss for epoch 50: 0.07783883810043335
# Val loss for epoch 50: 1.087418794631958
# Train loss for epoch 0: 5.4657087326049805
# Val loss for epoch 0: 0.6109583973884583
# 0
# Train loss for epoch 1: 0.7107835412025452
# Val loss for epoch 1: 0.20362067222595215
# 1
# Train loss for epoch 2: 0.11343270540237427
# Val loss for epoch 2: 0.18466845154762268
# 2
# Train loss for epoch 3: 0.08654677122831345
# Val loss for epoch 3: 0.1565091460943222
# 3
# Train loss for epoch 4: 0.04510142281651497
# Val loss for epoch 4: 0.14525184035301208
# 4
# Train loss for epoch 5: 0.05437950789928436
# Val loss for epoch 5: 0.19007840752601624
# Train loss for epoch 6: 0.038385216146707535
# Val loss for epoch 6: 0.2913482189178467
# Train loss for epoch 7: 0.032326240092515945
# Val loss for epoch 7: 0.19257491827011108
# Train loss for epoch 8: 0.05559730529785156
# Val loss for epoch 8: 0.2319549173116684
# Train loss for epoch 9: 0.03740685433149338
# Val loss for epoch 9: 0.23540285229682922
# Train loss for epoch 10: 0.03383726254105568
# Val loss for epoch 10: 0.23235873878002167
# Train loss for epoch 11: 0.043270811438560486
# Val loss for epoch 11: 0.3103245794773102
# Train loss for epoch 12: 0.02385523170232773
# Val loss for epoch 12: 0.2556128203868866
# Train loss for epoch 13: 0.034400928765535355
# Val loss for epoch 13: 0.33716467022895813
# Train loss for epoch 14: 0.019778789952397346
# Val loss for epoch 14: 0.3601149618625641
# Train loss for epoch 15: 0.011349868960678577
# Val loss for epoch 15: 0.37813135981559753
# Train loss for epoch 16: 0.03679460659623146
# Val loss for epoch 16: 0.4260169565677643
# Train loss for epoch 17: 0.07486420124769211
# Val loss for epoch 17: 0.9979223012924194
# Train loss for epoch 18: 0.043533481657505035
# Val loss for epoch 18: 0.53599613904953
# Train loss for epoch 19: 0.029369600117206573
# Val loss for epoch 19: 0.9849557876586914
# Train loss for epoch 20: 0.023382551968097687
# Val loss for epoch 20: 0.4778003990650177
# Train loss for epoch 21: 0.010227244347333908
# Val loss for epoch 21: 0.5428574085235596
# Train loss for epoch 22: 0.04548932611942291
# Val loss for epoch 22: 0.7252813577651978
# Train loss for epoch 23: 0.03153364360332489
# Val loss for epoch 23: 0.5684881210327148
# Train loss for epoch 24: 0.022788822650909424
# Val loss for epoch 24: 0.5660768747329712
# Train loss for epoch 25: 0.015916606411337852
# Val loss for epoch 25: 0.9341264367103577
# Train loss for epoch 26: 0.412759393453598
# Val loss for epoch 26: 0.9623169302940369
# Train loss for epoch 27: 0.04661167040467262
# Val loss for epoch 27: 0.7654570937156677
# Train loss for epoch 28: 0.021133681759238243
# Val loss for epoch 28: 0.6107602715492249
# Train loss for epoch 29: 0.018962016329169273
# Val loss for epoch 29: 0.912487268447876
# Train loss for epoch 30: 0.023436229676008224
# Val loss for epoch 30: 0.7863382697105408
# Train loss for epoch 31: 0.04200822860002518
# Val loss for epoch 31: 0.6697558760643005
# Train loss for epoch 32: 0.04712161421775818
# Val loss for epoch 32: 0.7778806686401367
# Train loss for epoch 33: 0.05003304034471512
# Val loss for epoch 33: 1.2018771171569824
# Train loss for epoch 34: 0.13785907626152039
# Val loss for epoch 34: 1.1354130506515503
# Train loss for epoch 35: 0.05966682732105255
# Val loss for epoch 35: 1.468376874923706
# Train loss for epoch 36: 0.04568038135766983
# Val loss for epoch 36: 1.3131710290908813
# Train loss for epoch 37: 0.021885061636567116
# Val loss for epoch 37: 1.2217354774475098
# Train loss for epoch 38: 0.011690827086567879
# Val loss for epoch 38: 1.0660686492919922
# Train loss for epoch 39: 0.04681113362312317
# Val loss for epoch 39: 1.2085249423980713
# Train loss for epoch 40: 0.055707719177007675
# Val loss for epoch 40: 1.2716503143310547
# Train loss for epoch 41: 0.2407897412776947
# Val loss for epoch 41: 1.2019234895706177
# Train loss for epoch 42: 0.04189847409725189
# Val loss for epoch 42: 1.2292122840881348
# Train loss for epoch 43: 0.041396331042051315
# Val loss for epoch 43: 1.0810768604278564
# Train loss for epoch 44: 0.12332119792699814
# Val loss for epoch 44: 1.1874353885650635
# Train loss for epoch 45: 0.11095733940601349
# Val loss for epoch 45: 1.1338720321655273
# Train loss for epoch 46: 0.035867929458618164
# Val loss for epoch 46: 1.1767685413360596
# Train loss for epoch 47: 0.01437507662922144
# Val loss for epoch 47: 1.1965819597244263
# Train loss for epoch 48: 0.060855086892843246
# Val loss for epoch 48: 1.4615734815597534
# Train loss for epoch 49: 0.053081214427948
# Val loss for epoch 49: 0.9474709033966064
# Train loss for epoch 50: 0.08749087154865265
# Val loss for epoch 50: 1.0099385976791382
# Train loss for epoch 0: 2.840864658355713
# Val loss for epoch 0: 0.23951329290866852
# 0
# Train loss for epoch 1: 0.12636183202266693
# Val loss for epoch 1: 0.15505248308181763
# 1
# Train loss for epoch 2: 0.07720265537500381
# Val loss for epoch 2: 0.15374892950057983
# 2
# Train loss for epoch 3: 0.06309013068675995
# Val loss for epoch 3: 0.266358882188797
# Train loss for epoch 4: 0.05434297397732735
# Val loss for epoch 4: 0.2295914888381958
# Train loss for epoch 5: 0.045642003417015076
# Val loss for epoch 5: 0.23902946710586548
# Train loss for epoch 6: 0.0422239676117897
# Val loss for epoch 6: 0.1972847580909729
# Train loss for epoch 7: 0.028545811772346497
# Val loss for epoch 7: 0.21905745565891266
# Train loss for epoch 8: 0.04008306562900543
# Val loss for epoch 8: 0.17423933744430542
# Train loss for epoch 9: 0.04969722405076027
# Val loss for epoch 9: 0.3323759138584137
# Train loss for epoch 10: 0.033412232995033264
# Val loss for epoch 10: 0.5222512483596802
# Train loss for epoch 11: 0.02531612105667591
# Val loss for epoch 11: 0.3384464383125305
# Train loss for epoch 12: 0.03903108462691307
# Val loss for epoch 12: 0.4260205626487732
# Train loss for epoch 13: 0.026838649064302444
# Val loss for epoch 13: 0.41674569249153137
# Train loss for epoch 14: 0.08426978439092636
# Val loss for epoch 14: 0.4332107901573181
# Train loss for epoch 15: 0.038156669586896896
# Val loss for epoch 15: 0.4527847468852997
# Train loss for epoch 16: 0.02228028140962124
# Val loss for epoch 16: 0.34663474559783936
# Train loss for epoch 17: 0.02909752167761326
# Val loss for epoch 17: 0.4168917238712311
# Train loss for epoch 18: 0.011125374585390091
# Val loss for epoch 18: 0.4706020653247833
# Train loss for epoch 19: 0.01887337490916252
# Val loss for epoch 19: 0.7289607524871826
# Train loss for epoch 20: 0.05350985378026962
# Val loss for epoch 20: 0.37084704637527466
# Train loss for epoch 21: 0.0529148206114769
# Val loss for epoch 21: 0.7083281874656677
# Train loss for epoch 22: 0.04188720881938934
# Val loss for epoch 22: 0.5434901118278503
# Train loss for epoch 23: 0.020912431180477142
# Val loss for epoch 23: 1.07492196559906
# Train loss for epoch 24: 0.024000536650419235
# Val loss for epoch 24: 0.7153486013412476
# Train loss for epoch 25: 0.03265499696135521
# Val loss for epoch 25: 0.4407482147216797
# Train loss for epoch 26: 0.04150955751538277
# Val loss for epoch 26: 0.7621000409126282
# Train loss for epoch 27: 0.1240367665886879
# Val loss for epoch 27: 0.6760209202766418
# Train loss for epoch 28: 0.0569252111017704
# Val loss for epoch 28: 0.9447958469390869
# Train loss for epoch 29: 0.04107826575636864
# Val loss for epoch 29: 0.9473311305046082
# Train loss for epoch 30: 0.04001123085618019
# Val loss for epoch 30: 0.8827354311943054
# Train loss for epoch 31: 0.04097668454051018
# Val loss for epoch 31: 0.7875409126281738
# Train loss for epoch 32: 0.02900824137032032
# Val loss for epoch 32: 1.0102890729904175
# Train loss for epoch 33: 0.018598122522234917
# Val loss for epoch 33: 1.1263293027877808
# Train loss for epoch 34: 0.020396480336785316
# Val loss for epoch 34: 1.025659441947937
# Train loss for epoch 35: 0.05079130083322525
# Val loss for epoch 35: 0.7741263508796692
# Train loss for epoch 36: 0.012140567414462566
# Val loss for epoch 36: 1.015991449356079
# Train loss for epoch 37: 0.024777337908744812
# Val loss for epoch 37: 1.3828681707382202
# Train loss for epoch 38: 0.04079853743314743
# Val loss for epoch 38: 0.751619279384613
# Train loss for epoch 39: 0.04964905232191086
# Val loss for epoch 39: 1.0241551399230957
# Train loss for epoch 40: 0.13054850697517395
# Val loss for epoch 40: 1.0672968626022339
# Train loss for epoch 41: 0.03879682347178459
# Val loss for epoch 41: 1.1036533117294312
# Train loss for epoch 42: 0.04735322296619415
# Val loss for epoch 42: 1.133134365081787
# Train loss for epoch 43: 0.03836772218346596
# Val loss for epoch 43: 1.0980418920516968
# Train loss for epoch 44: 0.02080489881336689
# Val loss for epoch 44: 1.0180163383483887
# Train loss for epoch 45: 0.040341150015592575
# Val loss for epoch 45: 1.0510035753250122
# Train loss for epoch 46: 0.039523568004369736
# Val loss for epoch 46: 1.2213507890701294
# Train loss for epoch 47: 0.11676186323165894
# Val loss for epoch 47: 2.120394229888916
# Train loss for epoch 48: 0.07558471709489822
# Val loss for epoch 48: 1.5255084037780762
# Train loss for epoch 49: 0.09215755760669708
# Val loss for epoch 49: 1.7323216199874878
# Train loss for epoch 50: 0.07383875548839569
# Val loss for epoch 50: 1.0953702926635742
# Train loss for epoch 0: 3.6261329650878906
# Val loss for epoch 0: 0.4364445209503174
# 0
# Train loss for epoch 1: 0.40632200241088867
# Val loss for epoch 1: 0.17356674373149872
# 1
# Train loss for epoch 2: 0.10886722058057785
# Val loss for epoch 2: 0.17758828401565552
# Train loss for epoch 3: 0.05791335180401802
# Val loss for epoch 3: 0.16962966322898865
# 3
# Train loss for epoch 4: 0.05497366189956665
# Val loss for epoch 4: 0.1920083910226822
# Train loss for epoch 5: 0.05120336264371872
# Val loss for epoch 5: 0.20857052505016327
# Train loss for epoch 6: 0.04407732933759689
# Val loss for epoch 6: 0.3126065135002136
# Train loss for epoch 7: 0.06371390074491501
# Val loss for epoch 7: 0.3065900206565857
# Train loss for epoch 8: 0.0653374046087265
# Val loss for epoch 8: 0.2024783194065094
# Train loss for epoch 9: 0.035983603447675705
# Val loss for epoch 9: 0.3030931055545807
# Train loss for epoch 10: 0.014355816878378391
# Val loss for epoch 10: 0.36375704407691956
# Train loss for epoch 11: 0.02973952330648899
# Val loss for epoch 11: 0.282541424036026
# Train loss for epoch 12: 0.020474400371313095
# Val loss for epoch 12: 0.27452707290649414
# Train loss for epoch 13: 0.021166611462831497
# Val loss for epoch 13: 0.23421163856983185
# Train loss for epoch 14: 0.06797658652067184
# Val loss for epoch 14: 0.5326747298240662
# Train loss for epoch 15: 0.07122308015823364
# Val loss for epoch 15: 0.4252815246582031
# Train loss for epoch 16: 0.07203665375709534
# Val loss for epoch 16: 0.43886977434158325
# Train loss for epoch 17: 0.03248288854956627
# Val loss for epoch 17: 0.48503556847572327
# Train loss for epoch 18: 0.03068922460079193
# Val loss for epoch 18: 0.3445240557193756
# Train loss for epoch 19: 0.02877717837691307
# Val loss for epoch 19: 0.47564956545829773
# Train loss for epoch 20: 0.032884884625673294
# Val loss for epoch 20: 0.6212895512580872
# Train loss for epoch 21: 0.020784880965948105
# Val loss for epoch 21: 0.4104863107204437
# Train loss for epoch 22: 0.02191503904759884
# Val loss for epoch 22: 0.9181309342384338
# Train loss for epoch 23: 0.14056234061717987
# Val loss for epoch 23: 0.8607494235038757
# Train loss for epoch 24: 0.0331265814602375
# Val loss for epoch 24: 1.1347979307174683
# Train loss for epoch 25: 0.011786382645368576
# Val loss for epoch 25: 0.569005012512207
# Train loss for epoch 26: 0.010155381634831429
# Val loss for epoch 26: 0.7657774090766907
# Train loss for epoch 27: 0.005895167123526335
# Val loss for epoch 27: 0.6879821419715881
# Train loss for epoch 28: 0.009738124907016754
# Val loss for epoch 28: 0.9153583645820618
# Train loss for epoch 29: 0.06588869541883469
# Val loss for epoch 29: 1.7337608337402344
# Train loss for epoch 30: 0.09556607156991959
# Val loss for epoch 30: 0.8082440495491028
# Train loss for epoch 31: 0.07611384242773056
# Val loss for epoch 31: 1.6684579849243164
# Train loss for epoch 32: 0.09402955323457718
# Val loss for epoch 32: 0.7928404211997986
# Train loss for epoch 33: 0.0364750437438488
# Val loss for epoch 33: 0.8279865384101868
# Train loss for epoch 34: 0.01986665092408657
# Val loss for epoch 34: 0.6322571039199829
# Train loss for epoch 35: 0.018686341121792793
# Val loss for epoch 35: 0.8566339612007141
# Train loss for epoch 36: 0.046247322112321854
# Val loss for epoch 36: 0.9100808501243591
# Train loss for epoch 37: 0.030139902606606483
# Val loss for epoch 37: 0.7017735838890076
# Train loss for epoch 38: 0.19262850284576416
# Val loss for epoch 38: 0.7361864447593689
# Train loss for epoch 39: 0.06162012740969658
# Val loss for epoch 39: 1.394760012626648
# Train loss for epoch 40: 0.09478884935379028
# Val loss for epoch 40: 1.6267995834350586
# Train loss for epoch 41: 0.030365530401468277
# Val loss for epoch 41: 1.72004234790802
# Train loss for epoch 42: 0.016663851216435432
# Val loss for epoch 42: 0.9053800702095032
# Train loss for epoch 43: 0.04747013375163078
# Val loss for epoch 43: 0.9496704936027527
# Train loss for epoch 44: 0.04774151369929314
# Val loss for epoch 44: 1.0155168771743774
# Train loss for epoch 45: 0.03210962563753128
# Val loss for epoch 45: 0.9070855975151062
# Train loss for epoch 46: 0.07446911931037903
# Val loss for epoch 46: 1.0982798337936401
# Train loss for epoch 47: 0.03317379206418991
# Val loss for epoch 47: 1.0613055229187012
# Train loss for epoch 48: 0.06208513677120209
# Val loss for epoch 48: 0.859872043132782
# Train loss for epoch 49: 0.16717760264873505
# Val loss for epoch 49: 1.3175225257873535
# Train loss for epoch 50: 0.06063070148229599
# Val loss for epoch 50: 1.069144606590271

# %%
model_MLP = os.listdir('/mnt/pesaranlab/People/Capstone_students/Yue/model/model_Goose_all_2_MLP')
# result = model_MLP[x].split('_') for x in len(model_MLP)
results = []
for x in range(0,len(model_MLP)):
    result = model_MLP[x].split('_') 
    dropout = [int(i) for i in result[4] if i.isdigit()]
    if len(dropout) ==2:
        dropout = dropout[1]/10
    else:
        dropout = dropout[0]
    res = [int(i) for i in result[5] if i.isdigit()]
    res = int(res[0])
    results.append([dropout, res])

results = pd.DataFrame(np.array(results), columns=['dropout', 'epoch'])
best_results = results.groupby('dropout').max(epoch)
print(best_results)
# Out:
#          epoch
# dropout
# 0.1        2.0
# 0.3        4.0
# 0.5        4.0
# 0.7        2.0
# 1.0        3.0

# %%
for i,(index,row) in enumerate(best_results.iterrows()):
    model = MLP().to(device)
    path = model_saving_path
    if index == 1.0:
        index = 1
    DO = index
    best_epoch = int(row)

    model.load_state_dict(torch.load('{}/{}_CH{}_LOSS{}_REG{}{}_DO{}_EPOCH{}.pt'.format(path, model_type, CH, loss_type, reg_type, alpha,DO, best_epoch)))
    print('{}/{}_CH{}_LOSS{}_REG{}{}_DO{}_EPOCH{}.pt'.format(path, model_type, CH, loss_type, reg_type, alpha,DO, best_epoch))
    test_loss, test_acc, test_preds, test_preds_probs, test_labels, cases_wrong_0 = evaluate(model, optimizer, test_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=True, device=device)
    print('test loss:{} accuracy:{}'.format(test_loss, test_acc))
    predictions_test = np.concatenate(test_preds)
    labels_test = np.concatenate(test_labels)

    df_test = pd.DataFrame({'predictions': predictions_test, 'labels': labels_test})

    cm_test = confusion_matrix(labels_test, predictions_test)
    ax = plt.axes()
    group_names = ['True Neg','False Pos','False Neg','True Pos']
    group_counts = ["{0:0.0f}".format(value) for value in
                    cm_test.flatten()]

    TNR = int(group_counts[0]) / (int(group_counts[0])+int(group_counts[1]))
    FPR = 1 - TNR
    TPR = int(group_counts[3]) / (int(group_counts[3])+int(group_counts[2]))
    FNR = 1-TPR
    group_percentages =[TNR, FPR, FNR, TPR]

    group_percentages = ["{0:.2%}".format(value) for value in
                         group_percentages]
    labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
              zip(group_names,group_counts,group_percentages)]
    labels = np.asarray(labels).reshape(2,2)
    sn.heatmap(cm_test, annot=labels, fmt='', center = 2000)
    ax.set_title('Test Confusion Matrix')
    ax.set_xlabel('Predicted Label')
    ax.set_ylabel('True Label')
    plt.show()
# Out:
# /mnt/pesaranlab/People/Capstone_students/Yue/model/model_Goose_all_2_MLP/MLP_CHall_LOSSbce_REGnone0_DO0.1_EPOCH2.pt
# test loss:0.27204984426498413 accuracy:0.9454312690030405
# /mnt/pesaranlab/People/Capstone_students/Yue/model/model_Goose_all_2_MLP/MLP_CHall_LOSSbce_REGnone0_DO0.3_EPOCH4.pt
# test loss:0.24148495495319366 accuracy:0.9511921907505201
# /mnt/pesaranlab/People/Capstone_students/Yue/model/model_Goose_all_2_MLP/MLP_CHall_LOSSbce_REGnone0_DO0.5_EPOCH4.pt
# test loss:0.194511279463768 accuracy:0.9587133941430629
# /mnt/pesaranlab/People/Capstone_students/Yue/model/model_Goose_all_2_MLP/MLP_CHall_LOSSbce_REGnone0_DO0.7_EPOCH2.pt
# test loss:0.19242489337921143 accuracy:0.957753240518483
# /mnt/pesaranlab/People/Capstone_students/Yue/model/model_Goose_all_2_MLP/MLP_CHall_LOSSbce_REGnone0_DO1_EPOCH3.pt

# %%
model = MLP().to(device)
path = model_saving_path

model.load_state_dict(torch.load('{}/{}_CH{}_LOSS{}_REG{}{}_DO{}_EPOCH{}.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, best_epoch)))
# Out:
# <All keys matched successfully>

# %%
test_loss, test_acc, test_preds, test_preds_probs, test_labels, cases_wrong_0 = evaluate(model, optimizer, test_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=True, device=device)
print('test loss:{} accuracy:{}'.format(test_loss, test_acc))
# Out:
# test loss:0.3285059332847595 accuracy:0.9359897583613378

# %%
predictions_test = np.concatenate(test_preds)
labels_test = np.concatenate(test_labels)

df_test = pd.DataFrame({'predictions': predictions_test, 'labels': labels_test})

cm_test = confusion_matrix(labels_test, predictions_test)
ax = plt.axes()
group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts = ["{0:0.0f}".format(value) for value in
                cm_test.flatten()]

TNR = int(group_counts[0]) / (int(group_counts[0])+int(group_counts[1]))
FPR = 1 - TNR
TPR = int(group_counts[3]) / (int(group_counts[3])+int(group_counts[2]))
FNR = 1-TPR
group_percentages =[TNR, FPR, FNR, TPR]

group_percentages = ["{0:.2%}".format(value) for value in
                     group_percentages]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
          zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
sn.heatmap(cm_test, annot=labels, fmt='', center = 2000)
ax.set_title('Test Confusion Matrix')
ax.set_xlabel('Predicted Label')
ax.set_ylabel('True Label')
plt.show()

# %% [markdown]
# ### Dropout

# %%
class MLP(nn.Module):
    def __init__(self, input_dim=100*10*62, output_dim=1):
        super(MLP, self).__init__()
        self.linear1 = nn.Linear(input_dim, 256)
        self.linear2 = nn.Linear(256, output_dim)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(0.5)
        
    def forward(self, x):
        x = x.reshape([x.shape[0], 1, -1]).float()
        x1 = self.dropout(self.relu(self.linear1(x)))
        outputs = self.linear2(x1)
        return outputs

# %%
device = torch.device('cuda')

tol = 0.01
learning_rate = 0.001
num_epochs = 51
alpha = 0
model_type = 'MLP'
loss_type = 'bce'
reg_type = 'none'
CH = 'all'

model = MLP().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)

# %%
epochs, training_losses, training_acc, val_losses, validation_acc = [], [], [], [], []

for epoch in range(num_epochs):
    train_loss, train_acc = train(model, optimizer, train_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
    print('Train loss for epoch {}: {}'.format(epoch, train_loss))
    val_loss, val_acc = evaluate(model, optimizer, val_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
    print('Val loss for epoch {}: {}'.format(epoch, val_loss))
    epochs.append(epoch)
    training_losses.append(train_loss)
    training_acc.append(train_acc)
    val_losses.append(val_loss)
    validation_acc.append(val_acc)
    if val_loss <= min(val_losses):
        best_epoch = epoch
        print(epoch)
        path = '/mnt/pesaranlab/People/Capstone_students/Yue/model/model_Goose_1st_2_upsample'
        torch.save(model.state_dict(), '{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}_DROPOUT.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, epoch))
# Out:
# Train loss for epoch 0: 6.210958957672119
# Val loss for epoch 0: 1.3904974460601807
# 0
# Train loss for epoch 1: 2.8511769771575928
# Val loss for epoch 1: 0.9024863839149475
# 1
# Train loss for epoch 2: 2.6460137367248535
# Val loss for epoch 2: 0.8673516511917114
# 2
# Train loss for epoch 3: 2.5403270721435547
# Val loss for epoch 3: 1.1848795413970947
# Train loss for epoch 4: 2.3245315551757812
# Val loss for epoch 4: 1.5877028703689575
# Train loss for epoch 5: 2.385533332824707
# Val loss for epoch 5: 1.2811344861984253
# Train loss for epoch 6: 2.3153772354125977
# Val loss for epoch 6: 1.1493852138519287
# Train loss for epoch 7: 2.1970767974853516
# Val loss for epoch 7: 1.6244819164276123
# Train loss for epoch 8: 2.396665096282959
# Val loss for epoch 8: 1.383778691291809
# Train loss for epoch 9: 2.252708911895752
# Val loss for epoch 9: 1.5159811973571777
# Train loss for epoch 10: 2.6541333198547363
# Val loss for epoch 10: 1.2681165933609009
# Train loss for epoch 11: 2.313107490539551
# Val loss for epoch 11: 1.3810244798660278
# Train loss for epoch 12: 2.433364152908325
# Val loss for epoch 12: 1.7836116552352905
# Train loss for epoch 13: 2.4212005138397217
# Val loss for epoch 13: 1.7717176675796509
# Train loss for epoch 14: 2.3381266593933105
# Val loss for epoch 14: 1.4946173429489136
# Train loss for epoch 15: 2.1956799030303955
# Val loss for epoch 15: 1.35940420627594
# Train loss for epoch 16: 2.2661399841308594
# Val loss for epoch 16: 2.933074951171875
# Train loss for epoch 17: 2.4323079586029053
# Val loss for epoch 17: 1.5017461776733398
# Train loss for epoch 18: 2.42612361907959
# Val loss for epoch 18: 1.4751479625701904
# Train loss for epoch 19: 2.2247064113616943
# Val loss for epoch 19: 1.5253081321716309
# Train loss for epoch 20: 2.4097392559051514
# Val loss for epoch 20: 1.8190230131149292
# Train loss for epoch 21: 2.545872688293457
# Val loss for epoch 21: 2.0393521785736084
# Train loss for epoch 22: 2.603722333908081
# Val loss for epoch 22: 2.1430954933166504
# Train loss for epoch 23: 2.3629324436187744
# Val loss for epoch 23: 2.1573851108551025
# Train loss for epoch 24: 2.361715316772461
# Val loss for epoch 24: 2.410593271255493
# Train loss for epoch 25: 2.348214864730835
# Val loss for epoch 25: 2.501023530960083
# Train loss for epoch 26: 2.2327568531036377
# Val loss for epoch 26: 2.192861795425415
# Train loss for epoch 27: 2.377087116241455
# Val loss for epoch 27: 2.149552822113037
# Train loss for epoch 28: 2.346137285232544
# Val loss for epoch 28: 4.974562168121338
# Train loss for epoch 29: 2.304971694946289
# Val loss for epoch 29: 2.4312729835510254
# Train loss for epoch 30: 2.3756277561187744
# Val loss for epoch 30: 2.6923069953918457
# Train loss for epoch 31: 2.106827974319458
# Val loss for epoch 31: 2.5046422481536865
# Train loss for epoch 32: 2.136174440383911
# Val loss for epoch 32: 2.392190933227539
# Train loss for epoch 33: 2.120375871658325
# Val loss for epoch 33: 2.3768818378448486
# Train loss for epoch 34: 2.0772037506103516
# Val loss for epoch 34: 1.8639460802078247
# Train loss for epoch 35: 2.6293890476226807
# Val loss for epoch 35: 2.4117271900177
# Train loss for epoch 36: 2.246634006500244
# Val loss for epoch 36: 2.5633492469787598
# Train loss for epoch 37: 2.100916862487793
# Val loss for epoch 37: 2.192262887954712
# Train loss for epoch 38: 2.2519190311431885
# Val loss for epoch 38: 2.2516281604766846
# Train loss for epoch 39: 2.184922456741333
# Val loss for epoch 39: 3.012239933013916
# Train loss for epoch 40: 2.4702847003936768
# Val loss for epoch 40: 1.8339385986328125
# Train loss for epoch 41: 2.3534786701202393
# Val loss for epoch 41: 2.1168315410614014
# Train loss for epoch 42: 2.339764356613159
# Val loss for epoch 42: 2.1822457313537598
# Train loss for epoch 43: 2.841719627380371
# Val loss for epoch 43: 3.495997905731201
# Train loss for epoch 44: 2.599613666534424
# Val loss for epoch 44: 3.128087043762207
# Train loss for epoch 45: 2.402019739151001
# Val loss for epoch 45: 3.557492256164551
# Train loss for epoch 46: 2.208097457885742
# Val loss for epoch 46: 3.0467326641082764
# Train loss for epoch 47: 2.249814987182617
# Val loss for epoch 47: 2.6039767265319824
# Train loss for epoch 48: 2.5581679344177246
# Val loss for epoch 48: 2.055091619491577
# Train loss for epoch 49: 2.582925319671631
# Val loss for epoch 49: 2.2628281116485596
# Train loss for epoch 50: 2.676723003387451
# Val loss for epoch 50: 7.6749958992004395

# %%
plot_loss_acc(training_losses, val_losses, training_acc, validation_acc, model_type)

# %%
model = MLP().to(device)
path = '/mnt/pesaranlab/People/Capstone_students/Yue/model/model_Goose_1st_2_upsample'
model.load_state_dict(torch.load('{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}_DROPOUT.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, best_epoch)))
# Out:
# <All keys matched successfully>

# %%
test_loss, test_acc, test_preds, test_preds_probs, test_labels, cases_wrong_0 = evaluate(model, optimizer, test_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=True, device=device)
print('test loss:{} accuracy:{}'.format(test_loss, test_acc))
# Out:
# test loss:1.6521267890930176 accuracy:0.9407905264842374

# %%
np.mean(np.concatenate(test_labels))
# Out:
# 0.7385182

# %%
predictions_test = np.concatenate(test_preds)
labels_test = np.concatenate(test_labels)

df_test = pd.DataFrame({'predictions': predictions_test, 'labels': labels_test})

cm_test = confusion_matrix(labels_test, predictions_test)
ax = plt.axes()
sn.heatmap(cm_test, annot = True, fmt = "d", ax = ax, center=2000)
ax.set_title('Test Confusion Matrix')
ax.set_xlabel('Predicted Label')
ax.set_ylabel('True Label')
plt.show()

# %% [markdown]
# ### Reduction = 'sum'

# %%
class MLP(nn.Module):
    def __init__(self, input_dim=100*10*62, output_dim=1):
        super(MLP, self).__init__()
        self.linear1 = nn.Linear(input_dim, 256)
        self.linear2 = nn.Linear(256, output_dim)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(0.5)
        
    def forward(self, x):
        x = x.reshape([x.shape[0], 1, -1]).float()
        x1 = self.relu(self.linear1(x))
        outputs = self.linear2(x1)
        return outputs

# %%
device = torch.device('cuda')

tol = 0.01
learning_rate = 0.001
num_epochs = 51
alpha = 0
model_type = 'MLP'
loss_type = 'bce'
reg_type = 'none'
CH = 'all'

model = MLP().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)

# %%
epochs, training_losses, training_acc, val_losses, validation_acc = [], [], [], [], []

for epoch in range(num_epochs):
    train_loss, train_acc = train(model, optimizer, train_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
    print('Train loss for epoch {}: {}'.format(epoch, train_loss))
    val_loss, val_acc = evaluate(model, optimizer, val_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
    print('Val loss for epoch {}: {}'.format(epoch, val_loss))
    epochs.append(epoch)
    training_losses.append(train_loss)
    training_acc.append(train_acc)
    val_losses.append(val_loss)
    validation_acc.append(val_acc)
    if val_loss <= min(val_losses):
        best_epoch = epoch
        print(epoch)
        path = '/mnt/pesaranlab/People/Capstone_students/Yue/model/model_Goose_1st_2_upsample'
        torch.save(model.state_dict(), '{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}_REDUCEsum.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, epoch))

# %%
plot_loss_acc(training_losses, val_losses, training_acc, validation_acc, model_type)

# %%
best_epoch
# Out:
# 5

# %%
model = MLP().to(device)
path = '/mnt/pesaranlab/People/Capstone_students/Yue/model/model_Goose_1st_2_upsample'
model.load_state_dict(torch.load('{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}_REDUCEsum.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, best_epoch)))
# Out:
# <All keys matched successfully>

# %%
test_loss, test_acc, test_preds, test_preds_probs, test_labels, cases_wrong_0 = evaluate(model, optimizer, test_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=True, device=device)
print('test loss:{} accuracy:{}'.format(test_loss, test_acc))
# Out:
# test loss:0.46965113282203674 accuracy:0.9455912946071371

# %%
predictions_test = np.concatenate(test_preds)
labels_test = np.concatenate(test_labels)

df_test = pd.DataFrame({'predictions': predictions_test, 'labels': labels_test})

cm_test = confusion_matrix(labels_test, predictions_test)
ax = plt.axes()
sn.heatmap(cm_test, annot = True, fmt = "d", ax = ax, center=2000)
ax.set_title('Test Confusion Matrix')
ax.set_xlabel('Predicted Label')
ax.set_ylabel('True Label')
plt.show()
