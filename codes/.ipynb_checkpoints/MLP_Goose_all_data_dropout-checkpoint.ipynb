# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
from torch.utils.data import Dataset, DataLoader
from torch import nn
import torch.nn.functional as F
from scipy.io import loadmat
import os
from os import listdir
import pandas as pd
from skimage import io
from PIL import Image
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pickle
import pdb

from utils import *

# %%
CH = 'all'
device = torch.device('cuda')
val_dates = ['180330','180331']
test_dates = ['180328','180329']
#load_path = '/home/bijanadmin/Desktop/Goose_data/data_Goose_1st_2/'
load_path = '/home/bijanadmin/Desktop/Goose_data/data_Goose_all_2/'
# save_path = '/mnt/pesaranlab/People/Capstone_students/Yue/model/model_Goose_1st_2_upsample'
save_path = '/home/bijanadmin/Desktop/Goose_data/data_Goose_all_2/Goose_ANN_models/'

train_files, val_files, test_files = create_files(load_path, val_dates, test_dates)
train_loader, val_loader, test_loader = create_dataloaders(train_files, val_files, test_files, load_path, batch_size=128)

# %%
len(train_loader), len(val_loader), len(test_loader)
# Out:
# (446, 49, 21)

# %%
for batch_idx, (data, label, date, rec, time) in enumerate(train_loader): # check shapes
    print(data.shape)
    print(label.shape)
    print(len(date))
    print(len(rec))
    print(len(time))
    break
# Out:
# torch.Size([128, 62, 100, 10])
# torch.Size([128, 1])
# 128
# 128
# 128

# %%
# movement labelled 0; non-movement labelled 1
for batch_idx, (data, label, date, rec, time) in enumerate(train_loader):
    for i in range(128):
        print('date:{}, rec:{}, time:{}, label:{}'.format(date[i], rec[i], time[i], label[i][0].numpy()))
        if label[i][0].numpy() == 0.0:
            data_sub = data[i][0]
            plt.yticks(ticks=[0, 20, 40, 60, 80, 99], labels=[round(np.logspace(0, 2.45, 100)[i]) for i in [0, 20, 40, 60, 80, 99]])
            plt.xticks(ticks=[0, 9], labels=[1, 10])
            plt.imshow(data_sub)
            plt.clim(-1.5, 1.5)
            plt.colorbar()
            plt.show()
    break
# Out:
# date:180414, rec:007, time:5708.0, label:0.0
# date:180414, rec:007, time:6218.0, label:0.0
# date:180325, rec:007, time:6553.0, label:0.0
# date:180414, rec:003, time:3480.0, label:1.0
# date:180324, rec:009, time:310.0, label:0.0
# date:180327, rec:005, time:2003.0, label:0.0
# date:180414, rec:001, time:2140.0, label:0.0
# date:180414, rec:001, time:1020.0, label:0.0
# date:180413, rec:002, time:6711.0, label:0.0
# date:180412, rec:003, time:3904.0, label:1.0
# date:180414, rec:007, time:4868.0, label:0.0
# date:180325, rec:004, time:1838.0, label:1.0
# date:180325, rec:004, time:3660.0, label:1.0
# date:180413, rec:002, time:1360.0, label:0.0
# date:180322, rec:003, time:1917.0, label:0.0
# date:180409, rec:006, time:2391.0, label:0.0
# date:180413, rec:002, time:1220.0, label:0.0
# date:180325, rec:009, time:1060.0, label:0.0
# date:180325, rec:009, time:1610.0, label:0.0
# date:180411, rec:004, time:4718.0, label:1.0
# date:180413, rec:001, time:6547.0, label:0.0
# date:180414, rec:001, time:3702.0, label:0.0
# date:180413, rec:003, time:6191.0, label:0.0
# date:180409, rec:003, time:120.0, label:1.0
# date:180414, rec:001, time:3158.0, label:1.0
# date:180327, rec:008, time:5073.0, label:0.0
# date:180325, rec:004, time:6720.0, label:1.0
# date:180412, rec:005, time:1587.0, label:1.0
# date:180413, rec:004, time:40.0, label:0.0
# date:180325, rec:001, time:5146.0, label:1.0
# date:180401, rec:001, time:740.0, label:0.0
# date:180327, rec:008, time:4102.0, label:0.0
# date:180414, rec:002, time:3891.0, label:1.0
# date:180413, rec:008, time:4524.0, label:1.0
# date:180401, rec:001, time:1250.0, label:0.0
# date:180323, rec:006, time:1676.0, label:1.0
# date:180414, rec:007, time:4157.0, label:0.0
# date:180414, rec:004, time:2395.0, label:1.0
# date:180324, rec:006, time:1082.0, label:1.0
# date:180325, rec:005, time:6884.0, label:1.0
# date:180414, rec:001, time:1340.0, label:0.0
# date:180325, rec:005, time:2104.0, label:1.0
# date:180413, rec:008, time:2195.0, label:1.0
# date:180401, rec:001, time:1730.0, label:0.0
# date:180326, rec:004, time:2429.0, label:1.0
# date:180327, rec:008, time:5493.0, label:0.0
# date:180413, rec:004, time:330.0, label:0.0
# date:180324, rec:008, time:2578.0, label:0.0
# date:180412, rec:005, time:1147.0, label:1.0
# date:180412, rec:003, time:6118.0, label:1.0
# date:180413, rec:001, time:2690.0, label:0.0
# date:180326, rec:003, time:4706.0, label:0.0
# date:180410, rec:006, time:1936.0, label:1.0
# date:180410, rec:005, time:1678.0, label:0.0
# date:180413, rec:001, time:3160.0, label:0.0
# date:180322, rec:007, time:4520.0, label:0.0
# date:180410, rec:005, time:277.0, label:1.0
# date:180413, rec:004, time:6682.0, label:1.0
# date:180410, rec:005, time:237.0, label:1.0
# date:180413, rec:001, time:6757.0, label:0.0
# date:180327, rec:008, time:4012.0, label:0.0
# date:180323, rec:001, time:6993.0, label:1.0
# date:180413, rec:001, time:920.0, label:0.0
# date:180325, rec:007, time:3086.0, label:0.0
# date:180327, rec:007, time:6961.0, label:0.0
# date:180414, rec:001, time:4947.0, label:1.0
# date:180411, rec:006, time:4201.0, label:1.0
# date:180413, rec:004, time:20.0, label:0.0
# date:180327, rec:007, time:4431.0, label:0.0
# date:180412, rec:006, time:4008.0, label:0.0
# date:180324, rec:009, time:310.0, label:0.0
# date:180327, rec:001, time:1510.0, label:0.0
# date:180413, rec:001, time:3833.0, label:0.0
# date:180325, rec:007, time:2053.0, label:1.0
# date:180324, rec:008, time:2001.0, label:0.0
# date:180414, rec:002, time:3076.0, label:1.0
# date:180413, rec:001, time:3673.0, label:0.0
# date:180410, rec:006, time:4239.0, label:1.0
# date:180325, rec:007, time:4953.0, label:0.0
# date:180409, rec:006, time:4778.0, label:0.0
# date:180325, rec:004, time:3760.0, label:1.0
# date:180411, rec:003, time:4382.0, label:1.0
# date:180324, rec:001, time:1582.0, label:1.0
# date:180410, rec:006, time:180.0, label:1.0
# date:180414, rec:007, time:5238.0, label:0.0
# date:180414, rec:001, time:800.0, label:0.0
# date:180322, rec:001, time:220.0, label:0.0
# date:180322, rec:005, time:2542.0, label:1.0
# date:180325, rec:009, time:5799.0, label:1.0
# date:180413, rec:004, time:5401.0, label:1.0
# date:180325, rec:005, time:2496.0, label:1.0
# date:180411, rec:007, time:90.0, label:0.0
# date:180324, rec:008, time:5604.0, label:0.0
# date:180410, rec:005, time:3719.0, label:1.0
# date:180412, rec:006, time:5668.0, label:0.0
# date:180412, rec:005, time:454.0, label:1.0
# date:180324, rec:001, time:3905.0, label:1.0
# date:180324, rec:003, time:4505.0, label:1.0
# date:180412, rec:003, time:6338.0, label:1.0
# date:180410, rec:004, time:3270.0, label:1.0
# date:180322, rec:007, time:4540.0, label:0.0
# date:180412, rec:003, time:2616.0, label:1.0
# date:180324, rec:008, time:2211.0, label:0.0
# date:180414, rec:007, time:3527.0, label:0.0
# date:180413, rec:002, time:5291.0, label:0.0
# date:180413, rec:008, time:2539.0, label:1.0
# date:180414, rec:001, time:510.0, label:0.0
# date:180412, rec:002, time:7031.0, label:1.0
# date:180401, rec:001, time:940.0, label:0.0
# date:180327, rec:005, time:6645.0, label:1.0
# date:180327, rec:007, time:3820.0, label:0.0
# date:180414, rec:001, time:1220.0, label:0.0
# date:180413, rec:002, time:7081.0, label:0.0
# date:180327, rec:002, time:6315.0, label:1.0
# date:180325, rec:001, time:6370.0, label:1.0
# date:180322, rec:003, time:783.0, label:1.0
# date:180327, rec:008, time:2422.0, label:0.0
# date:180412, rec:001, time:2320.0, label:1.0
# date:180412, rec:005, time:5127.0, label:0.0
# date:180413, rec:003, time:5441.0, label:0.0
# date:180409, rec:006, time:423.0, label:1.0
# date:180322, rec:007, time:2143.0, label:0.0
# date:180412, rec:006, time:2119.0, label:1.0
# date:180410, rec:006, time:1686.0, label:1.0
# date:180327, rec:005, time:6572.0, label:0.0
# date:180327, rec:007, time:2750.0, label:0.0
# date:180325, rec:003, time:5747.0, label:1.0
# date:180324, rec:003, time:4135.0, label:1.0

# %%
class MLP(nn.Module): # add dropo
    def __init__(self, input_dim=100*10*62, output_dim=1, embed_dim=256,drop_prob=0.):
        super(MLP, self).__init__()
        self.linear1 = nn.Linear(input_dim, embed_dim)
        self.linear2 = nn.Linear(embed_dim, output_dim)
        self.dropout = nn.Dropout(drop_prob)
        
    def forward(self, x):
        
        x = x.reshape([x.shape[0], 1, -1]).float()
        x = self.dropout(F.relu(self.linear1(x)))
        outputs = self.linear2(x)
        
        return outputs

# %%
device = torch.device('cuda')

tol = 0.01
learning_rate = 0.001
num_epochs = 51
alpha = 0
model_type = 'MLP'
loss_type = 'bce'
reg_type = 'none'
input_dim = 62*10*100
embed_dim = 256
p = 0.


model = MLP(input_dim=input_dim, embed_dim=embed_dim,drop_prob = p).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)
model
# Out:
# MLP(
#   (linear1): Linear(in_features=62000, out_features=256, bias=True)
#   (linear2): Linear(in_features=256, out_features=1, bias=True)
#   (dropout): Dropout(p=0.0, inplace=False)
# )

# %%
(data, labels, _, _, _) = next(iter(train_loader))
data = data.to(device)
output = model(data)
output.shape
# Out:
# torch.Size([128, 1, 1])

# %%
epochs, training_losses, training_acc, val_losses, validation_acc = [], [], [], [], []

for epoch in range(num_epochs):
    train_loss, train_acc = train(model, optimizer, train_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, 
                                  reg_type=reg_type, collect_result=False, device=device)
    print('Train loss for epoch {}: {}'.format(epoch, train_loss))
    val_loss, val_acc = evaluate(model, optimizer, val_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, 
                                 reg_type=reg_type, collect_result=False, device=device)
    print('Val loss for epoch {}: {}'.format(epoch, val_loss))
    if val_losses:
        if val_loss < min(val_losses):
            best_epoch = epoch
            print(epoch)
            torch.save(model.state_dict(), '{}/{}_CH{}_LOSS{}_REG{}{}_EMBED{}_EPOCH{}.pt'.format(
                save_path, model_type, CH, loss_type, reg_type, alpha, embed_dim, epoch))
    epochs.append(epoch)
    training_losses.append(train_loss)
    training_acc.append(train_acc)
    val_losses.append(val_loss)
    validation_acc.append(val_acc)
    
    if train_loss < tol:
        break
# Out:
# Train loss for epoch 0: 5.517220973968506
# Val loss for epoch 0: 0.618596076965332
# Train loss for epoch 1: 0.33566877245903015
# Val loss for epoch 1: 0.2368520349264145
# 1
# Train loss for epoch 2: 0.085982546210289
# Val loss for epoch 2: 0.2401837855577469
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-a13de8558dbf> in <module>
#       2
#       3 for epoch in range(num_epochs):
# ----> 4     train_loss, train_acc = train(model, optimizer, train_loader, alpha=alpha, model_type=model_type, loss_type=loss_type,
#       5                                   reg_type=reg_type, collect_result=False, device=device)
#       6     print('Train loss for epoch {}: {}'.format(epoch, train_loss))
#
# /mnt/pesaranlab/People/Capstone_students/Gino/Sleeping-Monkeys/codes/utils.py in train(model, optimizer, loader, alpha, timewindow, model_type, loss_type, reg_type, collect_result, device)
#     176     batch_lengths = 0
#     177
# --> 178     for batch_idx, (data, labels, _, _, _) in enumerate(loader):
#     179         data = data.to(device)
#     180         labels = labels.to(device).float()
#
# ~/anaconda3/lib/python3.8/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     433         if self._sampler_iter is None:
#     434             self._reset()
# --> 435         data = self._next_data()
#     436         self._num_yielded += 1
#     437         if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~/anaconda3/lib/python3.8/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#     473     def _next_data(self):
#     474         index = self._next_index()  # may raise StopIteration
# --> 475         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     476         if self._pin_memory:
#     477             data = _utils.pin_memory.pin_memory(data)
#
# ~/anaconda3/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# ~/anaconda3/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# /mnt/pesaranlab/People/Capstone_students/Gino/Sleeping-Monkeys/codes/utils.py in __getitem__(self, idx)
#      30     def __getitem__(self, idx):
#      31         f, label, mvmt_type, date, rec, time = self.files[idx]
# ---> 32         spec = torch.from_numpy(np.load(self.load_path+mvmt_type+'/'+f))
#      33         if self.CH is not None:
#      34             return torch.transpose(spec[self.CH,:,:].unsqueeze(0), 2, 1), torch.Tensor([label]), date, rec, time
#
# ~/anaconda3/lib/python3.8/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     414             own_fid = False
#     415         else:
# --> 416             fid = stack.enter_context(open(os_fspath(file), "rb"))
#     417             own_fid = True
#     418
#
# KeyboardInterrupt:

# %%
plot_loss_acc(training_losses, val_losses, training_acc, validation_acc, model_type) # embed_dim=64

# %%
model = MLP(input_dim=100*10, embed_dim=embed_dim).to(device)
path = '/mnt/pesaranlab/People/Capstone_students/Yue/model/model_Goose_1st_1_upsample'
model.load_state_dict(torch.load('{}/{}_CH{}_LOSS{}_REG{}{}_EMBED{}_EPOCH{}.pt'.format(
    path, model_type, CH, loss_type, reg_type, alpha, embed_dim, best_epoch)))
# Out:
# <All keys matched successfully>

# %%
plt.plot(model.linear2.weight.cpu().detach().numpy().flatten())
plt.show()

# %%
test_loss, test_acc, test_preds, test_preds_probs, test_labels, cases_wrong_0 = evaluate(model, optimizer, test_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=True, device=device)
print('test loss:{} accuracy:{}'.format(test_loss, test_acc))
# Out:
# test loss:0.5320249795913696 accuracy:0.8441538461538461

# %%
predictions_test = np.concatenate(test_preds)
labels_test = np.concatenate(test_labels)

df_test = pd.DataFrame({'predictions': predictions_test, 'labels': labels_test})

cm_test = confusion_matrix(labels_test, predictions_test)
ax = plt.axes()
sn.heatmap(cm_test, annot = True, fmt = "d", ax = ax, center=2000)
ax.set_title('Test Confusion Matrix')
ax.set_xlabel('Predicted Label')
ax.set_ylabel('True Label')
plt.show()

# %%
plot_loss_acc(training_losses, val_losses, training_acc, validation_acc, model_type) # embed_dim=256

# %%
model = MLP(input_dim=100*10).to(device)
path = '/mnt/pesaranlab/People/Capstone_students/Yue/model/model_Goose_1st_1_upsample'
model.load_state_dict(torch.load('{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}.pt'.format(
    path, model_type, CH, loss_type, reg_type, alpha, 4)))
# Out:
# <All keys matched successfully>

# %%
plt.plot(model.linear2.weight.cpu().detach().numpy().flatten())
plt.show()

# %%
test_loss, test_acc, test_preds, test_preds_probs, test_labels, cases_wrong_0 = evaluate(model, optimizer, test_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=True, device=device)
print('test loss:{} accuracy:{}'.format(test_loss, test_acc))
# Out:
# test loss:0.5888658761978149 accuracy:0.8316923076923077

# %%
predictions_test = np.concatenate(test_preds)
labels_test = np.concatenate(test_labels)

df_test = pd.DataFrame({'predictions': predictions_test, 'labels': labels_test})

cm_test = confusion_matrix(labels_test, predictions_test)
ax = plt.axes()
sn.heatmap(cm_test, annot = True, fmt = "d", ax = ax, center=2000)
ax.set_title('Test Confusion Matrix')
ax.set_xlabel('Predicted Label')
ax.set_ylabel('True Label')
plt.show()
