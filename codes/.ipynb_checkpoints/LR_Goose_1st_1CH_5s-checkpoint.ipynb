# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
from torch.utils.data import Dataset, DataLoader
from torch import nn
from torch.nn.functional import relu
from scipy.io import loadmat
import os
from os import listdir
import pandas as pd
from skimage import io
from PIL import Image
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pickle

from utils import *

# %%
#selected subset of dates. 
val_dates = ['180327','180329']
test_dates = ['180330','180331']
bad_dates = ['180326', '180328', '171019', '180715', '180716', '180717']
load_path = '/home/bijanadmin/Desktop/Goose_data/data_Goose_1st_5s_2/'
model_saving_path = '/home/bijanadmin/Desktop/Goose_data/data_Goose_1st_5s_2/LR_models'
CH = 23

train_files, val_files, test_files = create_files(load_path, val_dates, test_dates, bad_dates)
train_loader, val_loader, test_loader = create_dataloaders(train_files, val_files, test_files,load_path, batch_size=256, CH = CH)

# %%
len(train_loader), len(val_loader), len(test_loader)
# Out:
# (161, 52, 52)

# %%
for batch_idx, (data, label, date, rec, time) in enumerate(train_loader): # check shapes
    print(data.shape)
    print(label.shape)
    print(len(date))
    print(len(rec))
    print(len(time))
    break
# Out:
# torch.Size([256, 1, 100, 5])
# torch.Size([256, 1])
# 256
# 256
# 256

# %%
# movement labelled 0; non-movement labelled 1
for batch_idx, (data, label, date, rec, time) in enumerate(train_loader):
    for i in range(128):
        print('date:{}, rec:{}, time:{}'.format(date[i], rec[i], time[i]))
        data_sub = data[i][0]
        plt.imshow(data_sub)
        plt.clim(-1.5, 1.5)
        plt.colorbar()
        plt.title(label[i][0].numpy())
        plt.show()
    break
# Out:
# date:180325, rec:009, time:3713.0
# date:180325, rec:005, time:6365.0
# date:180325, rec:007, time:3600.0
# date:180325, rec:005, time:1646.0
# date:180401, rec:001, time:3440.0
# date:180324, rec:003, time:607.0
# date:180325, rec:001, time:3229.0
# date:180322, rec:007, time:1749.0
# date:180324, rec:009, time:127.0
# date:180325, rec:005, time:6025.0
# date:180322, rec:004, time:4816.0
# date:180325, rec:007, time:5480.0
# date:180325, rec:005, time:4253.0
# date:180325, rec:009, time:4916.0
# date:180324, rec:001, time:527.0
# date:180323, rec:007, time:2246.0
# date:180325, rec:009, time:1142.0
# date:180324, rec:008, time:5896.0
# date:180325, rec:002, time:2722.0
# date:180325, rec:003, time:843.0
# date:180325, rec:007, time:6520.0
# date:180325, rec:004, time:5528.0
# date:180324, rec:009, time:657.0
# date:180324, rec:003, time:4787.0
# date:180324, rec:008, time:2880.0
# date:180325, rec:004, time:3747.0
# date:180323, rec:006, time:1543.0
# date:180323, rec:001, time:1112.0
# date:180325, rec:009, time:4586.0
# date:180324, rec:006, time:6325.0
# date:180322, rec:003, time:530.0
# date:180322, rec:005, time:1050.0
# date:180325, rec:007, time:6955.0
# date:180323, rec:007, time:2827.0
# date:180322, rec:004, time:4366.0
# date:180323, rec:003, time:729.0
# date:180324, rec:004, time:4901.0
# date:180325, rec:002, time:397.0
# date:180325, rec:006, time:4037.0
# date:180325, rec:006, time:3415.0
# date:180322, rec:005, time:6376.0
# date:180322, rec:003, time:3920.0
# date:180325, rec:003, time:719.0
# date:180325, rec:002, time:6227.0
# date:180324, rec:008, time:1060.0
# date:180325, rec:009, time:2457.0
# date:180322, rec:007, time:4377.0
# date:180401, rec:003, time:392.0
# date:180325, rec:001, time:282.0
# date:180322, rec:007, time:3306.0
# date:180324, rec:008, time:2785.0
# date:180324, rec:008, time:443.0
# date:180323, rec:002, time:332.0
# date:180401, rec:001, time:97.0
# date:180325, rec:002, time:6991.0
# date:180325, rec:003, time:2207.0
# date:180322, rec:007, time:4077.0
# date:180325, rec:007, time:2708.0
# date:180325, rec:007, time:4080.0
# date:180322, rec:007, time:1364.0
# date:180325, rec:006, time:3000.0
# date:180401, rec:001, time:4068.0
# date:180325, rec:006, time:5682.0
# date:180325, rec:009, time:2688.0
# date:180325, rec:001, time:717.0
# date:180324, rec:005, time:2682.0
# date:180324, rec:008, time:2590.0
# date:180325, rec:009, time:1552.0
# date:180401, rec:001, time:6465.0
# date:180401, rec:001, time:882.0
# date:180325, rec:005, time:4208.0
# date:180324, rec:008, time:198.0
# date:180401, rec:001, time:117.0
# date:180325, rec:009, time:4511.0
# date:180325, rec:007, time:6555.0
# date:180322, rec:002, time:6508.0
# date:180322, rec:007, time:2150.0
# date:180325, rec:009, time:1057.0
# date:180325, rec:002, time:2429.0
# date:180325, rec:006, time:861.0
# date:180323, rec:001, time:852.0
# date:180325, rec:007, time:4890.0
# date:180325, rec:001, time:1497.0
# date:180325, rec:002, time:582.0
# date:180322, rec:003, time:1085.0
# date:180324, rec:004, time:3084.0
# date:180324, rec:003, time:6015.0
# date:180323, rec:005, time:3153.0
# date:180324, rec:006, time:3546.0
# date:180325, rec:002, time:5195.0
# date:180324, rec:009, time:872.0
# date:180325, rec:009, time:4501.0
# date:180401, rec:001, time:857.0
# date:180325, rec:006, time:1755.0
# date:180325, rec:002, time:4365.0
# date:180325, rec:007, time:4715.0
# date:180325, rec:007, time:4805.0
# date:180323, rec:007, time:6538.0
# date:180325, rec:009, time:1217.0
# date:180325, rec:005, time:1236.0
# date:180325, rec:002, time:3896.0
# date:180401, rec:003, time:785.0
# date:180325, rec:002, time:6656.0
# date:180324, rec:003, time:3659.0
# date:180325, rec:002, time:1984.0
# date:180325, rec:006, time:6883.0
# date:180324, rec:004, time:6234.0
# date:180323, rec:007, time:4278.0
# date:180325, rec:007, time:2573.0
# date:180323, rec:007, time:6903.0
# date:180325, rec:009, time:1032.0
# date:180325, rec:006, time:4687.0
# date:180401, rec:003, time:942.0
# date:180324, rec:001, time:5631.0
# date:180325, rec:006, time:3840.0
# date:180322, rec:001, time:67.0
# date:180324, rec:009, time:842.0
# date:180324, rec:008, time:5961.0
# date:180401, rec:003, time:977.0
# date:180325, rec:007, time:3208.0
# date:180324, rec:008, time:2655.0
# date:180324, rec:001, time:2153.0
# date:180324, rec:008, time:3360.0
# date:180325, rec:006, time:711.0
# date:180325, rec:006, time:6858.0
# date:180322, rec:007, time:2300.0
# date:180323, rec:002, time:582.0
# date:180401, rec:003, time:825.0

# %% [markdown]
# ### Logistic regression with no regularization

# %%
device = torch.device('cuda')

tol = 0.01
learning_rate = 0.001
num_epochs = 51
alphas = [1,50,100]
model_type = 'LR'
loss_type = 'bce'
reg_type = 'none'
timewindow = 5

# %%
for alpha in alphas:
    model = GLM(input_dim=100*timewindow).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)
    epochs, training_losses, training_acc, val_losses, validation_acc = [], [], [], [], []

    for epoch in range(num_epochs):
        train_loss, train_acc = train(model, optimizer, train_loader, timewindow = timewindow, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
        print('Train loss for epoch {}: {}'.format(epoch, train_loss))
        val_loss, val_acc = evaluate(model, optimizer, val_loader, alpha=alpha, timewindow = timewindow, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
        print('Val loss for epoch {}: {}'.format(epoch, val_loss))
        if val_losses:
            if val_loss < min(val_losses):
                best_epoch = epoch
                print(epoch)
                path = model_saving_path
                torch.save(model.state_dict(), '{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, epoch))
        epochs.append(epoch)
        training_losses.append(train_loss)
        training_acc.append(train_acc)
        val_losses.append(val_loss)
        validation_acc.append(val_acc)

        if train_loss < tol:
            break
    plot_loss_acc(training_losses, val_losses, training_acc, validation_acc, model_type)
# Out:
# Train loss for epoch 0: 0.5468421578407288
# Val loss for epoch 0: 0.5211985111236572
# Train loss for epoch 1: 0.5209980607032776
# Val loss for epoch 1: 0.5040707588195801
# 1
# Train loss for epoch 2: 0.5139855742454529
# Val loss for epoch 2: 0.4907415211200714
# 2
# Train loss for epoch 3: 0.5097635984420776
# Val loss for epoch 3: 0.4755452573299408
# 3
# Train loss for epoch 4: 0.5064084529876709
# Val loss for epoch 4: 0.46800002455711365
# 4
# Train loss for epoch 5: 0.5051366090774536
# Val loss for epoch 5: 0.46518751978874207
# 5
# Train loss for epoch 6: 0.5028734803199768
# Val loss for epoch 6: 0.4571511447429657
# 6
# Train loss for epoch 7: 0.5018301606178284
# Val loss for epoch 7: 0.4527896046638489
# 7
# Train loss for epoch 8: 0.5008988976478577
# Val loss for epoch 8: 0.4578162729740143
# Train loss for epoch 9: 0.5001735091209412
# Val loss for epoch 9: 0.45256727933883667
# 9
# Train loss for epoch 10: 0.49989184737205505
# Val loss for epoch 10: 0.45352062582969666
# Train loss for epoch 11: 0.49902141094207764
# Val loss for epoch 11: 0.4547424614429474
# Train loss for epoch 12: 0.4989071786403656
# Val loss for epoch 12: 0.44580739736557007
# 12
# Train loss for epoch 13: 0.4989975392818451
# Val loss for epoch 13: 0.44521141052246094
# 13
# Train loss for epoch 14: 0.4994559586048126
# Val loss for epoch 14: 0.43907836079597473
# 14
# Train loss for epoch 15: 0.4979785680770874
# Val loss for epoch 15: 0.44846662878990173
# Train loss for epoch 16: 0.4981141686439514
# Val loss for epoch 16: 0.45173701643943787
# Train loss for epoch 17: 0.4979393184185028
# Val loss for epoch 17: 0.4484783113002777
# Train loss for epoch 18: 0.49753281474113464
# Val loss for epoch 18: 0.43940940499305725
# Train loss for epoch 19: 0.496757447719574
# Val loss for epoch 19: 0.4509536325931549
# Train loss for epoch 20: 0.496845006942749
# Val loss for epoch 20: 0.4427521526813507
# Train loss for epoch 21: 0.4966559112071991
# Val loss for epoch 21: 0.4408220052719116
# Train loss for epoch 22: 0.4970083236694336
# Val loss for epoch 22: 0.4470387101173401
# Train loss for epoch 23: 0.4965149164199829
# Val loss for epoch 23: 0.44945213198661804
# Train loss for epoch 24: 0.4961179792881012
# Val loss for epoch 24: 0.44874024391174316
# Train loss for epoch 25: 0.4967954158782959
# Val loss for epoch 25: 0.4422858953475952
# Train loss for epoch 26: 0.4963940978050232
# Val loss for epoch 26: 0.44035831093788147
# Train loss for epoch 27: 0.4962230324745178
# Val loss for epoch 27: 0.45182934403419495
# Train loss for epoch 28: 0.4961996078491211
# Val loss for epoch 28: 0.4562942385673523
# Train loss for epoch 29: 0.4959193468093872
# Val loss for epoch 29: 0.44949448108673096
# Train loss for epoch 30: 0.49550315737724304
# Val loss for epoch 30: 0.4401545226573944
# Train loss for epoch 31: 0.495839387178421
# Val loss for epoch 31: 0.437656968832016
# 31
# Train loss for epoch 32: 0.49598050117492676
# Val loss for epoch 32: 0.4518969655036926
# Train loss for epoch 33: 0.495031476020813
# Val loss for epoch 33: 0.44648098945617676
# Train loss for epoch 34: 0.49557772278785706
# Val loss for epoch 34: 0.45280754566192627
# Train loss for epoch 35: 0.49451759457588196
# Val loss for epoch 35: 0.45135557651519775
# Train loss for epoch 36: 0.495008260011673
# Val loss for epoch 36: 0.44705909490585327
# Train loss for epoch 37: 0.4951721131801605
# Val loss for epoch 37: 0.4488299489021301
# Train loss for epoch 38: 0.49467629194259644
# Val loss for epoch 38: 0.43971699476242065
# Train loss for epoch 39: 0.4949514865875244
# Val loss for epoch 39: 0.45055460929870605
# Train loss for epoch 40: 0.49521034955978394
# Val loss for epoch 40: 0.4527570903301239
# Train loss for epoch 41: 0.4945836663246155
# Val loss for epoch 41: 0.4480663537979126
# Train loss for epoch 42: 0.4943040609359741
# Val loss for epoch 42: 0.45024704933166504
# Train loss for epoch 43: 0.49433934688568115
# Val loss for epoch 43: 0.44484519958496094
# Train loss for epoch 44: 0.49375391006469727
# Val loss for epoch 44: 0.4501321315765381
# Train loss for epoch 45: 0.4939712584018707
# Val loss for epoch 45: 0.44257834553718567
# Train loss for epoch 46: 0.4938869774341583
# Val loss for epoch 46: 0.44840914011001587
# Train loss for epoch 47: 0.4949153959751129
# Val loss for epoch 47: 0.45367515087127686
# Train loss for epoch 48: 0.49327582120895386
# Val loss for epoch 48: 0.4503423273563385
# Train loss for epoch 49: 0.4930698871612549
# Val loss for epoch 49: 0.44783124327659607
# Train loss for epoch 50: 0.49424850940704346
# Val loss for epoch 50: 0.44880276918411255
# Train loss for epoch 0: 0.5512533783912659
# Val loss for epoch 0: 0.5350548624992371
# Train loss for epoch 1: 0.5240875482559204
# Val loss for epoch 1: 0.5186637043952942
# 1
# Train loss for epoch 2: 0.5166817903518677
# Val loss for epoch 2: 0.4967309236526489
# 2
# Train loss for epoch 3: 0.5117945075035095
# Val loss for epoch 3: 0.47894713282585144
# 3
# Train loss for epoch 4: 0.5083206295967102
# Val loss for epoch 4: 0.49028804898262024
# Train loss for epoch 5: 0.5058724880218506
# Val loss for epoch 5: 0.469216912984848
# 5
# Train loss for epoch 6: 0.5039342641830444
# Val loss for epoch 6: 0.46633684635162354
# 6
# Train loss for epoch 7: 0.5020054578781128
# Val loss for epoch 7: 0.45986753702163696
# 7
# Train loss for epoch 8: 0.5016250610351562
# Val loss for epoch 8: 0.45646077394485474
# 8
# Train loss for epoch 9: 0.500674843788147
# Val loss for epoch 9: 0.4507875144481659
# 9
# Train loss for epoch 10: 0.4997946619987488
# Val loss for epoch 10: 0.45074814558029175
# 10
# Train loss for epoch 11: 0.4999079704284668
# Val loss for epoch 11: 0.44951093196868896
# 11
# Train loss for epoch 12: 0.49889829754829407
# Val loss for epoch 12: 0.4448528289794922
# 12
# Train loss for epoch 13: 0.4984405040740967
# Val loss for epoch 13: 0.45794302225112915
# Train loss for epoch 14: 0.4987906813621521
# Val loss for epoch 14: 0.444827675819397
# 14
# Train loss for epoch 15: 0.4983014762401581
# Val loss for epoch 15: 0.44778770208358765
# Train loss for epoch 16: 0.4976511299610138
# Val loss for epoch 16: 0.4426237940788269
# 16
# Train loss for epoch 17: 0.49788954854011536
# Val loss for epoch 17: 0.4496886432170868
# Train loss for epoch 18: 0.4973827600479126
# Val loss for epoch 18: 0.45348426699638367
# Train loss for epoch 19: 0.49726614356040955
# Val loss for epoch 19: 0.45221418142318726
# Train loss for epoch 20: 0.4965716600418091
# Val loss for epoch 20: 0.44286656379699707
# Train loss for epoch 21: 0.49698755145072937
# Val loss for epoch 21: 0.45035627484321594
# Train loss for epoch 22: 0.49616074562072754
# Val loss for epoch 22: 0.4459104537963867
# Train loss for epoch 23: 0.49677762389183044
# Val loss for epoch 23: 0.44512104988098145
# Train loss for epoch 24: 0.4964262545108795
# Val loss for epoch 24: 0.4417153000831604
# 24
# Train loss for epoch 25: 0.4958499073982239
# Val loss for epoch 25: 0.44163063168525696
# 25
# Train loss for epoch 26: 0.49636971950531006
# Val loss for epoch 26: 0.44427070021629333
# Train loss for epoch 27: 0.4957260489463806
# Val loss for epoch 27: 0.44481122493743896
# Train loss for epoch 28: 0.4966091811656952
# Val loss for epoch 28: 0.45855969190597534
# Train loss for epoch 29: 0.49511441588401794
# Val loss for epoch 29: 0.43985822796821594
# 29
# Train loss for epoch 30: 0.49607327580451965
# Val loss for epoch 30: 0.4544481933116913
# Train loss for epoch 31: 0.4955287277698517
# Val loss for epoch 31: 0.4518147110939026
# Train loss for epoch 32: 0.4947473108768463
# Val loss for epoch 32: 0.4510118365287781
# Train loss for epoch 33: 0.4958244562149048
# Val loss for epoch 33: 0.4436035454273224
# Train loss for epoch 34: 0.4954491853713989
# Val loss for epoch 34: 0.4427209198474884
# Train loss for epoch 35: 0.4945339262485504
# Val loss for epoch 35: 0.4461635947227478
# Train loss for epoch 36: 0.4944610595703125
# Val loss for epoch 36: 0.44517040252685547
# Train loss for epoch 37: 0.49498501420021057
# Val loss for epoch 37: 0.4436171352863312
# Train loss for epoch 38: 0.4946507215499878
# Val loss for epoch 38: 0.4547879099845886
# Train loss for epoch 39: 0.49511489272117615
# Val loss for epoch 39: 0.4457565248012543
# Train loss for epoch 40: 0.49384623765945435
# Val loss for epoch 40: 0.4529581069946289
# Train loss for epoch 41: 0.4954527020454407
# Val loss for epoch 41: 0.45774248242378235
# Train loss for epoch 42: 0.49447160959243774
# Val loss for epoch 42: 0.4479750990867615
# Train loss for epoch 43: 0.4941243827342987
# Val loss for epoch 43: 0.4558202922344208
# Train loss for epoch 44: 0.49408382177352905
# Val loss for epoch 44: 0.44789665937423706
# Train loss for epoch 45: 0.4942129850387573
# Val loss for epoch 45: 0.4468531310558319
# Train loss for epoch 46: 0.4936503767967224
# Val loss for epoch 46: 0.44688355922698975
# Train loss for epoch 47: 0.49398428201675415
# Val loss for epoch 47: 0.45204976201057434
# Train loss for epoch 48: 0.49351564049720764
# Val loss for epoch 48: 0.4435546100139618
# Train loss for epoch 49: 0.49354052543640137
# Val loss for epoch 49: 0.45195290446281433
# Train loss for epoch 50: 0.49377021193504333
# Val loss for epoch 50: 0.44279032945632935
# Train loss for epoch 0: 0.5519995093345642
# Val loss for epoch 0: 0.532158374786377
# Train loss for epoch 1: 0.5244548320770264
# Val loss for epoch 1: 0.5068095326423645
# 1
# Train loss for epoch 2: 0.5169021487236023
# Val loss for epoch 2: 0.5002050399780273
# 2
# Train loss for epoch 3: 0.5121719837188721
# Val loss for epoch 3: 0.49379274249076843
# 3
# Train loss for epoch 4: 0.5081307888031006
# Val loss for epoch 4: 0.4752594530582428
# 4
# Train loss for epoch 5: 0.5053982734680176
# Val loss for epoch 5: 0.4779472053050995
# Train loss for epoch 6: 0.5037462115287781
# Val loss for epoch 6: 0.4601462185382843
# 6
# Train loss for epoch 7: 0.5019757151603699
# Val loss for epoch 7: 0.46866142749786377
# Train loss for epoch 8: 0.5015802979469299
# Val loss for epoch 8: 0.4568007290363312
# 8
# Train loss for epoch 9: 0.5000607371330261
# Val loss for epoch 9: 0.4543083608150482
# 9
# Train loss for epoch 10: 0.5002661943435669
# Val loss for epoch 10: 0.4598041772842407
# Train loss for epoch 11: 0.4999646842479706
# Val loss for epoch 11: 0.44624826312065125
# 11
# Train loss for epoch 12: 0.4990781545639038
# Val loss for epoch 12: 0.4446099102497101
# 12
# Train loss for epoch 13: 0.49868810176849365
# Val loss for epoch 13: 0.4471694231033325
# Train loss for epoch 14: 0.4994685649871826
# Val loss for epoch 14: 0.44617342948913574
# Train loss for epoch 15: 0.49858635663986206
# Val loss for epoch 15: 0.4465106129646301
# Train loss for epoch 16: 0.4981740713119507
# Val loss for epoch 16: 0.4477577805519104
# Train loss for epoch 17: 0.4973718523979187
# Val loss for epoch 17: 0.4543129503726959
# Train loss for epoch 18: 0.4971241354942322
# Val loss for epoch 18: 0.43920350074768066
# 18
# Train loss for epoch 19: 0.4967193305492401
# Val loss for epoch 19: 0.4478788673877716
# Train loss for epoch 20: 0.4969843029975891
# Val loss for epoch 20: 0.45532289147377014
# Train loss for epoch 21: 0.4970129430294037
# Val loss for epoch 21: 0.44221246242523193
# Train loss for epoch 22: 0.496337890625
# Val loss for epoch 22: 0.44418865442276
# Train loss for epoch 23: 0.496936172246933
# Val loss for epoch 23: 0.4424830973148346
# Train loss for epoch 24: 0.4968145191669464
# Val loss for epoch 24: 0.45086389780044556
# Train loss for epoch 25: 0.49647220969200134
# Val loss for epoch 25: 0.4541865885257721
# Train loss for epoch 26: 0.4961105287075043
# Val loss for epoch 26: 0.4494382441043854
# Train loss for epoch 27: 0.4963351786136627
# Val loss for epoch 27: 0.45667412877082825
# Train loss for epoch 28: 0.49559664726257324
# Val loss for epoch 28: 0.4452039897441864
# Train loss for epoch 29: 0.49525800347328186
# Val loss for epoch 29: 0.44351956248283386
# Train loss for epoch 30: 0.49572187662124634
# Val loss for epoch 30: 0.4523337483406067
# Train loss for epoch 31: 0.4954172670841217
# Val loss for epoch 31: 0.4517046809196472
# Train loss for epoch 32: 0.4950346052646637
# Val loss for epoch 32: 0.4500907063484192
# Train loss for epoch 33: 0.4952012002468109
# Val loss for epoch 33: 0.4432717263698578
# Train loss for epoch 34: 0.49458885192871094
# Val loss for epoch 34: 0.4453887343406677
# Train loss for epoch 35: 0.4944011867046356
# Val loss for epoch 35: 0.461285263299942
# Train loss for epoch 36: 0.49465352296829224
# Val loss for epoch 36: 0.44690749049186707
# Train loss for epoch 37: 0.494536429643631
# Val loss for epoch 37: 0.44717007875442505
# Train loss for epoch 38: 0.4950466454029083
# Val loss for epoch 38: 0.45018938183784485
# Train loss for epoch 39: 0.4940452575683594
# Val loss for epoch 39: 0.4410547614097595
# Train loss for epoch 40: 0.49480560421943665
# Val loss for epoch 40: 0.4484756588935852
# Train loss for epoch 41: 0.49434491991996765
# Val loss for epoch 41: 0.4512192904949188
# Train loss for epoch 42: 0.49423524737358093
# Val loss for epoch 42: 0.44882461428642273
# Train loss for epoch 43: 0.49392378330230713
# Val loss for epoch 43: 0.44461843371391296
# Train loss for epoch 44: 0.4942525029182434
# Val loss for epoch 44: 0.45194870233535767
# Train loss for epoch 45: 0.49408861994743347
# Val loss for epoch 45: 0.4460468292236328
# Train loss for epoch 46: 0.49377140402793884
# Val loss for epoch 46: 0.4444205164909363
# Train loss for epoch 47: 0.4936287999153137
# Val loss for epoch 47: 0.4515187740325928
# Train loss for epoch 48: 0.4934937357902527
# Val loss for epoch 48: 0.44208765029907227
# Train loss for epoch 49: 0.49355548620224
# Val loss for epoch 49: 0.45061445236206055
# Train loss for epoch 50: 0.4933374524116516
# Val loss for epoch 50: 0.4596429169178009

# %%
alpha
# Out:
# 100

# %%
model_LR = os.listdir(model_saving_path)
results = []
for alpha in alphas:
    epoch_results = []
    reg_alpha = 'REG'+reg_type+str(alpha)+'_'
    for i, s in enumerate(model_LR):
        if '_CH23_' in s and reg_alpha in s:
            model_name = model_LR[i].split('_')
            epoch_name = [ind for ind,item in enumerate(np.array(model_name)) if "EPOCH" in item]
            res = [int(i) for i in model_name[epoch_name[0]] if i.isdigit()]
            if len(res) > 1:
                epoch_result = res[0]*10+res[1]
            else:
                epoch_result = res[0]
            epoch_results.append(epoch_result)
            
    results.append([alpha, max(epoch_results)])
    
results = pd.DataFrame(np.array(results), columns=['alpha', 'epoch'])
best_results = results.groupby('alpha').max('epoch')
print(best_results)
# Out:
#        epoch
# alpha
# 1         31
# 50        39
# 100       31

# %%
for i,(index,row) in enumerate(best_results.iterrows()):
    
    path = model_saving_path
    best_epoch = int(row)
    alpha = index
    
    
    # load best model
    model = GLM(input_dim=100*timewindow).to(device)
    path = model_saving_path
    optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)
    model.load_state_dict(torch.load('{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, best_epoch)))
    
    print('{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, best_epoch))

    ## Show one feature
    weights = model.linear.weight.view(100, timewindow)
    weights_sub = weights.detach().cpu()
    plt.axis('off')
    plt.imshow(weights_sub)
    plt.title(str(CH))
    # plt.clim(-0.03, 0.03)
    plt.show()
    
    ## Calculate accuracy and validation loss
    val_loss, val_acc, val_preds, val_preds_probs, val_labels,_,_,_, cases_wrong_1 = evaluate(model, optimizer, val_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=True, device=device)
    print('validation loss:{} accuracy:{}'.format(val_loss, val_acc))
    print(np.mean(np.concatenate(val_labels)))
    
    
    ## Wrong Classifications
    path_wrong = '/mnt/pesaranlab/People/Capstone_students/Yue/wrong_pred'
    pickle.dump(cases_wrong_1, open('{}/{}_CH{}_LOSS{}_REG{}{}.pt'.format(path_wrong, model_type, CH, loss_type, reg_type, alpha), 'wb'))
    idx = 0
    print('date:{}, rec:{}, time:{}, label:{}'.format(cases_wrong_1[0][0], cases_wrong_1[0][1], cases_wrong_1[0][2], cases_wrong_1[0][3]))
    print('Original data 62 CH')
    weights_sub = cases_wrong_1[0][-1][0]
    plt.axis('off')
    plt.imshow(weights_sub)
    # plt.clim(-0.03, 0.03)
    plt.show()
    
    ## Confusion matrix
    predictions_val = np.concatenate(val_preds)
    labels_val = np.concatenate(val_labels)

    df_val = pd.DataFrame({'predictions': predictions_val, 'labels': labels_val})

    cm_val = confusion_matrix(labels_val, predictions_val)
    ax = plt.axes()
    group_names = ['True Neg','False Pos','False Neg','True Pos']
    group_counts = ["{0:0.0f}".format(value) for value in
                    cm_val.flatten()]

    TNR = int(group_counts[0]) / (int(group_counts[0])+int(group_counts[1]))
    FPR = 1 - TNR
    TPR = int(group_counts[3]) / (int(group_counts[3])+int(group_counts[2]))
    FNR = 1-TPR
    group_percentages =[TNR, FPR, FNR, TPR]

    group_percentages = ["{0:.2%}".format(value) for value in
                         group_percentages]
    labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
              zip(group_names,group_counts,group_percentages)]
    labels = np.asarray(labels).reshape(2,2)
    sn.heatmap(cm_val, annot=labels, fmt='', center = 2000)
    ax.set_title('Validation Confusion Matrix')
    ax.set_xlabel('Predicted Label')
    ax.set_ylabel('True Label')
    plt.show()
# Out:
# /home/bijanadmin/Desktop/Goose_data/data_Goose_1st_5s_2/LR_models/LR_CH23_LOSSbce_REGnone1_EPOCH31.pt
# validation loss:0.437656968832016 accuracy:0.8006329113924051
# 0.7787824
# date:180329, rec:001, time:4703.0, label:1.0
# Original data 62 CH
# /home/bijanadmin/Desktop/Goose_data/data_Goose_1st_5s_2/LR_models/LR_CH23_LOSSbce_REGnone50_EPOCH39.pt
# validation loss:0.43152517080307007 accuracy:0.8028179626280892
# 0.7787824
# date:180329, rec:004, time:6251.0, label:1.0
# Original data 62 CH
# /home/bijanadmin/Desktop/Goose_data/data_Goose_1st_5s_2/LR_models/LR_CH23_LOSSbce_REGnone100_EPOCH31.pt
# validation loss:0.43903785943984985 accuracy:0.8056057866184448
# 0.7787824
# date:180329, rec:005, time:1527.0, label:1.0
# Original data 62 CH

# %% [markdown]
# ### Logistic regression with L2 regularization

# %%
device = torch.device('cuda')

tol = 0.01
learning_rate = 0.001
num_epochs = 51
alphas = [1,50,100]
model_type = 'LR'
loss_type = 'bce'
reg_type = 'l2'
timewindow = 5

# %%
for alpha in alphas:
    model = GLM(input_dim=100*timewindow).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)
    epochs, training_losses, training_acc, val_losses, validation_acc = [], [], [], [], []

    for epoch in range(num_epochs):
        train_loss, train_acc = train(model, optimizer, train_loader, timewindow = timewindow, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
        print('Train loss for epoch {}: {}'.format(epoch, train_loss))
        val_loss, val_acc = evaluate(model, optimizer, val_loader, alpha=alpha, timewindow = timewindow, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
        print('Val loss for epoch {}: {}'.format(epoch, val_loss))
        if val_losses:
            if val_loss < min(val_losses):
                best_epoch = epoch
                print(epoch)
                path = model_saving_path
                torch.save(model.state_dict(), '{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, epoch))
        epochs.append(epoch)
        training_losses.append(train_loss)
        training_acc.append(train_acc)
        val_losses.append(val_loss)
        validation_acc.append(val_acc)

        if train_loss < tol:
            break
    plot_loss_acc(training_losses, val_losses, training_acc, validation_acc, model_type)
# Out:
# Train loss for epoch 0: 0.5506401658058167
# Val loss for epoch 0: 0.5369616150856018
# Train loss for epoch 1: 0.5252757668495178
# Val loss for epoch 1: 0.5146918296813965
# 1
# Train loss for epoch 2: 0.5200588703155518
# Val loss for epoch 2: 0.49397021532058716
# 2
# Train loss for epoch 3: 0.5134511590003967
# Val loss for epoch 3: 0.4905494749546051
# 3
# Train loss for epoch 4: 0.5106613039970398
# Val loss for epoch 4: 0.4833867847919464
# 4
# Train loss for epoch 5: 0.5084254145622253
# Val loss for epoch 5: 0.4712044894695282
# 5
# Train loss for epoch 6: 0.5070433020591736
# Val loss for epoch 6: 0.4746645987033844
# Train loss for epoch 7: 0.5054364800453186
# Val loss for epoch 7: 0.46611487865448
# 7
# Train loss for epoch 8: 0.5049983859062195
# Val loss for epoch 8: 0.4584169089794159
# 8
# Train loss for epoch 9: 0.5047644376754761
# Val loss for epoch 9: 0.4496976137161255
# 9
# Train loss for epoch 10: 0.5039312243461609
# Val loss for epoch 10: 0.4471634328365326
# 10
# Train loss for epoch 11: 0.5039981007575989
# Val loss for epoch 11: 0.44834089279174805
# Train loss for epoch 12: 0.5037873387336731
# Val loss for epoch 12: 0.46026578545570374
# Train loss for epoch 13: 0.5038571357727051
# Val loss for epoch 13: 0.44663751125335693
# 13
# Train loss for epoch 14: 0.5029687881469727
# Val loss for epoch 14: 0.452656090259552
# Train loss for epoch 15: 0.5032775402069092
# Val loss for epoch 15: 0.44517287611961365
# 15
# Train loss for epoch 16: 0.5032514333724976
# Val loss for epoch 16: 0.4484844207763672
# Train loss for epoch 17: 0.5029231309890747
# Val loss for epoch 17: 0.44509366154670715
# 17
# Train loss for epoch 18: 0.503893256187439
# Val loss for epoch 18: 0.44696569442749023
# Train loss for epoch 19: 0.5027202367782593
# Val loss for epoch 19: 0.4551713466644287
# Train loss for epoch 20: 0.5022247433662415
# Val loss for epoch 20: 0.4645967483520508
# Train loss for epoch 21: 0.5040192008018494
# Val loss for epoch 21: 0.44309136271476746
# 21
# Train loss for epoch 22: 0.502817690372467
# Val loss for epoch 22: 0.448544979095459
# Train loss for epoch 23: 0.5028436183929443
# Val loss for epoch 23: 0.46219122409820557
# Train loss for epoch 24: 0.5023527145385742
# Val loss for epoch 24: 0.4468851089477539
# Train loss for epoch 25: 0.5019762516021729
# Val loss for epoch 25: 0.4527817368507385
# Train loss for epoch 26: 0.50171959400177
# Val loss for epoch 26: 0.4484906792640686
# Train loss for epoch 27: 0.5025540590286255
# Val loss for epoch 27: 0.4450457692146301
# Train loss for epoch 28: 0.502720296382904
# Val loss for epoch 28: 0.4502789378166199
# Train loss for epoch 29: 0.5026602745056152
# Val loss for epoch 29: 0.45373770594596863
# Train loss for epoch 30: 0.5019877552986145
# Val loss for epoch 30: 0.43897584080696106
# 30
# Train loss for epoch 31: 0.5021560192108154
# Val loss for epoch 31: 0.44737768173217773
# Train loss for epoch 32: 0.5031779408454895
# Val loss for epoch 32: 0.4475935995578766
# Train loss for epoch 33: 0.5018044710159302
# Val loss for epoch 33: 0.4650954306125641
# Train loss for epoch 34: 0.5016591548919678
# Val loss for epoch 34: 0.45610862970352173
# Train loss for epoch 35: 0.501831591129303
# Val loss for epoch 35: 0.44865795969963074
# Train loss for epoch 36: 0.5021838545799255
# Val loss for epoch 36: 0.4516535997390747
# Train loss for epoch 37: 0.5025718212127686
# Val loss for epoch 37: 0.4531407058238983
# Train loss for epoch 38: 0.5020380020141602
# Val loss for epoch 38: 0.44970858097076416
# Train loss for epoch 39: 0.5020531415939331
# Val loss for epoch 39: 0.4517541825771332
# Train loss for epoch 40: 0.5011666417121887
# Val loss for epoch 40: 0.4527406096458435
# Train loss for epoch 41: 0.5018887519836426
# Val loss for epoch 41: 0.4598548412322998
# Train loss for epoch 42: 0.501895010471344
# Val loss for epoch 42: 0.4519025683403015
# Train loss for epoch 43: 0.5018870234489441
# Val loss for epoch 43: 0.46175888180732727
# Train loss for epoch 44: 0.5029424428939819
# Val loss for epoch 44: 0.4481019377708435
# Train loss for epoch 45: 0.5025327801704407
# Val loss for epoch 45: 0.45071354508399963
# Train loss for epoch 46: 0.502019464969635
# Val loss for epoch 46: 0.4579683244228363
# Train loss for epoch 47: 0.5019580125808716
# Val loss for epoch 47: 0.4411701261997223
# Train loss for epoch 48: 0.5023692846298218
# Val loss for epoch 48: 0.44927310943603516
# Train loss for epoch 49: 0.5019289255142212
# Val loss for epoch 49: 0.45815181732177734
# Train loss for epoch 50: 0.5015632510185242
# Val loss for epoch 50: 0.46199581027030945
# Train loss for epoch 0: 0.6274186968803406
# Val loss for epoch 0: 0.577853798866272
# Train loss for epoch 1: 0.5915736556053162
# Val loss for epoch 1: 0.5638038516044617
# 1
# Train loss for epoch 2: 0.5882057547569275
# Val loss for epoch 2: 0.5452870726585388
# 2
# Train loss for epoch 3: 0.5868346095085144
# Val loss for epoch 3: 0.542874813079834
# 3
# Train loss for epoch 4: 0.5856619477272034
# Val loss for epoch 4: 0.5263060331344604
# 4
# Train loss for epoch 5: 0.58458012342453
# Val loss for epoch 5: 0.5193871855735779
# 5
# Train loss for epoch 6: 0.5843930840492249
# Val loss for epoch 6: 0.5210751891136169
# Train loss for epoch 7: 0.5844032764434814
# Val loss for epoch 7: 0.5298248529434204
# Train loss for epoch 8: 0.5847840309143066
# Val loss for epoch 8: 0.5287037491798401
# Train loss for epoch 9: 0.5844423174858093
# Val loss for epoch 9: 0.5185851454734802
# 9
# Train loss for epoch 10: 0.5845333933830261
# Val loss for epoch 10: 0.5247235894203186
# Train loss for epoch 11: 0.5852275490760803
# Val loss for epoch 11: 0.5100040435791016
# 11
# Train loss for epoch 12: 0.5853967666625977
# Val loss for epoch 12: 0.5239349603652954
# Train loss for epoch 13: 0.5842030048370361
# Val loss for epoch 13: 0.5069338083267212
# 13
# Train loss for epoch 14: 0.5844797492027283
# Val loss for epoch 14: 0.525866687297821
# Train loss for epoch 15: 0.5846866965293884
# Val loss for epoch 15: 0.52000892162323
# Train loss for epoch 16: 0.5848329067230225
# Val loss for epoch 16: 0.51935213804245
# Train loss for epoch 17: 0.5848432183265686
# Val loss for epoch 17: 0.5143771767616272
# Train loss for epoch 18: 0.5844399929046631
# Val loss for epoch 18: 0.5132216811180115
# Train loss for epoch 19: 0.5849559903144836
# Val loss for epoch 19: 0.5201185941696167
# Train loss for epoch 20: 0.5853883028030396
# Val loss for epoch 20: 0.519561767578125
# Train loss for epoch 21: 0.5843293070793152
# Val loss for epoch 21: 0.5179891586303711
# Train loss for epoch 22: 0.5845268368721008
# Val loss for epoch 22: 0.5084996223449707
# Train loss for epoch 23: 0.5851912498474121
# Val loss for epoch 23: 0.5214869976043701
# Train loss for epoch 24: 0.5845066905021667
# Val loss for epoch 24: 0.5156294703483582
# Train loss for epoch 25: 0.5841782689094543
# Val loss for epoch 25: 0.5219231843948364
# Train loss for epoch 26: 0.5841151475906372
# Val loss for epoch 26: 0.510723352432251
# Train loss for epoch 27: 0.5847336649894714
# Val loss for epoch 27: 0.51361083984375
# Train loss for epoch 28: 0.584174394607544
# Val loss for epoch 28: 0.5153133273124695
# Train loss for epoch 29: 0.5846684575080872
# Val loss for epoch 29: 0.5208417177200317
# Train loss for epoch 30: 0.5842965245246887
# Val loss for epoch 30: 0.521773636341095
# Train loss for epoch 31: 0.584469199180603
# Val loss for epoch 31: 0.5128358602523804
# Train loss for epoch 32: 0.5842093229293823
# Val loss for epoch 32: 0.5304564833641052
# Train loss for epoch 33: 0.584457278251648
# Val loss for epoch 33: 0.5164681077003479
# Train loss for epoch 34: 0.5843112468719482
# Val loss for epoch 34: 0.5146772861480713
# Train loss for epoch 35: 0.5846026539802551
# Val loss for epoch 35: 0.5152304768562317
# Train loss for epoch 36: 0.5842603445053101
# Val loss for epoch 36: 0.5162512063980103
# Train loss for epoch 37: 0.5846982598304749
# Val loss for epoch 37: 0.5242282152175903
# Train loss for epoch 38: 0.5842145681381226
# Val loss for epoch 38: 0.5135982036590576
# Train loss for epoch 39: 0.5845019817352295
# Val loss for epoch 39: 0.526749312877655
# Train loss for epoch 40: 0.5844965577125549
# Val loss for epoch 40: 0.5325878858566284
# Train loss for epoch 41: 0.5845103859901428
# Val loss for epoch 41: 0.5130806565284729
# Train loss for epoch 42: 0.5845746994018555
# Val loss for epoch 42: 0.5220499634742737
# Train loss for epoch 43: 0.5842835307121277
# Val loss for epoch 43: 0.5178915858268738
# Train loss for epoch 44: 0.5840144753456116
# Val loss for epoch 44: 0.5179662704467773
# Train loss for epoch 45: 0.5850214958190918
# Val loss for epoch 45: 0.5139448642730713
# Train loss for epoch 46: 0.5847684741020203
# Val loss for epoch 46: 0.5176690816879272
# Train loss for epoch 47: 0.5840551257133484
# Val loss for epoch 47: 0.5215404629707336
# Train loss for epoch 48: 0.5854823589324951
# Val loss for epoch 48: 0.517821729183197
# Train loss for epoch 49: 0.5841735005378723
# Val loss for epoch 49: 0.518549382686615
# Train loss for epoch 50: 0.584151566028595
# Val loss for epoch 50: 0.5143293738365173
# Train loss for epoch 0: 0.6785528659820557
# Val loss for epoch 0: 0.6192858219146729
# Train loss for epoch 1: 0.6257746815681458
# Val loss for epoch 1: 0.593034029006958
# 1
# Train loss for epoch 2: 0.6231237053871155
# Val loss for epoch 2: 0.5836453437805176
# 2
# Train loss for epoch 3: 0.6221792697906494
# Val loss for epoch 3: 0.5740019679069519
# 3
# Train loss for epoch 4: 0.6220683455467224
# Val loss for epoch 4: 0.5666659474372864
# 4
# Train loss for epoch 5: 0.6216058135032654
# Val loss for epoch 5: 0.5726600289344788
# Train loss for epoch 6: 0.6223049163818359
# Val loss for epoch 6: 0.5675515532493591
# Train loss for epoch 7: 0.6218133568763733
# Val loss for epoch 7: 0.570559561252594
# Train loss for epoch 8: 0.622876763343811
# Val loss for epoch 8: 0.5737013816833496
# Train loss for epoch 9: 0.6222266554832458
# Val loss for epoch 9: 0.5709583163261414
# Train loss for epoch 10: 0.6225748658180237
# Val loss for epoch 10: 0.5623947381973267
# 10
# Train loss for epoch 11: 0.6221433877944946
# Val loss for epoch 11: 0.5574917793273926
# 11
# Train loss for epoch 12: 0.6223538517951965
# Val loss for epoch 12: 0.564349889755249
# Train loss for epoch 13: 0.6217858195304871
# Val loss for epoch 13: 0.5530118346214294
# 13
# Train loss for epoch 14: 0.6218879818916321
# Val loss for epoch 14: 0.553913414478302
# Train loss for epoch 15: 0.6226662993431091
# Val loss for epoch 15: 0.5633276104927063
# Train loss for epoch 16: 0.622313916683197
# Val loss for epoch 16: 0.5787985324859619
# Train loss for epoch 17: 0.6217484474182129
# Val loss for epoch 17: 0.5578696131706238
# Train loss for epoch 18: 0.6218147277832031
# Val loss for epoch 18: 0.5592473149299622
# Train loss for epoch 19: 0.6223987340927124
# Val loss for epoch 19: 0.5609581470489502
# Train loss for epoch 20: 0.6221651434898376
# Val loss for epoch 20: 0.5600940585136414
# Train loss for epoch 21: 0.6221341490745544
# Val loss for epoch 21: 0.5684295892715454
# Train loss for epoch 22: 0.622157096862793
# Val loss for epoch 22: 0.5524807572364807
# 22
# Train loss for epoch 23: 0.6217180490493774
# Val loss for epoch 23: 0.5680680871009827
# Train loss for epoch 24: 0.6217194199562073
# Val loss for epoch 24: 0.5601586699485779
# Train loss for epoch 25: 0.6214709877967834
# Val loss for epoch 25: 0.5547398328781128
# Train loss for epoch 26: 0.6218155026435852
# Val loss for epoch 26: 0.561136782169342
# Train loss for epoch 27: 0.6218265295028687
# Val loss for epoch 27: 0.5686991214752197
# Train loss for epoch 28: 0.6227171421051025
# Val loss for epoch 28: 0.5597770810127258
# Train loss for epoch 29: 0.6218219995498657
# Val loss for epoch 29: 0.5668236613273621
# Train loss for epoch 30: 0.6219305992126465
# Val loss for epoch 30: 0.5695489048957825
# Train loss for epoch 31: 0.622032105922699
# Val loss for epoch 31: 0.5606417655944824
# Train loss for epoch 32: 0.6222462058067322
# Val loss for epoch 32: 0.5571433305740356
# Train loss for epoch 33: 0.6214994192123413
# Val loss for epoch 33: 0.5634409189224243
# Train loss for epoch 34: 0.6235621571540833
# Val loss for epoch 34: 0.5595755577087402
# Train loss for epoch 35: 0.6214313507080078
# Val loss for epoch 35: 0.5671814680099487
# Train loss for epoch 36: 0.6227524876594543
# Val loss for epoch 36: 0.5749786496162415
# Train loss for epoch 37: 0.6217761635780334
# Val loss for epoch 37: 0.5617974996566772
# Train loss for epoch 38: 0.6221785545349121
# Val loss for epoch 38: 0.5640240907669067
# Train loss for epoch 39: 0.622643232345581
# Val loss for epoch 39: 0.5636721849441528
# Train loss for epoch 40: 0.6217213869094849
# Val loss for epoch 40: 0.559840202331543
# Train loss for epoch 41: 0.6226597428321838
# Val loss for epoch 41: 0.570046067237854
# Train loss for epoch 42: 0.6216952204704285
# Val loss for epoch 42: 0.5766826868057251
# Train loss for epoch 43: 0.6226690411567688
# Val loss for epoch 43: 0.5698403120040894
# Train loss for epoch 44: 0.6218995451927185
# Val loss for epoch 44: 0.5548609495162964
# Train loss for epoch 45: 0.6216498017311096
# Val loss for epoch 45: 0.5659963488578796
# Train loss for epoch 46: 0.6218835115432739
# Val loss for epoch 46: 0.5625658631324768
# Train loss for epoch 47: 0.6212621927261353
# Val loss for epoch 47: 0.5623223185539246
# Train loss for epoch 48: 0.6221531629562378
# Val loss for epoch 48: 0.5567602515220642
# Train loss for epoch 49: 0.6228204965591431
# Val loss for epoch 49: 0.5725927948951721
# Train loss for epoch 50: 0.621974527835846
# Val loss for epoch 50: 0.5603194236755371

# %%
model_LR = os.listdir(model_saving_path)
results = []
for alpha in alphas:
    epoch_results = []
    reg_alpha = 'REG'+reg_type+str(alpha)+'_'
    for i, s in enumerate(model_LR):
        if '_CH23_' in s and reg_alpha in s:
            model_name = model_LR[i].split('_')
            epoch_name = [ind for ind,item in enumerate(np.array(model_name)) if "EPOCH" in item]
            res = [int(i) for i in model_name[epoch_name[0]] if i.isdigit()]
            if len(res) > 1:
                epoch_result = res[0]*10+res[1]
            else:
                epoch_result = res[0]
            epoch_results.append(epoch_result)
            
    results.append([alpha, max(epoch_results)])
    
results = pd.DataFrame(np.array(results), columns=['alpha', 'epoch'])
best_results = results.groupby('alpha').max('epoch')
print(best_results)
# Out:
#        epoch
# alpha
# 1         46
# 50        13
# 100       22

# %%
for i,(index,row) in enumerate(best_results.iterrows()):
    
    path = model_saving_path
    best_epoch = int(row)
    alpha = index
    
    
    # load best model
    model = GLM(input_dim=100*timewindow).to(device)
    path = model_saving_path
    optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)
    model.load_state_dict(torch.load('{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, best_epoch)))
    
    print('{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, best_epoch))

    ## Show one feature
    weights = model.linear.weight.view(100, timewindow)
    weights_sub = weights.detach().cpu()
    plt.axis('off')
    plt.imshow(weights_sub)
    plt.title(str(CH))
    # plt.clim(-0.03, 0.03)
    plt.show()
    
    ## Calculate accuracy and validation loss
    val_loss, val_acc, val_preds, val_preds_probs, val_labels,_,_,_, cases_wrong_1 = evaluate(model, optimizer, val_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=True, device=device, timewindow = timewindow)
    print('validation loss:{} accuracy:{}'.format(val_loss, val_acc))
    print(np.mean(np.concatenate(val_labels)))
    
    
    ## Wrong Classifications
    path_wrong = '/mnt/pesaranlab/People/Capstone_students/Yue/wrong_pred'
    pickle.dump(cases_wrong_1, open('{}/{}_CH{}_LOSS{}_REG{}{}.pt'.format(path_wrong, model_type, CH, loss_type, reg_type, alpha), 'wb'))
    idx = 0
    print('date:{}, rec:{}, time:{}, label:{}'.format(cases_wrong_1[0][0], cases_wrong_1[0][1], cases_wrong_1[0][2], cases_wrong_1[0][3]))
    print('Original data 62 CH')
    weights_sub = cases_wrong_1[0][-1][0]
    plt.axis('off')
    plt.imshow(weights_sub)
    # plt.clim(-0.03, 0.03)
    plt.show()
    
    ## Confusion matrix
    predictions_val = np.concatenate(val_preds)
    labels_val = np.concatenate(val_labels)

    df_val = pd.DataFrame({'predictions': predictions_val, 'labels': labels_val})

    cm_val = confusion_matrix(labels_val, predictions_val)
    ax = plt.axes()
    group_names = ['True Neg','False Pos','False Neg','True Pos']
    group_counts = ["{0:0.0f}".format(value) for value in
                    cm_val.flatten()]

    TNR = int(group_counts[0]) / (int(group_counts[0])+int(group_counts[1]))
    FPR = 1 - TNR
    TPR = int(group_counts[3]) / (int(group_counts[3])+int(group_counts[2]))
    FNR = 1-TPR
    group_percentages =[TNR, FPR, FNR, TPR]

    group_percentages = ["{0:.2%}".format(value) for value in
                         group_percentages]
    labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
              zip(group_names,group_counts,group_percentages)]
    labels = np.asarray(labels).reshape(2,2)
    sn.heatmap(cm_val, annot=labels, fmt='', center = 2000)
    ax.set_title('Validation Confusion Matrix')
    ax.set_xlabel('Predicted Label')
    ax.set_ylabel('True Label')
    plt.show()
# Out:
# /home/bijanadmin/Desktop/Goose_data/data_Goose_1st_5s_2/LR_models/LR_CH23_LOSSbce_REGl21_EPOCH46.pt
# validation loss:0.4341197609901428 accuracy:0.8117842073538276
# 0.7787824
# date:180329, rec:004, time:6251.0, label:1.0
# Original data 62 CH
# /home/bijanadmin/Desktop/Goose_data/data_Goose_1st_5s_2/LR_models/LR_CH23_LOSSbce_REGl250_EPOCH13.pt
# validation loss:0.5069338083267212 accuracy:0.8069620253164557
# 0.7787824
# date:180329, rec:002, time:4807.0, label:1.0
# Original data 62 CH
# /home/bijanadmin/Desktop/Goose_data/data_Goose_1st_5s_2/LR_models/LR_CH23_LOSSbce_REGl2100_EPOCH22.pt
# validation loss:0.5524807572364807 accuracy:0.8165310427968656
# 0.7787824
# date:180329, rec:002, time:4807.0, label:1.0
# Original data 62 CH

# %% [markdown]
# ### Logistic Regression with finite difference regularization

# %%
device = torch.device('cuda')

tol = 0.01
learning_rate = 0.001
num_epochs = 51
alphas = [1,50,100]
model_type = 'LR'
loss_type = 'bce'
reg_type = 'finite_diff'
timewindow = 5

# %%
for alpha in alphas:
    model = GLM(input_dim=100*timewindow).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)
    epochs, training_losses, training_acc, val_losses, validation_acc = [], [], [], [], []

    for epoch in range(num_epochs):
        train_loss, train_acc = train(model, optimizer, train_loader, timewindow = timewindow, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
        print('Train loss for epoch {}: {}'.format(epoch, train_loss))
        val_loss, val_acc = evaluate(model, optimizer, val_loader, alpha=alpha, timewindow = timewindow, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
        print('Val loss for epoch {}: {}'.format(epoch, val_loss))
        if val_losses:
            if val_loss < min(val_losses):
                best_epoch = epoch
                print(epoch)
                path = model_saving_path
                torch.save(model.state_dict(), '{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, epoch))
        epochs.append(epoch)
        training_losses.append(train_loss)
        training_acc.append(train_acc)
        val_losses.append(val_loss)
        validation_acc.append(val_acc)

        if train_loss < tol:
            break
    plot_loss_acc(training_losses, val_losses, training_acc, validation_acc, model_type)
# Out:
# Train loss for epoch 0: 0.5605483651161194
# Val loss for epoch 0: 0.5439552664756775
# Train loss for epoch 1: 0.5312784910202026
# Val loss for epoch 1: 0.5265381932258606
# 1
# Train loss for epoch 2: 0.5232731103897095
# Val loss for epoch 2: 0.512570321559906
# 2
# Train loss for epoch 3: 0.5169447660446167
# Val loss for epoch 3: 0.48952654004096985
# 3
# Train loss for epoch 4: 0.5131033658981323
# Val loss for epoch 4: 0.4827527403831482
# 4
# Train loss for epoch 5: 0.5106768012046814
# Val loss for epoch 5: 0.47678548097610474
# 5
# Train loss for epoch 6: 0.5090463161468506
# Val loss for epoch 6: 0.46584758162498474
# 6
# Train loss for epoch 7: 0.50733482837677
# Val loss for epoch 7: 0.4602009057998657
# 7
# Train loss for epoch 8: 0.5071295499801636
# Val loss for epoch 8: 0.47267982363700867
# Train loss for epoch 9: 0.5069358348846436
# Val loss for epoch 9: 0.45518508553504944
# 9
# Train loss for epoch 10: 0.5061883926391602
# Val loss for epoch 10: 0.4523266553878784
# 10
# Train loss for epoch 11: 0.5060620307922363
# Val loss for epoch 11: 0.45078805088996887
# 11
# Train loss for epoch 12: 0.5055401921272278
# Val loss for epoch 12: 0.45313799381256104
# Train loss for epoch 13: 0.5064022541046143
# Val loss for epoch 13: 0.44820404052734375
# 13
# Train loss for epoch 14: 0.5058262348175049
# Val loss for epoch 14: 0.4500768184661865
# Train loss for epoch 15: 0.5058945417404175
# Val loss for epoch 15: 0.4532288610935211
# Train loss for epoch 16: 0.506638765335083
# Val loss for epoch 16: 0.4521450400352478
# Train loss for epoch 17: 0.5054441094398499
# Val loss for epoch 17: 0.454590380191803
# Train loss for epoch 18: 0.5058822631835938
# Val loss for epoch 18: 0.4564671814441681
# Train loss for epoch 19: 0.5061392188072205
# Val loss for epoch 19: 0.4494099020957947
# Train loss for epoch 20: 0.5057383179664612
# Val loss for epoch 20: 0.4496602416038513
# Train loss for epoch 21: 0.5056164264678955
# Val loss for epoch 21: 0.45246613025665283
# Train loss for epoch 22: 0.5052672624588013
# Val loss for epoch 22: 0.447908878326416
# 22
# Train loss for epoch 23: 0.5055750608444214
# Val loss for epoch 23: 0.4502619504928589
# Train loss for epoch 24: 0.5058289766311646
# Val loss for epoch 24: 0.4504397511482239
# Train loss for epoch 25: 0.5062401294708252
# Val loss for epoch 25: 0.45139190554618835
# Train loss for epoch 26: 0.5054469704627991
# Val loss for epoch 26: 0.44944366812705994
# Train loss for epoch 27: 0.5054246783256531
# Val loss for epoch 27: 0.4462832808494568
# 27
# Train loss for epoch 28: 0.506592869758606
# Val loss for epoch 28: 0.4482022523880005
# Train loss for epoch 29: 0.506217360496521
# Val loss for epoch 29: 0.44791126251220703
# Train loss for epoch 30: 0.5056020021438599
# Val loss for epoch 30: 0.45272552967071533
# Train loss for epoch 31: 0.5053825974464417
# Val loss for epoch 31: 0.43720486760139465
# 31
# Train loss for epoch 32: 0.5053651332855225
# Val loss for epoch 32: 0.45102939009666443
# Train loss for epoch 33: 0.5059356689453125
# Val loss for epoch 33: 0.4487558603286743
# Train loss for epoch 34: 0.5057585835456848
# Val loss for epoch 34: 0.4574967920780182
# Train loss for epoch 35: 0.5055986642837524
# Val loss for epoch 35: 0.4704781472682953
# Train loss for epoch 36: 0.5054629445075989
# Val loss for epoch 36: 0.4537729024887085
# Train loss for epoch 37: 0.5059484243392944
# Val loss for epoch 37: 0.44097575545310974
# Train loss for epoch 38: 0.5057776570320129
# Val loss for epoch 38: 0.44914770126342773
# Train loss for epoch 39: 0.5062214136123657
# Val loss for epoch 39: 0.4470970928668976
# Train loss for epoch 40: 0.5053899884223938
# Val loss for epoch 40: 0.4520695209503174
# Train loss for epoch 41: 0.5055737495422363
# Val loss for epoch 41: 0.4441367983818054
# Train loss for epoch 42: 0.5056895017623901
# Val loss for epoch 42: 0.4432869553565979
# Train loss for epoch 43: 0.5059285759925842
# Val loss for epoch 43: 0.4576912522315979
# Train loss for epoch 44: 0.5060826539993286
# Val loss for epoch 44: 0.4520958960056305
# Train loss for epoch 45: 0.5054956078529358
# Val loss for epoch 45: 0.4664849042892456
# Train loss for epoch 46: 0.5063610076904297
# Val loss for epoch 46: 0.44995445013046265
# Train loss for epoch 47: 0.5063106417655945
# Val loss for epoch 47: 0.44673892855644226
# Train loss for epoch 48: 0.5051478743553162
# Val loss for epoch 48: 0.44264236092567444
# Train loss for epoch 49: 0.5054487586021423
# Val loss for epoch 49: 0.45505136251449585
# Train loss for epoch 50: 0.5056195855140686
# Val loss for epoch 50: 0.4488770365715027
# Train loss for epoch 0: 0.6538047194480896
# Val loss for epoch 0: 0.5497997999191284
# Train loss for epoch 1: 0.5612425208091736
# Val loss for epoch 1: 0.5288083553314209
# 1
# Train loss for epoch 2: 0.5583029389381409
# Val loss for epoch 2: 0.528441846370697
# 2
# Train loss for epoch 3: 0.5567829012870789
# Val loss for epoch 3: 0.5131222605705261
# 3
# Train loss for epoch 4: 0.5559137463569641
# Val loss for epoch 4: 0.5059943795204163
# 4
# Train loss for epoch 5: 0.5555688738822937
# Val loss for epoch 5: 0.5066738724708557
# Train loss for epoch 6: 0.5547356605529785
# Val loss for epoch 6: 0.49581149220466614
# 6
# Train loss for epoch 7: 0.5543886423110962
# Val loss for epoch 7: 0.49622946977615356
# Train loss for epoch 8: 0.554465651512146
# Val loss for epoch 8: 0.4880776107311249
# 8
# Train loss for epoch 9: 0.553717315196991
# Val loss for epoch 9: 0.49159762263298035
# Train loss for epoch 10: 0.55445796251297
# Val loss for epoch 10: 0.48693427443504333
# 10
# Train loss for epoch 11: 0.5543370246887207
# Val loss for epoch 11: 0.49303776025772095
# Train loss for epoch 12: 0.553848147392273
# Val loss for epoch 12: 0.49106696248054504
# Train loss for epoch 13: 0.5542559623718262
# Val loss for epoch 13: 0.48705431818962097
# Train loss for epoch 14: 0.5548445582389832
# Val loss for epoch 14: 0.4981166124343872
# Train loss for epoch 15: 0.5546748042106628
# Val loss for epoch 15: 0.4899144470691681
# Train loss for epoch 16: 0.5546658635139465
# Val loss for epoch 16: 0.5004212260246277
# Train loss for epoch 17: 0.5543967485427856
# Val loss for epoch 17: 0.4921729862689972
# Train loss for epoch 18: 0.5542100667953491
# Val loss for epoch 18: 0.48666906356811523
# 18
# Train loss for epoch 19: 0.5537348985671997
# Val loss for epoch 19: 0.48422515392303467
# 19
# Train loss for epoch 20: 0.5539987683296204
# Val loss for epoch 20: 0.49440863728523254
# Train loss for epoch 21: 0.5538495779037476
# Val loss for epoch 21: 0.48555004596710205
# Train loss for epoch 22: 0.5549101233482361
# Val loss for epoch 22: 0.4871945381164551
# Train loss for epoch 23: 0.5539734959602356
# Val loss for epoch 23: 0.49138665199279785
# Train loss for epoch 24: 0.5547077655792236
# Val loss for epoch 24: 0.4872245788574219
# Train loss for epoch 25: 0.554777204990387
# Val loss for epoch 25: 0.48816388845443726
# Train loss for epoch 26: 0.5548794269561768
# Val loss for epoch 26: 0.4950784742832184
# Train loss for epoch 27: 0.554523766040802
# Val loss for epoch 27: 0.4946667551994324
# Train loss for epoch 28: 0.554935097694397
# Val loss for epoch 28: 0.4964221715927124
# Train loss for epoch 29: 0.5541938543319702
# Val loss for epoch 29: 0.4857487380504608
# Train loss for epoch 30: 0.5542705655097961
# Val loss for epoch 30: 0.5005366206169128
# Train loss for epoch 31: 0.5544061064720154
# Val loss for epoch 31: 0.49283596873283386
# Train loss for epoch 32: 0.5540984869003296
# Val loss for epoch 32: 0.49193644523620605
# Train loss for epoch 33: 0.5545300841331482
# Val loss for epoch 33: 0.48727425932884216
# Train loss for epoch 34: 0.5545046925544739
# Val loss for epoch 34: 0.48753494024276733
# Train loss for epoch 35: 0.5546059012413025
# Val loss for epoch 35: 0.48987430334091187
# Train loss for epoch 36: 0.5545881986618042
# Val loss for epoch 36: 0.5027450919151306
# Train loss for epoch 37: 0.5548928380012512
# Val loss for epoch 37: 0.48725825548171997
# Train loss for epoch 38: 0.5543936491012573
# Val loss for epoch 38: 0.49247655272483826
# Train loss for epoch 39: 0.5543258786201477
# Val loss for epoch 39: 0.4970971941947937
# Train loss for epoch 40: 0.5541427731513977
# Val loss for epoch 40: 0.48998692631721497
# Train loss for epoch 41: 0.5547372102737427
# Val loss for epoch 41: 0.4856349229812622
# Train loss for epoch 42: 0.5541216731071472
# Val loss for epoch 42: 0.49517059326171875
# Train loss for epoch 43: 0.5542313456535339
# Val loss for epoch 43: 0.48963722586631775
# Train loss for epoch 44: 0.5544549822807312
# Val loss for epoch 44: 0.48281487822532654
# 44
# Train loss for epoch 45: 0.5546950101852417
# Val loss for epoch 45: 0.4880901575088501
# Train loss for epoch 46: 0.5540842413902283
# Val loss for epoch 46: 0.4806343913078308
# 46
# Train loss for epoch 47: 0.5557398796081543
# Val loss for epoch 47: 0.4865563213825226
# Train loss for epoch 48: 0.554885983467102
# Val loss for epoch 48: 0.4871663451194763
# Train loss for epoch 49: 0.5548893213272095
# Val loss for epoch 49: 0.4951791763305664
# Train loss for epoch 50: 0.5542927384376526
# Val loss for epoch 50: 0.4884567856788635
# Train loss for epoch 0: 0.658065140247345
# Val loss for epoch 0: 0.5542029142379761
# Train loss for epoch 1: 0.5735452771186829
# Val loss for epoch 1: 0.539218544960022
# 1
# Train loss for epoch 2: 0.5721288323402405
# Val loss for epoch 2: 0.5322418808937073
# 2
# Train loss for epoch 3: 0.5708854794502258
# Val loss for epoch 3: 0.5192171931266785
# 3
# Train loss for epoch 4: 0.5704436898231506
# Val loss for epoch 4: 0.5203266739845276
# Train loss for epoch 5: 0.5708757042884827
# Val loss for epoch 5: 0.5107821822166443
# 5
# Train loss for epoch 6: 0.5705698728561401
# Val loss for epoch 6: 0.5125894546508789
# Train loss for epoch 7: 0.57045578956604
# Val loss for epoch 7: 0.5093804001808167
# 7
# Train loss for epoch 8: 0.5704256892204285
# Val loss for epoch 8: 0.5176969170570374
# Train loss for epoch 9: 0.5702293515205383
# Val loss for epoch 9: 0.5096965432167053
# Train loss for epoch 10: 0.5704655051231384
# Val loss for epoch 10: 0.507936418056488
# 10
# Train loss for epoch 11: 0.5710667371749878
# Val loss for epoch 11: 0.501605212688446
# 11
# Train loss for epoch 12: 0.5703495740890503
# Val loss for epoch 12: 0.5153502225875854
# Train loss for epoch 13: 0.571151077747345
# Val loss for epoch 13: 0.504520058631897
# Train loss for epoch 14: 0.5707958340644836
# Val loss for epoch 14: 0.5027462840080261
# Train loss for epoch 15: 0.5714496970176697
# Val loss for epoch 15: 0.5243908166885376
# Train loss for epoch 16: 0.5711452960968018
# Val loss for epoch 16: 0.5000543594360352
# 16
# Train loss for epoch 17: 0.5709630250930786
# Val loss for epoch 17: 0.5094114542007446
# Train loss for epoch 18: 0.5702639222145081
# Val loss for epoch 18: 0.5070936679840088
# Train loss for epoch 19: 0.571242094039917
# Val loss for epoch 19: 0.5036513805389404
# Train loss for epoch 20: 0.5704076886177063
# Val loss for epoch 20: 0.5056304335594177
# Train loss for epoch 21: 0.570594847202301
# Val loss for epoch 21: 0.5045706033706665
# Train loss for epoch 22: 0.5707935094833374
# Val loss for epoch 22: 0.5101150274276733
# Train loss for epoch 23: 0.5701932311058044
# Val loss for epoch 23: 0.5067621469497681
# Train loss for epoch 24: 0.5708519816398621
# Val loss for epoch 24: 0.5017532706260681
# Train loss for epoch 25: 0.5700066089630127
# Val loss for epoch 25: 0.5027459263801575
# Train loss for epoch 26: 0.5715535879135132
# Val loss for epoch 26: 0.5038489699363708
# Train loss for epoch 27: 0.5705207586288452
# Val loss for epoch 27: 0.5113418102264404
# Train loss for epoch 28: 0.5709758996963501
# Val loss for epoch 28: 0.5159706473350525
# Train loss for epoch 29: 0.5704708695411682
# Val loss for epoch 29: 0.5001769065856934
# Train loss for epoch 30: 0.5703006982803345
# Val loss for epoch 30: 0.5082074403762817
# Train loss for epoch 31: 0.5702323913574219
# Val loss for epoch 31: 0.4971681833267212
# 31
# Train loss for epoch 32: 0.5710601210594177
# Val loss for epoch 32: 0.50627601146698
# Train loss for epoch 33: 0.5703592896461487
# Val loss for epoch 33: 0.5066128373146057
# Train loss for epoch 34: 0.5707769989967346
# Val loss for epoch 34: 0.509827196598053
# Train loss for epoch 35: 0.570270299911499
# Val loss for epoch 35: 0.5184539556503296
# Train loss for epoch 36: 0.5715726613998413
# Val loss for epoch 36: 0.5029139518737793
# Train loss for epoch 37: 0.5712091326713562
# Val loss for epoch 37: 0.4995937943458557
# Train loss for epoch 38: 0.5706705451011658
# Val loss for epoch 38: 0.504568338394165
# Train loss for epoch 39: 0.5712970495223999
# Val loss for epoch 39: 0.5022305250167847
# Train loss for epoch 40: 0.5702747702598572
# Val loss for epoch 40: 0.5013085603713989
# Train loss for epoch 41: 0.5705389380455017
# Val loss for epoch 41: 0.5117948651313782
# Train loss for epoch 42: 0.5704988241195679
# Val loss for epoch 42: 0.5037736296653748
# Train loss for epoch 43: 0.5718263983726501
# Val loss for epoch 43: 0.49544209241867065
# 43
# Train loss for epoch 44: 0.5716526508331299
# Val loss for epoch 44: 0.49743565917015076
# Train loss for epoch 45: 0.5702351331710815
# Val loss for epoch 45: 0.516020655632019
# Train loss for epoch 46: 0.5712266564369202
# Val loss for epoch 46: 0.5065303444862366
# Train loss for epoch 47: 0.5701932907104492
# Val loss for epoch 47: 0.5052642226219177
# Train loss for epoch 48: 0.5712200403213501
# Val loss for epoch 48: 0.5022014379501343
# Train loss for epoch 49: 0.5709810853004456
# Val loss for epoch 49: 0.501321017742157
# Train loss for epoch 50: 0.5707598924636841
# Val loss for epoch 50: 0.513260006904602

# %%
model_LR = os.listdir(model_saving_path)
results = []
for alpha in alphas:
    epoch_results = []
    reg_alpha = 'REG'+reg_type+str(alpha)+'_'
    for i, s in enumerate(model_LR):
        if '_CH23_' in s and reg_alpha in s:
            model_name = model_LR[i].split('_')
            epoch_name = [ind for ind,item in enumerate(np.array(model_name)) if "EPOCH" in item]
            res = [int(i) for i in model_name[epoch_name[0]] if i.isdigit()]
            if len(res) > 1:
                epoch_result = res[0]*10+res[1]
            else:
                epoch_result = res[0]
            epoch_results.append(epoch_result)
            
    results.append([alpha, max(epoch_results)])
    
results = pd.DataFrame(np.array(results), columns=['alpha', 'epoch'])
best_results = results.groupby('alpha').max('epoch')
print(best_results)
# Out:
#        epoch
# alpha
# 1         31
# 50        46
# 100       43

# %%
for i,(index,row) in enumerate(best_results.iterrows()):
    
    path = model_saving_path
    best_epoch = int(row)
    alpha = index
    
    
    # load best model
    model = GLM(input_dim=100*timewindow).to(device)
    path = model_saving_path
    optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)
    model.load_state_dict(torch.load('{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, best_epoch)))
    
    print('{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, best_epoch))

    ## Show one feature
    weights = model.linear.weight.view(100, timewindow)
    weights_sub = weights.detach().cpu()
    plt.axis('off')
    plt.imshow(weights_sub)
    plt.title(str(CH))
    # plt.clim(-0.03, 0.03)
    plt.show()
    
    ## Calculate accuracy and validation loss
    val_loss, val_acc, val_preds, val_preds_probs, val_labels,_,_,_, cases_wrong_1 = evaluate(model, optimizer, val_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=True, device=device, timewindow = timewindow)
    print('validation loss:{} accuracy:{}'.format(val_loss, val_acc))
    print(np.mean(np.concatenate(val_labels)))
    
    
    ## Wrong Classifications
    path_wrong = '/mnt/pesaranlab/People/Capstone_students/Yue/wrong_pred'
    pickle.dump(cases_wrong_1, open('{}/{}_CH{}_LOSS{}_REG{}{}.pt'.format(path_wrong, model_type, CH, loss_type, reg_type, alpha), 'wb'))
    idx = 0
    print('date:{}, rec:{}, time:{}, label:{}'.format(cases_wrong_1[0][0], cases_wrong_1[0][1], cases_wrong_1[0][2], cases_wrong_1[0][3]))
    print('Original data 62 CH')
    weights_sub = cases_wrong_1[0][-1][0]
    plt.axis('off')
    plt.imshow(weights_sub)
    # plt.clim(-0.03, 0.03)
    plt.show()
    
    ## Confusion matrix
    predictions_val = np.concatenate(val_preds)
    labels_val = np.concatenate(val_labels)

    df_val = pd.DataFrame({'predictions': predictions_val, 'labels': labels_val})

    cm_val = confusion_matrix(labels_val, predictions_val)
    ax = plt.axes()
    group_names = ['True Neg','False Pos','False Neg','True Pos']
    group_counts = ["{0:0.0f}".format(value) for value in
                    cm_val.flatten()]

    TNR = int(group_counts[0]) / (int(group_counts[0])+int(group_counts[1]))
    FPR = 1 - TNR
    TPR = int(group_counts[3]) / (int(group_counts[3])+int(group_counts[2]))
    FNR = 1-TPR
    group_percentages =[TNR, FPR, FNR, TPR]

    group_percentages = ["{0:.2%}".format(value) for value in
                         group_percentages]
    labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
              zip(group_names,group_counts,group_percentages)]
    labels = np.asarray(labels).reshape(2,2)
    sn.heatmap(cm_val, annot=labels, fmt='', center = 2000)
    ax.set_title('Validation Confusion Matrix')
    ax.set_xlabel('Predicted Label')
    ax.set_ylabel('True Label')
    plt.show()
# Out:
# /home/bijanadmin/Desktop/Goose_data/data_Goose_1st_5s_2/LR_models/LR_CH23_LOSSbce_REGfinite_diff1_EPOCH31.pt
# validation loss:0.43720486760139465 accuracy:0.8040235081374322
# 0.7787824
# date:180329, rec:004, time:6251.0, label:1.0
# Original data 62 CH
# /home/bijanadmin/Desktop/Goose_data/data_Goose_1st_5s_2/LR_models/LR_CH23_LOSSbce_REGfinite_diff50_EPOCH46.pt
# validation loss:0.4806343913078308 accuracy:0.7949065702230259
# 0.7787824
# date:180327, rec:005, time:3082.0, label:1.0
# Original data 62 CH
# /home/bijanadmin/Desktop/Goose_data/data_Goose_1st_5s_2/LR_models/LR_CH23_LOSSbce_REGfinite_diff100_EPOCH43.pt
# validation loss:0.49544209241867065 accuracy:0.7819469559975889
# 0.7787824
# date:180327, rec:005, time:3082.0, label:1.0
# Original data 62 CH

# %% [markdown]
# Done here. Not done w SVM.

# %% [markdown]
# ### SVM without regularization

# %% [markdown]
# ### SVM with L2 regularization

# %%
device = torch.device('cuda')

tol = 0.01
learning_rate = 0.001
num_epochs = 51
alpha = 0.5 # have special meaning as margin, corresponding to 1 in the hinge loss
model_type = 'SVM'
loss_type = 'hinge'
reg_type = 'l2'

model = GLM(input_dim=100*10).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)

# %%
epochs, training_losses, training_acc, val_losses, validation_acc = [], [], [], [], []

for epoch in range(num_epochs):
    train_loss, train_acc = train(model, optimizer, train_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
    print('Train loss for epoch {}: {}'.format(epoch, train_loss))
    val_loss, val_acc = evaluate(model, optimizer, val_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
    print('Val loss for epoch {}: {}'.format(epoch, val_loss))
    if val_losses:
        if val_loss < min(val_losses):
            best_epoch = epoch
            print(epoch)
            path = '/mnt/pesaranlab/People/Capstone_students/Yue/model/model_Goose_1st_1_upsample'
            torch.save(model.state_dict(), '{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, epoch))
    epochs.append(epoch)
    training_losses.append(train_loss)
    training_acc.append(train_acc)
    val_losses.append(val_loss)
    validation_acc.append(val_acc)
    
    if train_loss < tol:
        break
# Out:
# Train loss for epoch 0: 0.6851320862770081
# Val loss for epoch 0: 0.7111771702766418
# Train loss for epoch 1: 0.6442375183105469
# Val loss for epoch 1: 0.7678999900817871
# Train loss for epoch 2: 0.6391520500183105
# Val loss for epoch 2: 0.7529788017272949
# Train loss for epoch 3: 0.6417877078056335
# Val loss for epoch 3: 0.6641672253608704
# 3
# Train loss for epoch 4: 0.6390126347541809
# Val loss for epoch 4: 0.6984342932701111
# Train loss for epoch 5: 0.6404396295547485
# Val loss for epoch 5: 0.7401537895202637
# Train loss for epoch 6: 0.639179527759552
# Val loss for epoch 6: 0.6993381977081299
# Train loss for epoch 7: 0.6405513882637024
# Val loss for epoch 7: 0.6649073362350464
# Train loss for epoch 8: 0.6384839415550232
# Val loss for epoch 8: 0.6716033816337585
# Train loss for epoch 9: 0.6426579356193542
# Val loss for epoch 9: 0.7246717214584351
# Train loss for epoch 10: 0.6410369277000427
# Val loss for epoch 10: 0.714557945728302
# Train loss for epoch 11: 0.640546977519989
# Val loss for epoch 11: 0.7000125050544739
# Train loss for epoch 12: 0.642488420009613
# Val loss for epoch 12: 0.6774542331695557
# Train loss for epoch 13: 0.6405550837516785
# Val loss for epoch 13: 0.7184460759162903
# Train loss for epoch 14: 0.6403983235359192
# Val loss for epoch 14: 0.7138395309448242
# Train loss for epoch 15: 0.6415858864784241
# Val loss for epoch 15: 0.7804384231567383
# Train loss for epoch 16: 0.639844536781311
# Val loss for epoch 16: 0.7306813597679138
# Train loss for epoch 17: 0.6411546468734741
# Val loss for epoch 17: 0.6943265795707703
# Train loss for epoch 18: 0.6401860117912292
# Val loss for epoch 18: 0.6885607838630676
# Train loss for epoch 19: 0.6396834850311279
# Val loss for epoch 19: 0.7206060290336609
# Train loss for epoch 20: 0.640455961227417
# Val loss for epoch 20: 0.702420175075531
# Train loss for epoch 21: 0.6402938961982727
# Val loss for epoch 21: 0.7104942202568054
# Train loss for epoch 22: 0.640040934085846
# Val loss for epoch 22: 0.7436862587928772
# Train loss for epoch 23: 0.6407786011695862
# Val loss for epoch 23: 0.6620125770568848
# 23
# Train loss for epoch 24: 0.6418817639350891
# Val loss for epoch 24: 0.7360722422599792
# Train loss for epoch 25: 0.6385318040847778
# Val loss for epoch 25: 0.7304670214653015
# Train loss for epoch 26: 0.640387773513794
# Val loss for epoch 26: 0.7861469388008118
# Train loss for epoch 27: 0.6426716446876526
# Val loss for epoch 27: 0.6352165341377258
# 27
# Train loss for epoch 28: 0.6454393267631531
# Val loss for epoch 28: 0.6951034069061279
# Train loss for epoch 29: 0.6385886073112488
# Val loss for epoch 29: 0.7505565285682678
# Train loss for epoch 30: 0.6399576663970947
# Val loss for epoch 30: 0.7399937510490417
# Train loss for epoch 31: 0.641554057598114
# Val loss for epoch 31: 0.6840065121650696
# Train loss for epoch 32: 0.6412416100502014
# Val loss for epoch 32: 0.6981443762779236
# Train loss for epoch 33: 0.6422035694122314
# Val loss for epoch 33: 0.6874670386314392
# Train loss for epoch 34: 0.6408448815345764
# Val loss for epoch 34: 0.8072331547737122
# Train loss for epoch 35: 0.6395016312599182
# Val loss for epoch 35: 0.730316162109375
# Train loss for epoch 36: 0.6403080224990845
# Val loss for epoch 36: 0.7818818688392639
# Train loss for epoch 37: 0.6434655785560608
# Val loss for epoch 37: 0.6429640650749207
# Train loss for epoch 38: 0.6408840417861938
# Val loss for epoch 38: 0.6359612941741943
# Train loss for epoch 39: 0.6419800519943237
# Val loss for epoch 39: 0.6931543946266174
# Train loss for epoch 40: 0.641847550868988
# Val loss for epoch 40: 0.6723946332931519
# Train loss for epoch 41: 0.6399581432342529
# Val loss for epoch 41: 0.7007078528404236
# Train loss for epoch 42: 0.637771725654602
# Val loss for epoch 42: 0.7417786717414856
# Train loss for epoch 43: 0.6427635550498962
# Val loss for epoch 43: 0.737413763999939
# Train loss for epoch 44: 0.6401107907295227
# Val loss for epoch 44: 0.6725066304206848
# Train loss for epoch 45: 0.6420534253120422
# Val loss for epoch 45: 0.6480686068534851
# Train loss for epoch 46: 0.6414241194725037
# Val loss for epoch 46: 0.7304709553718567
# Train loss for epoch 47: 0.6403049826622009
# Val loss for epoch 47: 0.7036920785903931
# Train loss for epoch 48: 0.6407722234725952
# Val loss for epoch 48: 0.6887156963348389
# Train loss for epoch 49: 0.6385686993598938
# Val loss for epoch 49: 0.7157089114189148
# Train loss for epoch 50: 0.6383669376373291
# Val loss for epoch 50: 0.7005918622016907

# %%
plot_loss_acc(training_losses, val_losses, training_acc, validation_acc, model_type)

# %%
best_epoch = 27

# %%
model = GLM(input_dim=100*10).to(device)
path = '/mnt/pesaranlab/People/Capstone_students/Yue/model/model_Goose_1st_1_upsample'
model.load_state_dict(torch.load('{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, best_epoch)))
weights = model.linear.weight.view(100, 10)
weights_sub = weights.detach().cpu()
plt.axis('off')
plt.imshow(weights_sub)
plt.title(str(CH))
# plt.clim(-0.03, 0.03)
plt.show()

# %%
test_loss, test_acc, test_preds, test_preds_probs, test_labels, cases_wrong_4 = evaluate(model, optimizer, test_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=True, device=device)
print('test loss:{} accuracy:{}'.format(test_loss, test_acc))
# Out:
# test loss:0.9384552836418152 accuracy:0.6475384615384615

# %%
predictions_test = np.concatenate(test_preds)
labels_test = np.concatenate(test_labels)

df_test = pd.DataFrame({'predictions': predictions_test, 'labels': labels_test})

cm_test = confusion_matrix(labels_test, predictions_test)
ax = plt.axes()
sn.heatmap(cm_test, annot = True, fmt = "d", ax = ax, center=2000)
ax.set_title('Test Confusion Matrix')
ax.set_xlabel('Predicted Label')
ax.set_ylabel('True Label')
plt.show()

# %%
idx = 0
print('date:{}, rec:{}, time:{}, label:{}'.format(cases_wrong_4[0][0], cases_wrong_4[0][1], cases_wrong_4[0][1], cases_wrong_4[0][3]))
print('Original data 62 CH')
weights_sub = cases_wrong_4[0][-1][0]
plt.axis('off')
plt.imshow(weights_sub)
# plt.clim(-0.03, 0.03)
plt.show()
# Out:
# date:180331, rec:004, time:004, label:1.0
# Original data 62 CH

# %% [markdown]
# ### SVM with finite difference regularization

# %%
device = torch.device('cuda')

tol = 0.01
learning_rate = 0.001
num_epochs = 51
alpha = 0.5
model_type = 'SVM'
loss_type = 'hinge'
reg_type = 'finite_diff'

model = GLM(input_dim=100*10).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)

# %%
epochs, training_losses, training_acc, val_losses, validation_acc = [], [], [], [], []

for epoch in range(num_epochs):
    train_loss, train_acc = train(model, optimizer, train_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
    print('Train loss for epoch {}: {}'.format(epoch, train_loss))
    val_loss, val_acc = evaluate(model, optimizer, val_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
    print('Val loss for epoch {}: {}'.format(epoch, val_loss))
    if val_losses:
        if val_loss < min(val_losses):
            best_epoch = epoch
            print(epoch)
            path = '/mnt/pesaranlab/People/Capstone_students/Yue/model/model_Goose_1st_1_upsample'
            torch.save(model.state_dict(), '{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, epoch))
    epochs.append(epoch)
    training_losses.append(train_loss)
    training_acc.append(train_acc)
    val_losses.append(val_loss)
    validation_acc.append(val_acc)
    
    if train_loss < tol:
        break
# Out:
# Train loss for epoch 0: 0.6690675616264343
# Val loss for epoch 0: 0.7053626179695129
# Train loss for epoch 1: 0.579605758190155
# Val loss for epoch 1: 0.6587177515029907
# 1
# Train loss for epoch 2: 0.5777973532676697
# Val loss for epoch 2: 0.661455512046814
# Train loss for epoch 3: 0.5772103071212769
# Val loss for epoch 3: 0.6873345375061035
# Train loss for epoch 4: 0.5797932744026184
# Val loss for epoch 4: 0.6312553286552429
# 4
# Train loss for epoch 5: 0.5747454762458801
# Val loss for epoch 5: 0.6387228965759277
# Train loss for epoch 6: 0.5753779411315918
# Val loss for epoch 6: 0.6457529067993164
# Train loss for epoch 7: 0.5756300687789917
# Val loss for epoch 7: 0.570262610912323
# 7
# Train loss for epoch 8: 0.5766920447349548
# Val loss for epoch 8: 0.6651206016540527
# Train loss for epoch 9: 0.5784576535224915
# Val loss for epoch 9: 0.6457962989807129
# Train loss for epoch 10: 0.5766485929489136
# Val loss for epoch 10: 0.6799610257148743
# Train loss for epoch 11: 0.577312171459198
# Val loss for epoch 11: 0.6357672810554504
# Train loss for epoch 12: 0.5765970945358276
# Val loss for epoch 12: 0.6243463754653931
# Train loss for epoch 13: 0.5763651728630066
# Val loss for epoch 13: 0.6528318524360657
# Train loss for epoch 14: 0.5787343978881836
# Val loss for epoch 14: 0.6197062134742737
# Train loss for epoch 15: 0.5766005516052246
# Val loss for epoch 15: 0.6669512391090393
# Train loss for epoch 16: 0.5740532279014587
# Val loss for epoch 16: 0.6083996891975403
# Train loss for epoch 17: 0.578143835067749
# Val loss for epoch 17: 0.6331867575645447
# Train loss for epoch 18: 0.5752172470092773
# Val loss for epoch 18: 0.6276236772537231
# Train loss for epoch 19: 0.5754168033599854
# Val loss for epoch 19: 0.6268960237503052
# Train loss for epoch 20: 0.5756818056106567
# Val loss for epoch 20: 0.6202787756919861
# Train loss for epoch 21: 0.5744140148162842
# Val loss for epoch 21: 0.6567234396934509
# Train loss for epoch 22: 0.5762956738471985
# Val loss for epoch 22: 0.6660755276679993
# Train loss for epoch 23: 0.5758554339408875
# Val loss for epoch 23: 0.6730091571807861
# Train loss for epoch 24: 0.577211320400238
# Val loss for epoch 24: 0.651534914970398
# Train loss for epoch 25: 0.5769349336624146
# Val loss for epoch 25: 0.7000337243080139
# Train loss for epoch 26: 0.5785800814628601
# Val loss for epoch 26: 0.687545120716095
# Train loss for epoch 27: 0.5782286524772644
# Val loss for epoch 27: 0.6496562361717224
# Train loss for epoch 28: 0.5788707137107849
# Val loss for epoch 28: 0.6680619120597839
# Train loss for epoch 29: 0.5760782957077026
# Val loss for epoch 29: 0.6649113893508911
# Train loss for epoch 30: 0.5756315588951111
# Val loss for epoch 30: 0.6239709854125977
# Train loss for epoch 31: 0.5757757425308228
# Val loss for epoch 31: 0.6552281379699707
# Train loss for epoch 32: 0.5736462473869324
# Val loss for epoch 32: 0.6681107878684998
# Train loss for epoch 33: 0.5752080082893372
# Val loss for epoch 33: 0.6992300748825073
# Train loss for epoch 34: 0.5773605704307556
# Val loss for epoch 34: 0.5969449281692505
# Train loss for epoch 35: 0.577599287033081
# Val loss for epoch 35: 0.7016803622245789
# Train loss for epoch 36: 0.5782400965690613
# Val loss for epoch 36: 0.6377145648002625
# Train loss for epoch 37: 0.5756941437721252
# Val loss for epoch 37: 0.689575731754303
# Train loss for epoch 38: 0.576504647731781
# Val loss for epoch 38: 0.6356939077377319
# Train loss for epoch 39: 0.579881489276886
# Val loss for epoch 39: 0.6778709292411804
# Train loss for epoch 40: 0.5781845450401306
# Val loss for epoch 40: 0.60308438539505
# Train loss for epoch 41: 0.577141284942627
# Val loss for epoch 41: 0.6428723931312561
# Train loss for epoch 42: 0.5757811665534973
# Val loss for epoch 42: 0.6472859382629395
# Train loss for epoch 43: 0.5753296613693237
# Val loss for epoch 43: 0.6884997487068176
# Train loss for epoch 44: 0.5757269859313965
# Val loss for epoch 44: 0.6618257164955139
# Train loss for epoch 45: 0.5760087966918945
# Val loss for epoch 45: 0.6461961269378662
# Train loss for epoch 46: 0.5766039490699768
# Val loss for epoch 46: 0.641828715801239
# Train loss for epoch 47: 0.5778237581253052
# Val loss for epoch 47: 0.6952266097068787
# Train loss for epoch 48: 0.5753308534622192
# Val loss for epoch 48: 0.6868410110473633
# Train loss for epoch 49: 0.5763373374938965
# Val loss for epoch 49: 0.7049767971038818
# Train loss for epoch 50: 0.5758347511291504
# Val loss for epoch 50: 0.6037036180496216

# %%
plot_loss_acc(training_losses, val_losses, training_acc, validation_acc, model_type)

# %%
best_epoch = 7

# %%
model = GLM(input_dim=100*10).to(device)
path = '/mnt/pesaranlab/People/Capstone_students/Yue/model/model_Goose_1st_1_upsample'
model.load_state_dict(torch.load('{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, best_epoch)))
weights = model.linear.weight.view(100, 10)
weights_sub = weights.detach().cpu()
plt.axis('off')
plt.imshow(weights_sub)
plt.title(str(CH))
# plt.clim(-0.03, 0.03)
plt.show()

# %%
test_loss, test_acc, test_preds, test_preds_probs, test_labels, cases_wrong_5 = evaluate(model, optimizer, test_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=True, device=device)
print('test loss:{} accuracy:{}'.format(test_loss, test_acc))
# Out:
# test loss:0.8175214529037476 accuracy:0.6916923076923077

# %%
predictions_test = np.concatenate(test_preds)
labels_test = np.concatenate(test_labels)

df_test = pd.DataFrame({'predictions': predictions_test, 'labels': labels_test})

cm_test = confusion_matrix(labels_test, predictions_test)
ax = plt.axes()
sn.heatmap(cm_test, annot = True, fmt = "d", ax = ax, center=2000)
ax.set_title('Test Confusion Matrix')
ax.set_xlabel('Predicted Label')
ax.set_ylabel('True Label')
plt.show()

# %%
idx = 0
print('date:{}, rec:{}, time:{}, label:{}'.format(cases_wrong_5[0][0], cases_wrong_5[0][1], cases_wrong_5[0][1], cases_wrong_5[0][3]))
print('Original data 62 CH')
weights_sub = cases_wrong_5[0][-1][0]
plt.axis('off')
plt.imshow(weights_sub)
# plt.clim(-0.03, 0.03)
plt.show()
# Out:
# date:180331, rec:004, time:004, label:1.0
# Original data 62 CH
