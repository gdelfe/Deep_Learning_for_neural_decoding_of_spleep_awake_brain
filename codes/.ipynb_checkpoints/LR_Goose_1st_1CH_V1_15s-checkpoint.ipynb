# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
from torch.utils.data import Dataset, DataLoader
from torch import nn
from torch.nn.functional import relu
from scipy.io import loadmat
import os
from os import listdir
import pandas as pd
from skimage import io
from PIL import Image
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pickle

from utils import *

# %%
#selected subset of dates. 
val_dates = ['180328','180329']
test_dates = ['180330','180331']

CH = 23
train_loader, val_loader, test_loader = create_dataloaders(val_dates=val_dates, test_dates=test_dates, batch_size=128, version='_Goose_1st_15s_1', CH=CH, upsample=True)

# %%
len(train_loader), len(val_loader), len(test_loader)
# Out:
# (166, 14, 33)

# %%
for batch_idx, (data, label, date, rec, time) in enumerate(train_loader): # check shapes
    print(data.shape)
    print(label.shape)
    print(len(date))
    print(len(rec))
    print(len(time))
    break
# Out:
# torch.Size([128, 1, 100, 15])
# torch.Size([128, 1])
# 128
# 128
# 128

# %%
# movement labelled 0; non-movement labelled 1
for batch_idx, (data, label, date, rec, time) in enumerate(train_loader):
    for i in range(128):
        print('date:{}, rec:{}, time:{}'.format(date[i], rec[i], time[i]))
        data_sub = data[i][0]
        plt.imshow(data_sub)
        plt.clim(-1.5, 1.5)
        plt.colorbar()
        plt.title(label[i][0].numpy())
        plt.show()
    break
# Out:
# date:180327, rec:007, time:6408.0
# date:180401, rec:002, time:3358.0
# date:180401, rec:001, time:5029.0
# date:180325, rec:005, time:1926.0
# date:180325, rec:005, time:2738.0
# date:180324, rec:003, time:2196.0
# date:180324, rec:009, time:2149.0
# date:180327, rec:008, time:5405.0
# date:180325, rec:003, time:2297.0
# date:180327, rec:008, time:4910.0
# date:180401, rec:001, time:2556.0
# date:180327, rec:001, time:3871.0
# date:180322, rec:003, time:1310.0
# date:180325, rec:007, time:2833.0
# date:180401, rec:001, time:1942.0
# date:180327, rec:001, time:1557.0
# date:180327, rec:007, time:3512.0
# date:180327, rec:008, time:5285.0
# date:180325, rec:004, time:1800.0
# date:180327, rec:008, time:4955.0
# date:180325, rec:002, time:927.0
# date:180323, rec:007, time:5558.0
# date:180327, rec:008, time:237.0
# date:180327, rec:005, time:3242.0
# date:180327, rec:007, time:3032.0
# date:180327, rec:002, time:1587.0
# date:180327, rec:001, time:597.0
# date:180325, rec:005, time:3338.0
# date:180327, rec:007, time:5463.0
# date:180323, rec:007, time:1931.0
# date:180327, rec:007, time:404.0
# date:180327, rec:005, time:2747.0
# date:180327, rec:007, time:6603.0
# date:180327, rec:001, time:7064.0
# date:180323, rec:005, time:2774.0
# date:180324, rec:006, time:2268.0
# date:180322, rec:005, time:1120.0
# date:180327, rec:001, time:1602.0
# date:180327, rec:008, time:462.0
# date:180327, rec:002, time:6637.0
# date:180327, rec:001, time:2919.0
# date:180322, rec:003, time:515.0
# date:180327, rec:007, time:3677.0
# date:180401, rec:001, time:3903.0
# date:180327, rec:008, time:2224.0
# date:180325, rec:001, time:1422.0
# date:180327, rec:008, time:4955.0
# date:180327, rec:007, time:3902.0
# date:180325, rec:002, time:3881.0
# date:180326, rec:004, time:3985.0
# date:180327, rec:007, time:4923.0
# date:180324, rec:003, time:762.0
# date:180327, rec:008, time:2749.0
# date:180325, rec:009, time:5574.0
# date:180327, rec:007, time:3137.0
# date:180325, rec:007, time:3462.0
# date:180327, rec:008, time:3979.0
# date:180325, rec:001, time:792.0
# date:180327, rec:006, time:972.0
# date:180327, rec:007, time:5763.0
# date:180327, rec:008, time:3124.0
# date:180325, rec:009, time:2127.0
# date:180323, rec:001, time:762.0
# date:180401, rec:001, time:267.0
# date:180327, rec:007, time:2732.0
# date:180327, rec:008, time:4625.0
# date:180327, rec:004, time:2571.0
# date:180322, rec:004, time:4011.0
# date:180323, rec:003, time:1642.0
# date:180327, rec:004, time:2481.0
# date:180327, rec:007, time:5688.0
# date:180323, rec:002, time:1529.0
# date:180327, rec:008, time:4655.0
# date:180323, rec:003, time:3829.0
# date:180325, rec:002, time:3319.0
# date:180324, rec:009, time:1014.0
# date:180322, rec:007, time:4367.0
# date:180322, rec:007, time:1574.0
# date:180327, rec:007, time:2147.0
# date:180325, rec:006, time:3820.0
# date:180324, rec:008, time:1273.0
# date:180327, rec:007, time:1082.0
# date:180326, rec:004, time:6757.0
# date:180323, rec:004, time:6123.0
# date:180327, rec:008, time:4159.0
# date:180327, rec:007, time:6933.0
# date:180324, rec:009, time:147.0
# date:180325, rec:005, time:27.0
# date:180327, rec:007, time:2987.0
# date:180325, rec:005, time:210.0
# date:180324, rec:004, time:3441.0
# date:180325, rec:009, time:27.0
# date:180324, rec:008, time:5956.0
# date:180327, rec:001, time:7079.0
# date:180325, rec:001, time:642.0
# date:180325, rec:007, time:2713.0
# date:180326, rec:004, time:4902.0
# date:180323, rec:007, time:5302.0
# date:180327, rec:001, time:6809.0
# date:180327, rec:008, time:4685.0
# date:180327, rec:007, time:5163.0
# date:180327, rec:002, time:6547.0
# date:180324, rec:008, time:1513.0
# date:180323, rec:004, time:4681.0
# date:180325, rec:009, time:942.0
# date:180325, rec:003, time:6284.0
# date:180327, rec:007, time:3977.0
# date:180324, rec:008, time:1678.0
# date:180322, rec:004, time:403.0
# date:180327, rec:008, time:1134.0
# date:180327, rec:002, time:6292.0
# date:180325, rec:007, time:117.0
# date:180327, rec:005, time:4277.0
# date:180325, rec:001, time:5654.0
# date:180324, rec:003, time:5225.0
# date:180401, rec:002, time:3133.0
# date:180322, rec:007, time:2285.0
# date:180325, rec:009, time:402.0
# date:180325, rec:003, time:1982.0
# date:180401, rec:001, time:2106.0
# date:180322, rec:003, time:5105.0
# date:180401, rec:001, time:1062.0
# date:180325, rec:007, time:3344.0
# date:180327, rec:007, time:6648.0
# date:180327, rec:001, time:2262.0
# date:180327, rec:008, time:4880.0
# date:180327, rec:008, time:5330.0
# date:180322, rec:007, time:4097.0

# %% [markdown]
# ### Logistic regression with no regularization

# %%
device = torch.device('cuda')

tol = 0.01
learning_rate = 0.001
num_epochs = 51
alpha = 0
model_type = 'LR'
loss_type = 'bce'
reg_type = 'none'
timewindow = 15
model_saving_path = '/mnt/pesaranlab/People/Capstone_students/Yue/model/model_Goose_15s_1st_1_upsample'

model = GLM(input_dim=100*timewindow).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)

# %%
epochs, training_losses, training_acc, val_losses, validation_acc = [], [], [], [], []

for epoch in range(num_epochs):
    train_loss, train_acc = train(model, optimizer, train_loader, timewindow = timewindow, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
    print('Train loss for epoch {}: {}'.format(epoch, train_loss))
    val_loss, val_acc = evaluate(model, optimizer, val_loader, alpha=alpha, timewindow = timewindow, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
    print('Val loss for epoch {}: {}'.format(epoch, val_loss))
    if val_losses:
        if val_loss < min(val_losses):
            best_epoch = epoch
            print(epoch)
            path = model_saving_path
            torch.save(model.state_dict(), '{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, epoch))
    epochs.append(epoch)
    training_losses.append(train_loss)
    training_acc.append(train_acc)
    val_losses.append(val_loss)
    validation_acc.append(val_acc)
    
    if train_loss < tol:
        break
# Out:
# Train loss for epoch 0: 0.4887293875217438
# Val loss for epoch 0: 0.6141195297241211
# Train loss for epoch 1: 0.4645993411540985
# Val loss for epoch 1: 0.6401581168174744
# Train loss for epoch 2: 0.4534475803375244
# Val loss for epoch 2: 0.49225351214408875
# 2
# Train loss for epoch 3: 0.4487893581390381
# Val loss for epoch 3: 0.574396550655365
# Train loss for epoch 4: 0.4416942000389099
# Val loss for epoch 4: 0.5205467343330383
# Train loss for epoch 5: 0.4367663264274597
# Val loss for epoch 5: 0.49866870045661926
# Train loss for epoch 6: 0.43313518166542053
# Val loss for epoch 6: 0.46133866906166077
# 6
# Train loss for epoch 7: 0.429278165102005
# Val loss for epoch 7: 0.5070674419403076
# Train loss for epoch 8: 0.4265091121196747
# Val loss for epoch 8: 0.5949410200119019
# Train loss for epoch 9: 0.42408785223960876
# Val loss for epoch 9: 0.5007067322731018
# Train loss for epoch 10: 0.42167550325393677
# Val loss for epoch 10: 0.5220397114753723
# Train loss for epoch 11: 0.41920173168182373
# Val loss for epoch 11: 0.4539541006088257
# 11
# Train loss for epoch 12: 0.41625046730041504
# Val loss for epoch 12: 0.4952562153339386
# Train loss for epoch 13: 0.41440197825431824
# Val loss for epoch 13: 0.4546758532524109
# Train loss for epoch 14: 0.412721186876297
# Val loss for epoch 14: 0.47319337725639343
# Train loss for epoch 15: 0.41188398003578186
# Val loss for epoch 15: 0.47625407576560974
# Train loss for epoch 16: 0.40966227650642395
# Val loss for epoch 16: 0.5097668170928955
# Train loss for epoch 17: 0.4091479182243347
# Val loss for epoch 17: 0.4911576211452484
# Train loss for epoch 18: 0.40876975655555725
# Val loss for epoch 18: 0.4701753854751587
# Train loss for epoch 19: 0.4063623249530792
# Val loss for epoch 19: 0.4670926034450531
# Train loss for epoch 20: 0.4050856828689575
# Val loss for epoch 20: 0.4882141351699829
# Train loss for epoch 21: 0.4036940634250641
# Val loss for epoch 21: 0.48290902376174927
# Train loss for epoch 22: 0.4029489755630493
# Val loss for epoch 22: 0.47725942730903625
# Train loss for epoch 23: 0.4033048152923584
# Val loss for epoch 23: 0.47307562828063965
# Train loss for epoch 24: 0.40203407406806946
# Val loss for epoch 24: 0.45620477199554443
# Train loss for epoch 25: 0.40167418122291565
# Val loss for epoch 25: 0.45136383175849915
# 25
# Train loss for epoch 26: 0.4008225202560425
# Val loss for epoch 26: 0.4610770344734192
# Train loss for epoch 27: 0.3975186347961426
# Val loss for epoch 27: 0.4812268018722534
# Train loss for epoch 28: 0.3957583010196686
# Val loss for epoch 28: 0.49423345923423767
# Train loss for epoch 29: 0.39583611488342285
# Val loss for epoch 29: 0.4899964928627014
# Train loss for epoch 30: 0.3973827064037323
# Val loss for epoch 30: 0.5284147262573242
# Train loss for epoch 31: 0.3950991630554199
# Val loss for epoch 31: 0.540189266204834
# Train loss for epoch 32: 0.3931572735309601
# Val loss for epoch 32: 0.5231137275695801
# Train loss for epoch 33: 0.3921259939670563
# Val loss for epoch 33: 0.5244125723838806
# Train loss for epoch 34: 0.3914013206958771
# Val loss for epoch 34: 0.5148045420646667
# Train loss for epoch 35: 0.39211511611938477
# Val loss for epoch 35: 0.5275537371635437
# Train loss for epoch 36: 0.3912549912929535
# Val loss for epoch 36: 0.43839114904403687
# 36
# Train loss for epoch 37: 0.39108872413635254
# Val loss for epoch 37: 0.5023832321166992
# Train loss for epoch 38: 0.3900770843029022
# Val loss for epoch 38: 0.5273858904838562
# Train loss for epoch 39: 0.3891742527484894
# Val loss for epoch 39: 0.5416801571846008
# Train loss for epoch 40: 0.3880254924297333
# Val loss for epoch 40: 0.5254208445549011
# Train loss for epoch 41: 0.3873507082462311
# Val loss for epoch 41: 0.522195041179657
# Train loss for epoch 42: 0.38844093680381775
# Val loss for epoch 42: 0.4579167366027832
# Train loss for epoch 43: 0.38579168915748596
# Val loss for epoch 43: 0.5068079233169556
# Train loss for epoch 44: 0.3876980245113373
# Val loss for epoch 44: 0.4754263162612915
# Train loss for epoch 45: 0.38736435770988464
# Val loss for epoch 45: 0.45461779832839966
# Train loss for epoch 46: 0.38654834032058716
# Val loss for epoch 46: 0.496502161026001
# Train loss for epoch 47: 0.3834816515445709
# Val loss for epoch 47: 0.517035186290741
# Train loss for epoch 48: 0.38410940766334534
# Val loss for epoch 48: 0.5341842770576477
# Train loss for epoch 49: 0.38443517684936523
# Val loss for epoch 49: 0.5553728938102722
# Train loss for epoch 50: 0.3825277090072632
# Val loss for epoch 50: 0.5309147834777832

# %%
plot_loss_acc(training_losses, val_losses, training_acc, validation_acc, model_type)

# %%
# best_epoch = 14

# %%
timewindow
# Out:
# 15

# %%
model = GLM(input_dim=100*timewindow).to(device)
path =model_saving_path
model.load_state_dict(torch.load('{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, best_epoch)))
weights = model.linear.weight.view(100, timewindow)
weights_sub = weights.detach().cpu()
plt.axis('off')
plt.imshow(weights_sub)
plt.title(str(CH))
# plt.clim(-0.03, 0.03)
plt.show()

# %%
test_loss, test_acc, test_preds, test_preds_probs, test_labels, cases_wrong_0 = evaluate(model, optimizer, test_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=True, device=device)
print('test loss:{} accuracy:{}'.format(test_loss, test_acc))
# Out:
# test loss:0.5928754210472107 accuracy:0.7251889782979761

# %%
np.mean(np.concatenate(test_labels))
# Out:
# 0.7444526

# %%
path_wrong = '/mnt/pesaranlab/People/Capstone_students/Yue/wrong_pred'
pickle.dump(cases_wrong_0, open('{}/{}_CH{}_LOSS{}_REG{}{}.pt'.format(path_wrong, model_type, CH, loss_type, reg_type, alpha), 'wb'))

# %%
predictions_test = np.concatenate(test_preds)
labels_test = np.concatenate(test_labels)

df_test = pd.DataFrame({'predictions': predictions_test, 'labels': labels_test})

cm_test = confusion_matrix(labels_test, predictions_test)
ax = plt.axes()
sn.heatmap(cm_test, annot = True, fmt = "d", ax = ax, center=2000)
ax.set_title('Test Confusion Matrix')
ax.set_xlabel('Predicted Label')
ax.set_ylabel('True Label')
plt.show()

# %%
idx = 0
print('date:{}, rec:{}, time:{}, label:{}'.format(cases_wrong_0[0][0], cases_wrong_0[0][1], cases_wrong_0[0][2], cases_wrong_0[0][3]))
print('Original data 62 CH')
weights_sub = cases_wrong_0[0][-1][0]
plt.axis('off')
plt.imshow(weights_sub)
# plt.clim(-0.03, 0.03)
plt.show()
# Out:
# date:180330, rec:001, time:4886.0, label:1.0
# Original data 62 CH

# %% [markdown]
# ### Logistic regression with L2 regularization

# %%
device = torch.device('cuda')

tol = 0.01
learning_rate = 0.001
num_epochs = 51
alpha = 0.1 #try 0.3, 0.5, 0.7
model_type = 'LR'
loss_type = 'bce'
reg_type = 'l2'
timewindow = 15
model_saving_path = '/mnt/pesaranlab/People/Capstone_students/Yue/model/model_Goose_15s_1st_1_upsample'

model = GLM(input_dim=100*timewindow).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)

# %%
epochs, training_losses, training_acc, val_losses, validation_acc = [], [], [], [], []

for epoch in range(num_epochs):
    train_loss, train_acc = train(model, optimizer, train_loader, timewindow = timewindow, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
    print('Train loss for epoch {}: {}'.format(epoch, train_loss))
    val_loss, val_acc = evaluate(model, optimizer, val_loader, alpha=alpha, timewindow = timewindow, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
    print('Val loss for epoch {}: {}'.format(epoch, val_loss))
    if val_losses:
        if val_loss < min(val_losses):
            best_epoch = epoch
            print(epoch)
            path = model_saving_path
            torch.save(model.state_dict(), '{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, epoch))
    epochs.append(epoch)
    training_losses.append(train_loss)
    training_acc.append(train_acc)
    val_losses.append(val_loss)
    validation_acc.append(val_acc)
    
    if train_loss < tol:
        break
# Out:
# Train loss for epoch 0: 0.4906684160232544
# Val loss for epoch 0: 0.5730698108673096
# Train loss for epoch 1: 0.4639695882797241
# Val loss for epoch 1: 0.5879006385803223
# Train loss for epoch 2: 0.45495954155921936
# Val loss for epoch 2: 0.5341275334358215
# 2
# Train loss for epoch 3: 0.4477125108242035
# Val loss for epoch 3: 0.5441039204597473
# Train loss for epoch 4: 0.4418882131576538
# Val loss for epoch 4: 0.5137771368026733
# 4
# Train loss for epoch 5: 0.4374123811721802
# Val loss for epoch 5: 0.5353819727897644
# Train loss for epoch 6: 0.43265923857688904
# Val loss for epoch 6: 0.5152532458305359
# Train loss for epoch 7: 0.43056824803352356
# Val loss for epoch 7: 0.5203282833099365
# Train loss for epoch 8: 0.4264998733997345
# Val loss for epoch 8: 0.5091029405593872
# 8
# Train loss for epoch 9: 0.4245143532752991
# Val loss for epoch 9: 0.5258313417434692
# Train loss for epoch 10: 0.4213443696498871
# Val loss for epoch 10: 0.5317609310150146
# Train loss for epoch 11: 0.4203876256942749
# Val loss for epoch 11: 0.5213054418563843
# Train loss for epoch 12: 0.4177951216697693
# Val loss for epoch 12: 0.4786340296268463
# 12
# Train loss for epoch 13: 0.4167783856391907
# Val loss for epoch 13: 0.4987129271030426
# Train loss for epoch 14: 0.4162488877773285
# Val loss for epoch 14: 0.47931918501853943
# Train loss for epoch 15: 0.4160315990447998
# Val loss for epoch 15: 0.46990105509757996
# 15
# Train loss for epoch 16: 0.4121182858943939
# Val loss for epoch 16: 0.5045865774154663
# Train loss for epoch 17: 0.4113011956214905
# Val loss for epoch 17: 0.4608977138996124
# 17
# Train loss for epoch 18: 0.4090333878993988
# Val loss for epoch 18: 0.5193447470664978
# Train loss for epoch 19: 0.4078825116157532
# Val loss for epoch 19: 0.48430436849594116
# Train loss for epoch 20: 0.40688005089759827
# Val loss for epoch 20: 0.45926663279533386
# 20
# Train loss for epoch 21: 0.40554189682006836
# Val loss for epoch 21: 0.5191329121589661
# Train loss for epoch 22: 0.40633895993232727
# Val loss for epoch 22: 0.501188337802887
# Train loss for epoch 23: 0.40518972277641296
# Val loss for epoch 23: 0.49625054001808167
# Train loss for epoch 24: 0.4031091332435608
# Val loss for epoch 24: 0.4834434688091278
# Train loss for epoch 25: 0.4018462300300598
# Val loss for epoch 25: 0.5165486931800842
# Train loss for epoch 26: 0.40203073620796204
# Val loss for epoch 26: 0.4800143539905548
# Train loss for epoch 27: 0.4011836051940918
# Val loss for epoch 27: 0.4691982567310333
# Train loss for epoch 28: 0.40157023072242737
# Val loss for epoch 28: 0.4693640172481537
# Train loss for epoch 29: 0.39905962347984314
# Val loss for epoch 29: 0.46379387378692627
# Train loss for epoch 30: 0.4006277024745941
# Val loss for epoch 30: 0.4634399116039276
# Train loss for epoch 31: 0.3972490131855011
# Val loss for epoch 31: 0.4842914938926697
# Train loss for epoch 32: 0.39685145020484924
# Val loss for epoch 32: 0.472156822681427
# Train loss for epoch 33: 0.3959406614303589
# Val loss for epoch 33: 0.5205620527267456
# Train loss for epoch 34: 0.3951064348220825
# Val loss for epoch 34: 0.466369092464447
# Train loss for epoch 35: 0.39460036158561707
# Val loss for epoch 35: 0.47974085807800293
# Train loss for epoch 36: 0.39360636472702026
# Val loss for epoch 36: 0.47981080412864685
# Train loss for epoch 37: 0.39314138889312744
# Val loss for epoch 37: 0.5042344331741333
# Train loss for epoch 38: 0.39215409755706787
# Val loss for epoch 38: 0.5195341110229492
# Train loss for epoch 39: 0.39225202798843384
# Val loss for epoch 39: 0.4863542318344116
# Train loss for epoch 40: 0.3921869993209839
# Val loss for epoch 40: 0.49701258540153503
# Train loss for epoch 41: 0.3922966718673706
# Val loss for epoch 41: 0.519921600818634
# Train loss for epoch 42: 0.39253273606300354
# Val loss for epoch 42: 0.5159307718276978
# Train loss for epoch 43: 0.3913182318210602
# Val loss for epoch 43: 0.489249050617218
# Train loss for epoch 44: 0.39129865169525146
# Val loss for epoch 44: 0.500339686870575
# Train loss for epoch 45: 0.3895443081855774
# Val loss for epoch 45: 0.5160728693008423
# Train loss for epoch 46: 0.390983909368515
# Val loss for epoch 46: 0.5338050127029419
# Train loss for epoch 47: 0.388942688703537
# Val loss for epoch 47: 0.5019201040267944
# Train loss for epoch 48: 0.3871968388557434
# Val loss for epoch 48: 0.4753769338130951
# Train loss for epoch 49: 0.38769397139549255
# Val loss for epoch 49: 0.5399883985519409
# Train loss for epoch 50: 0.38557612895965576
# Val loss for epoch 50: 0.48563528060913086

# %%
plot_loss_acc(training_losses, val_losses, training_acc, validation_acc, model_type)

# %%
model = GLM(input_dim=100*timewindow).to(device)
path =model_saving_path
model.load_state_dict(torch.load('{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, best_epoch)))
weights = model.linear.weight.view(100, timewindow)
weights_sub = weights.detach().cpu()
plt.axis('off')
plt.imshow(weights_sub)
plt.title(str(CH))
# plt.clim(-0.03, 0.03)
plt.show()

# %%
test_loss, test_acc, test_preds, test_preds_probs, test_labels, cases_wrong_0 = evaluate(model, optimizer, test_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, timewindow = timewindow, reg_type=reg_type, collect_result=True, device=device)
print('test loss:{} accuracy:{}'.format(test_loss, test_acc))
# Out:
# test loss:0.6076214909553528 accuracy:0.7239697634723238

# %%
np.mean(np.concatenate(test_labels))
# Out:
# 0.7444526

# %%
path_wrong = '/mnt/pesaranlab/People/Capstone_students/Yue/wrong_pred'
pickle.dump(cases_wrong_0, open('{}/{}_CH{}_LOSS{}_REG{}{}.pt'.format(path_wrong, model_type, CH, loss_type, reg_type, alpha), 'wb'))

# %%
predictions_test = np.concatenate(test_preds)
labels_test = np.concatenate(test_labels)

df_test = pd.DataFrame({'predictions': predictions_test, 'labels': labels_test})

cm_test = confusion_matrix(labels_test, predictions_test)
ax = plt.axes()
sn.heatmap(cm_test, annot = True, fmt = "d", ax = ax, center=2000)
ax.set_title('Test Confusion Matrix')
ax.set_xlabel('Predicted Label')
ax.set_ylabel('True Label')
plt.show()

# %%
idx = 0
print('date:{}, rec:{}, time:{}, label:{}'.format(cases_wrong_0[0][0], cases_wrong_0[0][1], cases_wrong_0[0][2], cases_wrong_0[0][3]))
print('Original data 62 CH')
weights_sub = cases_wrong_0[0][-1][0]
plt.axis('off')
plt.imshow(weights_sub)
# plt.clim(-0.03, 0.03)
plt.show()
# Out:
# date:180330, rec:003, time:1663.0, label:1.0
# Original data 62 CH

# %% [markdown]
# ### Logistic Regression with finite difference regularization

# %%
device = torch.device('cuda')

tol = 0.01
learning_rate = 0.001
num_epochs = 51
alpha = 0.1
model_type = 'LR'
loss_type = 'bce'
reg_type = 'finite_diff'
timewindow = 15
model_saving_path = '/mnt/pesaranlab/People/Capstone_students/Yue/model/model_Goose_15s_1st_1_upsample'

model = GLM(input_dim=100*timewindow).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)

# %%
epochs, training_losses, training_acc, val_losses, validation_acc = [], [], [], [], []

for epoch in range(num_epochs):
    train_loss, train_acc = train(model, optimizer, train_loader, timewindow = timewindow, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
    print('Train loss for epoch {}: {}'.format(epoch, train_loss))
    val_loss, val_acc = evaluate(model, optimizer, val_loader, alpha=alpha, timewindow = timewindow, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
    print('Val loss for epoch {}: {}'.format(epoch, val_loss))
    if val_losses:
        if val_loss < min(val_losses):
            best_epoch = epoch
            print(epoch)
            path = model_saving_path
            torch.save(model.state_dict(), '{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, epoch))
    epochs.append(epoch)
    training_losses.append(train_loss)
    training_acc.append(train_acc)
    val_losses.append(val_loss)
    validation_acc.append(val_acc)
    
    if train_loss < tol:
        break
# Out:
# Train loss for epoch 0: 0.48835405707359314
# Val loss for epoch 0: 0.5776076316833496
# Train loss for epoch 1: 0.46507886052131653
# Val loss for epoch 1: 0.5650385618209839
# 1
# Train loss for epoch 2: 0.4551863968372345
# Val loss for epoch 2: 0.5708184838294983
# Train loss for epoch 3: 0.4487701654434204
# Val loss for epoch 3: 0.5147285461425781
# 3
# Train loss for epoch 4: 0.4436693489551544
# Val loss for epoch 4: 0.532871425151825
# Train loss for epoch 5: 0.43735504150390625
# Val loss for epoch 5: 0.5292325615882874
# Train loss for epoch 6: 0.43333005905151367
# Val loss for epoch 6: 0.5159125328063965
# Train loss for epoch 7: 0.431753545999527
# Val loss for epoch 7: 0.48988232016563416
# 7
# Train loss for epoch 8: 0.4300651252269745
# Val loss for epoch 8: 0.5159211754798889
# Train loss for epoch 9: 0.4266694486141205
# Val loss for epoch 9: 0.545358419418335
# Train loss for epoch 10: 0.4253247082233429
# Val loss for epoch 10: 0.5430928468704224
# Train loss for epoch 11: 0.4236656725406647
# Val loss for epoch 11: 0.5135015249252319
# Train loss for epoch 12: 0.4221615195274353
# Val loss for epoch 12: 0.4909379780292511
# Train loss for epoch 13: 0.42074987292289734
# Val loss for epoch 13: 0.5026822090148926
# Train loss for epoch 14: 0.4186234474182129
# Val loss for epoch 14: 0.5544330477714539
# Train loss for epoch 15: 0.41788801550865173
# Val loss for epoch 15: 0.48932766914367676
# 15
# Train loss for epoch 16: 0.4158581495285034
# Val loss for epoch 16: 0.4977172017097473
# Train loss for epoch 17: 0.4148818552494049
# Val loss for epoch 17: 0.5346478223800659
# Train loss for epoch 18: 0.4142886698246002
# Val loss for epoch 18: 0.43391111493110657
# 18
# Train loss for epoch 19: 0.4142250418663025
# Val loss for epoch 19: 0.49298298358917236
# Train loss for epoch 20: 0.4122326672077179
# Val loss for epoch 20: 0.507681667804718
# Train loss for epoch 21: 0.4102783799171448
# Val loss for epoch 21: 0.4798125624656677
# Train loss for epoch 22: 0.4092084467411041
# Val loss for epoch 22: 0.5318720936775208
# Train loss for epoch 23: 0.4109428822994232
# Val loss for epoch 23: 0.5364702343940735
# Train loss for epoch 24: 0.40738049149513245
# Val loss for epoch 24: 0.47545647621154785
# Train loss for epoch 25: 0.4067430794239044
# Val loss for epoch 25: 0.5151317715644836
# Train loss for epoch 26: 0.40619978308677673
# Val loss for epoch 26: 0.4814845621585846
# Train loss for epoch 27: 0.4063698649406433
# Val loss for epoch 27: 0.5141368508338928
# Train loss for epoch 28: 0.4060893952846527
# Val loss for epoch 28: 0.5045539736747742
# Train loss for epoch 29: 0.40556252002716064
# Val loss for epoch 29: 0.5377516150474548
# Train loss for epoch 30: 0.40424367785453796
# Val loss for epoch 30: 0.48422771692276
# Train loss for epoch 31: 0.40300166606903076
# Val loss for epoch 31: 0.4883628487586975
# Train loss for epoch 32: 0.4050125181674957
# Val loss for epoch 32: 0.5170480608940125
# Train loss for epoch 33: 0.4035232663154602
# Val loss for epoch 33: 0.5084806084632874
# Train loss for epoch 34: 0.4016260802745819
# Val loss for epoch 34: 0.4843320846557617
# Train loss for epoch 35: 0.40199363231658936
# Val loss for epoch 35: 0.4800634980201721
# Train loss for epoch 36: 0.4003165662288666
# Val loss for epoch 36: 0.5012962818145752
# Train loss for epoch 37: 0.4022192656993866
# Val loss for epoch 37: 0.4568221867084503
# Train loss for epoch 38: 0.40116313099861145
# Val loss for epoch 38: 0.4900612235069275
# Train loss for epoch 39: 0.3996656835079193
# Val loss for epoch 39: 0.49487873911857605
# Train loss for epoch 40: 0.39778274297714233
# Val loss for epoch 40: 0.5578667521476746
# Train loss for epoch 41: 0.4003652334213257
# Val loss for epoch 41: 0.4645758867263794
# Train loss for epoch 42: 0.39955320954322815
# Val loss for epoch 42: 0.528408944606781
# Train loss for epoch 43: 0.3982555866241455
# Val loss for epoch 43: 0.5133482217788696
# Train loss for epoch 44: 0.39855989813804626
# Val loss for epoch 44: 0.5077356100082397
# Train loss for epoch 45: 0.3973601162433624
# Val loss for epoch 45: 0.4523889720439911
# Train loss for epoch 46: 0.39713382720947266
# Val loss for epoch 46: 0.5191792249679565
# Train loss for epoch 47: 0.3983122408390045
# Val loss for epoch 47: 0.5523293614387512
# Train loss for epoch 48: 0.3963388502597809
# Val loss for epoch 48: 0.48240211606025696
# Train loss for epoch 49: 0.3966370224952698
# Val loss for epoch 49: 0.5657631158828735
# Train loss for epoch 50: 0.39741799235343933
# Val loss for epoch 50: 0.45439672470092773

# %%
plot_loss_acc(training_losses, val_losses, training_acc, validation_acc, model_type)

# %%
model = GLM(input_dim=100*timewindow).to(device)
path =model_saving_path
model.load_state_dict(torch.load('{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, best_epoch)))
weights = model.linear.weight.view(100, timewindow)
weights_sub = weights.detach().cpu()
plt.axis('off')
plt.imshow(weights_sub)
plt.title(str(CH))
# plt.clim(-0.03, 0.03)
plt.show()

# %%
test_loss, test_acc, test_preds, test_preds_probs, test_labels, cases_wrong_0 = evaluate(model, optimizer, test_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, timewindow = timewindow, reg_type=reg_type, collect_result=True, device=device)
print('test loss:{} accuracy:{}'.format(test_loss, test_acc))
# Out:
# test loss:0.5770523548126221 accuracy:0.7346988539380639

# %%
np.mean(np.concatenate(test_labels))
# Out:
# 0.7444526

# %%
path_wrong = '/mnt/pesaranlab/People/Capstone_students/Yue/wrong_pred'
pickle.dump(cases_wrong_0, open('{}/{}_CH{}_LOSS{}_REG{}{}.pt'.format(path_wrong, model_type, CH, loss_type, reg_type, alpha), 'wb'))

# %%
predictions_test = np.concatenate(test_preds)
labels_test = np.concatenate(test_labels)

df_test = pd.DataFrame({'predictions': predictions_test, 'labels': labels_test})

cm_test = confusion_matrix(labels_test, predictions_test)
ax = plt.axes()
sn.heatmap(cm_test, annot = True, fmt = "d", ax = ax, center=2000)
ax.set_title('Test Confusion Matrix')
ax.set_xlabel('Predicted Label')
ax.set_ylabel('True Label')
plt.show()

idx = 0
print('date:{}, rec:{}, time:{}, label:{}'.format(cases_wrong_0[0][0], cases_wrong_0[0][1], cases_wrong_0[0][2], cases_wrong_0[0][3]))
print('Original data 62 CH')
weights_sub = cases_wrong_0[0][-1][0]
plt.axis('off')
plt.imshow(weights_sub)
# plt.clim(-0.03, 0.03)
plt.show()
# Out:
# date:180330, rec:003, time:1663.0, label:1.0
# Original data 62 CH

# %% [markdown]
# ### SVM without regularization

# %% [markdown]
# ### SVM with L2 regularization

# %%
device = torch.device('cuda')

tol = 0.01
learning_rate = 0.001
num_epochs = 51
alpha = 0.5 # have special meaning as margin, corresponding to 1 in the hinge loss
model_type = 'SVM'
loss_type = 'hinge'
reg_type = 'l2'

model = GLM(input_dim=100*10).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)

# %%
epochs, training_losses, training_acc, val_losses, validation_acc = [], [], [], [], []

for epoch in range(num_epochs):
    train_loss, train_acc = train(model, optimizer, train_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
    print('Train loss for epoch {}: {}'.format(epoch, train_loss))
    val_loss, val_acc = evaluate(model, optimizer, val_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
    print('Val loss for epoch {}: {}'.format(epoch, val_loss))
    if val_losses:
        if val_loss < min(val_losses):
            best_epoch = epoch
            print(epoch)
            path = '/mnt/pesaranlab/People/Capstone_students/Yue/model/model_Goose_1st_1_upsample'
            torch.save(model.state_dict(), '{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, epoch))
    epochs.append(epoch)
    training_losses.append(train_loss)
    training_acc.append(train_acc)
    val_losses.append(val_loss)
    validation_acc.append(val_acc)
    
    if train_loss < tol:
        break
# Out:
# Train loss for epoch 0: 0.6851320862770081
# Val loss for epoch 0: 0.7111771702766418
# Train loss for epoch 1: 0.6442375183105469
# Val loss for epoch 1: 0.7678999900817871
# Train loss for epoch 2: 0.6391520500183105
# Val loss for epoch 2: 0.7529788017272949
# Train loss for epoch 3: 0.6417877078056335
# Val loss for epoch 3: 0.6641672253608704
# 3
# Train loss for epoch 4: 0.6390126347541809
# Val loss for epoch 4: 0.6984342932701111
# Train loss for epoch 5: 0.6404396295547485
# Val loss for epoch 5: 0.7401537895202637
# Train loss for epoch 6: 0.639179527759552
# Val loss for epoch 6: 0.6993381977081299
# Train loss for epoch 7: 0.6405513882637024
# Val loss for epoch 7: 0.6649073362350464
# Train loss for epoch 8: 0.6384839415550232
# Val loss for epoch 8: 0.6716033816337585
# Train loss for epoch 9: 0.6426579356193542
# Val loss for epoch 9: 0.7246717214584351
# Train loss for epoch 10: 0.6410369277000427
# Val loss for epoch 10: 0.714557945728302
# Train loss for epoch 11: 0.640546977519989
# Val loss for epoch 11: 0.7000125050544739
# Train loss for epoch 12: 0.642488420009613
# Val loss for epoch 12: 0.6774542331695557
# Train loss for epoch 13: 0.6405550837516785
# Val loss for epoch 13: 0.7184460759162903
# Train loss for epoch 14: 0.6403983235359192
# Val loss for epoch 14: 0.7138395309448242
# Train loss for epoch 15: 0.6415858864784241
# Val loss for epoch 15: 0.7804384231567383
# Train loss for epoch 16: 0.639844536781311
# Val loss for epoch 16: 0.7306813597679138
# Train loss for epoch 17: 0.6411546468734741
# Val loss for epoch 17: 0.6943265795707703
# Train loss for epoch 18: 0.6401860117912292
# Val loss for epoch 18: 0.6885607838630676
# Train loss for epoch 19: 0.6396834850311279
# Val loss for epoch 19: 0.7206060290336609
# Train loss for epoch 20: 0.640455961227417
# Val loss for epoch 20: 0.702420175075531
# Train loss for epoch 21: 0.6402938961982727
# Val loss for epoch 21: 0.7104942202568054
# Train loss for epoch 22: 0.640040934085846
# Val loss for epoch 22: 0.7436862587928772
# Train loss for epoch 23: 0.6407786011695862
# Val loss for epoch 23: 0.6620125770568848
# 23
# Train loss for epoch 24: 0.6418817639350891
# Val loss for epoch 24: 0.7360722422599792
# Train loss for epoch 25: 0.6385318040847778
# Val loss for epoch 25: 0.7304670214653015
# Train loss for epoch 26: 0.640387773513794
# Val loss for epoch 26: 0.7861469388008118
# Train loss for epoch 27: 0.6426716446876526
# Val loss for epoch 27: 0.6352165341377258
# 27
# Train loss for epoch 28: 0.6454393267631531
# Val loss for epoch 28: 0.6951034069061279
# Train loss for epoch 29: 0.6385886073112488
# Val loss for epoch 29: 0.7505565285682678
# Train loss for epoch 30: 0.6399576663970947
# Val loss for epoch 30: 0.7399937510490417
# Train loss for epoch 31: 0.641554057598114
# Val loss for epoch 31: 0.6840065121650696
# Train loss for epoch 32: 0.6412416100502014
# Val loss for epoch 32: 0.6981443762779236
# Train loss for epoch 33: 0.6422035694122314
# Val loss for epoch 33: 0.6874670386314392
# Train loss for epoch 34: 0.6408448815345764
# Val loss for epoch 34: 0.8072331547737122
# Train loss for epoch 35: 0.6395016312599182
# Val loss for epoch 35: 0.730316162109375
# Train loss for epoch 36: 0.6403080224990845
# Val loss for epoch 36: 0.7818818688392639
# Train loss for epoch 37: 0.6434655785560608
# Val loss for epoch 37: 0.6429640650749207
# Train loss for epoch 38: 0.6408840417861938
# Val loss for epoch 38: 0.6359612941741943
# Train loss for epoch 39: 0.6419800519943237
# Val loss for epoch 39: 0.6931543946266174
# Train loss for epoch 40: 0.641847550868988
# Val loss for epoch 40: 0.6723946332931519
# Train loss for epoch 41: 0.6399581432342529
# Val loss for epoch 41: 0.7007078528404236
# Train loss for epoch 42: 0.637771725654602
# Val loss for epoch 42: 0.7417786717414856
# Train loss for epoch 43: 0.6427635550498962
# Val loss for epoch 43: 0.737413763999939
# Train loss for epoch 44: 0.6401107907295227
# Val loss for epoch 44: 0.6725066304206848
# Train loss for epoch 45: 0.6420534253120422
# Val loss for epoch 45: 0.6480686068534851
# Train loss for epoch 46: 0.6414241194725037
# Val loss for epoch 46: 0.7304709553718567
# Train loss for epoch 47: 0.6403049826622009
# Val loss for epoch 47: 0.7036920785903931
# Train loss for epoch 48: 0.6407722234725952
# Val loss for epoch 48: 0.6887156963348389
# Train loss for epoch 49: 0.6385686993598938
# Val loss for epoch 49: 0.7157089114189148
# Train loss for epoch 50: 0.6383669376373291
# Val loss for epoch 50: 0.7005918622016907

# %%
plot_loss_acc(training_losses, val_losses, training_acc, validation_acc, model_type)

# %%
best_epoch = 27

# %%
model = GLM(input_dim=100*10).to(device)
path = '/mnt/pesaranlab/People/Capstone_students/Yue/model/model_Goose_1st_1_upsample'
model.load_state_dict(torch.load('{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, best_epoch)))
weights = model.linear.weight.view(100, 10)
weights_sub = weights.detach().cpu()
plt.axis('off')
plt.imshow(weights_sub)
plt.title(str(CH))
# plt.clim(-0.03, 0.03)
plt.show()

# %%
test_loss, test_acc, test_preds, test_preds_probs, test_labels, cases_wrong_4 = evaluate(model, optimizer, test_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=True, device=device)
print('test loss:{} accuracy:{}'.format(test_loss, test_acc))
# Out:
# test loss:0.9384552836418152 accuracy:0.6475384615384615

# %%
predictions_test = np.concatenate(test_preds)
labels_test = np.concatenate(test_labels)

df_test = pd.DataFrame({'predictions': predictions_test, 'labels': labels_test})

cm_test = confusion_matrix(labels_test, predictions_test)
ax = plt.axes()
sn.heatmap(cm_test, annot = True, fmt = "d", ax = ax, center=2000)
ax.set_title('Test Confusion Matrix')
ax.set_xlabel('Predicted Label')
ax.set_ylabel('True Label')
plt.show()

# %%
idx = 0
print('date:{}, rec:{}, time:{}, label:{}'.format(cases_wrong_4[0][0], cases_wrong_4[0][1], cases_wrong_4[0][1], cases_wrong_4[0][3]))
print('Original data 62 CH')
weights_sub = cases_wrong_4[0][-1][0]
plt.axis('off')
plt.imshow(weights_sub)
# plt.clim(-0.03, 0.03)
plt.show()
# Out:
# date:180331, rec:004, time:004, label:1.0
# Original data 62 CH

# %% [markdown]
# ### SVM with finite difference regularization

# %%
device = torch.device('cuda')

tol = 0.01
learning_rate = 0.001
num_epochs = 51
alpha = 0.5
model_type = 'SVM'
loss_type = 'hinge'
reg_type = 'finite_diff'

model = GLM(input_dim=100*10).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)

# %%
epochs, training_losses, training_acc, val_losses, validation_acc = [], [], [], [], []

for epoch in range(num_epochs):
    train_loss, train_acc = train(model, optimizer, train_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
    print('Train loss for epoch {}: {}'.format(epoch, train_loss))
    val_loss, val_acc = evaluate(model, optimizer, val_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
    print('Val loss for epoch {}: {}'.format(epoch, val_loss))
    if val_losses:
        if val_loss < min(val_losses):
            best_epoch = epoch
            print(epoch)
            path = '/mnt/pesaranlab/People/Capstone_students/Yue/model/model_Goose_1st_1_upsample'
            torch.save(model.state_dict(), '{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, epoch))
    epochs.append(epoch)
    training_losses.append(train_loss)
    training_acc.append(train_acc)
    val_losses.append(val_loss)
    validation_acc.append(val_acc)
    
    if train_loss < tol:
        break
# Out:
# Train loss for epoch 0: 0.6690675616264343
# Val loss for epoch 0: 0.7053626179695129
# Train loss for epoch 1: 0.579605758190155
# Val loss for epoch 1: 0.6587177515029907
# 1
# Train loss for epoch 2: 0.5777973532676697
# Val loss for epoch 2: 0.661455512046814
# Train loss for epoch 3: 0.5772103071212769
# Val loss for epoch 3: 0.6873345375061035
# Train loss for epoch 4: 0.5797932744026184
# Val loss for epoch 4: 0.6312553286552429
# 4
# Train loss for epoch 5: 0.5747454762458801
# Val loss for epoch 5: 0.6387228965759277
# Train loss for epoch 6: 0.5753779411315918
# Val loss for epoch 6: 0.6457529067993164
# Train loss for epoch 7: 0.5756300687789917
# Val loss for epoch 7: 0.570262610912323
# 7
# Train loss for epoch 8: 0.5766920447349548
# Val loss for epoch 8: 0.6651206016540527
# Train loss for epoch 9: 0.5784576535224915
# Val loss for epoch 9: 0.6457962989807129
# Train loss for epoch 10: 0.5766485929489136
# Val loss for epoch 10: 0.6799610257148743
# Train loss for epoch 11: 0.577312171459198
# Val loss for epoch 11: 0.6357672810554504
# Train loss for epoch 12: 0.5765970945358276
# Val loss for epoch 12: 0.6243463754653931
# Train loss for epoch 13: 0.5763651728630066
# Val loss for epoch 13: 0.6528318524360657
# Train loss for epoch 14: 0.5787343978881836
# Val loss for epoch 14: 0.6197062134742737
# Train loss for epoch 15: 0.5766005516052246
# Val loss for epoch 15: 0.6669512391090393
# Train loss for epoch 16: 0.5740532279014587
# Val loss for epoch 16: 0.6083996891975403
# Train loss for epoch 17: 0.578143835067749
# Val loss for epoch 17: 0.6331867575645447
# Train loss for epoch 18: 0.5752172470092773
# Val loss for epoch 18: 0.6276236772537231
# Train loss for epoch 19: 0.5754168033599854
# Val loss for epoch 19: 0.6268960237503052
# Train loss for epoch 20: 0.5756818056106567
# Val loss for epoch 20: 0.6202787756919861
# Train loss for epoch 21: 0.5744140148162842
# Val loss for epoch 21: 0.6567234396934509
# Train loss for epoch 22: 0.5762956738471985
# Val loss for epoch 22: 0.6660755276679993
# Train loss for epoch 23: 0.5758554339408875
# Val loss for epoch 23: 0.6730091571807861
# Train loss for epoch 24: 0.577211320400238
# Val loss for epoch 24: 0.651534914970398
# Train loss for epoch 25: 0.5769349336624146
# Val loss for epoch 25: 0.7000337243080139
# Train loss for epoch 26: 0.5785800814628601
# Val loss for epoch 26: 0.687545120716095
# Train loss for epoch 27: 0.5782286524772644
# Val loss for epoch 27: 0.6496562361717224
# Train loss for epoch 28: 0.5788707137107849
# Val loss for epoch 28: 0.6680619120597839
# Train loss for epoch 29: 0.5760782957077026
# Val loss for epoch 29: 0.6649113893508911
# Train loss for epoch 30: 0.5756315588951111
# Val loss for epoch 30: 0.6239709854125977
# Train loss for epoch 31: 0.5757757425308228
# Val loss for epoch 31: 0.6552281379699707
# Train loss for epoch 32: 0.5736462473869324
# Val loss for epoch 32: 0.6681107878684998
# Train loss for epoch 33: 0.5752080082893372
# Val loss for epoch 33: 0.6992300748825073
# Train loss for epoch 34: 0.5773605704307556
# Val loss for epoch 34: 0.5969449281692505
# Train loss for epoch 35: 0.577599287033081
# Val loss for epoch 35: 0.7016803622245789
# Train loss for epoch 36: 0.5782400965690613
# Val loss for epoch 36: 0.6377145648002625
# Train loss for epoch 37: 0.5756941437721252
# Val loss for epoch 37: 0.689575731754303
# Train loss for epoch 38: 0.576504647731781
# Val loss for epoch 38: 0.6356939077377319
# Train loss for epoch 39: 0.579881489276886
# Val loss for epoch 39: 0.6778709292411804
# Train loss for epoch 40: 0.5781845450401306
# Val loss for epoch 40: 0.60308438539505
# Train loss for epoch 41: 0.577141284942627
# Val loss for epoch 41: 0.6428723931312561
# Train loss for epoch 42: 0.5757811665534973
# Val loss for epoch 42: 0.6472859382629395
# Train loss for epoch 43: 0.5753296613693237
# Val loss for epoch 43: 0.6884997487068176
# Train loss for epoch 44: 0.5757269859313965
# Val loss for epoch 44: 0.6618257164955139
# Train loss for epoch 45: 0.5760087966918945
# Val loss for epoch 45: 0.6461961269378662
# Train loss for epoch 46: 0.5766039490699768
# Val loss for epoch 46: 0.641828715801239
# Train loss for epoch 47: 0.5778237581253052
# Val loss for epoch 47: 0.6952266097068787
# Train loss for epoch 48: 0.5753308534622192
# Val loss for epoch 48: 0.6868410110473633
# Train loss for epoch 49: 0.5763373374938965
# Val loss for epoch 49: 0.7049767971038818
# Train loss for epoch 50: 0.5758347511291504
# Val loss for epoch 50: 0.6037036180496216

# %%
plot_loss_acc(training_losses, val_losses, training_acc, validation_acc, model_type)

# %%
best_epoch = 7

# %%
model = GLM(input_dim=100*10).to(device)
path = '/mnt/pesaranlab/People/Capstone_students/Yue/model/model_Goose_1st_1_upsample'
model.load_state_dict(torch.load('{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, best_epoch)))
weights = model.linear.weight.view(100, 10)
weights_sub = weights.detach().cpu()
plt.axis('off')
plt.imshow(weights_sub)
plt.title(str(CH))
# plt.clim(-0.03, 0.03)
plt.show()

# %%
test_loss, test_acc, test_preds, test_preds_probs, test_labels, cases_wrong_5 = evaluate(model, optimizer, test_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=True, device=device)
print('test loss:{} accuracy:{}'.format(test_loss, test_acc))
# Out:
# test loss:0.8175214529037476 accuracy:0.6916923076923077

# %%
predictions_test = np.concatenate(test_preds)
labels_test = np.concatenate(test_labels)

df_test = pd.DataFrame({'predictions': predictions_test, 'labels': labels_test})

cm_test = confusion_matrix(labels_test, predictions_test)
ax = plt.axes()
sn.heatmap(cm_test, annot = True, fmt = "d", ax = ax, center=2000)
ax.set_title('Test Confusion Matrix')
ax.set_xlabel('Predicted Label')
ax.set_ylabel('True Label')
plt.show()

# %%
idx = 0
print('date:{}, rec:{}, time:{}, label:{}'.format(cases_wrong_5[0][0], cases_wrong_5[0][1], cases_wrong_5[0][1], cases_wrong_5[0][3]))
print('Original data 62 CH')
weights_sub = cases_wrong_5[0][-1][0]
plt.axis('off')
plt.imshow(weights_sub)
# plt.clim(-0.03, 0.03)
plt.show()
# Out:
# date:180331, rec:004, time:004, label:1.0
# Original data 62 CH
