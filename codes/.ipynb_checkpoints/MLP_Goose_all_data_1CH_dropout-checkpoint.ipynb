# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
from torch.utils.data import Dataset, DataLoader
from torch import nn
import torch.nn.functional as F
from scipy.io import loadmat
import os
from os import listdir
import pandas as pd
from skimage import io
from PIL import Image
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pickle
import pdb

from utils import *

# %%
CH = 23
device = torch.device('cuda')
val_dates = ['180330','180331']
test_dates = ['180328','180329']
#load_path = '/home/bijanadmin/Desktop/Goose_data/data_Goose_1st_2/'
load_path = '/home/bijanadmin/Desktop/Goose_data/data_Goose_all_2/'
# save_path = '/mnt/pesaranlab/People/Capstone_students/Yue/model/model_Goose_1st_2_upsample'
save_path = '/home/bijanadmin/Desktop/Goose_data/data_Goose_all_2/Goose_ANN_models/'

train_files, val_files, test_files = create_files(load_path, val_dates, test_dates)
train_loader, val_loader, test_loader = create_dataloaders(train_files, val_files, test_files, load_path, batch_size=128,CH=CH)

# %%
len(train_loader), len(val_loader), len(test_loader)
# Out:
# (446, 49, 21)

# %%
for batch_idx, (data, label, date, rec, time) in enumerate(train_loader): # check shapes
    print(data.shape)
    print(label.shape)
    print(len(date))
    print(len(rec))
    print(len(time))
    break
# Out:
# torch.Size([128, 1, 100, 10])
# torch.Size([128, 1])
# 128
# 128
# 128

# %%
# movement labelled 0; non-movement labelled 1
for batch_idx, (data, label, date, rec, time) in enumerate(train_loader):
    for i in range(128):
        print('date:{}, rec:{}, time:{}, label:{}'.format(date[i], rec[i], time[i], label[i][0].numpy()))
        if label[i][0].numpy() == 0.0:
            data_sub = data[i][0]
            plt.yticks(ticks=[0, 20, 40, 60, 80, 99], labels=[round(np.logspace(0, 2.45, 100)[i]) for i in [0, 20, 40, 60, 80, 99]])
            plt.xticks(ticks=[0, 9], labels=[1, 10])
            plt.imshow(data_sub)
            plt.clim(-1.5, 1.5)
            plt.colorbar()
            plt.show()
    break
# Out:
# date:180324, rec:008, time:2448.0, label:0.0
# date:180325, rec:009, time:1330.0, label:0.0
# date:180413, rec:002, time:1600.0, label:0.0
# date:180327, rec:007, time:3350.0, label:0.0
# date:180327, rec:004, time:2174.0, label:0.0
# date:180324, rec:008, time:893.0, label:1.0
# date:180325, rec:005, time:2936.0, label:1.0
# date:180327, rec:005, time:1803.0, label:0.0
# date:180409, rec:006, time:5168.0, label:0.0
# date:180411, rec:004, time:958.0, label:1.0
# date:180409, rec:006, time:6128.0, label:0.0
# date:180323, rec:007, time:5731.0, label:0.0
# date:180325, rec:007, time:4803.0, label:0.0
# date:180327, rec:007, time:5191.0, label:0.0
# date:180413, rec:006, time:5540.0, label:1.0
# date:180324, rec:008, time:3773.0, label:0.0
# date:180409, rec:003, time:4835.0, label:1.0
# date:180411, rec:006, time:1498.0, label:1.0
# date:180325, rec:001, time:1500.0, label:0.0
# date:180323, rec:003, time:3361.0, label:1.0
# date:180323, rec:001, time:4001.0, label:0.0
# date:180409, rec:003, time:4845.0, label:1.0
# date:180411, rec:007, time:190.0, label:0.0
# date:180413, rec:003, time:4748.0, label:0.0
# date:180414, rec:007, time:4408.0, label:0.0
# date:180324, rec:008, time:5714.0, label:0.0
# date:180401, rec:002, time:7056.0, label:1.0
# date:180410, rec:006, time:889.0, label:1.0
# date:180324, rec:008, time:6104.0, label:0.0
# date:180411, rec:006, time:1911.0, label:1.0
# date:180327, rec:008, time:1932.0, label:0.0
# date:180414, rec:004, time:6045.0, label:1.0
# date:180322, rec:005, time:6939.0, label:1.0
# date:180325, rec:003, time:2185.0, label:1.0
# date:180413, rec:003, time:650.0, label:0.0
# date:180412, rec:006, time:5158.0, label:0.0
# date:180327, rec:007, time:6861.0, label:0.0
# date:180413, rec:008, time:3088.0, label:1.0
# date:180327, rec:001, time:2040.0, label:0.0
# date:180325, rec:004, time:100.0, label:1.0
# date:180325, rec:007, time:2666.0, label:0.0
# date:180411, rec:002, time:1580.0, label:1.0
# date:180412, rec:005, time:2315.0, label:0.0
# date:180414, rec:001, time:760.0, label:0.0
# date:180411, rec:006, time:1321.0, label:1.0
# date:180327, rec:001, time:4731.0, label:1.0
# date:180414, rec:003, time:4999.0, label:1.0
# date:180325, rec:004, time:3670.0, label:1.0
# date:180410, rec:006, time:3959.0, label:1.0
# date:180327, rec:002, time:3921.0, label:0.0
# date:180414, rec:001, time:3572.0, label:0.0
# date:180410, rec:006, time:1936.0, label:1.0
# date:180401, rec:001, time:420.0, label:0.0
# date:180325, rec:007, time:5573.0, label:0.0
# date:180327, rec:008, time:2872.0, label:0.0
# date:180327, rec:007, time:4501.0, label:0.0
# date:180413, rec:002, time:3367.0, label:1.0
# date:180326, rec:003, time:2969.0, label:1.0
# date:180409, rec:004, time:6905.0, label:1.0
# date:180413, rec:001, time:3940.0, label:1.0
# date:180414, rec:007, time:5308.0, label:0.0
# date:180323, rec:001, time:3885.0, label:0.0
# date:180413, rec:002, time:500.0, label:0.0
# date:180325, rec:003, time:7054.0, label:1.0
# date:180413, rec:003, time:6041.0, label:0.0
# date:180413, rec:003, time:490.0, label:0.0
# date:180325, rec:004, time:3990.0, label:1.0
# date:180325, rec:001, time:1770.0, label:0.0
# date:180327, rec:005, time:5598.0, label:0.0
# date:180327, rec:008, time:5083.0, label:0.0
# date:180413, rec:004, time:450.0, label:0.0
# date:180414, rec:005, time:1176.0, label:1.0
# date:180325, rec:006, time:5035.0, label:1.0
# date:180414, rec:002, time:3841.0, label:1.0
# date:180324, rec:006, time:6453.0, label:1.0
# date:180327, rec:007, time:4160.0, label:0.0
# date:180414, rec:007, time:2727.0, label:0.0
# date:180327, rec:008, time:4132.0, label:0.0
# date:180414, rec:003, time:585.0, label:1.0
# date:180412, rec:005, time:1777.0, label:1.0
# date:180414, rec:001, time:320.0, label:0.0
# date:180327, rec:008, time:2202.0, label:0.0
# date:180411, rec:004, time:7073.0, label:1.0
# date:180413, rec:002, time:570.0, label:0.0
# date:180326, rec:004, time:6352.0, label:1.0
# date:180414, rec:007, time:2227.0, label:0.0
# date:180326, rec:003, time:1349.0, label:1.0
# date:180327, rec:006, time:220.0, label:1.0
# date:180413, rec:001, time:1980.0, label:0.0
# date:180409, rec:006, time:4628.0, label:0.0
# date:180409, rec:006, time:4343.0, label:1.0
# date:180410, rec:005, time:1858.0, label:0.0
# date:180327, rec:001, time:480.0, label:0.0
# date:180410, rec:005, time:4602.0, label:1.0
# date:180325, rec:009, time:4619.0, label:0.0
# date:180410, rec:006, time:6202.0, label:0.0
# date:180409, rec:006, time:4728.0, label:0.0
# date:180414, rec:001, time:320.0, label:0.0
# date:180327, rec:002, time:2990.0, label:1.0
# date:180413, rec:001, time:4512.0, label:0.0
# date:180327, rec:007, time:5311.0, label:0.0
# date:180414, rec:004, time:1840.0, label:1.0
# date:180325, rec:003, time:6027.0, label:1.0
# date:180327, rec:008, time:1297.0, label:1.0
# date:180327, rec:007, time:4841.0, label:0.0
# date:180325, rec:005, time:6463.0, label:1.0
# date:180401, rec:001, time:4096.0, label:1.0
# date:180412, rec:001, time:180.0, label:0.0
# date:180325, rec:004, time:6337.0, label:1.0
# date:180411, rec:007, time:2009.0, label:0.0
# date:180324, rec:003, time:2419.0, label:1.0
# date:180322, rec:004, time:6153.0, label:1.0
# date:180327, rec:008, time:3082.0, label:0.0
# date:180327, rec:007, time:5711.0, label:0.0
# date:180410, rec:003, time:5675.0, label:1.0
# date:180413, rec:001, time:3783.0, label:0.0
# date:180412, rec:001, time:3256.0, label:0.0
# date:180413, rec:002, time:6411.0, label:0.0
# date:180412, rec:006, time:5468.0, label:0.0
# date:180324, rec:001, time:1116.0, label:1.0
# date:180324, rec:001, time:6667.0, label:1.0
# date:180412, rec:002, time:2757.0, label:1.0
# date:180412, rec:005, time:2780.0, label:0.0
# date:180413, rec:002, time:750.0, label:0.0
# date:180325, rec:001, time:1570.0, label:0.0
# date:180411, rec:007, time:1989.0, label:0.0
# date:180401, rec:001, time:6033.0, label:1.0
# date:180413, rec:003, time:360.0, label:0.0

# %%
class MLP(nn.Module): # add dropo
    def __init__(self, input_dim=100*10*62, output_dim=1, embed_dim=256,drop_prob=0.):
        super(MLP, self).__init__()
        self.linear1 = nn.Linear(input_dim, embed_dim)
        self.linear2 = nn.Linear(embed_dim, output_dim)
        self.dropout = nn.Dropout(drop_prob)
        
    def forward(self, x):
        
        x = x.reshape([x.shape[0], 1, -1]).float()
        x = self.dropout(F.relu(self.linear1(x)))
        outputs = self.linear2(x)
        
        return outputs

# %%
device = torch.device('cuda')

tol = 0.01
learning_rate = 0.001
num_epochs = 51
alpha = 0
model_type = 'MLP'
loss_type = 'bce'
reg_type = 'none'
input_dim = 1*10*100
embed_dim = 256
p = 0.


model = MLP(input_dim=input_dim, embed_dim=embed_dim,drop_prob = p).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)
model
# Out:
# MLP(
#   (linear1): Linear(in_features=1000, out_features=256, bias=True)
#   (linear2): Linear(in_features=256, out_features=1, bias=True)
#   (dropout): Dropout(p=0.0, inplace=False)
# )

# %%
(data, labels, _, _, _) = next(iter(train_loader))
data = data.to(device)
output = model(data)
output.shape
# Out:
# torch.Size([128, 1, 1])

# %%
epochs, training_losses, training_acc, val_losses, validation_acc = [], [], [], [], []

for epoch in range(num_epochs):
    train_loss, train_acc = train(model, optimizer, train_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, 
                                  reg_type=reg_type, collect_result=False, device=device)
    print('Train loss for epoch {}: {}'.format(epoch, train_loss))
    val_loss, val_acc = evaluate(model, optimizer, val_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, 
                                 reg_type=reg_type, collect_result=False, device=device)
    print('Val loss for epoch {}: {}'.format(epoch, val_loss))
    if val_losses:
        if val_loss < min(val_losses):
            best_epoch = epoch
            print(epoch)
            torch.save(model.state_dict(), '{}/{}_CH{}_LOSS{}_REG{}{}_EMBED{}_EPOCH{}.pt'.format(
                save_path, model_type, CH, loss_type, reg_type, alpha, embed_dim, epoch))
    epochs.append(epoch)
    training_losses.append(train_loss)
    training_acc.append(train_acc)
    val_losses.append(val_loss)
    validation_acc.append(val_acc)
    
    if train_loss < tol:
        break

# %%
plot_loss_acc(training_losses, val_losses, training_acc, validation_acc, model_type) # embed_dim=64

# %%
model = MLP(input_dim=100*10, embed_dim=embed_dim).to(device)
path = '/mnt/pesaranlab/People/Capstone_students/Yue/model/model_Goose_1st_1_upsample'
model.load_state_dict(torch.load('{}/{}_CH{}_LOSS{}_REG{}{}_EMBED{}_EPOCH{}.pt'.format(
    path, model_type, CH, loss_type, reg_type, alpha, embed_dim, best_epoch)))
# Out:
# <All keys matched successfully>

# %%
plt.plot(model.linear2.weight.cpu().detach().numpy().flatten())
plt.show()

# %%
test_loss, test_acc, test_preds, test_preds_probs, test_labels, cases_wrong_0 = evaluate(model, optimizer, test_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=True, device=device)
print('test loss:{} accuracy:{}'.format(test_loss, test_acc))
# Out:
# test loss:0.5320249795913696 accuracy:0.8441538461538461

# %%
predictions_test = np.concatenate(test_preds)
labels_test = np.concatenate(test_labels)

df_test = pd.DataFrame({'predictions': predictions_test, 'labels': labels_test})

cm_test = confusion_matrix(labels_test, predictions_test)
ax = plt.axes()
sn.heatmap(cm_test, annot = True, fmt = "d", ax = ax, center=2000)
ax.set_title('Test Confusion Matrix')
ax.set_xlabel('Predicted Label')
ax.set_ylabel('True Label')
plt.show()

# %%
plot_loss_acc(training_losses, val_losses, training_acc, validation_acc, model_type) # embed_dim=256

# %%
model = MLP(input_dim=100*10).to(device)
path = '/mnt/pesaranlab/People/Capstone_students/Yue/model/model_Goose_1st_1_upsample'
model.load_state_dict(torch.load('{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}.pt'.format(
    path, model_type, CH, loss_type, reg_type, alpha, 4)))
# Out:
# <All keys matched successfully>

# %%
plt.plot(model.linear2.weight.cpu().detach().numpy().flatten())
plt.show()

# %%
test_loss, test_acc, test_preds, test_preds_probs, test_labels, cases_wrong_0 = evaluate(model, optimizer, test_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=True, device=device)
print('test loss:{} accuracy:{}'.format(test_loss, test_acc))
# Out:
# test loss:0.5888658761978149 accuracy:0.8316923076923077

# %%
predictions_test = np.concatenate(test_preds)
labels_test = np.concatenate(test_labels)

df_test = pd.DataFrame({'predictions': predictions_test, 'labels': labels_test})

cm_test = confusion_matrix(labels_test, predictions_test)
ax = plt.axes()
sn.heatmap(cm_test, annot = True, fmt = "d", ax = ax, center=2000)
ax.set_title('Test Confusion Matrix')
ax.set_xlabel('Predicted Label')
ax.set_ylabel('True Label')
plt.show()
