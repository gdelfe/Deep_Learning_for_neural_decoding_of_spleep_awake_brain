# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
from torch.utils.data import Dataset, DataLoader
from torch import nn
import torch.nn.functional as F
from scipy.io import loadmat
import os
from os import listdir
import pandas as pd
from skimage import io
from PIL import Image
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pickle
import pdb

from utils import *

# %% [markdown]
# # Goose 1st + 2nd series

# %%
CH = 23
device = torch.device('cuda')
val_dates = ['180409','180412','180414']
test_dates = ['180411', '180413']
#load_path = '/home/bijanadmin/Desktop/Goose_data/data_Goose_1st_2/'
load_path = '/home/bijanadmin/Desktop/Goose_data/data_Goose_all_2/'
# save_path = '/mnt/pesaranlab/People/Capstone_students/Yue/model/model_Goose_1st_2_upsample'
save_path = '/home/bijanadmin/Desktop/Goose_data/data_Goose_all_2/Goose_ANN_models'
model_name = 'MLP_1_ch_Drop_03'


train_files, val_files, test_files = create_files(load_path, val_dates, test_dates)
train_loader, val_loader, test_loader = create_dataloaders(train_files, val_files, test_files, load_path, batch_size=128,CH=CH)

# %%
len(train_loader), len(val_loader), len(test_loader)
# Out:
# (416, 52, 48)

# %%
for batch_idx, (data, label, date, rec, time) in enumerate(train_loader): # check shapes
    print(data.shape)
    print(label.shape)
    print(len(date))
    print(len(rec))
    print(len(time))
    break
# Out:
# torch.Size([128, 1, 100, 10])
# torch.Size([128, 1])
# 128
# 128
# 128

# %%
# movement labelled 0; non-movement labelled 1
for batch_idx, (data, label, date, rec, time) in enumerate(train_loader):
    for i in range(128):
        print('date:{}, rec:{}, time:{}, label:{}'.format(date[i], rec[i], time[i], label[i][0].numpy()))
        if label[i][0].numpy() == 0.0:
            data_sub = data[i][0]
            plt.yticks(ticks=[0, 20, 40, 60, 80, 99], labels=[round(np.logspace(0, 2.45, 100)[i]) for i in [0, 20, 40, 60, 80, 99]])
            plt.xticks(ticks=[0, 9], labels=[1, 10])
            plt.imshow(data_sub)
            plt.clim(-1.5, 1.5)
            plt.colorbar()
            plt.show()
    break
# Out:
# date:180325, rec:005, time:6093.0, label:1.0
# date:180322, rec:002, time:4659.0, label:1.0
# date:180327, rec:002, time:2330.0, label:1.0
# date:180327, rec:005, time:6655.0, label:1.0
# date:180322, rec:007, time:4840.0, label:0.0
# date:180322, rec:004, time:6933.0, label:1.0
# date:180323, rec:005, time:2867.0, label:1.0
# date:180410, rec:003, time:891.0, label:1.0
# date:180327, rec:001, time:1890.0, label:0.0
# date:180325, rec:007, time:4833.0, label:0.0
# date:180401, rec:001, time:460.0, label:0.0
# date:180323, rec:002, time:6226.0, label:1.0
# date:180325, rec:009, time:360.0, label:0.0
# date:180327, rec:008, time:2642.0, label:0.0
# date:180330, rec:001, time:580.0, label:0.0
# date:180322, rec:007, time:4650.0, label:0.0
# date:180323, rec:007, time:5571.0, label:0.0
# date:180327, rec:006, time:3867.0, label:1.0
# date:180401, rec:001, time:6553.0, label:1.0
# date:180327, rec:007, time:1310.0, label:0.0
# date:180325, rec:001, time:5884.0, label:1.0
# date:180322, rec:003, time:5213.0, label:1.0
# date:180330, rec:008, time:401.0, label:0.0
# date:180410, rec:004, time:2008.0, label:1.0
# date:180324, rec:009, time:1248.0, label:0.0
# date:180410, rec:002, time:3969.0, label:1.0
# date:180331, rec:007, time:6498.0, label:0.0
# date:180327, rec:007, time:1770.0, label:0.0
# date:180327, rec:001, time:6692.0, label:0.0
# date:180325, rec:006, time:6061.0, label:1.0
# date:180324, rec:008, time:6074.0, label:0.0
# date:180329, rec:002, time:509.0, label:1.0
# date:180322, rec:005, time:6574.0, label:1.0
# date:180324, rec:004, time:5019.0, label:1.0
# date:180329, rec:001, time:5739.0, label:1.0
# date:180330, rec:001, time:4436.0, label:0.0
# date:180327, rec:004, time:2584.0, label:0.0
# date:180330, rec:009, time:6181.0, label:0.0
# date:180330, rec:008, time:2736.0, label:0.0
# date:180327, rec:008, time:3272.0, label:0.0
# date:180327, rec:008, time:4202.0, label:0.0
# date:180331, rec:004, time:6411.0, label:0.0
# date:180330, rec:008, time:3696.0, label:0.0
# date:180329, rec:004, time:1365.0, label:0.0
# date:180324, rec:006, time:902.0, label:1.0
# date:180325, rec:003, time:4623.0, label:0.0
# date:180327, rec:008, time:4563.0, label:0.0
# date:180322, rec:007, time:1397.0, label:0.0
# date:180327, rec:008, time:2912.0, label:0.0
# date:180331, rec:004, time:6476.0, label:1.0
# date:180325, rec:009, time:2030.0, label:0.0
# date:180327, rec:007, time:5751.0, label:0.0
# date:180327, rec:008, time:3002.0, label:0.0
# date:180327, rec:007, time:6051.0, label:0.0
# date:180330, rec:009, time:1434.0, label:0.0
# date:180325, rec:004, time:5677.0, label:1.0
# date:180326, rec:003, time:3299.0, label:1.0
# date:180330, rec:009, time:5901.0, label:0.0
# date:180331, rec:001, time:5517.0, label:1.0
# date:180401, rec:001, time:1540.0, label:0.0
# date:180325, rec:007, time:2796.0, label:0.0
# date:180330, rec:005, time:1646.0, label:1.0
# date:180323, rec:002, time:3929.0, label:1.0
# date:180410, rec:002, time:5182.0, label:1.0
# date:180324, rec:004, time:1899.0, label:1.0
# date:180331, rec:007, time:4677.0, label:0.0
# date:180324, rec:009, time:670.0, label:0.0
# date:180327, rec:008, time:3332.0, label:0.0
# date:180329, rec:001, time:270.0, label:0.0
# date:180322, rec:007, time:3920.0, label:0.0
# date:180327, rec:007, time:6211.0, label:0.0
# date:180323, rec:003, time:5011.0, label:1.0
# date:180326, rec:003, time:5183.0, label:0.0
# date:180323, rec:001, time:100.0, label:0.0
# date:180330, rec:008, time:6055.0, label:0.0
# date:180327, rec:001, time:7062.0, label:0.0
# date:180331, rec:007, time:4187.0, label:0.0
# date:180327, rec:007, time:6641.0, label:0.0
# date:180323, rec:005, time:4471.0, label:1.0
# date:180329, rec:001, time:1430.0, label:0.0
# date:180410, rec:006, time:5812.0, label:0.0
# date:180329, rec:001, time:1400.0, label:0.0
# date:180327, rec:008, time:1582.0, label:0.0
# date:180323, rec:007, time:4351.0, label:0.0
# date:180329, rec:001, time:6281.0, label:1.0
# date:180327, rec:001, time:360.0, label:0.0
# date:180330, rec:009, time:3630.0, label:0.0
# date:180323, rec:002, time:3999.0, label:1.0
# date:180325, rec:001, time:950.0, label:0.0
# date:180325, rec:007, time:2636.0, label:0.0
# date:180329, rec:005, time:1815.0, label:1.0
# date:180331, rec:007, time:6608.0, label:0.0
# date:180330, rec:009, time:2844.0, label:1.0
# date:180329, rec:004, time:5921.0, label:1.0
# date:180327, rec:001, time:4183.0, label:1.0
# date:180324, rec:006, time:1523.0, label:1.0
# date:180327, rec:007, time:6931.0, label:0.0
# date:180327, rec:001, time:6872.0, label:0.0
# date:180324, rec:008, time:1451.0, label:0.0
# date:180327, rec:007, time:1910.0, label:0.0
# date:180327, rec:001, time:130.0, label:0.0
# date:180327, rec:005, time:3880.0, label:1.0
# date:180327, rec:008, time:1097.0, label:1.0
# date:180324, rec:001, time:5460.0, label:0.0
# date:180324, rec:009, time:710.0, label:0.0
# date:180324, rec:004, time:5299.0, label:1.0
# date:180326, rec:003, time:979.0, label:1.0
# date:180324, rec:008, time:6094.0, label:0.0
# date:180410, rec:005, time:5297.0, label:1.0
# date:180329, rec:002, time:6077.0, label:1.0
# date:180330, rec:009, time:1644.0, label:0.0
# date:180323, rec:002, time:6441.0, label:1.0
# date:180327, rec:001, time:6175.0, label:1.0
# date:180327, rec:008, time:1892.0, label:0.0
# date:180324, rec:008, time:6134.0, label:0.0
# date:180327, rec:007, time:6791.0, label:0.0
# date:180327, rec:007, time:5331.0, label:0.0
# date:180324, rec:005, time:2430.0, label:1.0
# date:180324, rec:008, time:6754.0, label:0.0
# date:180323, rec:004, time:5089.0, label:1.0
# date:180327, rec:001, time:1380.0, label:0.0
# date:180325, rec:005, time:4903.0, label:1.0
# date:180327, rec:006, time:6490.0, label:1.0
# date:180329, rec:001, time:1070.0, label:0.0
# date:180329, rec:005, time:2015.0, label:1.0
# date:180331, rec:001, time:2290.0, label:0.0
# date:180330, rec:009, time:1564.0, label:0.0
# date:180327, rec:005, time:2356.0, label:1.0

# %%
class MLP(nn.Module): # add dropo
    def __init__(self, input_dim=100*10*62, output_dim=1, embed_dim=256,drop_prob=0.):
        super(MLP, self).__init__()
        self.linear1 = nn.Linear(input_dim, embed_dim)
        self.linear2 = nn.Linear(embed_dim, output_dim)
        self.dropout = nn.Dropout(drop_prob)
        
    def forward(self, x):
        
        x = x.reshape([x.shape[0], 1, -1]).float()
        x = self.dropout(F.relu(self.linear1(x)))
        outputs = self.linear2(x)
        
        return outputs

# %%
device = torch.device('cuda')

tol = 0.01
learning_rate = 0.001
num_epochs = 51
alpha = 0
model_type = 'MLP'
loss_type = 'bce'
reg_type = 'none'
input_dim = 1*10*100
embed_dim = 256
dropout_all = [0.1,0.3,0.5,0.7,0.9,1]

# %%
for d in range(0,len(dropout_all)):
    dropout = dropout_all[d]
    model = MLP(input_dim=input_dim, embed_dim=embed_dim,drop_prob = dropout).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)
    (data, labels, _, _, _) = next(iter(train_loader))
    data = data.to(device)
    output = model(data)
    print('dropout: ', dropout)
    output.shape

    epochs, training_losses, training_acc, val_losses, validation_acc = [], [], [], [], []

    for epoch in range(num_epochs):
        train_loss, train_acc = train(model, optimizer, train_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, 
                                      reg_type=reg_type, collect_result=False, device=device)
        print('Train loss for epoch {}: {}'.format(epoch, train_loss))
        val_loss, val_acc = evaluate(model, optimizer, val_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, 
                                     reg_type=reg_type, collect_result=False, device=device)
        print('Val loss for epoch {}: {}'.format(epoch, val_loss))
        if epoch == 0:
            torch.save(model.state_dict(), '{}/{}_CH{}_LOSS{}_REG{}{}_DO{}_EMBED{}_EPOCH{}_MODEL_{}.pt'.format(
                    save_path, model_type, CH, loss_type, reg_type, alpha, dropout, embed_dim, epoch,model_name))

        if val_losses:
            
            if val_loss < min(val_losses):
                best_epoch = epoch
                print(epoch)
                torch.save(model.state_dict(), '{}/{}_CH{}_LOSS{}_REG{}{}_DO{}_EMBED{}_EPOCH{}_MODEL_{}.pt'.format(
                    save_path, model_type, CH, loss_type, reg_type, alpha, dropout, embed_dim, epoch,model_name))
        epochs.append(epoch)
        training_losses.append(train_loss)
        training_acc.append(train_acc)
        val_losses.append(val_loss)
        validation_acc.append(val_acc)

        if train_loss < tol:
            break
    plot_loss_acc(training_losses, val_losses, training_acc, validation_acc, model_type) # embed_dim=64
# Out:
# dropout:  0.1
# Train loss for epoch 0: 0.34281590580940247
# Val loss for epoch 0: 0.2787000834941864
# Train loss for epoch 1: 0.2344484031200409
# Val loss for epoch 1: 0.288552463054657
# Train loss for epoch 2: 0.1982542723417282
# Val loss for epoch 2: 0.2964707314968109
# Train loss for epoch 3: 0.17439241707324982
# Val loss for epoch 3: 0.31730225682258606
# Train loss for epoch 4: 0.1586615890264511
# Val loss for epoch 4: 0.3239644467830658
# Train loss for epoch 5: 0.14446189999580383
# Val loss for epoch 5: 0.31426331400871277
# Train loss for epoch 6: 0.13515865802764893
# Val loss for epoch 6: 0.394182950258255
# Train loss for epoch 7: 0.13441532850265503
# Val loss for epoch 7: 0.3296968340873718
# Train loss for epoch 8: 0.12642911076545715
# Val loss for epoch 8: 0.38254520297050476
# Train loss for epoch 9: 0.10596092790365219
# Val loss for epoch 9: 0.4238676428794861
# Train loss for epoch 10: 0.10981818288564682
# Val loss for epoch 10: 0.4068177342414856
# Train loss for epoch 11: 0.11295367032289505
# Val loss for epoch 11: 0.4116390347480774
# Train loss for epoch 12: 0.09464653581380844
# Val loss for epoch 12: 0.46651691198349
# Train loss for epoch 13: 0.09301181137561798
# Val loss for epoch 13: 0.48628881573677063
# Train loss for epoch 14: 0.0932345986366272
# Val loss for epoch 14: 0.4958096146583557
# Train loss for epoch 15: 0.09363236278295517
# Val loss for epoch 15: 0.5074273347854614
# Train loss for epoch 16: 0.08860249817371368
# Val loss for epoch 16: 0.5576095581054688
# Train loss for epoch 17: 0.08552993088960648
# Val loss for epoch 17: 0.6636574268341064
# Train loss for epoch 18: 0.0862777903676033
# Val loss for epoch 18: 0.5691254138946533
# Train loss for epoch 19: 0.07653839141130447
# Val loss for epoch 19: 0.7053017616271973
# Train loss for epoch 20: 0.0807253047823906
# Val loss for epoch 20: 0.6805943250656128
# Train loss for epoch 21: 0.07883347570896149
# Val loss for epoch 21: 0.6414803862571716
# Train loss for epoch 22: 0.06744677573442459
# Val loss for epoch 22: 0.7273820638656616
# Train loss for epoch 23: 0.07133540511131287
# Val loss for epoch 23: 0.7493990659713745
# Train loss for epoch 24: 0.08087221533060074
# Val loss for epoch 24: 0.7416341304779053
# Train loss for epoch 25: 0.06749475002288818
# Val loss for epoch 25: 0.7567079663276672
# Train loss for epoch 26: 0.0683201253414154
# Val loss for epoch 26: 0.8600662350654602
# Train loss for epoch 27: 0.06263727694749832
# Val loss for epoch 27: 1.1024996042251587
# Train loss for epoch 28: 0.058184217661619186
# Val loss for epoch 28: 1.05258047580719
# Train loss for epoch 29: 0.08207176625728607
# Val loss for epoch 29: 0.9305508732795715
# Train loss for epoch 30: 0.05149051174521446
# Val loss for epoch 30: 0.9641490578651428
# Train loss for epoch 31: 0.054995812475681305
# Val loss for epoch 31: 1.0013359785079956
# Train loss for epoch 32: 0.05679313838481903
# Val loss for epoch 32: 1.0301700830459595
# Train loss for epoch 33: 0.07296054065227509
# Val loss for epoch 33: 1.1649446487426758
# Train loss for epoch 34: 0.051556628197431564
# Val loss for epoch 34: 1.092776894569397
# Train loss for epoch 35: 0.06002659350633621
# Val loss for epoch 35: 1.0783923864364624
# Train loss for epoch 36: 0.06346927583217621
# Val loss for epoch 36: 1.398188829421997
# Train loss for epoch 37: 0.059657830744981766
# Val loss for epoch 37: 1.252947449684143
# Train loss for epoch 38: 0.052388835698366165
# Val loss for epoch 38: 1.3080275058746338
# Train loss for epoch 39: 0.055658288300037384
# Val loss for epoch 39: 1.4372793436050415
# Train loss for epoch 40: 0.05310241878032684
# Val loss for epoch 40: 1.118119239807129
# Train loss for epoch 41: 0.04922615364193916
# Val loss for epoch 41: 1.3496228456497192
# Train loss for epoch 42: 0.04259299486875534
# Val loss for epoch 42: 1.4526389837265015
# Train loss for epoch 43: 0.03762873634696007
# Val loss for epoch 43: 1.3414875268936157
# Train loss for epoch 44: 0.04347068443894386
# Val loss for epoch 44: 1.2955999374389648
# Train loss for epoch 45: 0.04203993082046509
# Val loss for epoch 45: 1.5096927881240845
# Train loss for epoch 46: 0.04610725864768028
# Val loss for epoch 46: 1.7037800550460815
# Train loss for epoch 47: 0.04823959618806839
# Val loss for epoch 47: 1.380606770515442
# Train loss for epoch 48: 0.0448664166033268
# Val loss for epoch 48: 1.4891382455825806
# Train loss for epoch 49: 0.04132288694381714
# Val loss for epoch 49: 1.7022145986557007
# Train loss for epoch 50: 0.040762629359960556
# Val loss for epoch 50: 1.5576088428497314
# dropout:  0.3
# Train loss for epoch 0: 0.36953872442245483
# Val loss for epoch 0: 0.31582385301589966
# Train loss for epoch 1: 0.27276334166526794
# Val loss for epoch 1: 0.31624260544776917
# Train loss for epoch 2: 0.23138576745986938
# Val loss for epoch 2: 0.28806599974632263
# 2
# Train loss for epoch 3: 0.22319847345352173
# Val loss for epoch 3: 0.28227150440216064
# 3
# Train loss for epoch 4: 0.19213862717151642
# Val loss for epoch 4: 0.290407657623291
# Train loss for epoch 5: 0.18250280618667603
# Val loss for epoch 5: 0.29597094655036926
# Train loss for epoch 6: 0.17153921723365784
# Val loss for epoch 6: 0.3340047001838684
# Train loss for epoch 7: 0.17217479646205902
# Val loss for epoch 7: 0.3039514720439911
# Train loss for epoch 8: 0.15792615711688995
# Val loss for epoch 8: 0.3097515106201172
# Train loss for epoch 9: 0.1552661657333374
# Val loss for epoch 9: 0.3036574125289917
# Train loss for epoch 10: 0.1477034091949463
# Val loss for epoch 10: 0.31215178966522217
# Train loss for epoch 11: 0.1457730084657669
# Val loss for epoch 11: 0.3553968369960785
# Train loss for epoch 12: 0.13589954376220703
# Val loss for epoch 12: 0.369841605424881
# Train loss for epoch 13: 0.1331159621477127
# Val loss for epoch 13: 0.3568533957004547
# Train loss for epoch 14: 0.13247741758823395
# Val loss for epoch 14: 0.3445187509059906
# Train loss for epoch 15: 0.1288970410823822
# Val loss for epoch 15: 0.4139035940170288
# Train loss for epoch 16: 0.11797741055488586
# Val loss for epoch 16: 0.4561282694339752
# Train loss for epoch 17: 0.12308693677186966
# Val loss for epoch 17: 0.41121798753738403
# Train loss for epoch 18: 0.11575949937105179
# Val loss for epoch 18: 0.4223411977291107
# Train loss for epoch 19: 0.11446136236190796
# Val loss for epoch 19: 0.4331216812133789
# Train loss for epoch 20: 0.10894230008125305
# Val loss for epoch 20: 0.463075190782547
# Train loss for epoch 21: 0.10895556956529617
# Val loss for epoch 21: 0.4703086316585541
# Train loss for epoch 22: 0.10893451422452927
# Val loss for epoch 22: 0.5012997388839722
# Train loss for epoch 23: 0.11792898178100586
# Val loss for epoch 23: 0.5262017846107483
# Train loss for epoch 24: 0.11429378390312195
# Val loss for epoch 24: 0.47676974534988403
# Train loss for epoch 25: 0.09719014912843704
# Val loss for epoch 25: 0.47527244687080383
# Train loss for epoch 26: 0.10360750555992126
# Val loss for epoch 26: 0.5441541075706482
# Train loss for epoch 27: 0.09256551414728165
# Val loss for epoch 27: 0.4918239712715149
# Train loss for epoch 28: 0.09458309412002563
# Val loss for epoch 28: 0.635488748550415
# Train loss for epoch 29: 0.09056678414344788
# Val loss for epoch 29: 0.6973552107810974
# Train loss for epoch 30: 0.092758908867836
# Val loss for epoch 30: 0.6806381940841675
# Train loss for epoch 31: 0.08864292502403259
# Val loss for epoch 31: 0.6457716822624207
# Train loss for epoch 32: 0.09603694081306458
# Val loss for epoch 32: 0.5896592736244202
# Train loss for epoch 33: 0.094985231757164
# Val loss for epoch 33: 0.6127544045448303
# Train loss for epoch 34: 0.08286114782094955
# Val loss for epoch 34: 0.6128905415534973
# Train loss for epoch 35: 0.08626790344715118
# Val loss for epoch 35: 0.7215920686721802
# Train loss for epoch 36: 0.0773601233959198
# Val loss for epoch 36: 0.6855083107948303
# Train loss for epoch 37: 0.08782236278057098
# Val loss for epoch 37: 0.7440820932388306
# Train loss for epoch 38: 0.07316464930772781
# Val loss for epoch 38: 0.8506307601928711
# Train loss for epoch 39: 0.0914580300450325
# Val loss for epoch 39: 0.853081464767456
# Train loss for epoch 40: 0.07859795540571213
# Val loss for epoch 40: 1.0512466430664062
# Train loss for epoch 41: 0.07263822108507156
# Val loss for epoch 41: 1.0222662687301636
# Train loss for epoch 42: 0.08733426034450531
# Val loss for epoch 42: 0.8627366423606873
# Train loss for epoch 43: 0.06969205290079117
# Val loss for epoch 43: 0.9813953638076782
# Train loss for epoch 44: 0.08453010022640228
# Val loss for epoch 44: 0.9838396310806274
# Train loss for epoch 45: 0.07563768327236176
# Val loss for epoch 45: 1.015321135520935
# Train loss for epoch 46: 0.06519236415624619
# Val loss for epoch 46: 1.0159281492233276
# Train loss for epoch 47: 0.0794573724269867
# Val loss for epoch 47: 1.0800293684005737
# Train loss for epoch 48: 0.06737534701824188
# Val loss for epoch 48: 1.263576626777649
# Train loss for epoch 49: 0.07255035638809204
# Val loss for epoch 49: 1.0719622373580933
# Train loss for epoch 50: 0.08329872041940689
# Val loss for epoch 50: 1.0359336137771606
# dropout:  0.5
# Train loss for epoch 0: 0.38826417922973633
# Val loss for epoch 0: 0.34781497716903687
# Train loss for epoch 1: 0.306262731552124
# Val loss for epoch 1: 0.28928443789482117
# 1
# Train loss for epoch 2: 0.2740726172924042
# Val loss for epoch 2: 0.29107770323753357
# Train loss for epoch 3: 0.25209325551986694
# Val loss for epoch 3: 0.26195597648620605
# 3
# Train loss for epoch 4: 0.2377704232931137
# Val loss for epoch 4: 0.2589702010154724
# 4
# Train loss for epoch 5: 0.22721748054027557
# Val loss for epoch 5: 0.2692064046859741
# Train loss for epoch 6: 0.21967142820358276
# Val loss for epoch 6: 0.284463495016098
# Train loss for epoch 7: 0.20359554886817932
# Val loss for epoch 7: 0.2949066460132599
# Train loss for epoch 8: 0.19661517441272736
# Val loss for epoch 8: 0.2596575915813446
# Train loss for epoch 9: 0.19446665048599243
# Val loss for epoch 9: 0.2813016474246979
# Train loss for epoch 10: 0.18608985841274261
# Val loss for epoch 10: 0.26746854186058044
# Train loss for epoch 11: 0.1780909299850464
# Val loss for epoch 11: 0.28867635130882263
# Train loss for epoch 12: 0.18180851638317108
# Val loss for epoch 12: 0.27750492095947266
# Train loss for epoch 13: 0.17424063384532928
# Val loss for epoch 13: 0.28498220443725586
# Train loss for epoch 14: 0.16411079466342926
# Val loss for epoch 14: 0.30745354294776917
# Train loss for epoch 15: 0.16863921284675598
# Val loss for epoch 15: 0.29017373919487
# Train loss for epoch 16: 0.16183441877365112
# Val loss for epoch 16: 0.3064253032207489
# Train loss for epoch 17: 0.1594446748495102
# Val loss for epoch 17: 0.3104759752750397
# Train loss for epoch 18: 0.16063188016414642
# Val loss for epoch 18: 0.3119460344314575
# Train loss for epoch 19: 0.1539289951324463
# Val loss for epoch 19: 0.31652817130088806
# Train loss for epoch 20: 0.1581030637025833
# Val loss for epoch 20: 0.31473761796951294
# Train loss for epoch 21: 0.1458587497472763
# Val loss for epoch 21: 0.350266695022583
# Train loss for epoch 22: 0.1476319134235382
# Val loss for epoch 22: 0.32704219222068787
# Train loss for epoch 23: 0.1418001502752304
# Val loss for epoch 23: 0.34270456433296204
# Train loss for epoch 24: 0.13969966769218445
# Val loss for epoch 24: 0.3360308110713959
# Train loss for epoch 25: 0.14179350435733795
# Val loss for epoch 25: 0.34188687801361084
# Train loss for epoch 26: 0.13985076546669006
# Val loss for epoch 26: 0.4053454101085663
# Train loss for epoch 27: 0.1319214403629303
# Val loss for epoch 27: 0.39467862248420715
# Train loss for epoch 28: 0.13036057353019714
# Val loss for epoch 28: 0.4068194031715393
# Train loss for epoch 29: 0.130557119846344
# Val loss for epoch 29: 0.3941196799278259
# Train loss for epoch 30: 0.1370554268360138
# Val loss for epoch 30: 0.3826371431350708
# Train loss for epoch 31: 0.12812890112400055
# Val loss for epoch 31: 0.3808879852294922
# Train loss for epoch 32: 0.12849944829940796
# Val loss for epoch 32: 0.4542812407016754
# Train loss for epoch 33: 0.12193126976490021
# Val loss for epoch 33: 0.48189014196395874
# Train loss for epoch 34: 0.12099963426589966
# Val loss for epoch 34: 0.5352780222892761
# Train loss for epoch 35: 0.11921132355928421
# Val loss for epoch 35: 0.4707084596157074
# Train loss for epoch 36: 0.12349381297826767
# Val loss for epoch 36: 0.4475703835487366
# Train loss for epoch 37: 0.11846887320280075
# Val loss for epoch 37: 0.47717931866645813
# Train loss for epoch 38: 0.12471358478069305
# Val loss for epoch 38: 0.46782025694847107
# Train loss for epoch 39: 0.11576753109693527
# Val loss for epoch 39: 0.44361740350723267
# Train loss for epoch 40: 0.11201829463243484
# Val loss for epoch 40: 0.4281856119632721
# Train loss for epoch 41: 0.10837803781032562
# Val loss for epoch 41: 0.5295636653900146
# Train loss for epoch 42: 0.10989319533109665
# Val loss for epoch 42: 0.5479327440261841
# Train loss for epoch 43: 0.11674609780311584
# Val loss for epoch 43: 0.5992351174354553
# Train loss for epoch 44: 0.11192714422941208
# Val loss for epoch 44: 0.5840497016906738
# Train loss for epoch 45: 0.11314582079648972
# Val loss for epoch 45: 0.6544063687324524
# Train loss for epoch 46: 0.10727576166391373
# Val loss for epoch 46: 0.6274530291557312
# Train loss for epoch 47: 0.10478146374225616
# Val loss for epoch 47: 0.602791965007782
# Train loss for epoch 48: 0.10287214815616608
# Val loss for epoch 48: 0.7407710552215576
# Train loss for epoch 49: 0.10160651057958603
# Val loss for epoch 49: 0.7715280652046204
# Train loss for epoch 50: 0.10087011009454727
# Val loss for epoch 50: 0.6357407569885254
# dropout:  0.7
# Train loss for epoch 0: 0.4282852113246918
# Val loss for epoch 0: 0.3496866226196289
# Train loss for epoch 1: 0.36495134234428406
# Val loss for epoch 1: 0.3071572482585907
# 1
# Train loss for epoch 2: 0.3390060067176819
# Val loss for epoch 2: 0.29953545331954956
# 2
# Train loss for epoch 3: 0.31707996129989624
# Val loss for epoch 3: 0.28413793444633484
# 3
# Train loss for epoch 4: 0.301297664642334
# Val loss for epoch 4: 0.29042670130729675
# Train loss for epoch 5: 0.29396912455558777
# Val loss for epoch 5: 0.2677317261695862
# 5
# Train loss for epoch 6: 0.27634620666503906
# Val loss for epoch 6: 0.2768457233905792
# Train loss for epoch 7: 0.2736678123474121
# Val loss for epoch 7: 0.26107725501060486
# 7
# Train loss for epoch 8: 0.2629781663417816
# Val loss for epoch 8: 0.24946752190589905
# 8
# Train loss for epoch 9: 0.2571695148944855
# Val loss for epoch 9: 0.2572158873081207
# Train loss for epoch 10: 0.2504761219024658
# Val loss for epoch 10: 0.2483082115650177
# 10
# Train loss for epoch 11: 0.24737600982189178
# Val loss for epoch 11: 0.24030375480651855
# 11
# Train loss for epoch 12: 0.23651637136936188
# Val loss for epoch 12: 0.26462623476982117
# Train loss for epoch 13: 0.23846694827079773
# Val loss for epoch 13: 0.25248053669929504
# Train loss for epoch 14: 0.22769157588481903
# Val loss for epoch 14: 0.24673745036125183
# Train loss for epoch 15: 0.23735037446022034
# Val loss for epoch 15: 0.25819408893585205
# Train loss for epoch 16: 0.22785210609436035
# Val loss for epoch 16: 0.2565613389015198
# Train loss for epoch 17: 0.21879205107688904
# Val loss for epoch 17: 0.2630966007709503
# Train loss for epoch 18: 0.2137691080570221
# Val loss for epoch 18: 0.256490021944046
# Train loss for epoch 19: 0.21022139489650726
# Val loss for epoch 19: 0.2616841197013855
# Train loss for epoch 20: 0.20851704478263855
# Val loss for epoch 20: 0.2553144097328186
# Train loss for epoch 21: 0.21027682721614838
# Val loss for epoch 21: 0.2593519389629364
# Train loss for epoch 22: 0.2045883983373642
# Val loss for epoch 22: 0.26615530252456665
# Train loss for epoch 23: 0.2020137757062912
# Val loss for epoch 23: 0.2637617886066437
# Train loss for epoch 24: 0.2003103494644165
# Val loss for epoch 24: 0.2596544921398163
# Train loss for epoch 25: 0.1991664469242096
# Val loss for epoch 25: 0.27244848012924194
# Train loss for epoch 26: 0.19692741334438324
# Val loss for epoch 26: 0.2766712009906769
# Train loss for epoch 27: 0.19450438022613525
# Val loss for epoch 27: 0.28835156559944153
# Train loss for epoch 28: 0.19145144522190094
# Val loss for epoch 28: 0.3001900315284729
# Train loss for epoch 29: 0.18827439844608307
# Val loss for epoch 29: 0.2964528501033783
# Train loss for epoch 30: 0.18692561984062195
# Val loss for epoch 30: 0.27198904752731323
# Train loss for epoch 31: 0.18568409979343414
# Val loss for epoch 31: 0.28000038862228394
# Train loss for epoch 32: 0.1901020109653473
# Val loss for epoch 32: 0.3012077212333679
# Train loss for epoch 33: 0.18225210905075073
# Val loss for epoch 33: 0.3007493019104004
# Train loss for epoch 34: 0.18766078352928162
# Val loss for epoch 34: 0.29907920956611633
# Train loss for epoch 35: 0.1857232302427292
# Val loss for epoch 35: 0.28055351972579956
# Train loss for epoch 36: 0.17766793072223663
# Val loss for epoch 36: 0.2978481352329254
# Train loss for epoch 37: 0.17378298938274384
# Val loss for epoch 37: 0.30212709307670593
# Train loss for epoch 38: 0.1701190024614334
# Val loss for epoch 38: 0.3085431158542633
# Train loss for epoch 39: 0.17433598637580872
# Val loss for epoch 39: 0.3136456608772278
# Train loss for epoch 40: 0.1708453744649887
# Val loss for epoch 40: 0.3006013333797455
# Train loss for epoch 41: 0.17042014002799988
# Val loss for epoch 41: 0.3084143400192261
# Train loss for epoch 42: 0.16732043027877808
# Val loss for epoch 42: 0.31275591254234314
# Train loss for epoch 43: 0.16746516525745392
# Val loss for epoch 43: 0.31895601749420166
# Train loss for epoch 44: 0.16798076033592224
# Val loss for epoch 44: 0.33778634667396545
# Train loss for epoch 45: 0.1618824452161789
# Val loss for epoch 45: 0.33093416690826416
# Train loss for epoch 46: 0.16056251525878906
# Val loss for epoch 46: 0.33368927240371704
# Train loss for epoch 47: 0.17050959169864655
# Val loss for epoch 47: 0.33717548847198486
# Train loss for epoch 48: 0.16629573702812195
# Val loss for epoch 48: 0.3316394090652466
# Train loss for epoch 49: 0.16099944710731506
# Val loss for epoch 49: 0.3427947163581848
# Train loss for epoch 50: 0.15763606131076813
# Val loss for epoch 50: 0.3446296453475952
# dropout:  0.9
# Train loss for epoch 0: 0.5040687918663025
# Val loss for epoch 0: 0.45985665917396545
# Train loss for epoch 1: 0.4655873775482178
# Val loss for epoch 1: 0.438922256231308
# 1
# Train loss for epoch 2: 0.4517093896865845
# Val loss for epoch 2: 0.3823639452457428
# 2
# Train loss for epoch 3: 0.44256797432899475
# Val loss for epoch 3: 0.37689515948295593
# 3
# Train loss for epoch 4: 0.4321069121360779
# Val loss for epoch 4: 0.3703621029853821
# 4
# Train loss for epoch 5: 0.42829081416130066
# Val loss for epoch 5: 0.32404136657714844
# 5
# Train loss for epoch 6: 0.4218331277370453
# Val loss for epoch 6: 0.35490238666534424
# Train loss for epoch 7: 0.41495272517204285
# Val loss for epoch 7: 0.33550137281417847
# Train loss for epoch 8: 0.40728452801704407
# Val loss for epoch 8: 0.3355637788772583
# Train loss for epoch 9: 0.40224722027778625
# Val loss for epoch 9: 0.33384355902671814
# Train loss for epoch 10: 0.3995177149772644
# Val loss for epoch 10: 0.3824215829372406
# Train loss for epoch 11: 0.3944539427757263
# Val loss for epoch 11: 0.33696621656417847
# Train loss for epoch 12: 0.38974207639694214
# Val loss for epoch 12: 0.2847501039505005
# 12
# Train loss for epoch 13: 0.384797066450119
# Val loss for epoch 13: 0.29226067662239075
# Train loss for epoch 14: 0.3830341398715973
# Val loss for epoch 14: 0.2809743881225586
# 14
# Train loss for epoch 15: 0.3801949918270111
# Val loss for epoch 15: 0.26441848278045654
# 15
# Train loss for epoch 16: 0.3766891658306122
# Val loss for epoch 16: 0.27895551919937134
# Train loss for epoch 17: 0.3741820156574249
# Val loss for epoch 17: 0.28544580936431885
# Train loss for epoch 18: 0.3729294240474701
# Val loss for epoch 18: 0.27821415662765503
# Train loss for epoch 19: 0.36489373445510864
# Val loss for epoch 19: 0.2947129011154175
# Train loss for epoch 20: 0.3586074709892273
# Val loss for epoch 20: 0.2941780090332031
# Train loss for epoch 21: 0.36449044942855835
# Val loss for epoch 21: 0.2842526435852051
# Train loss for epoch 22: 0.35883867740631104
# Val loss for epoch 22: 0.2703595757484436
# Train loss for epoch 23: 0.3562559187412262
# Val loss for epoch 23: 0.269535094499588
# Train loss for epoch 24: 0.3507896661758423
# Val loss for epoch 24: 0.28381869196891785
# Train loss for epoch 25: 0.3518655598163605
# Val loss for epoch 25: 0.2655083239078522
# Train loss for epoch 26: 0.3471948504447937
# Val loss for epoch 26: 0.2565494179725647
# 26
# Train loss for epoch 27: 0.3432362377643585
# Val loss for epoch 27: 0.24973702430725098
# 27
# Train loss for epoch 28: 0.34479570388793945
# Val loss for epoch 28: 0.24583597481250763
# 28
# Train loss for epoch 29: 0.33957692980766296
# Val loss for epoch 29: 0.24231651425361633
# 29
# Train loss for epoch 30: 0.339967280626297
# Val loss for epoch 30: 0.2602456510066986
# Train loss for epoch 31: 0.3441569209098816
# Val loss for epoch 31: 0.2627730369567871
# Train loss for epoch 32: 0.3344278633594513
# Val loss for epoch 32: 0.26152709126472473
# Train loss for epoch 33: 0.336818665266037
# Val loss for epoch 33: 0.25068745017051697
# Train loss for epoch 34: 0.3386472463607788
# Val loss for epoch 34: 0.25256940722465515
# Train loss for epoch 35: 0.32908374071121216
# Val loss for epoch 35: 0.2517174780368805
# Train loss for epoch 36: 0.32784244418144226
# Val loss for epoch 36: 0.25396865606307983
# Train loss for epoch 37: 0.3288053572177887
# Val loss for epoch 37: 0.2525584101676941
# Train loss for epoch 38: 0.324106365442276
# Val loss for epoch 38: 0.26287609338760376
# Train loss for epoch 39: 0.3276852071285248
# Val loss for epoch 39: 0.24431851506233215
# Train loss for epoch 40: 0.3261294662952423
# Val loss for epoch 40: 0.24870476126670837
# Train loss for epoch 41: 0.319575697183609
# Val loss for epoch 41: 0.25419503450393677
# Train loss for epoch 42: 0.32696834206581116
# Val loss for epoch 42: 0.2558020055294037
# Train loss for epoch 43: 0.31866106390953064
# Val loss for epoch 43: 0.25369447469711304
# Train loss for epoch 44: 0.3179783523082733
# Val loss for epoch 44: 0.2503332793712616
# Train loss for epoch 45: 0.31685805320739746
# Val loss for epoch 45: 0.24148565530776978
# 45
# Train loss for epoch 46: 0.31342437863349915
# Val loss for epoch 46: 0.26030996441841125
# Train loss for epoch 47: 0.312498539686203
# Val loss for epoch 47: 0.2577115297317505
# Train loss for epoch 48: 0.315202921628952
# Val loss for epoch 48: 0.24567623436450958
# Train loss for epoch 49: 0.31064021587371826
# Val loss for epoch 49: 0.24652691185474396
# Train loss for epoch 50: 0.3110291063785553
# Val loss for epoch 50: 0.2544558644294739
# dropout:  1
# Train loss for epoch 0: 0.6856540441513062
# Val loss for epoch 0: 0.7940808534622192
# Train loss for epoch 1: 0.6838292479515076
# Val loss for epoch 1: 0.808368980884552
# Train loss for epoch 2: 0.6837865710258484
# Val loss for epoch 2: 0.8081523180007935
# Train loss for epoch 3: 0.6837851405143738
# Val loss for epoch 3: 0.8133434653282166
# Train loss for epoch 4: 0.6837892532348633
# Val loss for epoch 4: 0.812093198299408
# Train loss for epoch 5: 0.6837979555130005
# Val loss for epoch 5: 0.8101344704627991
# Train loss for epoch 6: 0.683789074420929
# Val loss for epoch 6: 0.8105877041816711
# Train loss for epoch 7: 0.6837913990020752
# Val loss for epoch 7: 0.8087476491928101
# Train loss for epoch 8: 0.6837934255599976
# Val loss for epoch 8: 0.8106309175491333
# Train loss for epoch 9: 0.6837856769561768
# Val loss for epoch 9: 0.8122179508209229
# Train loss for epoch 10: 0.6837854385375977
# Val loss for epoch 10: 0.8125029802322388
# Train loss for epoch 11: 0.68379145860672
# Val loss for epoch 11: 0.8124785423278809
# Train loss for epoch 12: 0.6837931871414185
# Val loss for epoch 12: 0.8100545406341553
# Train loss for epoch 13: 0.6837802529335022
# Val loss for epoch 13: 0.8064022660255432
# Train loss for epoch 14: 0.6837836503982544
# Val loss for epoch 14: 0.8103665709495544
# Train loss for epoch 15: 0.6837857365608215
# Val loss for epoch 15: 0.811025083065033
# Train loss for epoch 16: 0.6837881207466125
# Val loss for epoch 16: 0.8133798241615295
# Train loss for epoch 17: 0.6837895512580872
# Val loss for epoch 17: 0.8130929470062256
# Train loss for epoch 18: 0.6837976574897766
# Val loss for epoch 18: 0.8108838796615601
# Train loss for epoch 19: 0.6837865710258484
# Val loss for epoch 19: 0.8107472062110901
# Train loss for epoch 20: 0.6837863326072693
# Val loss for epoch 20: 0.8101422190666199
# Train loss for epoch 21: 0.6837834715843201
# Val loss for epoch 21: 0.8120797276496887
# Train loss for epoch 22: 0.6837834119796753
# Val loss for epoch 22: 0.8083899021148682
# Train loss for epoch 23: 0.6837850213050842
# Val loss for epoch 23: 0.8074155449867249
# Train loss for epoch 24: 0.6837900876998901
# Val loss for epoch 24: 0.8076027631759644
# Train loss for epoch 25: 0.6837837100028992
# Val loss for epoch 25: 0.8112728595733643
# Train loss for epoch 26: 0.6837857961654663
# Val loss for epoch 26: 0.8076249361038208
# Train loss for epoch 27: 0.6837910413742065
# Val loss for epoch 27: 0.8085212111473083
# Train loss for epoch 28: 0.6837853789329529
# Val loss for epoch 28: 0.8108517527580261
# Train loss for epoch 29: 0.6837904453277588
# Val loss for epoch 29: 0.8100395798683167
# Train loss for epoch 30: 0.6837888360023499
# Val loss for epoch 30: 0.8095306158065796
# Train loss for epoch 31: 0.6837893724441528
# Val loss for epoch 31: 0.8090190887451172
# Train loss for epoch 32: 0.6837948560714722
# Val loss for epoch 32: 0.809139609336853
# Train loss for epoch 33: 0.6837912201881409
# Val loss for epoch 33: 0.8094127774238586
# Train loss for epoch 34: 0.683793306350708
# Val loss for epoch 34: 0.8092355728149414
# Train loss for epoch 35: 0.6837852597236633
# Val loss for epoch 35: 0.8109626770019531
# Train loss for epoch 36: 0.6837896704673767
# Val loss for epoch 36: 0.8089945912361145
# Train loss for epoch 37: 0.6837961077690125
# Val loss for epoch 37: 0.8115018010139465
# Train loss for epoch 38: 0.6837896704673767
# Val loss for epoch 38: 0.8105787634849548
# Train loss for epoch 39: 0.6837722063064575
# Val loss for epoch 39: 0.8055260181427002
# Train loss for epoch 40: 0.683801531791687
# Val loss for epoch 40: 0.8101343512535095
# Train loss for epoch 41: 0.6837863922119141
# Val loss for epoch 41: 0.8102706670761108
# Train loss for epoch 42: 0.6837878823280334
# Val loss for epoch 42: 0.8080938458442688
# Train loss for epoch 43: 0.6837851405143738
# Val loss for epoch 43: 0.8081789016723633
# Train loss for epoch 44: 0.6837965846061707
# Val loss for epoch 44: 0.8082798719406128
# Train loss for epoch 45: 0.6837924122810364
# Val loss for epoch 45: 0.8087930679321289
# Train loss for epoch 46: 0.6837831735610962
# Val loss for epoch 46: 0.8100931644439697
# Train loss for epoch 47: 0.6837935447692871
# Val loss for epoch 47: 0.808611273765564
# Train loss for epoch 48: 0.6837887763977051
# Val loss for epoch 48: 0.8125511407852173
# Train loss for epoch 49: 0.6837897896766663
# Val loss for epoch 49: 0.8092553019523621
# Train loss for epoch 50: 0.6837960481643677
# Val loss for epoch 50: 0.810734748840332

# %%
model_MLP = os.listdir(save_path)
results = []
for x in range(0,len(model_MLP)):
    result = model_MLP[x].split('_') 
    channel = [i for i,item in enumerate(np.array(result)) if "CH23" in item]
    if not(channel):
        continue
    else:
        model_dropout = [i for i,item in enumerate(np.array(result)) if "DO" in item]
        if not(model_dropout):
            continue
        else:
            dropout = [int(i) for i in result[model_dropout[0]] if i.isdigit()]
            if len(dropout) ==2:
                dropout = dropout[1]/10
            else:
                dropout = dropout[0]
            epoch_name = [i for i,item in enumerate(np.array(result)) if "EPOCH" in item]
            res = [int(i) for i in result[epoch_name[0]] if i.isdigit()]
            if len(res) > 1:
                epoch_result = res[0]*10+res[1]
            else:
                epoch_result = res[0]
            results.append([dropout, epoch_result])

results = pd.DataFrame(np.array(results), columns=['dropout', 'epoch'])
best_results = results.groupby('dropout').max(epoch)
print(best_results)
# Out:
#          epoch
# dropout
# 0.1        4.0
# 0.3        3.0
# 0.5        4.0
# 0.7       11.0
# 0.9       45.0
# 1.0        0.0

# %%
for i,(index,row) in enumerate(best_results.iterrows()):
    model = MLP().to(device)
    path = save_path
    if index == 1.0:
        index = 1
    DO = index
    best_epoch = int(row)
    ## Load best model
    model = MLP(input_dim=input_dim, embed_dim=embed_dim).to(device)
    model.load_state_dict(torch.load('{}/{}_CH{}_LOSS{}_REG{}{}_DO{}_EMBED{}_EPOCH{}_MODEL_{}.pt'.format(
    save_path, model_type, CH, loss_type, reg_type, alpha, DO, embed_dim, best_epoch,model_name)))
    print('{}/{}_CH{}_LOSS{}_REG{}{}_DO{}_EPOCH{}.pt'.format(path, model_type, CH, loss_type, reg_type, alpha,DO, best_epoch))
    
    # Print Shape
    w1 = model.linear1.weight.view(256,10,100)
    w2 = model.linear2.weight
    print(w1.shape, w2.shape)
    w1 = w1.detach().cpu().numpy()
    w2 = w2.detach().cpu().numpy()
    w1[0].shape
    type(w1)
    
    # Print one feature
    print('One feature')
    plt.yticks(ticks=[0, 20, 40, 60, 80, 99], labels=[round(np.logspace(0, 2.45, 100)[i]) for i in [0, 20, 40, 60, 80, 99]])
    plt.xticks(ticks=[0, 9], labels=[1, 10])
    plt.imshow(w1[1].transpose(),origin='lower')
    # plt.clim(-1.5, 1.5)
    plt.colorbar()
    plt.show()
    
    # All features
    timewindow = 10
    plt.figure(figsize=(20,20))
    ylabels_list = [0,32,64,96,128,160,192,224,256] 
    for i in range(256):
        weights_sub = w1[i]
        plt.subplot(8,32,i+1)
        if i in ylabels_list:
            plt.yticks(ticks=[0, 20, 40, 60, 80, 99], labels=[round(np.logspace(0, 2.45, 100)[i]) for i in [0, 20, 40, 60, 80, 99]])
            plt.xticks(ticks=[0, timewindow-1], labels=[1, timewindow])
        else:
            plt.axis('off')
    #     plt.imshow(weights_sub)
        plt.imshow(w1[i][0].transpose(),origin='lower')
        plt.title(str(i+1))
    plt.show()
    
    
    ## Calculate accuracy and test loss
    test_loss, test_acc, test_preds, test_preds_probs, test_labels, cases_wrong_0 = evaluate(model, optimizer, test_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=True, device=device)
    print('test loss:{} accuracy:{}'.format(test_loss, test_acc))
    
    ## Confusion matrix
    predictions_test = np.concatenate(test_preds)
    labels_test = np.concatenate(test_labels)

    df_test = pd.DataFrame({'predictions': predictions_test, 'labels': labels_test})

    cm_test = confusion_matrix(labels_test, predictions_test)
    ax = plt.axes()
    group_names = ['True Neg','False Pos','False Neg','True Pos']
    group_counts = ["{0:0.0f}".format(value) for value in
                    cm_test.flatten()]

    TNR = int(group_counts[0]) / (int(group_counts[0])+int(group_counts[1]))
    FPR = 1 - TNR
    TPR = int(group_counts[3]) / (int(group_counts[3])+int(group_counts[2]))
    FNR = 1-TPR
    group_percentages =[TNR, FPR, FNR, TPR]

    group_percentages = ["{0:.2%}".format(value) for value in
                         group_percentages]
    labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
              zip(group_names,group_counts,group_percentages)]
    labels = np.asarray(labels).reshape(2,2)
    sn.heatmap(cm_test, annot=labels, fmt='', center = 2000)
    ax.set_title('Test Confusion Matrix')
    ax.set_xlabel('Predicted Label')
    ax.set_ylabel('True Label')
    plt.show()
# Out:
# /home/bijanadmin/Desktop/Goose_data/data_Goose_all_2/Goose_ANN_models/MLP_CH23_LOSSbce_REGnone0_DO0.1_EPOCH4.pt
# torch.Size([256, 1000])
# torch.Size([256, 10, 100]) torch.Size([1, 256])
# (100,)
# One feature
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-fce256c487d0> in <module>
#      26     plt.yticks(ticks=[0, 20, 40, 60, 80, 99], labels=[round(np.logspace(0, 2.45, 100)[i]) for i in [0, 20, 40, 60, 80, 99]])
#      27     plt.xticks(ticks=[0, 9], labels=[1, 10])
# ---> 28     plt.imshow(w1[0][0].transpose(),origin='lower')
#      29     # plt.clim(-1.5, 1.5)
#      30     plt.colorbar()
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, data, **kwargs)
#    2722         filternorm=True, filterrad=4.0, resample=None, url=None,
#    2723         data=None, **kwargs):
# -> 2724     __ret = gca().imshow(
#    2725         X, cmap=cmap, norm=norm, aspect=aspect,
#    2726         interpolation=interpolation, alpha=alpha, vmin=vmin,
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# -> 1438             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1439
#    1440         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, **kwargs)
#    5521                               resample=resample, **kwargs)
#    5522
# -> 5523         im.set_data(X)
#    5524         im.set_alpha(alpha)
#    5525         if im.get_clip_path() is None:
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/image.py in set_data(self, A)
#     707         if not (self._A.ndim == 2
#     708                 or self._A.ndim == 3 and self._A.shape[-1] in [3, 4]):
# --> 709             raise TypeError("Invalid shape {} for image data"
#     710                             .format(self._A.shape))
#     711
#
# TypeError: Invalid shape (100,) for image data

# %%
model = MLP(input_dim=input_dim, embed_dim=embed_dim).to(device)
model.load_state_dict(torch.load('{}/{}_CH{}_LOSS{}_REG{}{}_EMBED{}_EPOCH{}_MODEL_{}.pt'.format(
    save_path, model_type, CH, loss_type, reg_type, alpha, embed_dim, best_epoch,model_name)))
# Out:
# <All keys matched successfully>

# %%
w1 = model.linear1.weight.view(256,10,100)
w2 = model.linear2.weight
print(w1.shape, w2.shape)
w1 = w1.detach().cpu().numpy()
w2 = w2.detach().cpu().numpy()
w1[0].shape
type(w1)
# Out:
# torch.Size([256, 10, 100]) torch.Size([1, 256])
# numpy.ndarray

# %%
plt.yticks(ticks=[0, 20, 40, 60, 80, 99], labels=[round(np.logspace(0, 2.45, 100)[i]) for i in [0, 20, 40, 60, 80, 99]])
plt.xticks(ticks=[0, 9], labels=[1, 10])
plt.imshow(w1[1].transpose(),origin='lower')
# plt.clim(-1.5, 1.5)
plt.colorbar()
plt.show()

# %%
timewindow = 10
plt.figure(figsize=(20,20))
ylabels_list = [0,32,64,96,128,160,192,224,256] 
for i in range(256):
    weights_sub = w1[i]
    plt.subplot(8,32,i+1)
    if i in ylabels_list:
        plt.yticks(ticks=[0, 20, 40, 60, 80, 99], labels=[round(np.logspace(0, 2.45, 100)[i]) for i in [0, 20, 40, 60, 80, 99]])
        plt.xticks(ticks=[0, timewindow-1], labels=[1, timewindow])
    else:
        plt.axis('off')
#     plt.imshow(weights_sub)
    plt.imshow(w1[i].transpose(),origin='lower')
    plt.title(str(i+1))
plt.show()

# %%
test_loss, test_acc, test_preds, test_preds_probs, test_labels, cases_wrong_0 = evaluate(model, optimizer, test_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=True, device=device)
print('test loss:{} accuracy:{}'.format(test_loss, test_acc))
# Out:
# test loss:0.16502971947193146 accuracy:0.9600608596424496

# %%
plot_confusion(test_preds, test_labels)

# %% [markdown]
# # train on Goose and test on Jesper

# %%
CH = 23
device = torch.device('cuda')
val_dates = ['171021','171023','180711','180714']
test_dates = ['171020','171022','180712', '180713']
#load_path = '/home/bijanadmin/Desktop/Goose_data/data_Goose_1st_2/'
load_path = '/home/bijanadmin/Desktop/Goose_and_Jester_data/data_Goose_all_Jester_all_2/'
# save_path = '/mnt/pesaranlab/People/Capstone_students/Yue/model/model_Goose_1st_2_upsample'
save_path = '/home/bijanadmin/Desktop/Goose_and_Jester_data/data_Goose_all_Jester_all_2/ANN_model'
model_name = 'MLP_all_ch_Drop_03'

train_files, val_files, test_files = create_files(load_path, val_dates, test_dates)
train_loader, val_loader, test_loader = create_dataloaders(train_files, val_files, test_files, load_path, batch_size=128)

# %%
len(train_loader), len(val_loader), len(test_loader)

# %%
for batch_idx, (data, label, date, rec, time) in enumerate(train_loader): # check shapes
    print(data.shape)
    print(label.shape)
    print(len(date))
    print(len(rec))
    print(len(time))
    break

# %%
# movement labelled 0; non-movement labelled 1
for batch_idx, (data, label, date, rec, time) in enumerate(train_loader):
    for i in range(128):
        print('date:{}, rec:{}, time:{}, label:{}'.format(date[i], rec[i], time[i], label[i][0].numpy()))
        if label[i][0].numpy() == 0.0:
            data_sub = data[i][0]
            plt.yticks(ticks=[0, 20, 40, 60, 80, 99], labels=[round(np.logspace(0, 2.45, 100)[i]) for i in [0, 20, 40, 60, 80, 99]])
            plt.xticks(ticks=[0, 9], labels=[1, 10])
            plt.imshow(data_sub)
            plt.clim(-1.5, 1.5)
            plt.colorbar()
            plt.show()
    break

# %%
class MLP(nn.Module): # add dropo
    def __init__(self, input_dim=100*10*62, output_dim=1, embed_dim=256,drop_prob=0.):
        super(MLP, self).__init__()
        self.linear1 = nn.Linear(input_dim, embed_dim)
        self.linear2 = nn.Linear(embed_dim, output_dim)
        self.dropout = nn.Dropout(drop_prob)
        
    def forward(self, x):
        
        x = x.reshape([x.shape[0], 1, -1]).float()
        x = self.dropout(F.relu(self.linear1(x)))
        outputs = self.linear2(x)
        
        return outputs

# %%
device = torch.device('cuda')

tol = 0.01
learning_rate = 0.001
num_epochs = 51
alpha = 0
model_type = 'MLP'
loss_type = 'bce'
reg_type = 'none'
input_dim = 1*10*100
embed_dim = 256
dropout_all = [0.1,0.3,0.5,0.7,0.9,1]

# %%
for d in range(0,len(dropout_all)):
    dropout = dropout_all[d]
    model = MLP(input_dim=input_dim, embed_dim=embed_dim,drop_prob = dropout).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)
    (data, labels, _, _, _) = next(iter(train_loader))
    data = data.to(device)
    output = model(data)
    print('dropout: ', dropout)
    output.shape

    epochs, training_losses, training_acc, val_losses, validation_acc = [], [], [], [], []

    for epoch in range(num_epochs):
        train_loss, train_acc = train(model, optimizer, train_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, 
                                      reg_type=reg_type, collect_result=False, device=device)
        print('Train loss for epoch {}: {}'.format(epoch, train_loss))
        val_loss, val_acc = evaluate(model, optimizer, val_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, 
                                     reg_type=reg_type, collect_result=False, device=device)
        print('Val loss for epoch {}: {}'.format(epoch, val_loss))
        if epoch == 0:
            torch.save(model.state_dict(), '{}/{}_CH{}_LOSS{}_REG{}{}_DO{}_EMBED{}_EPOCH{}_MODEL_{}.pt'.format(
                    save_path, model_type, CH, loss_type, reg_type, alpha, dropout, embed_dim, epoch,model_name))

        if val_losses:
            
            if val_loss < min(val_losses):
                best_epoch = epoch
                print(epoch)
                torch.save(model.state_dict(), '{}/{}_CH{}_LOSS{}_REG{}{}_EMBED{}_EPOCH{}_MODEL_{}.pt'.format(
                    save_path, model_type, CH, loss_type, reg_type, alpha, embed_dim, epoch,model_name))
        epochs.append(epoch)
        training_losses.append(train_loss)
        training_acc.append(train_acc)
        val_losses.append(val_loss)
        validation_acc.append(val_acc)

        if train_loss < tol:
            break
    plot_loss_acc(training_losses, val_losses, training_acc, validation_acc, model_type) # embed_dim=64

# %%
model_MLP = os.listdir(save_path)
results = []
for x in range(0,len(model_MLP)):
    result = model_MLP[x].split('_') 
    CH = [i for i,item in enumerate(np.array(result)) if "CH23" in item]
    if not(CH):
        continue
    else:
        model_dropout = [i for i,item in enumerate(np.array(result)) if "DO" in item]
        if not(model_dropout):
            continue
        else:
            dropout = [int(i) for i in result[model_dropout[0]] if i.isdigit()]
            if len(dropout) ==2:
                dropout = dropout[1]/10
            else:
                dropout = dropout[0]
            epoch_name = [i for i,item in enumerate(np.array(result)) if "EPOCH" in item]
            res = [int(i) for i in result[epoch_name[0]] if i.isdigit()]
            res = int(res[0])
            results.append([dropout, res])

results = pd.DataFrame(np.array(results), columns=['dropout', 'epoch'])
best_results = results.groupby('dropout').max(epoch)
print(best_results)

# %%
model = MLP(input_dim=input_dim, embed_dim=embed_dim).to(device)
model.load_state_dict(torch.load('{}/{}_CH{}_LOSS{}_REG{}{}_EMBED{}_EPOCH{}_MODEL_{}.pt'.format(
    save_path, model_type, CH, loss_type, reg_type, alpha, embed_dim, best_epoch,model_name)))

# %%
w1 = model.linear1.weight.view(256,10,100)
w2 = model.linear2.weight
print(w1.shape, w2.shape)
w1 = w1.detach().cpu().numpy()
w2 = w2.detach().cpu().numpy()
w1[0].shape
type(w1)

# %%
plt.yticks(ticks=[0, 20, 40, 60, 80, 99], labels=[round(np.logspace(0, 2.45, 100)[i]) for i in [0, 20, 40, 60, 80, 99]])
plt.xticks(ticks=[0, 9], labels=[1, 10])
plt.imshow(w1[1].transpose(),origin='lower')
# plt.clim(-1.5, 1.5)
plt.colorbar()
plt.show()

# %%
timewindow = 10
plt.figure(figsize=(20,20))
ylabels_list = [0,32,64,96,128,160,192,224,256] 
for i in range(256):
    weights_sub = w1[i]
    plt.subplot(8,32,i+1)
    if i in ylabels_list:
        plt.yticks(ticks=[0, 20, 40, 60, 80, 99], labels=[round(np.logspace(0, 2.45, 100)[i]) for i in [0, 20, 40, 60, 80, 99]])
        plt.xticks(ticks=[0, timewindow-1], labels=[1, timewindow])
    else:
        plt.axis('off')
#     plt.imshow(weights_sub)
    plt.imshow(w1[i].transpose(),origin='lower')
    plt.title(str(i+1))
plt.show()

# %%
test_loss, test_acc, test_preds, test_preds_probs, test_labels, cases_wrong_0 = evaluate(model, optimizer, test_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=True, device=device)
print('test loss:{} accuracy:{}'.format(test_loss, test_acc))

# %%
plot_confusion(test_preds, test_labels)
