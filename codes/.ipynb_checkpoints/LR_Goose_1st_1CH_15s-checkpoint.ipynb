# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
from torch.utils.data import Dataset, DataLoader
from torch import nn
from torch.nn.functional import relu
from scipy.io import loadmat
import os
from os import listdir
import pandas as pd
from skimage import io
from PIL import Image
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pickle

from utils import *

# %%
#selected subset of dates. 
val_dates = ['180327','180329']
test_dates = ['180330','180331']
bad_dates = ['180326', '180328', '171019', '180715', '180716', '180717']
load_path = '/home/bijanadmin/Desktop/Goose_data/data_Goose_1st_15s_2/'
model_saving_path = '/home/bijanadmin/Desktop/Goose_data/data_Goose_1st_15s_2/LR_models'

CH = 23
train_files, val_files, test_files = create_files(load_path, val_dates, test_dates, bad_dates)
train_loader, val_loader, test_loader = create_dataloaders(train_files, val_files, test_files,load_path, batch_size=256, CH = CH)

# %%
len(train_loader), len(val_loader), len(test_loader)
# Out:
# (50, 16, 16)

# %%
for batch_idx, (data, label, date, rec, time) in enumerate(train_loader): # check shapes
    print(data.shape)
    print(label.shape)
    print(len(date))
    print(len(rec))
    print(len(time))
    break
# Out:
# torch.Size([256, 1, 100, 15])
# torch.Size([256, 1])
# 256
# 256
# 256

# %%
# movement labelled 0; non-movement labelled 1
for batch_idx, (data, label, date, rec, time) in enumerate(train_loader):
    for i in range(128):
        print('date:{}, rec:{}, time:{}'.format(date[i], rec[i], time[i]))
        data_sub = data[i][0]
        plt.imshow(data_sub)
        plt.clim(-1.5, 1.5)
        plt.colorbar()
        plt.title(label[i][0].numpy())
        plt.show()
    break
# Out:
# date:180325, rec:001, time:1152.0
# date:180325, rec:006, time:2394.0
# date:180325, rec:003, time:4520.0
# date:180401, rec:002, time:4103.0
# date:180325, rec:001, time:1542.0
# date:180325, rec:009, time:2052.0
# date:180325, rec:009, time:6924.0
# date:180322, rec:005, time:925.0
# date:180325, rec:007, time:972.0
# date:180325, rec:003, time:6299.0
# date:180325, rec:007, time:4865.0
# date:180323, rec:002, time:1484.0
# date:180323, rec:003, time:914.0
# date:180325, rec:005, time:6125.0
# date:180323, rec:003, time:297.0
# date:180324, rec:003, time:222.0
# date:180325, rec:003, time:4255.0
# date:180324, rec:003, time:1446.0
# date:180322, rec:005, time:1552.0
# date:180322, rec:005, time:1402.0
# date:180325, rec:007, time:5750.0
# date:180323, rec:002, time:4912.0
# date:180323, rec:004, time:4111.0
# date:180323, rec:001, time:27.0
# date:180401, rec:001, time:1047.0
# date:180325, rec:002, time:4595.0
# date:180323, rec:007, time:5513.0
# date:180323, rec:002, time:5948.0
# date:180322, rec:003, time:5330.0
# date:180325, rec:009, time:4541.0
# date:180324, rec:008, time:5416.0
# date:180324, rec:008, time:3415.0
# date:180323, rec:007, time:5678.0
# date:180323, rec:007, time:4649.0
# date:180322, rec:002, time:4911.0
# date:180325, rec:001, time:6593.0
# date:180324, rec:008, time:1363.0
# date:180325, rec:001, time:1512.0
# date:180324, rec:008, time:2710.0
# date:180401, rec:002, time:7018.0
# date:180325, rec:007, time:5900.0
# date:180325, rec:007, time:3600.0
# date:180325, rec:006, time:4337.0
# date:180324, rec:006, time:1600.0
# date:180325, rec:001, time:27.0
# date:180401, rec:001, time:4474.0
# date:180324, rec:008, time:5296.0
# date:180323, rec:003, time:2908.0
# date:180325, rec:007, time:4805.0
# date:180324, rec:009, time:1270.0
# date:180322, rec:007, time:1424.0
# date:180325, rec:001, time:3957.0
# date:180323, rec:003, time:839.0
# date:180323, rec:003, time:4998.0
# date:180322, rec:007, time:4412.0
# date:180325, rec:007, time:5495.0
# date:180325, rec:007, time:4655.0
# date:180323, rec:007, time:5528.0
# date:180324, rec:008, time:1603.0
# date:180324, rec:009, time:132.0
# date:180324, rec:001, time:5253.0
# date:180325, rec:002, time:5570.0
# date:180322, rec:003, time:4576.0
# date:180323, rec:003, time:3478.0
# date:180324, rec:003, time:5210.0
# date:180324, rec:004, time:6674.0
# date:180401, rec:001, time:927.0
# date:180325, rec:009, time:162.0
# date:180325, rec:007, time:2420.0
# date:180325, rec:002, time:3911.0
# date:180325, rec:003, time:4904.0
# date:180324, rec:009, time:822.0
# date:180324, rec:008, time:880.0
# date:180324, rec:006, time:3266.0
# date:180324, rec:008, time:6796.0
# date:180323, rec:001, time:1167.0
# date:180324, rec:008, time:2605.0
# date:180401, rec:001, time:1137.0
# date:180325, rec:006, time:1131.0
# date:180322, rec:005, time:3143.0
# date:180325, rec:004, time:6179.0
# date:180324, rec:003, time:162.0
# date:180325, rec:004, time:1710.0
# date:180324, rec:008, time:1558.0
# date:180325, rec:003, time:7136.0
# date:180325, rec:001, time:1902.0
# date:180324, rec:003, time:3534.0
# date:180325, rec:007, time:3163.0
# date:180325, rec:001, time:3224.0
# date:180324, rec:008, time:5956.0
# date:180325, rec:003, time:2402.0
# date:180324, rec:004, time:2106.0
# date:180325, rec:006, time:3385.0
# date:180324, rec:008, time:3775.0
# date:180325, rec:009, time:1197.0
# date:180323, rec:007, time:4754.0
# date:180323, rec:002, time:1499.0
# date:180325, rec:007, time:2788.0
# date:180322, rec:007, time:1694.0
# date:180325, rec:002, time:3184.0
# date:180325, rec:009, time:4856.0
# date:180325, rec:001, time:3552.0
# date:180323, rec:005, time:2084.0
# date:180325, rec:009, time:5931.0
# date:180323, rec:001, time:42.0
# date:180323, rec:002, time:1304.0
# date:180325, rec:009, time:87.0
# date:180325, rec:009, time:4886.0
# date:180323, rec:007, time:6218.0
# date:180325, rec:006, time:4187.0
# date:180325, rec:001, time:1152.0
# date:180322, rec:003, time:1100.0
# date:180324, rec:006, time:6335.0
# date:180324, rec:004, time:4596.0
# date:180325, rec:004, time:1365.0
# date:180325, rec:001, time:1167.0
# date:180323, rec:001, time:1317.0
# date:180322, rec:007, time:3296.0
# date:180325, rec:002, time:7141.0
# date:180401, rec:001, time:5194.0
# date:180324, rec:008, time:1543.0
# date:180325, rec:001, time:6563.0
# date:180325, rec:001, time:6668.0
# date:180324, rec:008, time:1045.0
# date:180325, rec:004, time:3472.0
# date:180322, rec:007, time:4052.0
# date:180322, rec:003, time:3460.0
# date:180401, rec:001, time:4218.0

# %% [markdown]
# ### Logistic regression with no regularization

# %%
device = torch.device('cuda')

tol = 0.01
learning_rate = 0.001
num_epochs = 51
alphas = [1,50,100]
model_type = 'LR'
loss_type = 'bce'
reg_type = 'none'
timewindow = 15

# %%
for alpha in alphas:
    model = GLM(input_dim=100*timewindow).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)
    epochs, training_losses, training_acc, val_losses, validation_acc = [], [], [], [], []

    for epoch in range(num_epochs):
        train_loss, train_acc = train(model, optimizer, train_loader, timewindow = timewindow, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
        print('Train loss for epoch {}: {}'.format(epoch, train_loss))
        val_loss, val_acc = evaluate(model, optimizer, val_loader, alpha=alpha, timewindow = timewindow, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
        print('Val loss for epoch {}: {}'.format(epoch, val_loss))
        if val_losses:
            if val_loss < min(val_losses):
                best_epoch = epoch
                print(epoch)
                path = model_saving_path
                torch.save(model.state_dict(), '{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, epoch))
        epochs.append(epoch)
        training_losses.append(train_loss)
        training_acc.append(train_acc)
        val_losses.append(val_loss)
        validation_acc.append(val_acc)

        if train_loss < tol:
            break
    plot_loss_acc(training_losses, val_losses, training_acc, validation_acc, model_type)
# Out:
# Train loss for epoch 0: 0.5364744067192078
# Val loss for epoch 0: 0.5188269019126892
# Train loss for epoch 1: 0.4996130168437958
# Val loss for epoch 1: 0.5114378929138184
# 1
# Train loss for epoch 2: 0.4865894317626953
# Val loss for epoch 2: 0.4939744472503662
# 2
# Train loss for epoch 3: 0.48506924510002136
# Val loss for epoch 3: 0.5042917728424072
# Train loss for epoch 4: 0.4731420874595642
# Val loss for epoch 4: 0.49809229373931885
# Train loss for epoch 5: 0.466434508562088
# Val loss for epoch 5: 0.48873239755630493
# 5
# Train loss for epoch 6: 0.4611108601093292
# Val loss for epoch 6: 0.5064411163330078
# Train loss for epoch 7: 0.4589370787143707
# Val loss for epoch 7: 0.49615272879600525
# Train loss for epoch 8: 0.4562077820301056
# Val loss for epoch 8: 0.48565468192100525
# 8
# Train loss for epoch 9: 0.4496828317642212
# Val loss for epoch 9: 0.4844835698604584
# 9
# Train loss for epoch 10: 0.449242502450943
# Val loss for epoch 10: 0.47331225872039795
# 10
# Train loss for epoch 11: 0.4402156472206116
# Val loss for epoch 11: 0.48465806245803833
# Train loss for epoch 12: 0.4380015432834625
# Val loss for epoch 12: 0.4709053337574005
# 12
# Train loss for epoch 13: 0.44105491042137146
# Val loss for epoch 13: 0.4729679524898529
# Train loss for epoch 14: 0.4326666593551636
# Val loss for epoch 14: 0.4760860502719879
# Train loss for epoch 15: 0.4334810674190521
# Val loss for epoch 15: 0.4713056683540344
# Train loss for epoch 16: 0.43281421065330505
# Val loss for epoch 16: 0.45827725529670715
# 16
# Train loss for epoch 17: 0.42820674180984497
# Val loss for epoch 17: 0.46561938524246216
# Train loss for epoch 18: 0.4404023289680481
# Val loss for epoch 18: 0.47645917534828186
# Train loss for epoch 19: 0.42320796847343445
# Val loss for epoch 19: 0.4479384422302246
# 19
# Train loss for epoch 20: 0.42247650027275085
# Val loss for epoch 20: 0.4457184970378876
# 20
# Train loss for epoch 21: 0.42312896251678467
# Val loss for epoch 21: 0.44816476106643677
# Train loss for epoch 22: 0.414796382188797
# Val loss for epoch 22: 0.46439966559410095
# Train loss for epoch 23: 0.4121783673763275
# Val loss for epoch 23: 0.46221357583999634
# Train loss for epoch 24: 0.42170459032058716
# Val loss for epoch 24: 0.45709070563316345
# Train loss for epoch 25: 0.40854412317276
# Val loss for epoch 25: 0.45586836338043213
# Train loss for epoch 26: 0.4062053859233856
# Val loss for epoch 26: 0.45260873436927795
# Train loss for epoch 27: 0.40654081106185913
# Val loss for epoch 27: 0.43846237659454346
# 27
# Train loss for epoch 28: 0.40427014231681824
# Val loss for epoch 28: 0.46012747287750244
# Train loss for epoch 29: 0.40935570001602173
# Val loss for epoch 29: 0.4471205770969391
# Train loss for epoch 30: 0.4049971103668213
# Val loss for epoch 30: 0.43266913294792175
# 30
# Train loss for epoch 31: 0.40367865562438965
# Val loss for epoch 31: 0.43913331627845764
# Train loss for epoch 32: 0.4044334292411804
# Val loss for epoch 32: 0.44238075613975525
# Train loss for epoch 33: 0.3972679078578949
# Val loss for epoch 33: 0.44608548283576965
# Train loss for epoch 34: 0.39733073115348816
# Val loss for epoch 34: 0.45200711488723755
# Train loss for epoch 35: 0.40676015615463257
# Val loss for epoch 35: 0.44214412569999695
# Train loss for epoch 36: 0.3925796449184418
# Val loss for epoch 36: 0.4393821060657501
# Train loss for epoch 37: 0.40190669894218445
# Val loss for epoch 37: 0.42866817116737366
# 37
# Train loss for epoch 38: 0.39330780506134033
# Val loss for epoch 38: 0.43885552883148193
# Train loss for epoch 39: 0.3895266354084015
# Val loss for epoch 39: 0.4346938729286194
# Train loss for epoch 40: 0.40136754512786865
# Val loss for epoch 40: 0.43612343072891235
# Train loss for epoch 41: 0.387690007686615
# Val loss for epoch 41: 0.4315161108970642
# Train loss for epoch 42: 0.3897772431373596
# Val loss for epoch 42: 0.43352895975112915
# Train loss for epoch 43: 0.4071525037288666
# Val loss for epoch 43: 0.43613988161087036
# Train loss for epoch 44: 0.3867235779762268
# Val loss for epoch 44: 0.43098628520965576
# Train loss for epoch 45: 0.38467520475387573
# Val loss for epoch 45: 0.43570759892463684
# Train loss for epoch 46: 0.3876465857028961
# Val loss for epoch 46: 0.4319039583206177
# Train loss for epoch 47: 0.39456674456596375
# Val loss for epoch 47: 0.4345504343509674
# Train loss for epoch 48: 0.3831462860107422
# Val loss for epoch 48: 0.4373681843280792
# Train loss for epoch 49: 0.3814370930194855
# Val loss for epoch 49: 0.42885056138038635
# Train loss for epoch 50: 0.3879227638244629
# Val loss for epoch 50: 0.43551912903785706
# Train loss for epoch 0: 0.5419975519180298
# Val loss for epoch 0: 0.5119302868843079
# Train loss for epoch 1: 0.498665988445282
# Val loss for epoch 1: 0.5142956376075745
# Train loss for epoch 2: 0.4908265769481659
# Val loss for epoch 2: 0.4919228255748749
# 2
# Train loss for epoch 3: 0.4840104579925537
# Val loss for epoch 3: 0.49276483058929443
# Train loss for epoch 4: 0.475016325712204
# Val loss for epoch 4: 0.502204179763794
# Train loss for epoch 5: 0.471017062664032
# Val loss for epoch 5: 0.48666900396347046
# 5
# Train loss for epoch 6: 0.4634009599685669
# Val loss for epoch 6: 0.4930382966995239
# Train loss for epoch 7: 0.4570362865924835
# Val loss for epoch 7: 0.4806888699531555
# 7
# Train loss for epoch 8: 0.45725134015083313
# Val loss for epoch 8: 0.48128071427345276
# Train loss for epoch 9: 0.46036311984062195
# Val loss for epoch 9: 0.4880364239215851
# Train loss for epoch 10: 0.45323142409324646
# Val loss for epoch 10: 0.4759089946746826
# 10
# Train loss for epoch 11: 0.44490137696266174
# Val loss for epoch 11: 0.46581706404685974
# 11
# Train loss for epoch 12: 0.46665164828300476
# Val loss for epoch 12: 0.46811383962631226
# Train loss for epoch 13: 0.44303184747695923
# Val loss for epoch 13: 0.4688650965690613
# Train loss for epoch 14: 0.4363551735877991
# Val loss for epoch 14: 0.4738573431968689
# Train loss for epoch 15: 0.4352739453315735
# Val loss for epoch 15: 0.466544508934021
# Train loss for epoch 16: 0.4294065237045288
# Val loss for epoch 16: 0.4610535502433777
# 16
# Train loss for epoch 17: 0.4275822937488556
# Val loss for epoch 17: 0.45615366101264954
# 17
# Train loss for epoch 18: 0.42934316396713257
# Val loss for epoch 18: 0.4571411907672882
# Train loss for epoch 19: 0.4250495731830597
# Val loss for epoch 19: 0.45869699120521545
# Train loss for epoch 20: 0.4265909790992737
# Val loss for epoch 20: 0.45109179615974426
# 20
# Train loss for epoch 21: 0.4197103977203369
# Val loss for epoch 21: 0.44516414403915405
# 21
# Train loss for epoch 22: 0.4180688261985779
# Val loss for epoch 22: 0.4532884359359741
# Train loss for epoch 23: 0.415609747171402
# Val loss for epoch 23: 0.46743687987327576
# Train loss for epoch 24: 0.42146411538124084
# Val loss for epoch 24: 0.44710537791252136
# Train loss for epoch 25: 0.4145343601703644
# Val loss for epoch 25: 0.4485120177268982
# Train loss for epoch 26: 0.41166090965270996
# Val loss for epoch 26: 0.4371569752693176
# 26
# Train loss for epoch 27: 0.4128083288669586
# Val loss for epoch 27: 0.4387900233268738
# Train loss for epoch 28: 0.41141363978385925
# Val loss for epoch 28: 0.46261242032051086
# Train loss for epoch 29: 0.41142916679382324
# Val loss for epoch 29: 0.4396054148674011
# Train loss for epoch 30: 0.40816402435302734
# Val loss for epoch 30: 0.4511774778366089
# Train loss for epoch 31: 0.4099154770374298
# Val loss for epoch 31: 0.43432027101516724
# 31
# Train loss for epoch 32: 0.40067291259765625
# Val loss for epoch 32: 0.43306705355644226
# 32
# Train loss for epoch 33: 0.40926384925842285
# Val loss for epoch 33: 0.45503175258636475
# Train loss for epoch 34: 0.40251877903938293
# Val loss for epoch 34: 0.42904388904571533
# 34
# Train loss for epoch 35: 0.401322603225708
# Val loss for epoch 35: 0.4338916838169098
# Train loss for epoch 36: 0.3979209363460541
# Val loss for epoch 36: 0.44511541724205017
# Train loss for epoch 37: 0.399687796831131
# Val loss for epoch 37: 0.4306400716304779
# Train loss for epoch 38: 0.39332911372184753
# Val loss for epoch 38: 0.4382232129573822
# Train loss for epoch 39: 0.40128371119499207
# Val loss for epoch 39: 0.43181872367858887
# Train loss for epoch 40: 0.39412227272987366
# Val loss for epoch 40: 0.4409734010696411
# Train loss for epoch 41: 0.40655529499053955
# Val loss for epoch 41: 0.4385986626148224
# Train loss for epoch 42: 0.3897767663002014
# Val loss for epoch 42: 0.4320724308490753
# Train loss for epoch 43: 0.38756707310676575
# Val loss for epoch 43: 0.43621453642845154
# Train loss for epoch 44: 0.4073916971683502
# Val loss for epoch 44: 0.4378635287284851
# Train loss for epoch 45: 0.3923214375972748
# Val loss for epoch 45: 0.42756643891334534
# 45
# Train loss for epoch 46: 0.3963657319545746
# Val loss for epoch 46: 0.43489623069763184
# Train loss for epoch 47: 0.3889865577220917
# Val loss for epoch 47: 0.4399173855781555
# Train loss for epoch 48: 0.385987788438797
# Val loss for epoch 48: 0.43161946535110474
# Train loss for epoch 49: 0.4158160090446472
# Val loss for epoch 49: 0.4480099081993103
# Train loss for epoch 50: 0.38757604360580444
# Val loss for epoch 50: 0.42991921305656433
# Train loss for epoch 0: 0.528800904750824
# Val loss for epoch 0: 0.499582976102829
# Train loss for epoch 1: 0.4955052435398102
# Val loss for epoch 1: 0.5083869695663452
# Train loss for epoch 2: 0.4929092228412628
# Val loss for epoch 2: 0.5089460015296936
# Train loss for epoch 3: 0.483672559261322
# Val loss for epoch 3: 0.5002098679542542
# Train loss for epoch 4: 0.4761410653591156
# Val loss for epoch 4: 0.4982110261917114
# 4
# Train loss for epoch 5: 0.46518540382385254
# Val loss for epoch 5: 0.472913533449173
# 5
# Train loss for epoch 6: 0.48095735907554626
# Val loss for epoch 6: 0.4787912368774414
# Train loss for epoch 7: 0.4575045704841614
# Val loss for epoch 7: 0.469680517911911
# 7
# Train loss for epoch 8: 0.45378050208091736
# Val loss for epoch 8: 0.48138192296028137
# Train loss for epoch 9: 0.45692816376686096
# Val loss for epoch 9: 0.47875845432281494
# Train loss for epoch 10: 0.44841235876083374
# Val loss for epoch 10: 0.4652034640312195
# 10
# Train loss for epoch 11: 0.44422295689582825
# Val loss for epoch 11: 0.45969149470329285
# 11
# Train loss for epoch 12: 0.45142728090286255
# Val loss for epoch 12: 0.4700029492378235
# Train loss for epoch 13: 0.4378180503845215
# Val loss for epoch 13: 0.4622316062450409
# Train loss for epoch 14: 0.437306672334671
# Val loss for epoch 14: 0.47365134954452515
# Train loss for epoch 15: 0.43459057807922363
# Val loss for epoch 15: 0.4689977169036865
# Train loss for epoch 16: 0.42963606119155884
# Val loss for epoch 16: 0.46034833788871765
# Train loss for epoch 17: 0.4257638156414032
# Val loss for epoch 17: 0.4413653314113617
# 17
# Train loss for epoch 18: 0.43967077136039734
# Val loss for epoch 18: 0.45377370715141296
# Train loss for epoch 19: 0.4241439402103424
# Val loss for epoch 19: 0.43652549386024475
# 19
# Train loss for epoch 20: 0.42586538195610046
# Val loss for epoch 20: 0.4480949938297272
# Train loss for epoch 21: 0.4323890209197998
# Val loss for epoch 21: 0.44803935289382935
# Train loss for epoch 22: 0.41816869378089905
# Val loss for epoch 22: 0.44467559456825256
# Train loss for epoch 23: 0.4159027636051178
# Val loss for epoch 23: 0.4445483386516571
# Train loss for epoch 24: 0.41447851061820984
# Val loss for epoch 24: 0.43833571672439575
# Train loss for epoch 25: 0.4170231819152832
# Val loss for epoch 25: 0.43976813554763794
# Train loss for epoch 26: 0.4177870750427246
# Val loss for epoch 26: 0.4367707371711731
# Train loss for epoch 27: 0.40815210342407227
# Val loss for epoch 27: 0.4477228820323944
# Train loss for epoch 28: 0.4137267470359802
# Val loss for epoch 28: 0.4407293498516083
# Train loss for epoch 29: 0.40514230728149414
# Val loss for epoch 29: 0.44290831685066223
# Train loss for epoch 30: 0.4050554633140564
# Val loss for epoch 30: 0.42472538352012634
# 30
# Train loss for epoch 31: 0.42855024337768555
# Val loss for epoch 31: 0.4375287890434265
# Train loss for epoch 32: 0.4060802757740021
# Val loss for epoch 32: 0.4274890422821045
# Train loss for epoch 33: 0.40114691853523254
# Val loss for epoch 33: 0.43605950474739075
# Train loss for epoch 34: 0.39823970198631287
# Val loss for epoch 34: 0.4417986273765564
# Train loss for epoch 35: 0.3981670141220093
# Val loss for epoch 35: 0.43544837832450867
# Train loss for epoch 36: 0.39706265926361084
# Val loss for epoch 36: 0.43376660346984863
# Train loss for epoch 37: 0.3949565887451172
# Val loss for epoch 37: 0.4249764084815979
# Train loss for epoch 38: 0.39754438400268555
# Val loss for epoch 38: 0.4369647204875946
# Train loss for epoch 39: 0.39321598410606384
# Val loss for epoch 39: 0.42197224497795105
# 39
# Train loss for epoch 40: 0.39188048243522644
# Val loss for epoch 40: 0.4394339919090271
# Train loss for epoch 41: 0.39216023683547974
# Val loss for epoch 41: 0.4364543557167053
# Train loss for epoch 42: 0.3895303010940552
# Val loss for epoch 42: 0.43041515350341797
# Train loss for epoch 43: 0.3897910416126251
# Val loss for epoch 43: 0.4266372621059418
# Train loss for epoch 44: 0.3995063602924347
# Val loss for epoch 44: 0.436574250459671
# Train loss for epoch 45: 0.3907824158668518
# Val loss for epoch 45: 0.44100221991539
# Train loss for epoch 46: 0.3877878487110138
# Val loss for epoch 46: 0.43914440274238586
# Train loss for epoch 47: 0.3948577642440796
# Val loss for epoch 47: 0.429998517036438
# Train loss for epoch 48: 0.3861675560474396
# Val loss for epoch 48: 0.4350126087665558
# Train loss for epoch 49: 0.38445767760276794
# Val loss for epoch 49: 0.42962613701820374
# Train loss for epoch 50: 0.3830408453941345
# Val loss for epoch 50: 0.42634981870651245

# %%
alpha
# Out:
# 100

# %%
model_LR = os.listdir(model_saving_path)
results = []
for alpha in alphas:
    epoch_results = []
    reg_alpha = 'REG'+reg_type+str(alpha)+'_'
    for i, s in enumerate(model_LR):
        if 'REDUCEsum' in s:
            continue
        else:
            if '_CH23_' in s and reg_alpha in s:
                model_name = model_LR[i].split('_')
                epoch_name = [ind for ind,item in enumerate(np.array(model_name)) if "EPOCH" in item]
                res = [int(i) for i in model_name[epoch_name[0]] if i.isdigit()]
                if len(res) > 1:
                    epoch_result = res[0]*10+res[1]
                else:
                    epoch_result = res[0]
                epoch_results.append(epoch_result)
            
    results.append([alpha, max(epoch_results)])
    
results = pd.DataFrame(np.array(results), columns=['alpha', 'epoch'])
best_results = results.groupby('alpha').max('epoch')
print(best_results)
# Out:
#        epoch
# alpha
# 1         37
# 50        45
# 100       39

# %%
for i,(index,row) in enumerate(best_results.iterrows()):
    
    path = model_saving_path
    best_epoch = int(row)
    alpha = index
    
    
    # load best model
    model = GLM(input_dim=100*timewindow).to(device)
    path = model_saving_path
    optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)
    model.load_state_dict(torch.load('{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, best_epoch)))
    
    print('{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, best_epoch))

    ## Show one feature
    weights = model.linear.weight.view(100, timewindow)
    weights_sub = weights.detach().cpu()
    plt.axis('off')
    plt.imshow(weights_sub)
    plt.title(str(CH))
    # plt.clim(-0.03, 0.03)
    plt.show()
    
    ## Calculate accuracy and validation loss
    val_loss, val_acc, val_preds, val_preds_probs, val_labels,_,_,_, cases_wrong_1 = evaluate(model, optimizer, val_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=True, device=device)
    print('validation loss:{} accuracy:{}'.format(val_loss, val_acc))
    print(np.mean(np.concatenate(val_labels)))
    
    
    ## Wrong Classifications
    path_wrong = '/mnt/pesaranlab/People/Capstone_students/Yue/wrong_pred'
    pickle.dump(cases_wrong_1, open('{}/{}_CH{}_LOSS{}_REG{}{}.pt'.format(path_wrong, model_type, CH, loss_type, reg_type, alpha), 'wb'))
    idx = 0
    print('date:{}, rec:{}, time:{}, label:{}'.format(cases_wrong_1[0][0], cases_wrong_1[0][1], cases_wrong_1[0][2], cases_wrong_1[0][3]))
    print('Original data 62 CH')
    weights_sub = cases_wrong_1[0][-1][0]
    plt.axis('off')
    plt.imshow(weights_sub)
    # plt.clim(-0.03, 0.03)
    plt.show()
    
    ## Confusion matrix
    predictions_val = np.concatenate(val_preds)
    labels_val = np.concatenate(val_labels)

    df_val = pd.DataFrame({'predictions': predictions_val, 'labels': labels_val})

    cm_val = confusion_matrix(labels_val, predictions_val)
    ax = plt.axes()
    group_names = ['True Neg','False Pos','False Neg','True Pos']
    group_counts = ["{0:0.0f}".format(value) for value in
                    cm_val.flatten()]

    TNR = int(group_counts[0]) / (int(group_counts[0])+int(group_counts[1]))
    FPR = 1 - TNR
    TPR = int(group_counts[3]) / (int(group_counts[3])+int(group_counts[2]))
    FNR = 1-TPR
    group_percentages =[TNR, FPR, FNR, TPR]

    group_percentages = ["{0:.2%}".format(value) for value in
                         group_percentages]
    labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
              zip(group_names,group_counts,group_percentages)]
    labels = np.asarray(labels).reshape(2,2)
    sn.heatmap(cm_val, annot=labels, fmt='', center = 2000)
    ax.set_title('Validation Confusion Matrix')
    ax.set_xlabel('Predicted Label')
    ax.set_ylabel('True Label')
    plt.show()
# Out:
# /home/bijanadmin/Desktop/Goose_data/data_Goose_1st_15s_2/LR_models/LR_CH23_LOSSbce_REGnone1_EPOCH37.pt
# validation loss:0.42866817116737366 accuracy:0.8092088527092343
# 0.7914017
# date:180327, rec:006, time:117.0, label:1.0
# Original data 62 CH
# /home/bijanadmin/Desktop/Goose_data/data_Goose_1st_15s_2/LR_models/LR_CH23_LOSSbce_REGnone50_EPOCH45.pt
# validation loss:0.42756643891334534 accuracy:0.8188756041719665
# 0.7914017
# date:180327, rec:006, time:117.0, label:1.0
# Original data 62 CH
# /home/bijanadmin/Desktop/Goose_data/data_Goose_1st_15s_2/LR_models/LR_CH23_LOSSbce_REGnone100_EPOCH39.pt
# validation loss:0.42197224497795105 accuracy:0.8181124395828033
# 0.7914017
# date:180327, rec:006, time:117.0, label:1.0
# Original data 62 CH

# %% [markdown]
# ### Logistic regression with L2 regularization

# %%
device = torch.device('cuda')

tol = 0.01
learning_rate = 0.001
num_epochs = 51
alphas = [1,50,100] 
model_type = 'LR'
loss_type = 'bce'
reg_type = 'l2'
timewindow = 15

# %%
for alpha in alphas:
    model = GLM(input_dim=100*timewindow).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)
    epochs, training_losses, training_acc, val_losses, validation_acc = [], [], [], [], []

    for epoch in range(num_epochs):
        train_loss, train_acc = train(model, optimizer, train_loader, timewindow = timewindow, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
        print('Train loss for epoch {}: {}'.format(epoch, train_loss))
        val_loss, val_acc = evaluate(model, optimizer, val_loader, alpha=alpha, timewindow = timewindow, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
        print('Val loss for epoch {}: {}'.format(epoch, val_loss))
        if val_losses:
            if val_loss < min(val_losses):
                best_epoch = epoch
                print(epoch)
                path = model_saving_path
                torch.save(model.state_dict(), '{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, epoch))
        epochs.append(epoch)
        training_losses.append(train_loss)
        training_acc.append(train_acc)
        val_losses.append(val_loss)
        validation_acc.append(val_acc)

        if train_loss < tol:
            break           
    plot_loss_acc(training_losses, val_losses, training_acc, validation_acc, model_type)
# Out:
# Train loss for epoch 0: 0.5352194905281067
# Val loss for epoch 0: 0.5142286419868469
# Train loss for epoch 1: 0.4912031590938568
# Val loss for epoch 1: 0.503485381603241
# 1
# Train loss for epoch 2: 0.4791366755962372
# Val loss for epoch 2: 0.49765244126319885
# 2
# Train loss for epoch 3: 0.47295987606048584

# %%
model_LR = os.listdir(model_saving_path)
results = []
for alpha in alphas:
    epoch_results = []
    reg_alpha = 'REG'+reg_type+str(alpha)+'_'
    for i, s in enumerate(model_LR):
        if 'REDUCEsum' in s:
            continue
        else:
            if '_CH23_' in s and reg_alpha in s:
                model_name = model_LR[i].split('_')
                epoch_name = [ind for ind,item in enumerate(np.array(model_name)) if "EPOCH" in item]
                res = [int(i) for i in model_name[epoch_name[0]] if i.isdigit()]
                if len(res) > 1:
                    epoch_result = res[0]*10+res[1]
                else:
                    epoch_result = res[0]
                epoch_results.append(epoch_result)
            
    results.append([alpha, max(epoch_results)])
    
results = pd.DataFrame(np.array(results), columns=['alpha', 'epoch'])
best_results = results.groupby('alpha').max('epoch')
print(best_results)

# %%
for i,(index,row) in enumerate(best_results.iterrows()):
    
    path = model_saving_path
    best_epoch = int(row)
    alpha = index
    
    
    # load best model
    model = GLM(input_dim=100*timewindow).to(device)
    path = model_saving_path
    optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)
    model.load_state_dict(torch.load('{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, best_epoch)))
    
    print('{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, best_epoch))

    ## Show one feature
    weights = model.linear.weight.view(100, timewindow)
    weights_sub = weights.detach().cpu()
    plt.axis('off')
    plt.imshow(weights_sub)
    plt.title(str(CH))
    # plt.clim(-0.03, 0.03)
    plt.show()
    
    ## Calculate accuracy and validation loss
    val_loss, val_acc, val_preds, val_preds_probs, val_labels,_,_,_, cases_wrong_1 = evaluate(model, optimizer, val_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=True, device=device)
    print('validation loss:{} accuracy:{}'.format(val_loss, val_acc))
    print(np.mean(np.concatenate(val_labels)))
    
    
    ## Wrong Classifications
    path_wrong = '/mnt/pesaranlab/People/Capstone_students/Yue/wrong_pred'
    pickle.dump(cases_wrong_1, open('{}/{}_CH{}_LOSS{}_REG{}{}.pt'.format(path_wrong, model_type, CH, loss_type, reg_type, alpha), 'wb'))
    idx = 0
    print('date:{}, rec:{}, time:{}, label:{}'.format(cases_wrong_1[0][0], cases_wrong_1[0][1], cases_wrong_1[0][2], cases_wrong_1[0][3]))
    print('Original data 62 CH')
    weights_sub = cases_wrong_1[0][-1][0]
    plt.axis('off')
    plt.imshow(weights_sub)
    # plt.clim(-0.03, 0.03)
    plt.show()
    
    ## Confusion matrix
    predictions_val = np.concatenate(val_preds)
    labels_val = np.concatenate(val_labels)

    df_val = pd.DataFrame({'predictions': predictions_val, 'labels': labels_val})

    cm_val = confusion_matrix(labels_val, predictions_val)
    ax = plt.axes()
    group_names = ['True Neg','False Pos','False Neg','True Pos']
    group_counts = ["{0:0.0f}".format(value) for value in
                    cm_val.flatten()]

    TNR = int(group_counts[0]) / (int(group_counts[0])+int(group_counts[1]))
    FPR = 1 - TNR
    TPR = int(group_counts[3]) / (int(group_counts[3])+int(group_counts[2]))
    FNR = 1-TPR
    group_percentages =[TNR, FPR, FNR, TPR]

    group_percentages = ["{0:.2%}".format(value) for value in
                         group_percentages]
    labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
              zip(group_names,group_counts,group_percentages)]
    labels = np.asarray(labels).reshape(2,2)
    sn.heatmap(cm_val, annot=labels, fmt='', center = 2000)
    ax.set_title('Validation Confusion Matrix')
    ax.set_xlabel('Predicted Label')
    ax.set_ylabel('True Label')
    plt.show()

# %% [markdown]
# ### Logistic Regression with finite difference regularization

# %%
device = torch.device('cuda')

tol = 0.01
learning_rate = 0.001
num_epochs = 51
alphas = [1,50,100]
model_type = 'LR'
loss_type = 'bce'
reg_type = 'finite_diff'
timewindow = 15

model = GLM(input_dim=100*timewindow).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)

# %%
for alpha in alphas:
    model = GLM(input_dim=100*timewindow).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)
    epochs, training_losses, training_acc, val_losses, validation_acc = [], [], [], [], []

    for epoch in range(num_epochs):
        train_loss, train_acc = train(model, optimizer, train_loader, timewindow = timewindow, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
        print('Train loss for epoch {}: {}'.format(epoch, train_loss))
        val_loss, val_acc = evaluate(model, optimizer, val_loader, alpha=alpha, timewindow = timewindow, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
        print('Val loss for epoch {}: {}'.format(epoch, val_loss))
        if val_losses:
            if val_loss < min(val_losses):
                best_epoch = epoch
                print(epoch)
                path = model_saving_path
                torch.save(model.state_dict(), '{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, epoch))
        epochs.append(epoch)
        training_losses.append(train_loss)
        training_acc.append(train_acc)
        val_losses.append(val_loss)
        validation_acc.append(val_acc)

        if train_loss < tol:
            break           
    plot_loss_acc(training_losses, val_losses, training_acc, validation_acc, model_type)

# %%
model_LR = os.listdir(model_saving_path)
results = []
for alpha in alphas:
    epoch_results = []
    reg_alpha = 'REG'+reg_type+str(alpha)+'_'
    for i, s in enumerate(model_LR):
        if 'REDUCEsum' in s:
            continue
        else:
            if '_CH23_' in s and reg_alpha in s:
                model_name = model_LR[i].split('_')
                epoch_name = [ind for ind,item in enumerate(np.array(model_name)) if "EPOCH" in item]
                res = [int(i) for i in model_name[epoch_name[0]] if i.isdigit()]
                if len(res) > 1:
                    epoch_result = res[0]*10+res[1]
                else:
                    epoch_result = res[0]
                epoch_results.append(epoch_result)
            
    results.append([alpha, max(epoch_results)])
    
results = pd.DataFrame(np.array(results), columns=['alpha', 'epoch'])
best_results = results.groupby('alpha').max('epoch')
print(best_results)

# %%
for i,(index,row) in enumerate(best_results.iterrows()):
    
    path = model_saving_path
    best_epoch = int(row)
    alpha = index
    
    
    # load best model
    model = GLM(input_dim=100*timewindow).to(device)
    path = model_saving_path
    optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)
    model.load_state_dict(torch.load('{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, best_epoch)))
    
    print('{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, best_epoch))

    ## Show one feature
    weights = model.linear.weight.view(100, timewindow)
    weights_sub = weights.detach().cpu()
    plt.axis('off')
    plt.imshow(weights_sub)
    plt.title(str(CH))
    # plt.clim(-0.03, 0.03)
    plt.show()
    
    ## Calculate accuracy and validation loss
    val_loss, val_acc, val_preds, val_preds_probs, val_labels,_,_,_, cases_wrong_1 = evaluate(model, optimizer, val_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=True, device=device)
    print('validation loss:{} accuracy:{}'.format(val_loss, val_acc))
    print(np.mean(np.concatenate(val_labels)))
    
    
    ## Wrong Classifications
    path_wrong = '/mnt/pesaranlab/People/Capstone_students/Yue/wrong_pred'
    pickle.dump(cases_wrong_1, open('{}/{}_CH{}_LOSS{}_REG{}{}.pt'.format(path_wrong, model_type, CH, loss_type, reg_type, alpha), 'wb'))
    idx = 0
    print('date:{}, rec:{}, time:{}, label:{}'.format(cases_wrong_1[0][0], cases_wrong_1[0][1], cases_wrong_1[0][2], cases_wrong_1[0][3]))
    print('Original data 62 CH')
    weights_sub = cases_wrong_1[0][-1][0]
    plt.axis('off')
    plt.imshow(weights_sub)
    # plt.clim(-0.03, 0.03)
    plt.show()
    
    ## Confusion matrix
    predictions_val = np.concatenate(val_preds)
    labels_val = np.concatenate(val_labels)

    df_val = pd.DataFrame({'predictions': predictions_val, 'labels': labels_val})

    cm_val = confusion_matrix(labels_val, predictions_val)
    ax = plt.axes()
    group_names = ['True Neg','False Pos','False Neg','True Pos']
    group_counts = ["{0:0.0f}".format(value) for value in
                    cm_val.flatten()]

    TNR = int(group_counts[0]) / (int(group_counts[0])+int(group_counts[1]))
    FPR = 1 - TNR
    TPR = int(group_counts[3]) / (int(group_counts[3])+int(group_counts[2]))
    FNR = 1-TPR
    group_percentages =[TNR, FPR, FNR, TPR]

    group_percentages = ["{0:.2%}".format(value) for value in
                         group_percentages]
    labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
              zip(group_names,group_counts,group_percentages)]
    labels = np.asarray(labels).reshape(2,2)
    sn.heatmap(cm_val, annot=labels, fmt='', center = 2000)
    ax.set_title('Validation Confusion Matrix')
    ax.set_xlabel('Predicted Label')
    ax.set_ylabel('True Label')
    plt.show()

# %% [markdown]
# ### SVM without regularization

# %% [markdown]
# ### SVM with L2 regularization

# %%
device = torch.device('cuda')

tol = 0.01
learning_rate = 0.001
num_epochs = 51
alpha = 0.5 # have special meaning as margin, corresponding to 1 in the hinge loss
model_type = 'SVM'
loss_type = 'hinge'
reg_type = 'l2'

model = GLM(input_dim=100*10).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)

# %%
epochs, training_losses, training_acc, val_losses, validation_acc = [], [], [], [], []

for epoch in range(num_epochs):
    train_loss, train_acc = train(model, optimizer, train_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
    print('Train loss for epoch {}: {}'.format(epoch, train_loss))
    val_loss, val_acc = evaluate(model, optimizer, val_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
    print('Val loss for epoch {}: {}'.format(epoch, val_loss))
    if val_losses:
        if val_loss < min(val_losses):
            best_epoch = epoch
            print(epoch)
            path = '/mnt/pesaranlab/People/Capstone_students/Yue/model/model_Goose_1st_1_upsample'
            torch.save(model.state_dict(), '{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, epoch))
    epochs.append(epoch)
    training_losses.append(train_loss)
    training_acc.append(train_acc)
    val_losses.append(val_loss)
    validation_acc.append(val_acc)
    
    if train_loss < tol:
        break
# Out:
# Train loss for epoch 0: 0.6851320862770081
# Val loss for epoch 0: 0.7111771702766418
# Train loss for epoch 1: 0.6442375183105469
# Val loss for epoch 1: 0.7678999900817871
# Train loss for epoch 2: 0.6391520500183105
# Val loss for epoch 2: 0.7529788017272949
# Train loss for epoch 3: 0.6417877078056335
# Val loss for epoch 3: 0.6641672253608704
# 3
# Train loss for epoch 4: 0.6390126347541809
# Val loss for epoch 4: 0.6984342932701111
# Train loss for epoch 5: 0.6404396295547485
# Val loss for epoch 5: 0.7401537895202637
# Train loss for epoch 6: 0.639179527759552
# Val loss for epoch 6: 0.6993381977081299
# Train loss for epoch 7: 0.6405513882637024
# Val loss for epoch 7: 0.6649073362350464
# Train loss for epoch 8: 0.6384839415550232
# Val loss for epoch 8: 0.6716033816337585
# Train loss for epoch 9: 0.6426579356193542
# Val loss for epoch 9: 0.7246717214584351
# Train loss for epoch 10: 0.6410369277000427
# Val loss for epoch 10: 0.714557945728302
# Train loss for epoch 11: 0.640546977519989
# Val loss for epoch 11: 0.7000125050544739
# Train loss for epoch 12: 0.642488420009613
# Val loss for epoch 12: 0.6774542331695557
# Train loss for epoch 13: 0.6405550837516785
# Val loss for epoch 13: 0.7184460759162903
# Train loss for epoch 14: 0.6403983235359192
# Val loss for epoch 14: 0.7138395309448242
# Train loss for epoch 15: 0.6415858864784241
# Val loss for epoch 15: 0.7804384231567383
# Train loss for epoch 16: 0.639844536781311
# Val loss for epoch 16: 0.7306813597679138
# Train loss for epoch 17: 0.6411546468734741
# Val loss for epoch 17: 0.6943265795707703
# Train loss for epoch 18: 0.6401860117912292
# Val loss for epoch 18: 0.6885607838630676
# Train loss for epoch 19: 0.6396834850311279
# Val loss for epoch 19: 0.7206060290336609
# Train loss for epoch 20: 0.640455961227417
# Val loss for epoch 20: 0.702420175075531
# Train loss for epoch 21: 0.6402938961982727
# Val loss for epoch 21: 0.7104942202568054
# Train loss for epoch 22: 0.640040934085846
# Val loss for epoch 22: 0.7436862587928772
# Train loss for epoch 23: 0.6407786011695862
# Val loss for epoch 23: 0.6620125770568848
# 23
# Train loss for epoch 24: 0.6418817639350891
# Val loss for epoch 24: 0.7360722422599792
# Train loss for epoch 25: 0.6385318040847778
# Val loss for epoch 25: 0.7304670214653015
# Train loss for epoch 26: 0.640387773513794
# Val loss for epoch 26: 0.7861469388008118
# Train loss for epoch 27: 0.6426716446876526
# Val loss for epoch 27: 0.6352165341377258
# 27
# Train loss for epoch 28: 0.6454393267631531
# Val loss for epoch 28: 0.6951034069061279
# Train loss for epoch 29: 0.6385886073112488
# Val loss for epoch 29: 0.7505565285682678
# Train loss for epoch 30: 0.6399576663970947
# Val loss for epoch 30: 0.7399937510490417
# Train loss for epoch 31: 0.641554057598114
# Val loss for epoch 31: 0.6840065121650696
# Train loss for epoch 32: 0.6412416100502014
# Val loss for epoch 32: 0.6981443762779236
# Train loss for epoch 33: 0.6422035694122314
# Val loss for epoch 33: 0.6874670386314392
# Train loss for epoch 34: 0.6408448815345764
# Val loss for epoch 34: 0.8072331547737122
# Train loss for epoch 35: 0.6395016312599182
# Val loss for epoch 35: 0.730316162109375
# Train loss for epoch 36: 0.6403080224990845
# Val loss for epoch 36: 0.7818818688392639
# Train loss for epoch 37: 0.6434655785560608
# Val loss for epoch 37: 0.6429640650749207
# Train loss for epoch 38: 0.6408840417861938
# Val loss for epoch 38: 0.6359612941741943
# Train loss for epoch 39: 0.6419800519943237
# Val loss for epoch 39: 0.6931543946266174
# Train loss for epoch 40: 0.641847550868988
# Val loss for epoch 40: 0.6723946332931519
# Train loss for epoch 41: 0.6399581432342529
# Val loss for epoch 41: 0.7007078528404236
# Train loss for epoch 42: 0.637771725654602
# Val loss for epoch 42: 0.7417786717414856
# Train loss for epoch 43: 0.6427635550498962
# Val loss for epoch 43: 0.737413763999939
# Train loss for epoch 44: 0.6401107907295227
# Val loss for epoch 44: 0.6725066304206848
# Train loss for epoch 45: 0.6420534253120422
# Val loss for epoch 45: 0.6480686068534851
# Train loss for epoch 46: 0.6414241194725037
# Val loss for epoch 46: 0.7304709553718567
# Train loss for epoch 47: 0.6403049826622009
# Val loss for epoch 47: 0.7036920785903931
# Train loss for epoch 48: 0.6407722234725952
# Val loss for epoch 48: 0.6887156963348389
# Train loss for epoch 49: 0.6385686993598938
# Val loss for epoch 49: 0.7157089114189148
# Train loss for epoch 50: 0.6383669376373291
# Val loss for epoch 50: 0.7005918622016907

# %%
plot_loss_acc(training_losses, val_losses, training_acc, validation_acc, model_type)

# %%
best_epoch = 27

# %%
model = GLM(input_dim=100*10).to(device)
path = '/mnt/pesaranlab/People/Capstone_students/Yue/model/model_Goose_1st_1_upsample'
model.load_state_dict(torch.load('{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, best_epoch)))
weights = model.linear.weight.view(100, 10)
weights_sub = weights.detach().cpu()
plt.axis('off')
plt.imshow(weights_sub)
plt.title(str(CH))
# plt.clim(-0.03, 0.03)
plt.show()

# %%
test_loss, test_acc, test_preds, test_preds_probs, test_labels, cases_wrong_4 = evaluate(model, optimizer, test_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=True, device=device)
print('test loss:{} accuracy:{}'.format(test_loss, test_acc))
# Out:
# test loss:0.9384552836418152 accuracy:0.6475384615384615

# %%
predictions_test = np.concatenate(test_preds)
labels_test = np.concatenate(test_labels)

df_test = pd.DataFrame({'predictions': predictions_test, 'labels': labels_test})

cm_test = confusion_matrix(labels_test, predictions_test)
ax = plt.axes()
sn.heatmap(cm_test, annot = True, fmt = "d", ax = ax, center=2000)
ax.set_title('Test Confusion Matrix')
ax.set_xlabel('Predicted Label')
ax.set_ylabel('True Label')
plt.show()

# %%
idx = 0
print('date:{}, rec:{}, time:{}, label:{}'.format(cases_wrong_4[0][0], cases_wrong_4[0][1], cases_wrong_4[0][1], cases_wrong_4[0][3]))
print('Original data 62 CH')
weights_sub = cases_wrong_4[0][-1][0]
plt.axis('off')
plt.imshow(weights_sub)
# plt.clim(-0.03, 0.03)
plt.show()
# Out:
# date:180331, rec:004, time:004, label:1.0
# Original data 62 CH

# %% [markdown]
# ### SVM with finite difference regularization

# %%
device = torch.device('cuda')

tol = 0.01
learning_rate = 0.001
num_epochs = 51
alpha = 0.5
model_type = 'SVM'
loss_type = 'hinge'
reg_type = 'finite_diff'

model = GLM(input_dim=100*10).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)

# %%
epochs, training_losses, training_acc, val_losses, validation_acc = [], [], [], [], []

for epoch in range(num_epochs):
    train_loss, train_acc = train(model, optimizer, train_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
    print('Train loss for epoch {}: {}'.format(epoch, train_loss))
    val_loss, val_acc = evaluate(model, optimizer, val_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
    print('Val loss for epoch {}: {}'.format(epoch, val_loss))
    if val_losses:
        if val_loss < min(val_losses):
            best_epoch = epoch
            print(epoch)
            path = '/mnt/pesaranlab/People/Capstone_students/Yue/model/model_Goose_1st_1_upsample'
            torch.save(model.state_dict(), '{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, epoch))
    epochs.append(epoch)
    training_losses.append(train_loss)
    training_acc.append(train_acc)
    val_losses.append(val_loss)
    validation_acc.append(val_acc)
    
    if train_loss < tol:
        break
# Out:
# Train loss for epoch 0: 0.6690675616264343
# Val loss for epoch 0: 0.7053626179695129
# Train loss for epoch 1: 0.579605758190155
# Val loss for epoch 1: 0.6587177515029907
# 1
# Train loss for epoch 2: 0.5777973532676697
# Val loss for epoch 2: 0.661455512046814
# Train loss for epoch 3: 0.5772103071212769
# Val loss for epoch 3: 0.6873345375061035
# Train loss for epoch 4: 0.5797932744026184
# Val loss for epoch 4: 0.6312553286552429
# 4
# Train loss for epoch 5: 0.5747454762458801
# Val loss for epoch 5: 0.6387228965759277
# Train loss for epoch 6: 0.5753779411315918
# Val loss for epoch 6: 0.6457529067993164
# Train loss for epoch 7: 0.5756300687789917
# Val loss for epoch 7: 0.570262610912323
# 7
# Train loss for epoch 8: 0.5766920447349548
# Val loss for epoch 8: 0.6651206016540527
# Train loss for epoch 9: 0.5784576535224915
# Val loss for epoch 9: 0.6457962989807129
# Train loss for epoch 10: 0.5766485929489136
# Val loss for epoch 10: 0.6799610257148743
# Train loss for epoch 11: 0.577312171459198
# Val loss for epoch 11: 0.6357672810554504
# Train loss for epoch 12: 0.5765970945358276
# Val loss for epoch 12: 0.6243463754653931
# Train loss for epoch 13: 0.5763651728630066
# Val loss for epoch 13: 0.6528318524360657
# Train loss for epoch 14: 0.5787343978881836
# Val loss for epoch 14: 0.6197062134742737
# Train loss for epoch 15: 0.5766005516052246
# Val loss for epoch 15: 0.6669512391090393
# Train loss for epoch 16: 0.5740532279014587
# Val loss for epoch 16: 0.6083996891975403
# Train loss for epoch 17: 0.578143835067749
# Val loss for epoch 17: 0.6331867575645447
# Train loss for epoch 18: 0.5752172470092773
# Val loss for epoch 18: 0.6276236772537231
# Train loss for epoch 19: 0.5754168033599854
# Val loss for epoch 19: 0.6268960237503052
# Train loss for epoch 20: 0.5756818056106567
# Val loss for epoch 20: 0.6202787756919861
# Train loss for epoch 21: 0.5744140148162842
# Val loss for epoch 21: 0.6567234396934509
# Train loss for epoch 22: 0.5762956738471985
# Val loss for epoch 22: 0.6660755276679993
# Train loss for epoch 23: 0.5758554339408875
# Val loss for epoch 23: 0.6730091571807861
# Train loss for epoch 24: 0.577211320400238
# Val loss for epoch 24: 0.651534914970398
# Train loss for epoch 25: 0.5769349336624146
# Val loss for epoch 25: 0.7000337243080139
# Train loss for epoch 26: 0.5785800814628601
# Val loss for epoch 26: 0.687545120716095
# Train loss for epoch 27: 0.5782286524772644
# Val loss for epoch 27: 0.6496562361717224
# Train loss for epoch 28: 0.5788707137107849
# Val loss for epoch 28: 0.6680619120597839
# Train loss for epoch 29: 0.5760782957077026
# Val loss for epoch 29: 0.6649113893508911
# Train loss for epoch 30: 0.5756315588951111
# Val loss for epoch 30: 0.6239709854125977
# Train loss for epoch 31: 0.5757757425308228
# Val loss for epoch 31: 0.6552281379699707
# Train loss for epoch 32: 0.5736462473869324
# Val loss for epoch 32: 0.6681107878684998
# Train loss for epoch 33: 0.5752080082893372
# Val loss for epoch 33: 0.6992300748825073
# Train loss for epoch 34: 0.5773605704307556
# Val loss for epoch 34: 0.5969449281692505
# Train loss for epoch 35: 0.577599287033081
# Val loss for epoch 35: 0.7016803622245789
# Train loss for epoch 36: 0.5782400965690613
# Val loss for epoch 36: 0.6377145648002625
# Train loss for epoch 37: 0.5756941437721252
# Val loss for epoch 37: 0.689575731754303
# Train loss for epoch 38: 0.576504647731781
# Val loss for epoch 38: 0.6356939077377319
# Train loss for epoch 39: 0.579881489276886
# Val loss for epoch 39: 0.6778709292411804
# Train loss for epoch 40: 0.5781845450401306
# Val loss for epoch 40: 0.60308438539505
# Train loss for epoch 41: 0.577141284942627
# Val loss for epoch 41: 0.6428723931312561
# Train loss for epoch 42: 0.5757811665534973
# Val loss for epoch 42: 0.6472859382629395
# Train loss for epoch 43: 0.5753296613693237
# Val loss for epoch 43: 0.6884997487068176
# Train loss for epoch 44: 0.5757269859313965
# Val loss for epoch 44: 0.6618257164955139
# Train loss for epoch 45: 0.5760087966918945
# Val loss for epoch 45: 0.6461961269378662
# Train loss for epoch 46: 0.5766039490699768
# Val loss for epoch 46: 0.641828715801239
# Train loss for epoch 47: 0.5778237581253052
# Val loss for epoch 47: 0.6952266097068787
# Train loss for epoch 48: 0.5753308534622192
# Val loss for epoch 48: 0.6868410110473633
# Train loss for epoch 49: 0.5763373374938965
# Val loss for epoch 49: 0.7049767971038818
# Train loss for epoch 50: 0.5758347511291504
# Val loss for epoch 50: 0.6037036180496216

# %%
plot_loss_acc(training_losses, val_losses, training_acc, validation_acc, model_type)

# %%
best_epoch = 7

# %%
model = GLM(input_dim=100*10).to(device)
path = '/mnt/pesaranlab/People/Capstone_students/Yue/model/model_Goose_1st_1_upsample'
model.load_state_dict(torch.load('{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, best_epoch)))
weights = model.linear.weight.view(100, 10)
weights_sub = weights.detach().cpu()
plt.axis('off')
plt.imshow(weights_sub)
plt.title(str(CH))
# plt.clim(-0.03, 0.03)
plt.show()

# %%
test_loss, test_acc, test_preds, test_preds_probs, test_labels, cases_wrong_5 = evaluate(model, optimizer, test_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=True, device=device)
print('test loss:{} accuracy:{}'.format(test_loss, test_acc))
# Out:
# test loss:0.8175214529037476 accuracy:0.6916923076923077

# %%
predictions_test = np.concatenate(test_preds)
labels_test = np.concatenate(test_labels)

df_test = pd.DataFrame({'predictions': predictions_test, 'labels': labels_test})

cm_test = confusion_matrix(labels_test, predictions_test)
ax = plt.axes()
sn.heatmap(cm_test, annot = True, fmt = "d", ax = ax, center=2000)
ax.set_title('Test Confusion Matrix')
ax.set_xlabel('Predicted Label')
ax.set_ylabel('True Label')
plt.show()

# %%
idx = 0
print('date:{}, rec:{}, time:{}, label:{}'.format(cases_wrong_5[0][0], cases_wrong_5[0][1], cases_wrong_5[0][1], cases_wrong_5[0][3]))
print('Original data 62 CH')
weights_sub = cases_wrong_5[0][-1][0]
plt.axis('off')
plt.imshow(weights_sub)
# plt.clim(-0.03, 0.03)
plt.show()
# Out:
# date:180331, rec:004, time:004, label:1.0
# Original data 62 CH
