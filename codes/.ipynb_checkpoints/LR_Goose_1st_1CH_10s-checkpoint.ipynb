# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
from torch.utils.data import Dataset, DataLoader
from torch import nn
from torch.nn.functional import relu
from scipy.io import loadmat
import os
from os import listdir
import pandas as pd
from skimage import io
from PIL import Image
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pickle

from utils import *

# %%
#selected subset of dates. 
val_dates = ['180328','180329']
test_dates = ['180330','180331']
load_path = '/home/bijanadmin/Desktop/Goose_data/data_Goose_all_2/'

train_files, val_files, test_files = create_files(load_path, val_dates, test_dates)
train_loader, val_loader, test_loader = create_dataloaders(train_files, val_files, test_files,load_path, batch_size=128)

# %%
len(train_loader), len(val_loader), len(test_loader)
# Out:
# (446, 21, 49)

# %%
for batch_idx, (data, label, date, rec, time) in enumerate(train_loader): # check shapes
    print(data.shape)
    print(label.shape)
    print(len(date))
    print(len(rec))
    print(len(time))
    break
# Out:
# torch.Size([128, 62, 100, 10])
# torch.Size([128, 1])
# 128
# 128
# 128

# %%
# movement labelled 0; non-movement labelled 1
for batch_idx, (data, label, date, rec, time) in enumerate(train_loader):
    for i in range(128):
        print('date:{}, rec:{}, time:{}'.format(date[i], rec[i], time[i]))
        data_sub = data[i][0]
        plt.imshow(data_sub)
        plt.clim(-1.5, 1.5)
        plt.colorbar()
        plt.title(label[i][0].numpy())
        plt.show()
    break
# Out:
# date:180409, rec:003, time:2699.0
# date:180411, rec:006, time:3733.0
# date:180325, rec:009, time:4839.0
# date:180326, rec:003, time:989.0
# date:180327, rec:002, time:4663.0
# date:180414, rec:001, time:6983.0
# date:180325, rec:009, time:7173.0
# date:180413, rec:003, time:930.0
# date:180413, rec:001, time:660.0
# date:180409, rec:003, time:6427.0
# date:180327, rec:007, time:4270.0
# date:180413, rec:003, time:6961.0
# date:180325, rec:009, time:6709.0
# date:180413, rec:007, time:5725.0
# date:180327, rec:007, time:3440.0
# date:180411, rec:007, time:890.0
# date:180325, rec:007, time:4543.0
# date:180325, rec:003, time:3773.0
# date:180413, rec:003, time:1140.0
# date:180413, rec:003, time:4748.0
# date:180413, rec:001, time:3723.0
# date:180413, rec:004, time:3944.0
# date:180327, rec:008, time:4523.0
# date:180409, rec:006, time:3205.0
# date:180409, rec:004, time:6105.0
# date:180325, rec:007, time:2956.0
# date:180413, rec:001, time:6967.0
# date:180324, rec:008, time:2528.0
# date:180411, rec:004, time:6138.0
# date:180409, rec:006, time:3185.0
# date:180413, rec:003, time:820.0
# date:180410, rec:005, time:3649.0
# date:180325, rec:009, time:3736.0
# date:180410, rec:005, time:3749.0
# date:180327, rec:008, time:5323.0
# date:180326, rec:004, time:1230.0
# date:180409, rec:006, time:4858.0
# date:180324, rec:008, time:5454.0
# date:180327, rec:008, time:4953.0
# date:180326, rec:003, time:1249.0
# date:180401, rec:001, time:4076.0
# date:180412, rec:002, time:3227.0
# date:180325, rec:009, time:2290.0
# date:180413, rec:002, time:5521.0
# date:180401, rec:001, time:3453.0
# date:180322, rec:003, time:773.0
# date:180325, rec:007, time:1558.0
# date:180413, rec:006, time:6830.0
# date:180413, rec:003, time:6201.0
# date:180414, rec:007, time:3897.0
# date:180327, rec:001, time:1050.0
# date:180325, rec:001, time:1670.0
# date:180327, rec:007, time:1730.0
# date:180325, rec:009, time:2280.0
# date:180409, rec:006, time:4768.0
# date:180413, rec:004, time:450.0
# date:180325, rec:009, time:1930.0
# date:180325, rec:005, time:4196.0
# date:180412, rec:002, time:5994.0
# date:180327, rec:006, time:6201.0
# date:180414, rec:001, time:1230.0
# date:180325, rec:007, time:5873.0
# date:180325, rec:002, time:6295.0
# date:180325, rec:006, time:4185.0
# date:180327, rec:007, time:4320.0
# date:180325, rec:007, time:4553.0
# date:180412, rec:006, time:3918.0
# date:180413, rec:002, time:4591.0
# date:180414, rec:001, time:1680.0
# date:180323, rec:002, time:5055.0
# date:180411, rec:003, time:6208.0
# date:180411, rec:003, time:6018.0
# date:180412, rec:003, time:5971.0
# date:180412, rec:002, time:2577.0
# date:180325, rec:009, time:4368.0
# date:180413, rec:002, time:4471.0
# date:180413, rec:001, time:1330.0
# date:180327, rec:001, time:1040.0
# date:180409, rec:006, time:1053.0
# date:180410, rec:006, time:919.0
# date:180324, rec:008, time:5214.0
# date:180414, rec:004, time:4708.0
# date:180412, rec:005, time:5137.0
# date:180411, rec:006, time:6464.0
# date:180412, rec:002, time:892.0
# date:180322, rec:007, time:3359.0
# date:180326, rec:003, time:4776.0
# date:180414, rec:007, time:6238.0
# date:180414, rec:001, time:920.0
# date:180410, rec:006, time:5246.0
# date:180323, rec:002, time:6156.0
# date:180414, rec:001, time:3562.0
# date:180324, rec:001, time:570.0
# date:180414, rec:005, time:2925.0
# date:180327, rec:002, time:4143.0
# date:180323, rec:007, time:7111.0
# date:180411, rec:006, time:731.0
# date:180401, rec:001, time:5197.0
# date:180413, rec:001, time:1080.0
# date:180413, rec:002, time:670.0
# date:180409, rec:005, time:4621.0
# date:180410, rec:005, time:1668.0
# date:180413, rec:001, time:5122.0
# date:180413, rec:001, time:5837.0
# date:180323, rec:007, time:2815.0
# date:180411, rec:003, time:4202.0
# date:180413, rec:002, time:5501.0
# date:180413, rec:003, time:6241.0
# date:180409, rec:003, time:4845.0
# date:180322, rec:004, time:6566.0
# date:180322, rec:002, time:4179.0
# date:180327, rec:007, time:3070.0
# date:180327, rec:007, time:2310.0
# date:180412, rec:003, time:6898.0
# date:180323, rec:007, time:4632.0
# date:180327, rec:007, time:3450.0
# date:180327, rec:007, time:1770.0
# date:180409, rec:005, time:530.0
# date:180325, rec:003, time:370.0
# date:180412, rec:002, time:5460.0
# date:180323, rec:002, time:2636.0
# date:180413, rec:001, time:5412.0
# date:180327, rec:002, time:1630.0
# date:180327, rec:004, time:4774.0
# date:180412, rec:006, time:5028.0
# date:180325, rec:001, time:1670.0
# date:180327, rec:008, time:2822.0
# date:180324, rec:001, time:3325.0

# %% [markdown]
# ### Logistic regression with no regularization

# %% [markdown]
# ### Logistic regression with L2 regularization

# %%
device = torch.device('cuda')

tol = 0.01
learning_rate = 0.001
num_epochs = 51
alpha = 0.1
model_type = 'LR'
loss_type = 'bce'
reg_type = 'l2'
model

model = GLM(input_dim=100*10).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)

# %%
epochs, training_losses, training_acc, val_losses, validation_acc = [], [], [], [], []

for epoch in range(num_epochs):
    train_loss, train_acc = train(model, optimizer, train_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
    print('Train loss for epoch {}: {}'.format(epoch, train_loss))
    val_loss, val_acc = evaluate(model, optimizer, val_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
    print('Val loss for epoch {}: {}'.format(epoch, val_loss))
    if val_losses:
        if val_loss < min(val_losses):
            best_epoch = epoch
            print(epoch)
            path = '/mnt/pesaranlab/People/Capstone_students/Yue/model/model_Goose_1st_1_upsample'
            torch.save(model.state_dict(), '{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, epoch))
    epochs.append(epoch)
    training_losses.append(train_loss)
    training_acc.append(train_acc)
    val_losses.append(val_loss)
    validation_acc.append(val_acc)
    
    if train_loss < tol:
        break
# Out:
# Train loss for epoch 0: 0.5589359402656555
# Val loss for epoch 0: 0.603571891784668
# Train loss for epoch 1: 0.5344599485397339
# Val loss for epoch 1: 0.6224754452705383
# Train loss for epoch 2: 0.5329248905181885
# Val loss for epoch 2: 0.5795549154281616
# 2
# Train loss for epoch 3: 0.5338733792304993
# Val loss for epoch 3: 0.5551152229309082
# 3
# Train loss for epoch 4: 0.535742998123169
# Val loss for epoch 4: 0.5393945574760437
# 4
# Train loss for epoch 5: 0.5367097854614258
# Val loss for epoch 5: 0.5799544453620911
# Train loss for epoch 6: 0.533765971660614
# Val loss for epoch 6: 0.5614364743232727
# Train loss for epoch 7: 0.532988965511322
# Val loss for epoch 7: 0.5580055117607117
# Train loss for epoch 8: 0.532912015914917
# Val loss for epoch 8: 0.5388731956481934
# 8
# Train loss for epoch 9: 0.5327494144439697
# Val loss for epoch 9: 0.5664029717445374
# Train loss for epoch 10: 0.5316610336303711
# Val loss for epoch 10: 0.5541503429412842
# Train loss for epoch 11: 0.5319799780845642
# Val loss for epoch 11: 0.5472258925437927
# Train loss for epoch 12: 0.5338551998138428
# Val loss for epoch 12: 0.5312713980674744
# 12
# Train loss for epoch 13: 0.5319334268569946
# Val loss for epoch 13: 0.5411567091941833
# Train loss for epoch 14: 0.5341183543205261
# Val loss for epoch 14: 0.5541858673095703
# Train loss for epoch 15: 0.5344502925872803
# Val loss for epoch 15: 0.5550460815429688
# Train loss for epoch 16: 0.5342845320701599
# Val loss for epoch 16: 0.5374096632003784
# Train loss for epoch 17: 0.5322862267494202
# Val loss for epoch 17: 0.569993257522583
# Train loss for epoch 18: 0.5345081090927124
# Val loss for epoch 18: 0.5576233267784119
# Train loss for epoch 19: 0.5327805280685425
# Val loss for epoch 19: 0.5813364386558533
# Train loss for epoch 20: 0.5323506593704224
# Val loss for epoch 20: 0.5544443130493164
# Train loss for epoch 21: 0.5330415368080139
# Val loss for epoch 21: 0.5483012795448303
# Train loss for epoch 22: 0.5321841835975647
# Val loss for epoch 22: 0.5699001550674438
# Train loss for epoch 23: 0.534680187702179
# Val loss for epoch 23: 0.528672993183136
# 23
# Train loss for epoch 24: 0.5326629877090454
# Val loss for epoch 24: 0.6218783855438232
# Train loss for epoch 25: 0.5324344635009766
# Val loss for epoch 25: 0.5453506708145142
# Train loss for epoch 26: 0.5344236493110657
# Val loss for epoch 26: 0.5503383874893188
# Train loss for epoch 27: 0.5340372323989868
# Val loss for epoch 27: 0.5566611289978027
# Train loss for epoch 28: 0.5322819948196411
# Val loss for epoch 28: 0.5639119744300842
# Train loss for epoch 29: 0.5350802540779114
# Val loss for epoch 29: 0.5375315546989441
# Train loss for epoch 30: 0.5324122309684753
# Val loss for epoch 30: 0.5547742247581482
# Train loss for epoch 31: 0.531858503818512
# Val loss for epoch 31: 0.5327873229980469
# Train loss for epoch 32: 0.5330846309661865
# Val loss for epoch 32: 0.5629622936248779
# Train loss for epoch 33: 0.5324780941009521
# Val loss for epoch 33: 0.5905995965003967
# Train loss for epoch 34: 0.534503161907196
# Val loss for epoch 34: 0.5806490182876587
# Train loss for epoch 35: 0.5331937670707703
# Val loss for epoch 35: 0.6057713627815247
# Train loss for epoch 36: 0.5335718393325806
# Val loss for epoch 36: 0.5602141618728638
# Train loss for epoch 37: 0.5335026383399963
# Val loss for epoch 37: 0.5573460459709167
# Train loss for epoch 38: 0.5327644944190979
# Val loss for epoch 38: 0.5610871911048889
# Train loss for epoch 39: 0.5325092077255249
# Val loss for epoch 39: 0.5583598017692566
# Train loss for epoch 40: 0.5324354767799377
# Val loss for epoch 40: 0.5419650673866272
# Train loss for epoch 41: 0.5322853922843933
# Val loss for epoch 41: 0.6123860478401184
# Train loss for epoch 42: 0.5319179892539978
# Val loss for epoch 42: 0.5490344166755676
# Train loss for epoch 43: 0.5323497653007507
# Val loss for epoch 43: 0.539212703704834
# Train loss for epoch 44: 0.5336762070655823
# Val loss for epoch 44: 0.5335750579833984
# Train loss for epoch 45: 0.5343385934829712
# Val loss for epoch 45: 0.529339611530304
# Train loss for epoch 46: 0.5341309309005737
# Val loss for epoch 46: 0.538231611251831
# Train loss for epoch 47: 0.5339242219924927
# Val loss for epoch 47: 0.5530511140823364
# Train loss for epoch 48: 0.5322916507720947
# Val loss for epoch 48: 0.5087031722068787
# 48
# Train loss for epoch 49: 0.534189760684967
# Val loss for epoch 49: 0.5206959843635559
# Train loss for epoch 50: 0.5336152911186218
# Val loss for epoch 50: 0.5364326238632202

# %%
plot_loss_acc(training_losses, val_losses, training_acc, validation_acc, model_type)

# %%
best_epoch = 48

# %%
model = GLM(input_dim=100*10).to(device)
path = '/mnt/pesaranlab/People/Capstone_students/Yue/model/model_Goose_1st_1_upsample'
model.load_state_dict(torch.load('{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, best_epoch)))
weights = model.linear.weight.view(100, 10)
weights_sub = weights.detach().cpu()
plt.axis('off')
plt.imshow(weights_sub)
plt.title(str(CH))
# plt.clim(-0.03, 0.03)
plt.show()

# %%
test_loss, test_acc, test_preds, test_preds_probs, test_labels, cases_wrong_1 = evaluate(model, optimizer, test_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=True, device=device)
print('test loss:{} accuracy:{}'.format(test_loss, test_acc))

# %%
np.mean(np.concatenate(test_labels))
# Out:
# 0.7407692

# %%
path_wrong = '/mnt/pesaranlab/People/Capstone_students/Yue/wrong_pred'
pickle.dump(cases_wrong_1, open('{}/{}_CH{}_LOSS{}_REG{}{}.pt'.format(path_wrong, model_type, CH, loss_type, reg_type, alpha), 'wb'))

# %%
predictions_test = np.concatenate(test_preds)
labels_test = np.concatenate(test_labels)

df_test = pd.DataFrame({'predictions': predictions_test, 'labels': labels_test})

cm_test = confusion_matrix(labels_test, predictions_test)
ax = plt.axes()
sn.heatmap(cm_test, annot = True, fmt = "d", ax = ax, center=2000)
ax.set_title('Test Confusion Matrix')
ax.set_xlabel('Predicted Label')
ax.set_ylabel('True Label')
plt.show()

# %%
idx = 0
print('date:{}, rec:{}, time:{}, label:{}'.format(cases_wrong_1[0][0], cases_wrong_1[0][1], cases_wrong_1[0][1], cases_wrong_1[0][3]))
print('Original data 62 CH')
weights_sub = cases_wrong_1[0][-1][0]
plt.axis('off')
plt.imshow(weights_sub)
# plt.clim(-0.03, 0.03)
plt.show()
# Out:
# date:180331, rec:004, time:004, label:1.0
# Original data 62 CH

# %% [markdown]
# ### Logistic Regression with finite difference regularization

# %%
device = torch.device('cuda')

tol = 0.01
learning_rate = 0.001
num_epochs = 51
alpha = 0.1
model_type = 'LR'
loss_type = 'bce'
reg_type = 'finite_diff'

model = GLM(input_dim=100*10).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)

# %%
epochs, training_losses, training_acc, val_losses, validation_acc = [], [], [], [], []

for epoch in range(num_epochs):
    train_loss, train_acc = train(model, optimizer, train_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
    print('Train loss for epoch {}: {}'.format(epoch, train_loss))
    val_loss, val_acc = evaluate(model, optimizer, val_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
    print('Val loss for epoch {}: {}'.format(epoch, val_loss))
    if val_losses:
        if val_loss < min(val_losses):
            best_epoch = epoch
            print(epoch)
            path = '/mnt/pesaranlab/People/Capstone_students/Yue/model/model_Goose_1st_1_upsample'
            torch.save(model.state_dict(), '{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, epoch))
    epochs.append(epoch)
    training_losses.append(train_loss)
    training_acc.append(train_acc)
    val_losses.append(val_loss)
    validation_acc.append(val_acc)
    
    if train_loss < tol:
        break
# Out:
# Train loss for epoch 0: 0.5540512204170227
# Val loss for epoch 0: 0.6293272376060486
# Train loss for epoch 1: 0.520308256149292
# Val loss for epoch 1: 0.599143385887146
# 1
# Train loss for epoch 2: 0.5185069441795349
# Val loss for epoch 2: 0.5533237457275391
# 2
# Train loss for epoch 3: 0.5189332365989685
# Val loss for epoch 3: 0.5713789463043213
# Train loss for epoch 4: 0.5191208124160767
# Val loss for epoch 4: 0.5534089803695679
# Train loss for epoch 5: 0.5172564387321472
# Val loss for epoch 5: 0.5609285831451416
# Train loss for epoch 6: 0.5166244506835938
# Val loss for epoch 6: 0.5145424008369446
# 6
# Train loss for epoch 7: 0.5169968605041504
# Val loss for epoch 7: 0.5158612132072449
# Train loss for epoch 8: 0.5198423862457275
# Val loss for epoch 8: 0.5343881249427795
# Train loss for epoch 9: 0.518610954284668
# Val loss for epoch 9: 0.5187738537788391
# Train loss for epoch 10: 0.5201048254966736
# Val loss for epoch 10: 0.5359609723091125
# Train loss for epoch 11: 0.5168486833572388
# Val loss for epoch 11: 0.5506997108459473
# Train loss for epoch 12: 0.5174359083175659
# Val loss for epoch 12: 0.5380701422691345
# Train loss for epoch 13: 0.5180127024650574
# Val loss for epoch 13: 0.5535598993301392
# Train loss for epoch 14: 0.5189056992530823
# Val loss for epoch 14: 0.5539572238922119
# Train loss for epoch 15: 0.5197487473487854
# Val loss for epoch 15: 0.5410504341125488
# Train loss for epoch 16: 0.5169944763183594
# Val loss for epoch 16: 0.5920229554176331
# Train loss for epoch 17: 0.5175062417984009
# Val loss for epoch 17: 0.5327460169792175
# Train loss for epoch 18: 0.5200621485710144
# Val loss for epoch 18: 0.5732588768005371
# Train loss for epoch 19: 0.5186213850975037
# Val loss for epoch 19: 0.5787131786346436
# Train loss for epoch 20: 0.5195239782333374
# Val loss for epoch 20: 0.54120934009552
# Train loss for epoch 21: 0.5184269547462463
# Val loss for epoch 21: 0.5661494135856628
# Train loss for epoch 22: 0.516508936882019
# Val loss for epoch 22: 0.5268204808235168
# Train loss for epoch 23: 0.5158305168151855
# Val loss for epoch 23: 0.5039585828781128
# 23
# Train loss for epoch 24: 0.5175143480300903
# Val loss for epoch 24: 0.5653547644615173
# Train loss for epoch 25: 0.5174909234046936
# Val loss for epoch 25: 0.5056016445159912
# Train loss for epoch 26: 0.5172810554504395
# Val loss for epoch 26: 0.5614798069000244
# Train loss for epoch 27: 0.5196675658226013
# Val loss for epoch 27: 0.49915990233421326
# 27
# Train loss for epoch 28: 0.5191391706466675
# Val loss for epoch 28: 0.5539485216140747
# Train loss for epoch 29: 0.5198783874511719
# Val loss for epoch 29: 0.4860941767692566
# 29
# Train loss for epoch 30: 0.5184901356697083
# Val loss for epoch 30: 0.564199686050415
# Train loss for epoch 31: 0.5181446075439453
# Val loss for epoch 31: 0.5816454887390137
# Train loss for epoch 32: 0.5180906057357788
# Val loss for epoch 32: 0.5146211981773376
# Train loss for epoch 33: 0.5167375206947327
# Val loss for epoch 33: 0.52984619140625
# Train loss for epoch 34: 0.5182183980941772
# Val loss for epoch 34: 0.5223173499107361
# Train loss for epoch 35: 0.5171069502830505
# Val loss for epoch 35: 0.516926109790802
# Train loss for epoch 36: 0.5171898603439331
# Val loss for epoch 36: 0.5578439831733704
# Train loss for epoch 37: 0.5175014138221741
# Val loss for epoch 37: 0.5818798542022705
# Train loss for epoch 38: 0.5162699222564697
# Val loss for epoch 38: 0.5529046654701233
# Train loss for epoch 39: 0.5181282758712769
# Val loss for epoch 39: 0.5030083656311035
# Train loss for epoch 40: 0.517669677734375
# Val loss for epoch 40: 0.5227518081665039
# Train loss for epoch 41: 0.5195574164390564
# Val loss for epoch 41: 0.5597096085548401
# Train loss for epoch 42: 0.5174499750137329
# Val loss for epoch 42: 0.5269723534584045
# Train loss for epoch 43: 0.517525315284729
# Val loss for epoch 43: 0.5178154110908508
# Train loss for epoch 44: 0.5175375938415527
# Val loss for epoch 44: 0.5272921919822693
# Train loss for epoch 45: 0.5182912945747375
# Val loss for epoch 45: 0.5463700294494629
# Train loss for epoch 46: 0.5194844603538513
# Val loss for epoch 46: 0.5530720949172974
# Train loss for epoch 47: 0.5184995532035828
# Val loss for epoch 47: 0.5472568273544312
# Train loss for epoch 48: 0.5197103023529053
# Val loss for epoch 48: 0.5411023497581482
# Train loss for epoch 49: 0.5185500979423523
# Val loss for epoch 49: 0.4907313883304596
# Train loss for epoch 50: 0.5160821080207825
# Val loss for epoch 50: 0.5750514268875122

# %%
plot_loss_acc(training_losses, val_losses, training_acc, validation_acc, model_type)

# %%
best_epoch = 29

# %%
model = GLM(input_dim=100*10).to(device)
path = '/mnt/pesaranlab/People/Capstone_students/Yue/model/model_Goose_1st_1_upsample'
model.load_state_dict(torch.load('{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, best_epoch)))
weights = model.linear.weight.view(100, 10)
weights_sub = weights.detach().cpu()
plt.axis('off')
plt.imshow(weights_sub)
plt.title(str(CH))
# plt.clim(-0.03, 0.03)
plt.show()

# %%
test_loss, test_acc, test_preds, test_preds_probs, test_labels, cases_wrong_2 = evaluate(model, optimizer, test_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=True, device=device)
print('test loss:{} accuracy:{}'.format(test_loss, test_acc))
# Out:
# test loss:0.6118581891059875 accuracy:0.7246153846153847

# %%
np.mean(np.concatenate(test_labels))
# Out:
# 0.7407692

# %%
path_wrong = '/mnt/pesaranlab/People/Capstone_students/Yue/wrong_pred'
pickle.dump(cases_wrong_2, open('{}/{}_CH{}_LOSS{}_REG{}{}.pt'.format(path_wrong, model_type, CH, loss_type, reg_type, alpha), 'wb'))

# %%
predictions_test = np.concatenate(test_preds)
labels_test = np.concatenate(test_labels)

df_test = pd.DataFrame({'predictions': predictions_test, 'labels': labels_test})

cm_test = confusion_matrix(labels_test, predictions_test)
ax = plt.axes()
sn.heatmap(cm_test, annot = True, fmt = "d", ax = ax, center=2000)
ax.set_title('Test Confusion Matrix')
ax.set_xlabel('Predicted Label')
ax.set_ylabel('True Label')
plt.show()

# %%
idx = 0
print('date:{}, rec:{}, time:{}, label:{}'.format(cases_wrong_2[0][0], cases_wrong_2[0][1], cases_wrong_2[0][1], cases_wrong_2[0][3]))
print('Original data 62 CH')
weights_sub = cases_wrong_2[0][-1][0]
plt.axis('off')
plt.imshow(weights_sub)
# plt.clim(-0.03, 0.03)
plt.show()
# Out:
# date:180331, rec:004, time:004, label:1.0
# Original data 62 CH

# %% [markdown]
# ### SVM without regularization

# %%
device = torch.device('cuda')

tol = 0.01
learning_rate = 0.001
num_epochs = 51
alpha = 0 
model_type = 'SVM'
loss_type = 'hinge'
reg_type = 'none' # expect to be bad, since predictions could be arbitrarily far from boundaries

model = GLM(input_dim=100*10).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)

# %%
epochs, training_losses, training_acc, val_losses, validation_acc = [], [], [], [], []

for epoch in range(num_epochs):
    train_loss, train_acc = train(model, optimizer, train_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
    print('Train loss for epoch {}: {}'.format(epoch, train_loss))
    val_loss, val_acc = evaluate(model, optimizer, val_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
    print('Val loss for epoch {}: {}'.format(epoch, val_loss))
    if val_losses:
        if val_loss < min(val_losses):
            best_epoch = epoch
            print(epoch)
            path = '/mnt/pesaranlab/People/Capstone_students/Yue/model/model_Goose_1st_1_upsample'
            torch.save(model.state_dict(), '{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, epoch))
    epochs.append(epoch)
    training_losses.append(train_loss)
    training_acc.append(train_acc)
    val_losses.append(val_loss)
    validation_acc.append(val_acc)
    
    if train_loss < tol:
        break
# Out:
# Train loss for epoch 0: 0.5633243322372437
# Val loss for epoch 0: 0.6515001654624939
# Train loss for epoch 1: 0.5354222655296326
# Val loss for epoch 1: 0.6230804324150085
# 1
# Train loss for epoch 2: 0.5250371098518372
# Val loss for epoch 2: 0.5986531376838684
# 2
# Train loss for epoch 3: 0.5187399387359619
# Val loss for epoch 3: 0.6033577919006348
# Train loss for epoch 4: 0.516137421131134
# Val loss for epoch 4: 0.6111773252487183
# Train loss for epoch 5: 0.5122883915901184
# Val loss for epoch 5: 0.5754786133766174
# 5
# Train loss for epoch 6: 0.5103127360343933
# Val loss for epoch 6: 0.5845819711685181
# Train loss for epoch 7: 0.5089962482452393
# Val loss for epoch 7: 0.6389201879501343
# Train loss for epoch 8: 0.5068846344947815
# Val loss for epoch 8: 0.609408438205719
# Train loss for epoch 9: 0.5067763924598694
# Val loss for epoch 9: 0.5766943097114563
# Train loss for epoch 10: 0.5029414892196655
# Val loss for epoch 10: 0.6333111524581909
# Train loss for epoch 11: 0.5027903914451599
# Val loss for epoch 11: 0.6283813118934631
# Train loss for epoch 12: 0.49862492084503174
# Val loss for epoch 12: 0.6215556263923645
# Train loss for epoch 13: 0.49789801239967346
# Val loss for epoch 13: 0.600615918636322
# Train loss for epoch 14: 0.496764600276947
# Val loss for epoch 14: 0.6210782527923584
# Train loss for epoch 15: 0.49772825837135315
# Val loss for epoch 15: 0.5827947854995728
# Train loss for epoch 16: 0.4956148862838745
# Val loss for epoch 16: 0.6167567372322083
# Train loss for epoch 17: 0.4980180263519287
# Val loss for epoch 17: 0.6262437105178833
# Train loss for epoch 18: 0.49394023418426514
# Val loss for epoch 18: 0.5981747508049011
# Train loss for epoch 19: 0.49473047256469727
# Val loss for epoch 19: 0.5992713570594788
# Train loss for epoch 20: 0.49407699704170227
# Val loss for epoch 20: 0.5866824984550476
# Train loss for epoch 21: 0.49083608388900757
# Val loss for epoch 21: 0.604365348815918
# Train loss for epoch 22: 0.4902659058570862
# Val loss for epoch 22: 0.6356371641159058
# Train loss for epoch 23: 0.49526262283325195
# Val loss for epoch 23: 0.5784186720848083
# Train loss for epoch 24: 0.49167993664741516
# Val loss for epoch 24: 0.5737777948379517
# 24
# Train loss for epoch 25: 0.49390432238578796
# Val loss for epoch 25: 0.5592086911201477
# 25
# Train loss for epoch 26: 0.49039193987846375
# Val loss for epoch 26: 0.5790180563926697
# Train loss for epoch 27: 0.4883337616920471
# Val loss for epoch 27: 0.6263961791992188
# Train loss for epoch 28: 0.4872538447380066
# Val loss for epoch 28: 0.6018573641777039
# Train loss for epoch 29: 0.48779675364494324
# Val loss for epoch 29: 0.6042619943618774
# Train loss for epoch 30: 0.4872977137565613
# Val loss for epoch 30: 0.6057131886482239
# Train loss for epoch 31: 0.4849295914173126
# Val loss for epoch 31: 0.6207031011581421
# Train loss for epoch 32: 0.48595550656318665
# Val loss for epoch 32: 0.6125434041023254
# Train loss for epoch 33: 0.4848772883415222
# Val loss for epoch 33: 0.6012614965438843
# Train loss for epoch 34: 0.48453816771507263
# Val loss for epoch 34: 0.5398704409599304
# 34
# Train loss for epoch 35: 0.48777589201927185
# Val loss for epoch 35: 0.6145412921905518
# Train loss for epoch 36: 0.4846753478050232
# Val loss for epoch 36: 0.5779409408569336
# Train loss for epoch 37: 0.48542138934135437
# Val loss for epoch 37: 0.5821791887283325
# Train loss for epoch 38: 0.4848628342151642
# Val loss for epoch 38: 0.5434736609458923
# Train loss for epoch 39: 0.4863278865814209
# Val loss for epoch 39: 0.6419786214828491
# Train loss for epoch 40: 0.48613476753234863
# Val loss for epoch 40: 0.5576764345169067
# Train loss for epoch 41: 0.48012325167655945
# Val loss for epoch 41: 0.6098731160163879
# Train loss for epoch 42: 0.4816954433917999
# Val loss for epoch 42: 0.6447066068649292
# Train loss for epoch 43: 0.4847228527069092
# Val loss for epoch 43: 0.569800078868866
# Train loss for epoch 44: 0.48325294256210327
# Val loss for epoch 44: 0.5656386017799377
# Train loss for epoch 45: 0.4824420213699341
# Val loss for epoch 45: 0.6288378834724426
# Train loss for epoch 46: 0.4831197261810303
# Val loss for epoch 46: 0.553519070148468
# Train loss for epoch 47: 0.48196667432785034
# Val loss for epoch 47: 0.5693246722221375
# Train loss for epoch 48: 0.4798113703727722
# Val loss for epoch 48: 0.5585370063781738
# Train loss for epoch 49: 0.480121910572052
# Val loss for epoch 49: 0.548427939414978
# Train loss for epoch 50: 0.4816622734069824
# Val loss for epoch 50: 0.5809991359710693

# %%
plot_loss_acc(training_losses, val_losses, training_acc, validation_acc, model_type)

# %%
best_epoch = 34

# %%
model = GLM(input_dim=100*10).to(device)
path = '/mnt/pesaranlab/People/Capstone_students/Yue/model/model_Goose_1st_1_upsample'
model.load_state_dict(torch.load('{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, best_epoch)))
weights = model.linear.weight.view(100, 10)
weights_sub = weights.detach().cpu()
plt.axis('off')
plt.imshow(weights_sub)
plt.title(str(CH))
# plt.clim(-0.03, 0.03)
plt.show()

# %%
test_loss, test_acc, test_preds, test_preds_probs, test_labels, cases_wrong_3 = evaluate(model, optimizer, test_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=True, device=device)
print('test loss:{} accuracy:{}'.format(test_loss, test_acc))
# Out:
# test loss:0.7474792003631592 accuracy:0.6978461538461539

# %%
predictions_test = np.concatenate(test_preds)
labels_test = np.concatenate(test_labels)

df_test = pd.DataFrame({'predictions': predictions_test, 'labels': labels_test})

cm_test = confusion_matrix(labels_test, predictions_test)
ax = plt.axes()
sn.heatmap(cm_test, annot = True, fmt = "d", ax = ax, center=2000)
ax.set_title('Test Confusion Matrix')
ax.set_xlabel('Predicted Label')
ax.set_ylabel('True Label')
plt.show()

# %%
idx = 0
print('date:{}, rec:{}, time:{}, label:{}'.format(cases_wrong_3[0][0], cases_wrong_3[0][1], cases_wrong_3[0][1], cases_wrong_3[0][3]))
print('Original data 62 CH')
weights_sub = cases_wrong_3[0][-1][0]
plt.axis('off')
plt.imshow(weights_sub)
# plt.clim(-0.03, 0.03)
plt.show()
# Out:
# date:180331, rec:004, time:004, label:1.0
# Original data 62 CH

# %% [markdown]
# ### SVM with L2 regularization

# %% [markdown]
# ### SVM with finite difference regularization
