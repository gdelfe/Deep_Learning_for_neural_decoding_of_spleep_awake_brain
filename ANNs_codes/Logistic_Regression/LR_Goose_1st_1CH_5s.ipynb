# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
from torch.utils.data import Dataset, DataLoader
from torch import nn
from torch.nn.functional import relu
from scipy.io import loadmat
import os
from os import listdir
import pandas as pd
from skimage import io
from PIL import Image
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pickle
from random import sample

from utils import *

# %%
#selected subset of dates. 
val_dates = ['180327','180329']
test_dates = ['180330','180331']
bad_dates = ['180326', '180328', '171019', '180715', '180716', '180717']
load_path = '/home/bijanadmin/Desktop/Goose_data/data_Goose_1st_5s_2/'
model_saving_path = '/home/bijanadmin/Desktop/Goose_data/data_Goose_1st_5s_2/LR_models'
CH = 23

train_files, val_files, test_files = create_files(load_path, val_dates, test_dates, bad_dates)
train_loader, val_loader, test_loader = create_dataloaders(train_files, val_files, test_files,load_path, batch_size=256, CH = CH)

# %%
# Balance Validation Dataset
sleep_files = []
move_files = []
for t in range(len(val_files)):
    if 'sleep' in val_files[t][0]:
        sleep_files.append(val_files[t])
    if 'move' in val_files[t][0]:
        move_files.append(val_files[t])

sleep_sample = sample(sleep_files, len(move_files))
val_2_files = sleep_sample+move_files
train_loader, val_loader, test_loader = create_dataloaders(train_files, val_2_files, test_files,load_path, batch_size=256,CH = CH)
print(len(train_loader), len(val_loader), len(test_loader))
## Check balance
# count_sleep = 0
# count_move = 0
# for t in range(len(val_2_files)):
#     if 'sleep' in val_2_files[t][0]:
#         count_sleep+=1
#     if 'move' in val_2_files[t][0]:
#         count_move +=1 
# print(count_sleep, count_move)
# Out:
# 161 23 52

# %%
for batch_idx, (data, label, date, rec, time) in enumerate(train_loader): # check shapes
    print(data.shape)
    print(label.shape)
    print(len(date))
    print(len(rec))
    print(len(time))
    break
# Out:
# torch.Size([256, 1, 100, 5])
# torch.Size([256, 1])
# 256
# 256
# 256

# %%
# movement labelled 0; non-movement labelled 1
for batch_idx, (data, label, date, rec, time) in enumerate(train_loader):
    for i in range(128):
        print('date:{}, rec:{}, time:{}'.format(date[i], rec[i], time[i]))
        data_sub = data[i][0]
        plt.imshow(data_sub)
        plt.clim(-1.5, 1.5)
        plt.colorbar()
        plt.title(label[i][0].numpy())
        plt.show()
    break
# Out:
# date:180322, rec:007, time:3486.0
# date:180324, rec:003, time:2969.0
# date:180325, rec:005, time:1251.0
# date:180325, rec:007, time:5105.0
# date:180401, rec:001, time:882.0
# date:180325, rec:007, time:5115.0
# date:180325, rec:001, time:1237.0
# date:180325, rec:009, time:4951.0
# date:180324, rec:008, time:3605.0
# date:180401, rec:003, time:601.0
# date:180401, rec:001, time:1817.0
# date:180323, rec:001, time:6585.0
# date:180325, rec:009, time:4886.0
# date:180401, rec:001, time:1712.0
# date:180323, rec:007, time:5453.0
# date:180323, rec:002, time:4166.0
# date:180323, rec:007, time:6123.0
# date:180325, rec:004, time:4137.0
# date:180324, rec:008, time:1923.0
# date:180325, rec:009, time:197.0
# date:180325, rec:001, time:3043.0
# date:180322, rec:001, time:102.0
# date:180324, rec:004, time:4341.0
# date:180325, rec:005, time:4228.0
# date:180322, rec:007, time:4487.0
# date:180325, rec:006, time:1181.0
# date:180322, rec:003, time:4546.0
# date:180325, rec:006, time:4467.0
# date:180323, rec:006, time:4426.0
# date:180323, rec:003, time:5523.0
# date:180324, rec:003, time:2001.0
# date:180325, rec:007, time:4670.0
# date:180323, rec:002, time:5082.0
# date:180401, rec:001, time:3958.0
# date:180325, rec:004, time:5589.0
# date:180323, rec:007, time:6568.0
# date:180325, rec:007, time:2608.0
# date:180325, rec:007, time:4070.0
# date:180324, rec:003, time:392.0
# date:180325, rec:003, time:2442.0
# date:180322, rec:007, time:3947.0
# date:180324, rec:009, time:177.0
# date:180324, rec:008, time:4386.0
# date:180325, rec:005, time:1621.0
# date:180322, rec:003, time:4576.0
# date:180325, rec:007, time:4805.0
# date:180325, rec:003, time:4500.0
# date:180324, rec:004, time:5341.0
# date:180322, rec:007, time:3897.0
# date:180322, rec:002, time:4891.0
# date:180324, rec:009, time:1004.0
# date:180323, rec:007, time:2917.0
# date:180325, rec:005, time:2568.0
# date:180322, rec:003, time:5968.0
# date:180325, rec:007, time:3183.0
# date:180324, rec:001, time:757.0
# date:180325, rec:001, time:627.0
# date:180323, rec:004, time:6488.0
# date:180325, rec:009, time:1457.0
# date:180322, rec:003, time:1080.0
# date:180324, rec:003, time:3664.0
# date:180325, rec:007, time:3198.0
# date:180323, rec:001, time:7070.0
# date:180401, rec:001, time:1062.0
# date:180322, rec:004, time:5091.0
# date:180323, rec:002, time:1359.0
# date:180322, rec:003, time:3255.0
# date:180324, rec:008, time:2855.0
# date:180325, rec:003, time:6659.0
# date:180322, rec:005, time:2718.0
# date:180323, rec:004, time:3765.0
# date:180401, rec:002, time:6436.0
# date:180323, rec:002, time:1779.0
# date:180324, rec:003, time:3234.0
# date:180325, rec:009, time:2342.0
# date:180325, rec:009, time:1332.0
# date:180325, rec:004, time:6787.0
# date:180323, rec:003, time:327.0
# date:180323, rec:007, time:5488.0
# date:180324, rec:008, time:1673.0
# date:180401, rec:001, time:637.0
# date:180325, rec:007, time:917.0
# date:180325, rec:001, time:732.0
# date:180325, rec:001, time:1882.0
# date:180322, rec:004, time:6818.0
# date:180323, rec:004, time:6133.0
# date:180325, rec:003, time:2212.0
# date:180323, rec:003, time:3173.0
# date:180323, rec:005, time:3593.0
# date:180325, rec:009, time:6492.0
# date:180401, rec:001, time:5474.0
# date:180324, rec:001, time:672.0
# date:180325, rec:004, time:5584.0
# date:180322, rec:001, time:102.0
# date:180323, rec:003, time:5763.0
# date:180324, rec:008, time:2745.0
# date:180325, rec:007, time:6685.0
# date:180325, rec:009, time:2472.0
# date:180325, rec:001, time:1897.0
# date:180324, rec:004, time:2006.0
# date:180325, rec:009, time:6086.0
# date:180325, rec:001, time:397.0
# date:180401, rec:001, time:3400.0
# date:180325, rec:007, time:352.0
# date:180325, rec:007, time:4620.0
# date:180325, rec:009, time:5101.0
# date:180401, rec:001, time:6455.0
# date:180324, rec:005, time:57.0
# date:180401, rec:001, time:1527.0
# date:180323, rec:003, time:4863.0
# date:180325, rec:002, time:1027.0
# date:180322, rec:001, time:92.0
# date:180322, rec:007, time:3286.0
# date:180322, rec:002, time:7067.0
# date:180323, rec:003, time:5298.0
# date:180325, rec:009, time:4561.0
# date:180324, rec:008, time:3790.0
# date:180324, rec:006, time:459.0
# date:180325, rec:007, time:4700.0
# date:180324, rec:008, time:1128.0
# date:180325, rec:007, time:6780.0
# date:180324, rec:008, time:3750.0
# date:180324, rec:009, time:1154.0
# date:180325, rec:002, time:717.0
# date:180323, rec:002, time:3956.0
# date:180322, rec:003, time:5647.0
# date:180325, rec:005, time:6640.0
# date:180401, rec:002, time:2288.0

# %% [markdown]
# ### Logistic regression with no regularization

# %%
device = torch.device('cuda')

tol = 0.01
learning_rate = 0.001
num_epochs = 51
alphas = [0]
model_type = 'LR'
loss_type = 'bce'
reg_type = 'none'
timewindow = 5

# %%
for alpha in alphas:
    model = GLM(input_dim=100*timewindow).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)
    epochs, training_losses, training_acc, val_losses, validation_acc = [], [], [], [], []

    for epoch in range(num_epochs):
        train_loss, train_acc = train(model, optimizer, train_loader, timewindow = timewindow, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
        print('Train loss for epoch {}: {}'.format(epoch, train_loss))
        val_loss, val_acc = evaluate(model, optimizer, val_loader, alpha=alpha, timewindow = timewindow, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
        print('Val loss for epoch {}: {}'.format(epoch, val_loss))
        if val_losses:
            if val_loss < min(val_losses):
                best_epoch = epoch
                print(epoch)
                path = model_saving_path
                torch.save(model.state_dict(), '{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}_valbalanced.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, epoch))
        epochs.append(epoch)
        training_losses.append(train_loss)
        training_acc.append(train_acc)
        val_losses.append(val_loss)
        validation_acc.append(val_acc)

        if train_loss < tol:
            break
    plot_loss_acc(training_losses, val_losses, training_acc, validation_acc, model_type)
# Out:
# Train loss for epoch 0: 0.5451551079750061
# Val loss for epoch 0: 0.5001120567321777
# Train loss for epoch 1: 0.5185078382492065
# Val loss for epoch 1: 0.49885037541389465
# 1
# Train loss for epoch 2: 0.5102680325508118
# Val loss for epoch 2: 0.49172350764274597
# 2
# Train loss for epoch 3: 0.5054313540458679
# Val loss for epoch 3: 0.49388831853866577
# Train loss for epoch 4: 0.5021870136260986
# Val loss for epoch 4: 0.49294421076774597
# Train loss for epoch 5: 0.4997963011264801
# Val loss for epoch 5: 0.4951026141643524
# Train loss for epoch 6: 0.49764445424079895
# Val loss for epoch 6: 0.49791043996810913
# Train loss for epoch 7: 0.4964556097984314
# Val loss for epoch 7: 0.490716814994812
# 7
# Train loss for epoch 8: 0.49514397978782654
# Val loss for epoch 8: 0.4894837439060211
# 8
# Train loss for epoch 9: 0.49459341168403625
# Val loss for epoch 9: 0.4913588762283325
# Train loss for epoch 10: 0.4942891299724579
# Val loss for epoch 10: 0.500741720199585
# Train loss for epoch 11: 0.4939888119697571
# Val loss for epoch 11: 0.505476713180542
# Train loss for epoch 12: 0.49293309450149536
# Val loss for epoch 12: 0.49164244532585144
# Train loss for epoch 13: 0.49275338649749756
# Val loss for epoch 13: 0.4958263635635376
# Train loss for epoch 14: 0.4924137592315674
# Val loss for epoch 14: 0.49473050236701965
# Train loss for epoch 15: 0.4921880066394806
# Val loss for epoch 15: 0.5021753311157227
# Train loss for epoch 16: 0.49185600876808167
# Val loss for epoch 16: 0.5040668249130249
# Train loss for epoch 17: 0.4916727542877197
# Val loss for epoch 17: 0.5080898404121399
# Train loss for epoch 18: 0.4916641414165497
# Val loss for epoch 18: 0.4961174428462982
# Train loss for epoch 19: 0.49218255281448364
# Val loss for epoch 19: 0.4969228208065033
# Train loss for epoch 20: 0.49072059988975525
# Val loss for epoch 20: 0.5042701959609985
# Train loss for epoch 21: 0.49097949266433716
# Val loss for epoch 21: 0.4990982413291931
# Train loss for epoch 22: 0.4904133677482605
# Val loss for epoch 22: 0.5053935050964355
# Train loss for epoch 23: 0.4903486371040344
# Val loss for epoch 23: 0.4987245202064514
# Train loss for epoch 24: 0.49073272943496704
# Val loss for epoch 24: 0.49656563997268677
# Train loss for epoch 25: 0.49008306860923767
# Val loss for epoch 25: 0.5014653205871582
# Train loss for epoch 26: 0.4895234704017639
# Val loss for epoch 26: 0.5049281120300293
# Train loss for epoch 27: 0.4896027743816376
# Val loss for epoch 27: 0.5032971501350403
# Train loss for epoch 28: 0.48897692561149597
# Val loss for epoch 28: 0.4990115463733673
# Train loss for epoch 29: 0.48933055996894836
# Val loss for epoch 29: 0.5036805868148804
# Train loss for epoch 30: 0.4890694320201874
# Val loss for epoch 30: 0.5029030442237854
# Train loss for epoch 31: 0.48955973982810974
# Val loss for epoch 31: 0.5027955770492554
# Train loss for epoch 32: 0.48893681168556213
# Val loss for epoch 32: 0.5035746693611145
# Train loss for epoch 33: 0.488678902387619
# Val loss for epoch 33: 0.5008664727210999
# Train loss for epoch 34: 0.4883248805999756
# Val loss for epoch 34: 0.5027468800544739
# Train loss for epoch 35: 0.4891403317451477
# Val loss for epoch 35: 0.5032071471214294
# Train loss for epoch 36: 0.48901358246803284
# Val loss for epoch 36: 0.5165671110153198
# Train loss for epoch 37: 0.48901858925819397
# Val loss for epoch 37: 0.5006558895111084
# Train loss for epoch 38: 0.4885109066963196
# Val loss for epoch 38: 0.5056505799293518
# Train loss for epoch 39: 0.4884208142757416
# Val loss for epoch 39: 0.5025671124458313
# Train loss for epoch 40: 0.487824022769928
# Val loss for epoch 40: 0.4976656138896942
# Train loss for epoch 41: 0.4879971742630005
# Val loss for epoch 41: 0.4958823323249817
# Train loss for epoch 42: 0.48816224932670593
# Val loss for epoch 42: 0.4996967315673828
# Train loss for epoch 43: 0.4880008399486542
# Val loss for epoch 43: 0.501024067401886
# Train loss for epoch 44: 0.48807036876678467
# Val loss for epoch 44: 0.5116273164749146
# Train loss for epoch 45: 0.48771581053733826
# Val loss for epoch 45: 0.5002089738845825
# Train loss for epoch 46: 0.4876137673854828
# Val loss for epoch 46: 0.4980691075325012
# Train loss for epoch 47: 0.48793378472328186
# Val loss for epoch 47: 0.5028608441352844
# Train loss for epoch 48: 0.4873456656932831
# Val loss for epoch 48: 0.5047168135643005
# Train loss for epoch 49: 0.4879147410392761
# Val loss for epoch 49: 0.5028961896896362
# Train loss for epoch 50: 0.4876059591770172
# Val loss for epoch 50: 0.5041115880012512

# %%
model_LR = os.listdir(model_saving_path)
results = []
alphas = [0]
for alpha in alphas:
    best_result = 0
    reg_alpha = 'REG'+reg_type+str(alpha)+'_'
    for i, s in enumerate(model_LR):
        if 'LR_CH23_' in s and reg_alpha in s and '_valbalanced' in s:
            model_name = model_LR[i].split('_')
            epoch_name = [ind for ind,item in enumerate(np.array(model_name)) if "EPOCH" in item]
            res = [int(i) for i in model_name[epoch_name[0]] if i.isdigit()]
            if len(res) > 1:
                epoch_result = res[0]*10+res[1]
            else:
                epoch_result = res[0]
            if epoch_result>best_result and epoch_result != 50:
                best_result = epoch_result

    results.append([alpha,best_result])

    
results = pd.DataFrame(np.array(results), columns=['alpha', 'epoch'])
best_results = results.groupby('alpha').max('epoch')
print(best_results)
# Out:
#        epoch
# alpha
# 0          8

# %%
for i,(index,row) in enumerate(best_results.iterrows()):
    
    path = model_saving_path
    best_epoch = int(row)
    alpha = index
    
    
    # load best model
    model = GLM(input_dim=100*timewindow).to(device)
    path = model_saving_path
    optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)
    model.load_state_dict(torch.load('{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}_valbalanced.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, best_epoch)))
    
    print('{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}_valbalanced.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, best_epoch))

    ## Show one feature
    weights = model.linear.weight.view(100, timewindow)
    weights_sub = weights.detach().cpu()
    plt.axis('off')
    plt.imshow(weights_sub)
    plt.title(str(CH))
    # plt.clim(-0.03, 0.03)
    plt.show()
    
    ## Calculate accuracy and validation loss
    val_loss, val_acc, val_preds, val_preds_probs, val_labels,_,_,_, cases_wrong_1 = evaluate(model, optimizer, val_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=True, device=device)
    print('validation loss:{} accuracy:{}'.format(val_loss, val_acc))
    print(np.mean(np.concatenate(val_labels)))
    
    
    ## Wrong Classifications
    path_wrong = '/mnt/pesaranlab/People/Capstone_students/Yue/wrong_pred'
    pickle.dump(cases_wrong_1, open('{}/{}_CH{}_LOSS{}_REG{}{}.pt'.format(path_wrong, model_type, CH, loss_type, reg_type, alpha), 'wb'))
    idx = 0
    print('date:{}, rec:{}, time:{}, label:{}'.format(cases_wrong_1[0][0], cases_wrong_1[0][1], cases_wrong_1[0][2], cases_wrong_1[0][3]))
    print('Original data 62 CH')
    weights_sub = cases_wrong_1[0][-1][0]
    plt.axis('off')
    plt.imshow(weights_sub)
    # plt.clim(-0.03, 0.03)
    plt.show()
    
    ## Confusion matrix
    predictions_val = np.concatenate(val_preds)
    labels_val = np.concatenate(val_labels)

    df_val = pd.DataFrame({'predictions': predictions_val, 'labels': labels_val})

    cm_val = confusion_matrix(labels_val, predictions_val)
    ax = plt.axes()
    group_names = ['True Neg','False Pos','False Neg','True Pos']
    group_counts = ["{0:0.0f}".format(value) for value in
                    cm_val.flatten()]

    TNR = int(group_counts[0]) / (int(group_counts[0])+int(group_counts[1]))
    FPR = 1 - TNR
    TPR = int(group_counts[3]) / (int(group_counts[3])+int(group_counts[2]))
    FNR = 1-TPR
    group_percentages =[TNR, FPR, FNR, TPR]

    group_percentages = ["{0:.2%}".format(value) for value in
                         group_percentages]
    labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
              zip(group_names,group_counts,group_percentages)]
    labels = np.asarray(labels).reshape(2,2)
    sn.heatmap(cm_val, annot=labels, fmt='', center = 2000)
    ax.set_title('Validation Confusion Matrix')
    ax.set_xlabel('Predicted Label')
    ax.set_ylabel('True Label')
    plt.show()
# Out:
# /home/bijanadmin/Desktop/Goose_data/data_Goose_1st_5s_2/LR_models/LR_CH23_LOSSbce_REGnone0_EPOCH8_valbalanced.pt
# validation loss:0.4799049496650696 accuracy:0.8172683923705722
# 0.5
# date:180329, rec:006, time:1801.0, label:1.0
# Original data 62 CH

# %% [markdown]
# ### Logistic regression with L2 regularization

# %%
device = torch.device('cuda')

tol = 0.01
learning_rate = 0.001
num_epochs = 51
alphas = [1,50,100]
model_type = 'LR'
loss_type = 'bce'
reg_type = 'l2'
timewindow = 5

# %%
for alpha in alphas:
    model = GLM(input_dim=100*timewindow).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)
    epochs, training_losses, training_acc, val_losses, validation_acc = [], [], [], [], []

    for epoch in range(num_epochs):
        train_loss, train_acc = train(model, optimizer, train_loader, timewindow = timewindow, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
        print('Train loss for epoch {}: {}'.format(epoch, train_loss))
        val_loss, val_acc = evaluate(model, optimizer, val_loader, alpha=alpha, timewindow = timewindow, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
        print('Val loss for epoch {}: {}'.format(epoch, val_loss))
        if val_losses:
            if val_loss < min(val_losses):
                best_epoch = epoch
                print(epoch)
                path = model_saving_path
                torch.save(model.state_dict(), '{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}_valbalanced.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, epoch))
        epochs.append(epoch)
        training_losses.append(train_loss)
        training_acc.append(train_acc)
        val_losses.append(val_loss)
        validation_acc.append(val_acc)

        if train_loss < tol:
            break
    plot_loss_acc(training_losses, val_losses, training_acc, validation_acc, model_type)
# Out:
# Train loss for epoch 0: 0.5482630133628845
# Val loss for epoch 0: 0.5046695470809937
# Train loss for epoch 1: 0.5206620693206787
# Val loss for epoch 1: 0.5079846382141113
# Train loss for epoch 2: 0.5134193897247314
# Val loss for epoch 2: 0.4968194365501404
# 2
# Train loss for epoch 3: 0.5092206597328186
# Val loss for epoch 3: 0.49933892488479614
# Train loss for epoch 4: 0.5049965381622314
# Val loss for epoch 4: 0.49627193808555603
# 4
# Train loss for epoch 5: 0.5029693245887756
# Val loss for epoch 5: 0.49270591139793396
# 5
# Train loss for epoch 6: 0.5022727251052856
# Val loss for epoch 6: 0.49206236004829407
# 6
# Train loss for epoch 7: 0.49975043535232544
# Val loss for epoch 7: 0.5034801959991455
# Train loss for epoch 8: 0.4992294907569885
# Val loss for epoch 8: 0.4936177134513855
# Train loss for epoch 9: 0.498761385679245
# Val loss for epoch 9: 0.49693533778190613
# Train loss for epoch 10: 0.49830275774002075
# Val loss for epoch 10: 0.504486620426178
# Train loss for epoch 11: 0.4988977313041687
# Val loss for epoch 11: 0.49753352999687195
# Train loss for epoch 12: 0.49786728620529175
# Val loss for epoch 12: 0.496039479970932
# Train loss for epoch 13: 0.49761563539505005
# Val loss for epoch 13: 0.49772605299949646
# Train loss for epoch 14: 0.49709421396255493
# Val loss for epoch 14: 0.4986554682254791
# Train loss for epoch 15: 0.497551828622818
# Val loss for epoch 15: 0.4999031722545624
# Train loss for epoch 16: 0.4976132810115814
# Val loss for epoch 16: 0.49753281474113464
# Train loss for epoch 17: 0.49669238924980164
# Val loss for epoch 17: 0.49753668904304504
# Train loss for epoch 18: 0.4973410964012146
# Val loss for epoch 18: 0.4981943368911743
# Train loss for epoch 19: 0.4965033531188965
# Val loss for epoch 19: 0.49947214126586914
# Train loss for epoch 20: 0.49637842178344727
# Val loss for epoch 20: 0.49979367852211
# Train loss for epoch 21: 0.49626851081848145
# Val loss for epoch 21: 0.4942655563354492
# Train loss for epoch 22: 0.4963514506816864
# Val loss for epoch 22: 0.5047248005867004
# Train loss for epoch 23: 0.4964247941970825
# Val loss for epoch 23: 0.5077886581420898
# Train loss for epoch 24: 0.49648284912109375
# Val loss for epoch 24: 0.5052549839019775
# Train loss for epoch 25: 0.4962266981601715
# Val loss for epoch 25: 0.5035440921783447
# Train loss for epoch 26: 0.4964200258255005
# Val loss for epoch 26: 0.49913036823272705
# Train loss for epoch 27: 0.496438205242157
# Val loss for epoch 27: 0.5054119825363159
# Train loss for epoch 28: 0.4970702826976776
# Val loss for epoch 28: 0.4996373653411865
# Train loss for epoch 29: 0.4962987005710602
# Val loss for epoch 29: 0.5023117065429688
# Train loss for epoch 30: 0.4966783821582794
# Val loss for epoch 30: 0.5008893609046936
# Train loss for epoch 31: 0.4962210953235626
# Val loss for epoch 31: 0.5059138536453247
# Train loss for epoch 32: 0.49561259150505066
# Val loss for epoch 32: 0.5259049534797668
# Train loss for epoch 33: 0.49743130803108215
# Val loss for epoch 33: 0.5024371147155762
# Train loss for epoch 34: 0.49636682868003845
# Val loss for epoch 34: 0.504351019859314
# Train loss for epoch 35: 0.49582651257514954
# Val loss for epoch 35: 0.5056074261665344
# Train loss for epoch 36: 0.49605682492256165
# Val loss for epoch 36: 0.504802405834198
# Train loss for epoch 37: 0.49576815962791443
# Val loss for epoch 37: 0.5008262395858765
# Train loss for epoch 38: 0.49635130167007446
# Val loss for epoch 38: 0.4990297853946686
# Train loss for epoch 39: 0.4958033859729767
# Val loss for epoch 39: 0.5082395076751709
# Train loss for epoch 40: 0.496015727519989
# Val loss for epoch 40: 0.5000980496406555
# Train loss for epoch 41: 0.4962359368801117
# Val loss for epoch 41: 0.5009297132492065
# Train loss for epoch 42: 0.4962771534919739
# Val loss for epoch 42: 0.504866898059845
# Train loss for epoch 43: 0.4958394467830658
# Val loss for epoch 43: 0.5100500583648682
# Train loss for epoch 44: 0.4955488443374634
# Val loss for epoch 44: 0.502871572971344
# Train loss for epoch 45: 0.49617981910705566
# Val loss for epoch 45: 0.503699004650116
# Train loss for epoch 46: 0.4953143000602722
# Val loss for epoch 46: 0.5100658535957336
# Train loss for epoch 47: 0.49678218364715576
# Val loss for epoch 47: 0.5071495175361633
# Train loss for epoch 48: 0.49568063020706177
# Val loss for epoch 48: 0.5024089813232422
# Train loss for epoch 49: 0.495829313993454
# Val loss for epoch 49: 0.5036812424659729
# Train loss for epoch 50: 0.4958014488220215
# Val loss for epoch 50: 0.5029693841934204
# Train loss for epoch 0: 0.638318657875061
# Val loss for epoch 0: 0.5557568669319153
# Train loss for epoch 1: 0.5894773602485657
# Val loss for epoch 1: 0.5538893342018127
# 1
# Train loss for epoch 2: 0.5838760137557983
# Val loss for epoch 2: 0.5586420297622681
# Train loss for epoch 3: 0.5818976163864136
# Val loss for epoch 3: 0.5489671230316162
# 3
# Train loss for epoch 4: 0.5800139904022217
# Val loss for epoch 4: 0.5508010983467102
# Train loss for epoch 5: 0.5788484811782837
# Val loss for epoch 5: 0.5505493879318237
# Train loss for epoch 6: 0.5784657597541809
# Val loss for epoch 6: 0.5580512881278992
# Train loss for epoch 7: 0.5786890983581543
# Val loss for epoch 7: 0.5497769713401794
# Train loss for epoch 8: 0.5785513520240784
# Val loss for epoch 8: 0.5527346730232239
# Train loss for epoch 9: 0.5797734260559082
# Val loss for epoch 9: 0.5494211912155151
# Train loss for epoch 10: 0.5782051682472229
# Val loss for epoch 10: 0.5611638426780701
# Train loss for epoch 11: 0.5790895223617554
# Val loss for epoch 11: 0.5551632642745972
# Train loss for epoch 12: 0.5785518884658813
# Val loss for epoch 12: 0.5547261834144592
# Train loss for epoch 13: 0.5785228610038757
# Val loss for epoch 13: 0.5510768890380859
# Train loss for epoch 14: 0.579376220703125
# Val loss for epoch 14: 0.5533086061477661
# Train loss for epoch 15: 0.5786744952201843
# Val loss for epoch 15: 0.5519566535949707
# Train loss for epoch 16: 0.5776960253715515
# Val loss for epoch 16: 0.5544230937957764
# Train loss for epoch 17: 0.5782527923583984
# Val loss for epoch 17: 0.5503440499305725
# Train loss for epoch 18: 0.578475296497345
# Val loss for epoch 18: 0.5555558800697327
# Train loss for epoch 19: 0.5783038139343262
# Val loss for epoch 19: 0.5489366054534912
# 19
# Train loss for epoch 20: 0.5778826475143433
# Val loss for epoch 20: 0.5539294481277466
# Train loss for epoch 21: 0.57862788438797
# Val loss for epoch 21: 0.5510880351066589
# Train loss for epoch 22: 0.578082799911499
# Val loss for epoch 22: 0.550532877445221
# Train loss for epoch 23: 0.5783926844596863
# Val loss for epoch 23: 0.5553349852561951
# Train loss for epoch 24: 0.5782527327537537
# Val loss for epoch 24: 0.5510435104370117
# Train loss for epoch 25: 0.5788496136665344
# Val loss for epoch 25: 0.5506542325019836
# Train loss for epoch 26: 0.578109085559845
# Val loss for epoch 26: 0.5534756779670715
# Train loss for epoch 27: 0.5783008933067322
# Val loss for epoch 27: 0.5556849241256714
# Train loss for epoch 28: 0.5786377787590027
# Val loss for epoch 28: 0.5534574389457703
# Train loss for epoch 29: 0.5779300332069397
# Val loss for epoch 29: 0.5499640703201294
# Train loss for epoch 30: 0.5783370733261108
# Val loss for epoch 30: 0.551762044429779
# Train loss for epoch 31: 0.5783945322036743
# Val loss for epoch 31: 0.5506784915924072
# Train loss for epoch 32: 0.578087329864502
# Val loss for epoch 32: 0.5530067086219788
# Train loss for epoch 33: 0.5785136818885803
# Val loss for epoch 33: 0.5520978569984436
# Train loss for epoch 34: 0.5780453681945801
# Val loss for epoch 34: 0.5530226230621338
# Train loss for epoch 35: 0.5784823894500732
# Val loss for epoch 35: 0.5480763912200928
# 35
# Train loss for epoch 36: 0.5782761573791504
# Val loss for epoch 36: 0.5596795082092285
# Train loss for epoch 37: 0.5793435573577881
# Val loss for epoch 37: 0.5542308688163757
# Train loss for epoch 38: 0.5786855816841125
# Val loss for epoch 38: 0.561721682548523
# Train loss for epoch 39: 0.5781907439231873
# Val loss for epoch 39: 0.5498931407928467
# Train loss for epoch 40: 0.5787692666053772
# Val loss for epoch 40: 0.5493238568305969
# Train loss for epoch 41: 0.5782743692398071
# Val loss for epoch 41: 0.5577257871627808
# Train loss for epoch 42: 0.5784465074539185
# Val loss for epoch 42: 0.5515223741531372
# Train loss for epoch 43: 0.5783745646476746
# Val loss for epoch 43: 0.5486706495285034
# Train loss for epoch 44: 0.5788769125938416
# Val loss for epoch 44: 0.5503420233726501
# Train loss for epoch 45: 0.5784769058227539
# Val loss for epoch 45: 0.5546374320983887
# Train loss for epoch 46: 0.5778442025184631
# Val loss for epoch 46: 0.5551925897598267
# Train loss for epoch 47: 0.5783334374427795
# Val loss for epoch 47: 0.5537682771682739
# Train loss for epoch 48: 0.5784471035003662
# Val loss for epoch 48: 0.5528489351272583
# Train loss for epoch 49: 0.5780937075614929
# Val loss for epoch 49: 0.5511518120765686
# Train loss for epoch 50: 0.5788686871528625
# Val loss for epoch 50: 0.554531991481781
# Train loss for epoch 0: 0.672538161277771
# Val loss for epoch 0: 0.5920963287353516
# Train loss for epoch 1: 0.6222304701805115
# Val loss for epoch 1: 0.5949996113777161
# Train loss for epoch 2: 0.6192807555198669
# Val loss for epoch 2: 0.5909090042114258
# 2
# Train loss for epoch 3: 0.6177476644515991
# Val loss for epoch 3: 0.590480387210846
# 3
# Train loss for epoch 4: 0.6179662346839905
# Val loss for epoch 4: 0.5916377902030945
# Train loss for epoch 5: 0.6179394125938416
# Val loss for epoch 5: 0.594789445400238
# Train loss for epoch 6: 0.6178857684135437
# Val loss for epoch 6: 0.5905293226242065
# Train loss for epoch 7: 0.6168380975723267
# Val loss for epoch 7: 0.5901867747306824
# 7
# Train loss for epoch 8: 0.6169061064720154
# Val loss for epoch 8: 0.595912516117096
# Train loss for epoch 9: 0.6175550818443298
# Val loss for epoch 9: 0.5967320799827576
# Train loss for epoch 10: 0.616608202457428
# Val loss for epoch 10: 0.5960974097251892
# Train loss for epoch 11: 0.6166254281997681
# Val loss for epoch 11: 0.5882903933525085
# 11
# Train loss for epoch 12: 0.6163475513458252
# Val loss for epoch 12: 0.5900648236274719
# Train loss for epoch 13: 0.6165555119514465
# Val loss for epoch 13: 0.6037063598632812
# Train loss for epoch 14: 0.6170397996902466
# Val loss for epoch 14: 0.5911814570426941
# Train loss for epoch 15: 0.616863489151001
# Val loss for epoch 15: 0.5892190933227539
# Train loss for epoch 16: 0.6172343492507935
# Val loss for epoch 16: 0.6019730567932129
# Train loss for epoch 17: 0.617041826248169
# Val loss for epoch 17: 0.5954578518867493
# Train loss for epoch 18: 0.6166759133338928
# Val loss for epoch 18: 0.5952416658401489
# Train loss for epoch 19: 0.6169912815093994
# Val loss for epoch 19: 0.589474618434906
# Train loss for epoch 20: 0.6169809103012085
# Val loss for epoch 20: 0.5885441899299622
# Train loss for epoch 21: 0.6169374585151672
# Val loss for epoch 21: 0.5944764018058777
# Train loss for epoch 22: 0.6168184280395508
# Val loss for epoch 22: 0.5919222831726074
# Train loss for epoch 23: 0.616702675819397
# Val loss for epoch 23: 0.5917453765869141
# Train loss for epoch 24: 0.6178259253501892
# Val loss for epoch 24: 0.5943098068237305
# Train loss for epoch 25: 0.6168416738510132
# Val loss for epoch 25: 0.5990122556686401
# Train loss for epoch 26: 0.6175187826156616
# Val loss for epoch 26: 0.5937372446060181
# Train loss for epoch 27: 0.6177356839179993
# Val loss for epoch 27: 0.5953178405761719
# Train loss for epoch 28: 0.6163691282272339
# Val loss for epoch 28: 0.5936740636825562
# Train loss for epoch 29: 0.6170216202735901
# Val loss for epoch 29: 0.5931673049926758
# Train loss for epoch 30: 0.6166448593139648
# Val loss for epoch 30: 0.5907679200172424
# Train loss for epoch 31: 0.6166220307350159
# Val loss for epoch 31: 0.5925909280776978
# Train loss for epoch 32: 0.616684079170227
# Val loss for epoch 32: 0.5964300632476807
# Train loss for epoch 33: 0.6164879202842712
# Val loss for epoch 33: 0.598870575428009
# Train loss for epoch 34: 0.6169393658638
# Val loss for epoch 34: 0.5900138020515442
# Train loss for epoch 35: 0.6163995862007141
# Val loss for epoch 35: 0.5925506949424744
# Train loss for epoch 36: 0.617428719997406
# Val loss for epoch 36: 0.5933310389518738
# Train loss for epoch 37: 0.6168783903121948
# Val loss for epoch 37: 0.5981139540672302
# Train loss for epoch 38: 0.6169825196266174
# Val loss for epoch 38: 0.5905286073684692
# Train loss for epoch 39: 0.6166640520095825
# Val loss for epoch 39: 0.5940319895744324
# Train loss for epoch 40: 0.6167469620704651
# Val loss for epoch 40: 0.5910407900810242
# Train loss for epoch 41: 0.6173579096794128
# Val loss for epoch 41: 0.5895503163337708
# Train loss for epoch 42: 0.61687171459198
# Val loss for epoch 42: 0.5908924341201782
# Train loss for epoch 43: 0.6174134016036987
# Val loss for epoch 43: 0.5946279168128967
# Train loss for epoch 44: 0.6176862716674805
# Val loss for epoch 44: 0.5919369459152222
# Train loss for epoch 45: 0.6177586317062378
# Val loss for epoch 45: 0.5907047390937805
# Train loss for epoch 46: 0.6164953708648682
# Val loss for epoch 46: 0.603580892086029
# Train loss for epoch 47: 0.6177989840507507
# Val loss for epoch 47: 0.5929802656173706
# Train loss for epoch 48: 0.61766117811203
# Val loss for epoch 48: 0.5885363221168518
# Train loss for epoch 49: 0.6171135306358337
# Val loss for epoch 49: 0.5917993783950806
# Train loss for epoch 50: 0.6175202131271362
# Val loss for epoch 50: 0.5907362699508667

# %%
model_LR = os.listdir(model_saving_path)
results = []
alphas = [1,50,100]
for alpha in alphas:
    best_result = 0
    reg_alpha = 'REG'+reg_type+str(alpha)+'_'
    for i, s in enumerate(model_LR):
        if 'LR_CH23_' in s and reg_alpha in s and '_valbalanced' in s:
            model_name = model_LR[i].split('_')
            epoch_name = [ind for ind,item in enumerate(np.array(model_name)) if "EPOCH" in item]
            res = [int(i) for i in model_name[epoch_name[0]] if i.isdigit()]
            if len(res) > 1:
                epoch_result = res[0]*10+res[1]
            else:
                epoch_result = res[0]
            if epoch_result>best_result and epoch_result != 50:
                best_result = epoch_result

    results.append([alpha,best_result])

    
results = pd.DataFrame(np.array(results), columns=['alpha', 'epoch'])
best_results = results.groupby('alpha').max('epoch')
print(best_results)
# Out:
#        epoch
# alpha
# 1          6
# 50        35
# 100       11

# %%
for i,(index,row) in enumerate(best_results.iterrows()):
    
    path = model_saving_path
    best_epoch = int(row)
    alpha = index
    
    
    # load best model
    model = GLM(input_dim=100*timewindow).to(device)
    path = model_saving_path
    optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)
    model.load_state_dict(torch.load('{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}_valbalanced.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, best_epoch)))
    
    print('{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}_valbalanced.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, best_epoch))

    ## Show one feature
    weights = model.linear.weight.view(100, timewindow)
    weights_sub = weights.detach().cpu()
    plt.axis('off')
    plt.imshow(weights_sub)
    plt.title(str(CH))
    # plt.clim(-0.03, 0.03)
    plt.show()
    
    ## Calculate accuracy and validation loss
    val_loss, val_acc, val_preds, val_preds_probs, val_labels,_,_,_, cases_wrong_1 = evaluate(model, optimizer, val_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=True, device=device, timewindow = timewindow)
    print('validation loss:{} accuracy:{}'.format(val_loss, val_acc))
    print(np.mean(np.concatenate(val_labels)))
    
    
    ## Wrong Classifications
    path_wrong = '/mnt/pesaranlab/People/Capstone_students/Yue/wrong_pred'
    pickle.dump(cases_wrong_1, open('{}/{}_CH{}_LOSS{}_REG{}{}.pt'.format(path_wrong, model_type, CH, loss_type, reg_type, alpha), 'wb'))
    idx = 0
    print('date:{}, rec:{}, time:{}, label:{}'.format(cases_wrong_1[0][0], cases_wrong_1[0][1], cases_wrong_1[0][2], cases_wrong_1[0][3]))
    print('Original data 62 CH')
    weights_sub = cases_wrong_1[0][-1][0]
    plt.axis('off')
    plt.imshow(weights_sub)
    # plt.clim(-0.03, 0.03)
    plt.show()
    
    ## Confusion matrix
    predictions_val = np.concatenate(val_preds)
    labels_val = np.concatenate(val_labels)

    df_val = pd.DataFrame({'predictions': predictions_val, 'labels': labels_val})

    cm_val = confusion_matrix(labels_val, predictions_val)
    ax = plt.axes()
    group_names = ['True Neg','False Pos','False Neg','True Pos']
    group_counts = ["{0:0.0f}".format(value) for value in
                    cm_val.flatten()]

    TNR = int(group_counts[0]) / (int(group_counts[0])+int(group_counts[1]))
    FPR = 1 - TNR
    TPR = int(group_counts[3]) / (int(group_counts[3])+int(group_counts[2]))
    FNR = 1-TPR
    group_percentages =[TNR, FPR, FNR, TPR]

    group_percentages = ["{0:.2%}".format(value) for value in
                         group_percentages]
    labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
              zip(group_names,group_counts,group_percentages)]
    labels = np.asarray(labels).reshape(2,2)
    sn.heatmap(cm_val, annot=labels, fmt='', center = 2000)
    ax.set_title('Validation Confusion Matrix')
    ax.set_xlabel('Predicted Label')
    ax.set_ylabel('True Label')
    plt.show()
# Out:
# /home/bijanadmin/Desktop/Goose_data/data_Goose_1st_5s_2/LR_models/LR_CH23_LOSSbce_REGl21_EPOCH6_valbalanced.pt
# validation loss:0.4827255606651306 accuracy:0.8194822888283378
# 0.5
# date:180329, rec:006, time:1801.0, label:1.0
# Original data 62 CH
# /home/bijanadmin/Desktop/Goose_data/data_Goose_1st_5s_2/LR_models/LR_CH23_LOSSbce_REGl250_EPOCH35_valbalanced.pt
# validation loss:0.5404431819915771 accuracy:0.833957765667575
# 0.5
# date:180329, rec:006, time:1801.0, label:1.0
# Original data 62 CH
# /home/bijanadmin/Desktop/Goose_data/data_Goose_1st_5s_2/LR_models/LR_CH23_LOSSbce_REGl2100_EPOCH11_valbalanced.pt
# validation loss:0.5816588401794434 accuracy:0.832425068119891
# 0.5
# date:180329, rec:006, time:1801.0, label:1.0
# Original data 62 CH

# %% [markdown]
# ### Logistic Regression with finite difference regularization

# %%
device = torch.device('cuda')

tol = 0.01
learning_rate = 0.001
num_epochs = 51
alphas = [1,50,100]
model_type = 'LR'
loss_type = 'bce'
reg_type = 'finite_diff'
timewindow = 5

# %%
for alpha in alphas:
    model = GLM(input_dim=100*timewindow).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)
    epochs, training_losses, training_acc, val_losses, validation_acc = [], [], [], [], []

    for epoch in range(num_epochs):
        train_loss, train_acc = train(model, optimizer, train_loader, timewindow = timewindow, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
        print('Train loss for epoch {}: {}'.format(epoch, train_loss))
        val_loss, val_acc = evaluate(model, optimizer, val_loader, alpha=alpha, timewindow = timewindow, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
        print('Val loss for epoch {}: {}'.format(epoch, val_loss))
        if val_losses:
            if val_loss < min(val_losses):
                best_epoch = epoch
                print(epoch)
                path = model_saving_path
                torch.save(model.state_dict(), '{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}_valbalanced.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, epoch))
        epochs.append(epoch)
        training_losses.append(train_loss)
        training_acc.append(train_acc)
        val_losses.append(val_loss)
        validation_acc.append(val_acc)

        if train_loss < tol:
            break
    plot_loss_acc(training_losses, val_losses, training_acc, validation_acc, model_type)
# Out:
# Train loss for epoch 0: 0.5460438132286072
# Val loss for epoch 0: 0.5069122314453125
# Train loss for epoch 1: 0.5233914256095886
# Val loss for epoch 1: 0.5024785995483398
# 1
# Train loss for epoch 2: 0.5156400203704834
# Val loss for epoch 2: 0.5023626089096069
# 2
# Train loss for epoch 3: 0.5096458792686462
# Val loss for epoch 3: 0.4975942075252533
# 3
# Train loss for epoch 4: 0.5059544444084167
# Val loss for epoch 4: 0.497525691986084
# 4
# Train loss for epoch 5: 0.5043193101882935
# Val loss for epoch 5: 0.4949284493923187
# 5
# Train loss for epoch 6: 0.5032591819763184
# Val loss for epoch 6: 0.4985094666481018
# Train loss for epoch 7: 0.5015373229980469
# Val loss for epoch 7: 0.4921189844608307
# 7
# Train loss for epoch 8: 0.500663161277771
# Val loss for epoch 8: 0.4939119517803192
# Train loss for epoch 9: 0.5004860162734985
# Val loss for epoch 9: 0.5008656978607178
# Train loss for epoch 10: 0.5000348091125488
# Val loss for epoch 10: 0.5000411868095398
# Train loss for epoch 11: 0.499668687582016
# Val loss for epoch 11: 0.5026712417602539
# Train loss for epoch 12: 0.5000548958778381
# Val loss for epoch 12: 0.5036880373954773
# Train loss for epoch 13: 0.4999169409275055
# Val loss for epoch 13: 0.4928242564201355
# Train loss for epoch 14: 0.49996018409729004
# Val loss for epoch 14: 0.501491129398346
# Train loss for epoch 15: 0.5003551244735718
# Val loss for epoch 15: 0.5032202005386353
# Train loss for epoch 16: 0.4999590814113617
# Val loss for epoch 16: 0.49631163477897644
# Train loss for epoch 17: 0.4994870722293854
# Val loss for epoch 17: 0.497880220413208
# Train loss for epoch 18: 0.4995739459991455
# Val loss for epoch 18: 0.5024999976158142
# Train loss for epoch 19: 0.4999788701534271
# Val loss for epoch 19: 0.5033841133117676
# Train loss for epoch 20: 0.4996943771839142
# Val loss for epoch 20: 0.5094369053840637
# Train loss for epoch 21: 0.5002318024635315
# Val loss for epoch 21: 0.4981517195701599
# Train loss for epoch 22: 0.4994616210460663
# Val loss for epoch 22: 0.4989354610443115
# Train loss for epoch 23: 0.4997996687889099
# Val loss for epoch 23: 0.5055369138717651
# Train loss for epoch 24: 0.5000734329223633
# Val loss for epoch 24: 0.4972257614135742
# Train loss for epoch 25: 0.5000229477882385
# Val loss for epoch 25: 0.49822527170181274
# Train loss for epoch 26: 0.4999561309814453
# Val loss for epoch 26: 0.5074741244316101
# Train loss for epoch 27: 0.49928024411201477
# Val loss for epoch 27: 0.49674350023269653
# Train loss for epoch 28: 0.5001406669616699
# Val loss for epoch 28: 0.4990035891532898
# Train loss for epoch 29: 0.49975448846817017
# Val loss for epoch 29: 0.5029309391975403
# Train loss for epoch 30: 0.5000628232955933
# Val loss for epoch 30: 0.5009334087371826
# Train loss for epoch 31: 0.5005897879600525
# Val loss for epoch 31: 0.502938985824585
# Train loss for epoch 32: 0.49981987476348877
# Val loss for epoch 32: 0.5030981302261353
# Train loss for epoch 33: 0.49955159425735474
# Val loss for epoch 33: 0.5026596188545227
# Train loss for epoch 34: 0.49970921874046326
# Val loss for epoch 34: 0.5053277015686035
# Train loss for epoch 35: 0.4997352659702301
# Val loss for epoch 35: 0.5034977197647095
# Train loss for epoch 36: 0.49996891617774963
# Val loss for epoch 36: 0.5062092542648315
# Train loss for epoch 37: 0.49987438321113586
# Val loss for epoch 37: 0.49772951006889343
# Train loss for epoch 38: 0.5008619427680969
# Val loss for epoch 38: 0.49852582812309265
# Train loss for epoch 39: 0.499546080827713
# Val loss for epoch 39: 0.4961642026901245
# Train loss for epoch 40: 0.49995550513267517
# Val loss for epoch 40: 0.5050467252731323
# Train loss for epoch 41: 0.49967002868652344
# Val loss for epoch 41: 0.5025109052658081
# Train loss for epoch 42: 0.49927234649658203
# Val loss for epoch 42: 0.4954213500022888
# Train loss for epoch 43: 0.5001767873764038
# Val loss for epoch 43: 0.5116146802902222
# Train loss for epoch 44: 0.5002961754798889
# Val loss for epoch 44: 0.5050356984138489
# Train loss for epoch 45: 0.49945253133773804
# Val loss for epoch 45: 0.49485263228416443
# Train loss for epoch 46: 0.49968278408050537
# Val loss for epoch 46: 0.5039428472518921
# Train loss for epoch 47: 0.5000672340393066
# Val loss for epoch 47: 0.5019392371177673
# Train loss for epoch 48: 0.5004492402076721
# Val loss for epoch 48: 0.5015729069709778
# Train loss for epoch 49: 0.5001075863838196
# Val loss for epoch 49: 0.505434513092041
# Train loss for epoch 50: 0.49953752756118774
# Val loss for epoch 50: 0.49973925948143005
# Train loss for epoch 0: 0.6228209733963013
# Val loss for epoch 0: 0.5277752876281738
# Train loss for epoch 1: 0.5554198622703552
# Val loss for epoch 1: 0.5226284861564636
# 1
# Train loss for epoch 2: 0.552306592464447
# Val loss for epoch 2: 0.5250723958015442
# Train loss for epoch 3: 0.5503568649291992
# Val loss for epoch 3: 0.5199850797653198
# 3
# Train loss for epoch 4: 0.5491759777069092
# Val loss for epoch 4: 0.5218523144721985
# Train loss for epoch 5: 0.548494279384613
# Val loss for epoch 5: 0.5194926857948303
# 5
# Train loss for epoch 6: 0.5479989051818848
# Val loss for epoch 6: 0.5187448263168335
# 6
# Train loss for epoch 7: 0.5474525094032288
# Val loss for epoch 7: 0.5207198262214661
# Train loss for epoch 8: 0.5479459762573242
# Val loss for epoch 8: 0.5226388573646545
# Train loss for epoch 9: 0.5481845140457153
# Val loss for epoch 9: 0.5175564885139465
# 9
# Train loss for epoch 10: 0.5482736229896545
# Val loss for epoch 10: 0.5254371166229248
# Train loss for epoch 11: 0.5486965179443359
# Val loss for epoch 11: 0.5212777853012085
# Train loss for epoch 12: 0.547448992729187
# Val loss for epoch 12: 0.5175955295562744
# Train loss for epoch 13: 0.5476277470588684
# Val loss for epoch 13: 0.5236591696739197
# Train loss for epoch 14: 0.5478541254997253
# Val loss for epoch 14: 0.5235729813575745
# Train loss for epoch 15: 0.5473437309265137
# Val loss for epoch 15: 0.5221582651138306
# Train loss for epoch 16: 0.5477476716041565
# Val loss for epoch 16: 0.5204842686653137
# Train loss for epoch 17: 0.5479854941368103
# Val loss for epoch 17: 0.5195067524909973
# Train loss for epoch 18: 0.5478419661521912
# Val loss for epoch 18: 0.5198529958724976
# Train loss for epoch 19: 0.5474520325660706
# Val loss for epoch 19: 0.5172637104988098
# 19
# Train loss for epoch 20: 0.5473091006278992
# Val loss for epoch 20: 0.5182427167892456
# Train loss for epoch 21: 0.5480372309684753
# Val loss for epoch 21: 0.5182060599327087
# Train loss for epoch 22: 0.5476438999176025
# Val loss for epoch 22: 0.5225940942764282
# Train loss for epoch 23: 0.5477217435836792
# Val loss for epoch 23: 0.5217530727386475
# Train loss for epoch 24: 0.5478264093399048
# Val loss for epoch 24: 0.5209648013114929
# Train loss for epoch 25: 0.5471721887588501
# Val loss for epoch 25: 0.5233951210975647
# Train loss for epoch 26: 0.5485725998878479
# Val loss for epoch 26: 0.5233950018882751
# Train loss for epoch 27: 0.5479530096054077
# Val loss for epoch 27: 0.5203750729560852
# Train loss for epoch 28: 0.5480315685272217
# Val loss for epoch 28: 0.5169399380683899
# 28
# Train loss for epoch 29: 0.5475500226020813
# Val loss for epoch 29: 0.5212109088897705
# Train loss for epoch 30: 0.5480785965919495
# Val loss for epoch 30: 0.5239194631576538
# Train loss for epoch 31: 0.5486323833465576
# Val loss for epoch 31: 0.5199262499809265
# Train loss for epoch 32: 0.5476255416870117
# Val loss for epoch 32: 0.5206465125083923
# Train loss for epoch 33: 0.5478515028953552
# Val loss for epoch 33: 0.5236127376556396
# Train loss for epoch 34: 0.5482146739959717
# Val loss for epoch 34: 0.5275859832763672
# Train loss for epoch 35: 0.5471748113632202
# Val loss for epoch 35: 0.520760178565979
# Train loss for epoch 36: 0.547701358795166
# Val loss for epoch 36: 0.5277183651924133
# Train loss for epoch 37: 0.5477115511894226
# Val loss for epoch 37: 0.5178593397140503
# Train loss for epoch 38: 0.5476323962211609
# Val loss for epoch 38: 0.5175413489341736
# Train loss for epoch 39: 0.5480666756629944
# Val loss for epoch 39: 0.5172303915023804
# Train loss for epoch 40: 0.5483909249305725
# Val loss for epoch 40: 0.5197348594665527
# Train loss for epoch 41: 0.5477138757705688
# Val loss for epoch 41: 0.5243586301803589
# Train loss for epoch 42: 0.5480515360832214
# Val loss for epoch 42: 0.5226410627365112
# Train loss for epoch 43: 0.5476232767105103
# Val loss for epoch 43: 0.5216706991195679
# Train loss for epoch 44: 0.547945499420166
# Val loss for epoch 44: 0.5190998911857605
# Train loss for epoch 45: 0.5482032299041748
# Val loss for epoch 45: 0.5201291441917419
# Train loss for epoch 46: 0.5480942130088806
# Val loss for epoch 46: 0.5296865701675415
# Train loss for epoch 47: 0.5472665429115295
# Val loss for epoch 47: 0.5218902230262756
# Train loss for epoch 48: 0.547690749168396
# Val loss for epoch 48: 0.5212246179580688
# Train loss for epoch 49: 0.5473626255989075
# Val loss for epoch 49: 0.5269908905029297
# Train loss for epoch 50: 0.548269510269165
# Val loss for epoch 50: 0.5212419033050537
# Train loss for epoch 0: 0.6782224178314209
# Val loss for epoch 0: 0.5373921990394592
# Train loss for epoch 1: 0.5690446496009827
# Val loss for epoch 1: 0.531588077545166
# 1
# Train loss for epoch 2: 0.567010760307312
# Val loss for epoch 2: 0.5281559228897095
# 2
# Train loss for epoch 3: 0.5652827024459839
# Val loss for epoch 3: 0.528592586517334
# Train loss for epoch 4: 0.5651664137840271
# Val loss for epoch 4: 0.5316159129142761
# Train loss for epoch 5: 0.5650668740272522
# Val loss for epoch 5: 0.5313742756843567
# Train loss for epoch 6: 0.5651289224624634
# Val loss for epoch 6: 0.5319618582725525
# Train loss for epoch 7: 0.5646390318870544
# Val loss for epoch 7: 0.5335805416107178
# Train loss for epoch 8: 0.5654207468032837
# Val loss for epoch 8: 0.5394229888916016
# Train loss for epoch 9: 0.5650312900543213
# Val loss for epoch 9: 0.5299184918403625
# Train loss for epoch 10: 0.5655269622802734
# Val loss for epoch 10: 0.5361539125442505
# Train loss for epoch 11: 0.5648902654647827
# Val loss for epoch 11: 0.526413083076477
# 11
# Train loss for epoch 12: 0.5648640394210815
# Val loss for epoch 12: 0.5329485535621643
# Train loss for epoch 13: 0.5653772354125977
# Val loss for epoch 13: 0.5281894207000732
# Train loss for epoch 14: 0.565319299697876
# Val loss for epoch 14: 0.5294727087020874
# Train loss for epoch 15: 0.5650046467781067
# Val loss for epoch 15: 0.5322197079658508
# Train loss for epoch 16: 0.5655540227890015
# Val loss for epoch 16: 0.5307124257087708
# Train loss for epoch 17: 0.5655591487884521
# Val loss for epoch 17: 0.5317227840423584
# Train loss for epoch 18: 0.565098226070404
# Val loss for epoch 18: 0.5338825583457947
# Train loss for epoch 19: 0.5666084885597229
# Val loss for epoch 19: 0.5302861928939819
# Train loss for epoch 20: 0.5650361776351929
# Val loss for epoch 20: 0.5401576161384583
# Train loss for epoch 21: 0.5652327537536621
# Val loss for epoch 21: 0.5294536352157593
# Train loss for epoch 22: 0.56495201587677
# Val loss for epoch 22: 0.5273470878601074
# Train loss for epoch 23: 0.5655089020729065
# Val loss for epoch 23: 0.5276984572410583
# Train loss for epoch 24: 0.5648679137229919
# Val loss for epoch 24: 0.5315641164779663
# Train loss for epoch 25: 0.5649577379226685
# Val loss for epoch 25: 0.5301987528800964
# Train loss for epoch 26: 0.5656487345695496
# Val loss for epoch 26: 0.5281943082809448
# Train loss for epoch 27: 0.5649282932281494
# Val loss for epoch 27: 0.5288427472114563
# Train loss for epoch 28: 0.5657942295074463
# Val loss for epoch 28: 0.5285898447036743
# Train loss for epoch 29: 0.5646670460700989
# Val loss for epoch 29: 0.5301380157470703
# Train loss for epoch 30: 0.5653961300849915
# Val loss for epoch 30: 0.5278205275535583
# Train loss for epoch 31: 0.566227912902832
# Val loss for epoch 31: 0.5305631160736084
# Train loss for epoch 32: 0.5646649599075317
# Val loss for epoch 32: 0.5262184739112854
# 32
# Train loss for epoch 33: 0.5649322271347046
# Val loss for epoch 33: 0.5252106189727783
# 33
# Train loss for epoch 34: 0.5656920671463013
# Val loss for epoch 34: 0.5293056964874268
# Train loss for epoch 35: 0.5647907853126526
# Val loss for epoch 35: 0.5321575403213501
# Train loss for epoch 36: 0.565148115158081
# Val loss for epoch 36: 0.5294370055198669
# Train loss for epoch 37: 0.5646347403526306
# Val loss for epoch 37: 0.5342777967453003
# Train loss for epoch 38: 0.5660570859909058
# Val loss for epoch 38: 0.5323938131332397
# Train loss for epoch 39: 0.5651668310165405
# Val loss for epoch 39: 0.5341248512268066
# Train loss for epoch 40: 0.5655580163002014
# Val loss for epoch 40: 0.5361419320106506
# Train loss for epoch 41: 0.5654033422470093
# Val loss for epoch 41: 0.5266396999359131
# Train loss for epoch 42: 0.565640926361084
# Val loss for epoch 42: 0.5343258380889893
# Train loss for epoch 43: 0.5648361444473267
# Val loss for epoch 43: 0.5282143950462341
# Train loss for epoch 44: 0.5651995539665222
# Val loss for epoch 44: 0.529273509979248
# Train loss for epoch 45: 0.5649220943450928
# Val loss for epoch 45: 0.5375086069107056
# Train loss for epoch 46: 0.5645110607147217
# Val loss for epoch 46: 0.5327417254447937
# Train loss for epoch 47: 0.5654904842376709
# Val loss for epoch 47: 0.5356231927871704
# Train loss for epoch 48: 0.5654156804084778
# Val loss for epoch 48: 0.5365179181098938
# Train loss for epoch 49: 0.5649420619010925
# Val loss for epoch 49: 0.528431236743927
# Train loss for epoch 50: 0.5652785301208496
# Val loss for epoch 50: 0.529316246509552

# %%
model_LR = os.listdir(model_saving_path)
results = []
alphas = [1,50,100]
for alpha in alphas:
    best_result = 0
    reg_alpha = 'REG'+reg_type+str(alpha)+'_'
    for i, s in enumerate(model_LR):
        if 'LR_CH23_' in s and reg_alpha in s and '_valbalanced' in s:
            model_name = model_LR[i].split('_')
            epoch_name = [ind for ind,item in enumerate(np.array(model_name)) if "EPOCH" in item]
            res = [int(i) for i in model_name[epoch_name[0]] if i.isdigit()]
            if len(res) > 1:
                epoch_result = res[0]*10+res[1]
            else:
                epoch_result = res[0]
            if epoch_result>best_result and epoch_result != 50:
                best_result = epoch_result

    results.append([alpha,best_result])

    
results = pd.DataFrame(np.array(results), columns=['alpha', 'epoch'])
best_results = results.groupby('alpha').max('epoch')
print(best_results)
# Out:
#        epoch
# alpha
# 1          7
# 50        28
# 100       33

# %%
for i,(index,row) in enumerate(best_results.iterrows()):
    
    path = model_saving_path
    best_epoch = int(row)
    alpha = index
    
    
    # load best model
    model = GLM(input_dim=100*timewindow).to(device)
    path = model_saving_path
    optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)
    model.load_state_dict(torch.load('{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}_valbalanced.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, best_epoch)))
    
    print('{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}_valbalanced.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, best_epoch))

    ## Show one feature
    weights = model.linear.weight.view(100, timewindow)
    weights_sub = weights.detach().cpu()
    plt.axis('off')
    plt.imshow(weights_sub)
    plt.title(str(CH))
    # plt.clim(-0.03, 0.03)
    plt.show()
    
    ## Calculate accuracy and validation loss
    val_loss, val_acc, val_preds, val_preds_probs, val_labels,_,_,_, cases_wrong_1 = evaluate(model, optimizer, val_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=True, device=device, timewindow = timewindow)
    print('validation loss:{} accuracy:{}'.format(val_loss, val_acc))
    print(np.mean(np.concatenate(val_labels)))
    
    
    ## Wrong Classifications
    path_wrong = '/mnt/pesaranlab/People/Capstone_students/Yue/wrong_pred'
    pickle.dump(cases_wrong_1, open('{}/{}_CH{}_LOSS{}_REG{}{}.pt'.format(path_wrong, model_type, CH, loss_type, reg_type, alpha), 'wb'))
    idx = 0
    print('date:{}, rec:{}, time:{}, label:{}'.format(cases_wrong_1[0][0], cases_wrong_1[0][1], cases_wrong_1[0][2], cases_wrong_1[0][3]))
    print('Original data 62 CH')
    weights_sub = cases_wrong_1[0][-1][0]
    plt.axis('off')
    plt.imshow(weights_sub)
    # plt.clim(-0.03, 0.03)
    plt.show()
    
    ## Confusion matrix
    predictions_val = np.concatenate(val_preds)
    labels_val = np.concatenate(val_labels)

    df_val = pd.DataFrame({'predictions': predictions_val, 'labels': labels_val})

    cm_val = confusion_matrix(labels_val, predictions_val)
    ax = plt.axes()
    group_names = ['True Neg','False Pos','False Neg','True Pos']
    group_counts = ["{0:0.0f}".format(value) for value in
                    cm_val.flatten()]

    TNR = int(group_counts[0]) / (int(group_counts[0])+int(group_counts[1]))
    FPR = 1 - TNR
    TPR = int(group_counts[3]) / (int(group_counts[3])+int(group_counts[2]))
    FNR = 1-TPR
    group_percentages =[TNR, FPR, FNR, TPR]

    group_percentages = ["{0:.2%}".format(value) for value in
                         group_percentages]
    labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
              zip(group_names,group_counts,group_percentages)]
    labels = np.asarray(labels).reshape(2,2)
    sn.heatmap(cm_val, annot=labels, fmt='', center = 2000)
    ax.set_title('Validation Confusion Matrix')
    ax.set_xlabel('Predicted Label')
    ax.set_ylabel('True Label')
    plt.show()
# Out:
# /home/bijanadmin/Desktop/Goose_data/data_Goose_1st_5s_2/LR_models/LR_CH23_LOSSbce_REGfinite_diff1_EPOCH7_valbalanced.pt
# validation loss:0.4834882318973541 accuracy:0.8261239782016349
# 0.5
# date:180329, rec:006, time:1801.0, label:1.0
# Original data 62 CH
# /home/bijanadmin/Desktop/Goose_data/data_Goose_1st_5s_2/LR_models/LR_CH23_LOSSbce_REGfinite_diff50_EPOCH28_valbalanced.pt
# validation loss:0.5093896985054016 accuracy:0.8201634877384196
# 0.5
# date:180329, rec:006, time:1801.0, label:1.0
# Original data 62 CH
# /home/bijanadmin/Desktop/Goose_data/data_Goose_1st_5s_2/LR_models/LR_CH23_LOSSbce_REGfinite_diff100_EPOCH33_valbalanced.pt
# validation loss:0.5182688236236572 accuracy:0.8188010899182562
# 0.5
# date:180329, rec:006, time:1801.0, label:1.0
# Original data 62 CH

# %% [markdown]
# Done here. Not done w SVM.

# %% [markdown]
# ### SVM without regularization

# %% [markdown]
# ### SVM with L2 regularization

# %%
device = torch.device('cuda')

tol = 0.01
learning_rate = 0.001
num_epochs = 51
alpha = 0.5 # have special meaning as margin, corresponding to 1 in the hinge loss
model_type = 'SVM'
loss_type = 'hinge'
reg_type = 'l2'

model = GLM(input_dim=100*10).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)

# %%
epochs, training_losses, training_acc, val_losses, validation_acc = [], [], [], [], []

for epoch in range(num_epochs):
    train_loss, train_acc = train(model, optimizer, train_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
    print('Train loss for epoch {}: {}'.format(epoch, train_loss))
    val_loss, val_acc = evaluate(model, optimizer, val_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
    print('Val loss for epoch {}: {}'.format(epoch, val_loss))
    if val_losses:
        if val_loss < min(val_losses):
            best_epoch = epoch
            print(epoch)
            path = '/mnt/pesaranlab/People/Capstone_students/Yue/model/model_Goose_1st_1_upsample'
            torch.save(model.state_dict(), '{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, epoch))
    epochs.append(epoch)
    training_losses.append(train_loss)
    training_acc.append(train_acc)
    val_losses.append(val_loss)
    validation_acc.append(val_acc)
    
    if train_loss < tol:
        break
# Out:
# Train loss for epoch 0: 0.6851320862770081
# Val loss for epoch 0: 0.7111771702766418
# Train loss for epoch 1: 0.6442375183105469
# Val loss for epoch 1: 0.7678999900817871
# Train loss for epoch 2: 0.6391520500183105
# Val loss for epoch 2: 0.7529788017272949
# Train loss for epoch 3: 0.6417877078056335
# Val loss for epoch 3: 0.6641672253608704
# 3
# Train loss for epoch 4: 0.6390126347541809
# Val loss for epoch 4: 0.6984342932701111
# Train loss for epoch 5: 0.6404396295547485
# Val loss for epoch 5: 0.7401537895202637
# Train loss for epoch 6: 0.639179527759552
# Val loss for epoch 6: 0.6993381977081299
# Train loss for epoch 7: 0.6405513882637024
# Val loss for epoch 7: 0.6649073362350464
# Train loss for epoch 8: 0.6384839415550232
# Val loss for epoch 8: 0.6716033816337585
# Train loss for epoch 9: 0.6426579356193542
# Val loss for epoch 9: 0.7246717214584351
# Train loss for epoch 10: 0.6410369277000427
# Val loss for epoch 10: 0.714557945728302
# Train loss for epoch 11: 0.640546977519989
# Val loss for epoch 11: 0.7000125050544739
# Train loss for epoch 12: 0.642488420009613
# Val loss for epoch 12: 0.6774542331695557
# Train loss for epoch 13: 0.6405550837516785
# Val loss for epoch 13: 0.7184460759162903
# Train loss for epoch 14: 0.6403983235359192
# Val loss for epoch 14: 0.7138395309448242
# Train loss for epoch 15: 0.6415858864784241
# Val loss for epoch 15: 0.7804384231567383
# Train loss for epoch 16: 0.639844536781311
# Val loss for epoch 16: 0.7306813597679138
# Train loss for epoch 17: 0.6411546468734741
# Val loss for epoch 17: 0.6943265795707703
# Train loss for epoch 18: 0.6401860117912292
# Val loss for epoch 18: 0.6885607838630676
# Train loss for epoch 19: 0.6396834850311279
# Val loss for epoch 19: 0.7206060290336609
# Train loss for epoch 20: 0.640455961227417
# Val loss for epoch 20: 0.702420175075531
# Train loss for epoch 21: 0.6402938961982727
# Val loss for epoch 21: 0.7104942202568054
# Train loss for epoch 22: 0.640040934085846
# Val loss for epoch 22: 0.7436862587928772
# Train loss for epoch 23: 0.6407786011695862
# Val loss for epoch 23: 0.6620125770568848
# 23
# Train loss for epoch 24: 0.6418817639350891
# Val loss for epoch 24: 0.7360722422599792
# Train loss for epoch 25: 0.6385318040847778
# Val loss for epoch 25: 0.7304670214653015
# Train loss for epoch 26: 0.640387773513794
# Val loss for epoch 26: 0.7861469388008118
# Train loss for epoch 27: 0.6426716446876526
# Val loss for epoch 27: 0.6352165341377258
# 27
# Train loss for epoch 28: 0.6454393267631531
# Val loss for epoch 28: 0.6951034069061279
# Train loss for epoch 29: 0.6385886073112488
# Val loss for epoch 29: 0.7505565285682678
# Train loss for epoch 30: 0.6399576663970947
# Val loss for epoch 30: 0.7399937510490417
# Train loss for epoch 31: 0.641554057598114
# Val loss for epoch 31: 0.6840065121650696
# Train loss for epoch 32: 0.6412416100502014
# Val loss for epoch 32: 0.6981443762779236
# Train loss for epoch 33: 0.6422035694122314
# Val loss for epoch 33: 0.6874670386314392
# Train loss for epoch 34: 0.6408448815345764
# Val loss for epoch 34: 0.8072331547737122
# Train loss for epoch 35: 0.6395016312599182
# Val loss for epoch 35: 0.730316162109375
# Train loss for epoch 36: 0.6403080224990845
# Val loss for epoch 36: 0.7818818688392639
# Train loss for epoch 37: 0.6434655785560608
# Val loss for epoch 37: 0.6429640650749207
# Train loss for epoch 38: 0.6408840417861938
# Val loss for epoch 38: 0.6359612941741943
# Train loss for epoch 39: 0.6419800519943237
# Val loss for epoch 39: 0.6931543946266174
# Train loss for epoch 40: 0.641847550868988
# Val loss for epoch 40: 0.6723946332931519
# Train loss for epoch 41: 0.6399581432342529
# Val loss for epoch 41: 0.7007078528404236
# Train loss for epoch 42: 0.637771725654602
# Val loss for epoch 42: 0.7417786717414856
# Train loss for epoch 43: 0.6427635550498962
# Val loss for epoch 43: 0.737413763999939
# Train loss for epoch 44: 0.6401107907295227
# Val loss for epoch 44: 0.6725066304206848
# Train loss for epoch 45: 0.6420534253120422
# Val loss for epoch 45: 0.6480686068534851
# Train loss for epoch 46: 0.6414241194725037
# Val loss for epoch 46: 0.7304709553718567
# Train loss for epoch 47: 0.6403049826622009
# Val loss for epoch 47: 0.7036920785903931
# Train loss for epoch 48: 0.6407722234725952
# Val loss for epoch 48: 0.6887156963348389
# Train loss for epoch 49: 0.6385686993598938
# Val loss for epoch 49: 0.7157089114189148
# Train loss for epoch 50: 0.6383669376373291
# Val loss for epoch 50: 0.7005918622016907

# %%
plot_loss_acc(training_losses, val_losses, training_acc, validation_acc, model_type)

# %%
best_epoch = 27

# %%
model = GLM(input_dim=100*10).to(device)
path = '/mnt/pesaranlab/People/Capstone_students/Yue/model/model_Goose_1st_1_upsample'
model.load_state_dict(torch.load('{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, best_epoch)))
weights = model.linear.weight.view(100, 10)
weights_sub = weights.detach().cpu()
plt.axis('off')
plt.imshow(weights_sub)
plt.title(str(CH))
# plt.clim(-0.03, 0.03)
plt.show()

# %%
test_loss, test_acc, test_preds, test_preds_probs, test_labels, cases_wrong_4 = evaluate(model, optimizer, test_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=True, device=device)
print('test loss:{} accuracy:{}'.format(test_loss, test_acc))
# Out:
# test loss:0.9384552836418152 accuracy:0.6475384615384615

# %%
predictions_test = np.concatenate(test_preds)
labels_test = np.concatenate(test_labels)

df_test = pd.DataFrame({'predictions': predictions_test, 'labels': labels_test})

cm_test = confusion_matrix(labels_test, predictions_test)
ax = plt.axes()
sn.heatmap(cm_test, annot = True, fmt = "d", ax = ax, center=2000)
ax.set_title('Test Confusion Matrix')
ax.set_xlabel('Predicted Label')
ax.set_ylabel('True Label')
plt.show()

# %%
idx = 0
print('date:{}, rec:{}, time:{}, label:{}'.format(cases_wrong_4[0][0], cases_wrong_4[0][1], cases_wrong_4[0][1], cases_wrong_4[0][3]))
print('Original data 62 CH')
weights_sub = cases_wrong_4[0][-1][0]
plt.axis('off')
plt.imshow(weights_sub)
# plt.clim(-0.03, 0.03)
plt.show()
# Out:
# date:180331, rec:004, time:004, label:1.0
# Original data 62 CH

# %% [markdown]
# ### SVM with finite difference regularization

# %%
device = torch.device('cuda')

tol = 0.01
learning_rate = 0.001
num_epochs = 51
alpha = 0.5
model_type = 'SVM'
loss_type = 'hinge'
reg_type = 'finite_diff'

model = GLM(input_dim=100*10).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)

# %%
epochs, training_losses, training_acc, val_losses, validation_acc = [], [], [], [], []

for epoch in range(num_epochs):
    train_loss, train_acc = train(model, optimizer, train_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
    print('Train loss for epoch {}: {}'.format(epoch, train_loss))
    val_loss, val_acc = evaluate(model, optimizer, val_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=False, device=device)
    print('Val loss for epoch {}: {}'.format(epoch, val_loss))
    if val_losses:
        if val_loss < min(val_losses):
            best_epoch = epoch
            print(epoch)
            path = '/mnt/pesaranlab/People/Capstone_students/Yue/model/model_Goose_1st_1_upsample'
            torch.save(model.state_dict(), '{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, epoch))
    epochs.append(epoch)
    training_losses.append(train_loss)
    training_acc.append(train_acc)
    val_losses.append(val_loss)
    validation_acc.append(val_acc)
    
    if train_loss < tol:
        break
# Out:
# Train loss for epoch 0: 0.6690675616264343
# Val loss for epoch 0: 0.7053626179695129
# Train loss for epoch 1: 0.579605758190155
# Val loss for epoch 1: 0.6587177515029907
# 1
# Train loss for epoch 2: 0.5777973532676697
# Val loss for epoch 2: 0.661455512046814
# Train loss for epoch 3: 0.5772103071212769
# Val loss for epoch 3: 0.6873345375061035
# Train loss for epoch 4: 0.5797932744026184
# Val loss for epoch 4: 0.6312553286552429
# 4
# Train loss for epoch 5: 0.5747454762458801
# Val loss for epoch 5: 0.6387228965759277
# Train loss for epoch 6: 0.5753779411315918
# Val loss for epoch 6: 0.6457529067993164
# Train loss for epoch 7: 0.5756300687789917
# Val loss for epoch 7: 0.570262610912323
# 7
# Train loss for epoch 8: 0.5766920447349548
# Val loss for epoch 8: 0.6651206016540527
# Train loss for epoch 9: 0.5784576535224915
# Val loss for epoch 9: 0.6457962989807129
# Train loss for epoch 10: 0.5766485929489136
# Val loss for epoch 10: 0.6799610257148743
# Train loss for epoch 11: 0.577312171459198
# Val loss for epoch 11: 0.6357672810554504
# Train loss for epoch 12: 0.5765970945358276
# Val loss for epoch 12: 0.6243463754653931
# Train loss for epoch 13: 0.5763651728630066
# Val loss for epoch 13: 0.6528318524360657
# Train loss for epoch 14: 0.5787343978881836
# Val loss for epoch 14: 0.6197062134742737
# Train loss for epoch 15: 0.5766005516052246
# Val loss for epoch 15: 0.6669512391090393
# Train loss for epoch 16: 0.5740532279014587
# Val loss for epoch 16: 0.6083996891975403
# Train loss for epoch 17: 0.578143835067749
# Val loss for epoch 17: 0.6331867575645447
# Train loss for epoch 18: 0.5752172470092773
# Val loss for epoch 18: 0.6276236772537231
# Train loss for epoch 19: 0.5754168033599854
# Val loss for epoch 19: 0.6268960237503052
# Train loss for epoch 20: 0.5756818056106567
# Val loss for epoch 20: 0.6202787756919861
# Train loss for epoch 21: 0.5744140148162842
# Val loss for epoch 21: 0.6567234396934509
# Train loss for epoch 22: 0.5762956738471985
# Val loss for epoch 22: 0.6660755276679993
# Train loss for epoch 23: 0.5758554339408875
# Val loss for epoch 23: 0.6730091571807861
# Train loss for epoch 24: 0.577211320400238
# Val loss for epoch 24: 0.651534914970398
# Train loss for epoch 25: 0.5769349336624146
# Val loss for epoch 25: 0.7000337243080139
# Train loss for epoch 26: 0.5785800814628601
# Val loss for epoch 26: 0.687545120716095
# Train loss for epoch 27: 0.5782286524772644
# Val loss for epoch 27: 0.6496562361717224
# Train loss for epoch 28: 0.5788707137107849
# Val loss for epoch 28: 0.6680619120597839
# Train loss for epoch 29: 0.5760782957077026
# Val loss for epoch 29: 0.6649113893508911
# Train loss for epoch 30: 0.5756315588951111
# Val loss for epoch 30: 0.6239709854125977
# Train loss for epoch 31: 0.5757757425308228
# Val loss for epoch 31: 0.6552281379699707
# Train loss for epoch 32: 0.5736462473869324
# Val loss for epoch 32: 0.6681107878684998
# Train loss for epoch 33: 0.5752080082893372
# Val loss for epoch 33: 0.6992300748825073
# Train loss for epoch 34: 0.5773605704307556
# Val loss for epoch 34: 0.5969449281692505
# Train loss for epoch 35: 0.577599287033081
# Val loss for epoch 35: 0.7016803622245789
# Train loss for epoch 36: 0.5782400965690613
# Val loss for epoch 36: 0.6377145648002625
# Train loss for epoch 37: 0.5756941437721252
# Val loss for epoch 37: 0.689575731754303
# Train loss for epoch 38: 0.576504647731781
# Val loss for epoch 38: 0.6356939077377319
# Train loss for epoch 39: 0.579881489276886
# Val loss for epoch 39: 0.6778709292411804
# Train loss for epoch 40: 0.5781845450401306
# Val loss for epoch 40: 0.60308438539505
# Train loss for epoch 41: 0.577141284942627
# Val loss for epoch 41: 0.6428723931312561
# Train loss for epoch 42: 0.5757811665534973
# Val loss for epoch 42: 0.6472859382629395
# Train loss for epoch 43: 0.5753296613693237
# Val loss for epoch 43: 0.6884997487068176
# Train loss for epoch 44: 0.5757269859313965
# Val loss for epoch 44: 0.6618257164955139
# Train loss for epoch 45: 0.5760087966918945
# Val loss for epoch 45: 0.6461961269378662
# Train loss for epoch 46: 0.5766039490699768
# Val loss for epoch 46: 0.641828715801239
# Train loss for epoch 47: 0.5778237581253052
# Val loss for epoch 47: 0.6952266097068787
# Train loss for epoch 48: 0.5753308534622192
# Val loss for epoch 48: 0.6868410110473633
# Train loss for epoch 49: 0.5763373374938965
# Val loss for epoch 49: 0.7049767971038818
# Train loss for epoch 50: 0.5758347511291504
# Val loss for epoch 50: 0.6037036180496216

# %%
plot_loss_acc(training_losses, val_losses, training_acc, validation_acc, model_type)

# %%
best_epoch = 7

# %%
model = GLM(input_dim=100*10).to(device)
path = '/mnt/pesaranlab/People/Capstone_students/Yue/model/model_Goose_1st_1_upsample'
model.load_state_dict(torch.load('{}/{}_CH{}_LOSS{}_REG{}{}_EPOCH{}.pt'.format(path, model_type, CH, loss_type, reg_type, alpha, best_epoch)))
weights = model.linear.weight.view(100, 10)
weights_sub = weights.detach().cpu()
plt.axis('off')
plt.imshow(weights_sub)
plt.title(str(CH))
# plt.clim(-0.03, 0.03)
plt.show()

# %%
test_loss, test_acc, test_preds, test_preds_probs, test_labels, cases_wrong_5 = evaluate(model, optimizer, test_loader, alpha=alpha, model_type=model_type, loss_type=loss_type, reg_type=reg_type, collect_result=True, device=device)
print('test loss:{} accuracy:{}'.format(test_loss, test_acc))
# Out:
# test loss:0.8175214529037476 accuracy:0.6916923076923077

# %%
predictions_test = np.concatenate(test_preds)
labels_test = np.concatenate(test_labels)

df_test = pd.DataFrame({'predictions': predictions_test, 'labels': labels_test})

cm_test = confusion_matrix(labels_test, predictions_test)
ax = plt.axes()
sn.heatmap(cm_test, annot = True, fmt = "d", ax = ax, center=2000)
ax.set_title('Test Confusion Matrix')
ax.set_xlabel('Predicted Label')
ax.set_ylabel('True Label')
plt.show()

# %%
idx = 0
print('date:{}, rec:{}, time:{}, label:{}'.format(cases_wrong_5[0][0], cases_wrong_5[0][1], cases_wrong_5[0][1], cases_wrong_5[0][3]))
print('Original data 62 CH')
weights_sub = cases_wrong_5[0][-1][0]
plt.axis('off')
plt.imshow(weights_sub)
# plt.clim(-0.03, 0.03)
plt.show()
# Out:
# date:180331, rec:004, time:004, label:1.0
# Original data 62 CH
