# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
from torch.utils.data import Dataset, DataLoader
from torch import nn
from torch.nn.functional import relu
from scipy.io import loadmat
import os
from os import listdir
import pandas as pd
from skimage import io
from PIL import Image

# %%
moving_files_dates = []
sleeping_files_dates = []
for f in os.listdir('/mnt/pesaranlab/People/Capstone_students/Noah/datav3/move/'):
    moving_files_dates.append(f[:6])
    
for f in os.listdir('/mnt/pesaranlab/People/Capstone_students/Noah/datav3/sleep/'):
    sleeping_files_dates.append(f[:6])

# %%
import pandas as pd
df_move = pd.DataFrame({'dates':moving_files_dates})
df_sleep = pd.DataFrame({'dates':sleeping_files_dates})

# %%
df_move.value_counts()
# Out:
# dates
# 180327    1553
# 180330     808
# 180329     231
# dtype: int64

# %%
df_sleep.value_counts()
# Out:
# dates
# 180327    1184
# 180330     966
# 180329     885
# dtype: int64

# %% [markdown]
# # Making Datasets

# %%
moving_files_train = []
moving_files_val = []
for f in os.listdir('/mnt/pesaranlab/People/Capstone_students/Noah/datav3/move/'):
    if np.load('/mnt/pesaranlab/People/Capstone_students/Noah/datav3/move/'+f).shape[0] == 100:
        x = np.load('/mnt/pesaranlab/People/Capstone_students/Noah/datav3/move/'+f)
        date = f.split('_')[0]
        rec = f.split('_')[1].split('_')[0]
        win = f.split('_')[3]
        if ('0329' not in f):
            moving_files_train.append((torch.from_numpy(x).unsqueeze(0), torch.Tensor([0]), date, rec, win))
        else:
            moving_files_val.append((torch.from_numpy(x).unsqueeze(0), torch.Tensor([0]), date, rec, win))
        
sleeping_files_train = []
sleeping_files_val = []
for f in os.listdir('/mnt/pesaranlab/People/Capstone_students/Noah/datav3/sleep/'):
    if np.load('/mnt/pesaranlab/People/Capstone_students/Noah/datav3/sleep/'+f).shape[0] == 100:
        x = np.load('/mnt/pesaranlab/People/Capstone_students/Noah/datav3/sleep/'+f)
        date = f.split('_')[0]
        rec = f.split('_')[1].split('_')[0]
        win = f.split('_')[3]
        if ('0329' not in f):
            sleeping_files_train.append((torch.from_numpy(x).unsqueeze(0), torch.Tensor([1]), date, rec, win))
        else:
            sleeping_files_val.append((torch.from_numpy(x).unsqueeze(0), torch.Tensor([1]), date, rec, win))

# %%
len(moving_files_train), len(sleeping_files_train)
# Out:
# (2361, 2150)

# %%
len(moving_files_val), len(sleeping_files_val)
# Out:
# (231, 885)

# %%
import random
diff_train = len(moving_files_train)-len(sleeping_files_train)
for i in range(diff_train):
    ind = random.randint(0,len(sleeping_files_train)-1)
    x= sleeping_files_train[ind]
    sleeping_files_train.append(x)

# %%
len(moving_files_train), len(sleeping_files_train)
# Out:
# (2361, 2361)

# %%
moving_files = moving_files_train + moving_files_val
sleeping_files = sleeping_files_train + sleeping_files_val

len(moving_files), len(sleeping_files)
# Out:
# (2592, 3246)

# %%
for i in moving_files:
    print(type(i[0]))
    break
# Out:
# <class 'torch.Tensor'>

# %%
class NoahSpectrogramDataset(Dataset):
    def __init__(self, mode='train',moving_files_train=moving_files_train,sleeping_files_train=sleeping_files_train,moving_files_val=moving_files_val,sleeping_files_val=sleeping_files_val):
        if mode == 'train':
            self.all_files = moving_files_train+sleeping_files_train
        elif mode == 'valid':
            self.all_files = moving_files_val+sleeping_files_val
            
    def __len__(self):
        return len(self.all_files)
    
    def __getitem__(self, idx):
        return self.all_files[idx]

# %%
train_dataset = NoahSpectrogramDataset(mode='train')
valid_dataset = NoahSpectrogramDataset(mode='valid')

# %%
train_loader = DataLoader(dataset = train_dataset, batch_size = 16, shuffle = True)
val_loader = DataLoader(dataset = valid_dataset, batch_size = 16, shuffle = False)

# %%
for (data, labels, date, rec, win) in train_loader:
    print(type(data))
    break
# Out:
# <class 'torch.Tensor'>

# %%
for batch_idx, (data, labels, date, rec, win) in enumerate(train_loader):
    print('batch number: '+str(batch_idx))
    print('date: '+str(date[0]))
    print('recording: '+str(rec[0]))
    print('window: ' +str(win[0]))
    print('label (move = 0, sleep = 1): ' +str(labels[0]))
    plt.imshow(data[0][0].cpu().detach().numpy())
#     if (channel != 0) and (channel != 32):
#         plt.axis('off')
    plt.show()
    if batch_idx == 10:
        break
# Out:
# batch number: 0
# date: 180330
# recording: 006
# window: win188
# label (move = 0, sleep = 1): tensor([1.])
# batch number: 1
# date: 180327
# recording: 003
# window: win135
# label (move = 0, sleep = 1): tensor([1.])
# batch number: 2
# date: 180327
# recording: 007
# window: win292
# label (move = 0, sleep = 1): tensor([0.])
# batch number: 3
# date: 180327
# recording: 008
# window: win353
# label (move = 0, sleep = 1): tensor([0.])
# batch number: 4
# date: 180330
# recording: 006
# window: win94
# label (move = 0, sleep = 1): tensor([1.])
# batch number: 5
# date: 180330
# recording: 009
# window: win239
# label (move = 0, sleep = 1): tensor([0.])
# batch number: 6
# date: 180330
# recording: 001
# window: win89
# label (move = 0, sleep = 1): tensor([1.])
# batch number: 7
# date: 180327
# recording: 003
# window: win82
# label (move = 0, sleep = 1): tensor([1.])
# batch number: 8
# date: 180327
# recording: 007
# window: win186
# label (move = 0, sleep = 1): tensor([0.])
# batch number: 9
# date: 180330
# recording: 009
# window: win125
# label (move = 0, sleep = 1): tensor([0.])
# batch number: 10
# date: 180330
# recording: 006
# window: win34
# label (move = 0, sleep = 1): tensor([1.])

# %%
input_size = 1000 #(10x100)
num_classes = 1
learning_rate = 0.001
num_epochs = 100

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
def train(loader, epoch):
    model.train()
    batch_losses = []
    preds = []
    labs = []
    
    correct = 0
    total = 0
    
    for batch_idx, (data, labels, date, rec, win) in enumerate(loader):
        data = data.to(device)
        labels = labels.to(device).float()
        
        if (torch.isinf(data).any()) or (torch.isnan(data).any()):
            continue
#         if batch_idx % 50 == 0 and epoch == 0:
#             print('Showing Train Images')
#             print('batch number: '+str(batch_idx))
#             print('label (move = 0, sleep = 1): ' +str(labels[0]))
#             plt.figure(figsize=(15,10))
#             for channel in range(62):
#                 plt.subplot(2,32,channel+1)
#                 plt.imshow(data[0][channel].cpu().detach().numpy())
#                 if (channel != 0) and (channel != 32):
#                     plt.axis('off')
#             plt.show()
        
        optimizer.zero_grad()
    
        output, conv1, conv2 = model(data)
        loss = criterion(output.reshape(output.shape[0],-1), labels)
        
        loss.backward()
        optimizer.step()
        
        batch_losses.append(loss)
        
        predictions = []
        for o in output:
            if o.item() > .5:
                predictions.append(1)
            else:
                predictions.append(0)
        predictions = np.array(predictions)
        total += labels.size(0)
        correct += (predictions.flatten() == labels.flatten().cpu().numpy()).sum().item()
        preds.append(predictions.flatten())
        labs.append(labels.flatten().cpu().numpy())
        
    
    epoch_loss = sum(batch_losses)/len(batch_losses)
    accuracy = correct / total
    
    return epoch_loss, accuracy, preds, labs

# %%
def test(loader, epoch):
    model.eval()
    batch_losses = []
    preds = []
    labs = []
    
    correct = 0
    total = 0
    
    with torch.no_grad():
        for batch_idx, (data, labels, date, rec, win) in enumerate(loader):
            data = data.to(device)
            labels = labels.to(device).float().flatten()
            
            if (torch.isinf(data).any()) or (torch.isnan(data).any()):
                continue
#             if batch_idx % 10 == 0 and epoch == 0:
#                 print('Showing Val Images')
#                 print('Showing Train Images')
#                 print('batch number: '+str(batch_idx))
#                 print('label (move = 0, sleep = 1): ' +str(labels[0]))
#                 plt.figure(figsize=(15,10))
#                 for channel in range(62):
#                     plt.subplot(2,32,channel+1)
#                     plt.imshow(data[0][channel].cpu().detach().numpy())
#                     if (channel != 0) and (channel != 32):
#                         plt.axis('off')
#                 plt.show()
            
            output, conv1, conv2 = model(data)
            loss = criterion(output, labels)
            
            batch_losses.append(loss)
            
            #get accuracy
            predictions = []
            for o in output:
                if o.item() > .5:
                    predictions.append(1)
                else:
                    predictions.append(0)
            predictions = np.array(predictions)
            total += labels.size(0)
            correct += (predictions.flatten() == labels.flatten().cpu().numpy()).sum().item()
            preds.append(predictions.flatten())
            labs.append(labels.flatten().cpu().numpy())
        
        epoch_loss = sum(batch_losses)/len(batch_losses)
        accuracy = correct/total
        
        return epoch_loss, accuracy, preds, labs

# %% [markdown]
# # Standard 4 layer CNN

# %%
class CNNsplit(nn.Module):
    def __init__(self, in_channels = 1, num_classes = 1):
        super(CNNsplit, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=2, kernel_size=(3,3), stride = (1,1), padding = (1,1))
        self.conv2 = nn.Conv2d(in_channels=2, out_channels=4, kernel_size=(3,3), stride = (1,1), padding = (1,1))
        self.conv3 = nn.Conv2d(in_channels=4, out_channels=8, kernel_size=(3,3), stride = (1,1), padding = (1,1))
        self.conv4 = nn.Conv2d(in_channels=8, out_channels=16, kernel_size=(3,3), stride = (1,1), padding = (1,1))
        self.fc1 = nn.Linear(16*10*100, num_classes)
#         self.fc1 = nn.Linear(4*10*100, num_classes)
        self.sigmoid = nn.Sigmoid()
        
    def forward(self, x, verbose=True):
        x = x.float()
        x1 = relu(self.conv1(x))
        x2 = relu(self.conv2(x1))
        x = relu(self.conv3(x2))
        x = relu(self.conv4(x))
        x = x.reshape(x.shape[0], -1)
        x = self.fc1(x).flatten()
        x = self.sigmoid(x)
        return x, x1, x2

# %%
model = CNNsplit().to(device)
# model.apply(weight_reset)

criterion = nn.BCELoss()
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)

training_losses = []
val_losses = []
training_acc = []
val_acc = []

train_predictions = []
validation_predictions = []
train_labels = []
validation_labels = []

for epoch in range(num_epochs):
    avg_train_loss, train_accuracy, train_preds, train_labs = train(train_loader, epoch)
    print('Train loss for epoch {}: {}'.format(epoch, avg_train_loss))
    val_loss, val_accuracy, val_preds, val_labels = test(val_loader, epoch)
    print('Val loss for epoch {}: {}'.format(epoch, val_loss))
    
    training_losses.append(avg_train_loss)
    training_acc.append(train_accuracy)
    val_losses.append(val_loss)
    val_acc.append(val_accuracy)
    
    train_predictions.append(train_preds)
    train_labels.append(train_labs)
    validation_predictions.append(val_preds)
    validation_labels.append(val_labels)
# Out:
# Train loss for epoch 0: 0.38057178258895874
# Val loss for epoch 0: 0.3042348027229309
# Train loss for epoch 1: 0.2951835095882416
# Val loss for epoch 1: 0.28504860401153564
# Train loss for epoch 2: 0.2847864329814911
# Val loss for epoch 2: 0.27813535928726196
# Train loss for epoch 3: 0.27185723185539246
# Val loss for epoch 3: 0.2830732464790344
# Train loss for epoch 4: 0.2724282145500183
# Val loss for epoch 4: 0.32654765248298645
# Train loss for epoch 5: 0.26151877641677856
# Val loss for epoch 5: 0.27628621459007263
# Train loss for epoch 6: 0.2549540400505066
# Val loss for epoch 6: 0.262839138507843
# Train loss for epoch 7: 0.25850269198417664
# Val loss for epoch 7: 0.2676328420639038
# Train loss for epoch 8: 0.25316566228866577
# Val loss for epoch 8: 0.2594459056854248
# Train loss for epoch 9: 0.24748773872852325
# Val loss for epoch 9: 0.26257821917533875
# Train loss for epoch 10: 0.2474982887506485
# Val loss for epoch 10: 0.27781081199645996
# Train loss for epoch 11: 0.24656085669994354
# Val loss for epoch 11: 0.29255470633506775
# Train loss for epoch 12: 0.2398272603750229
# Val loss for epoch 12: 0.26719337701797485
# Train loss for epoch 13: 0.23726452887058258
# Val loss for epoch 13: 0.27041327953338623
# Train loss for epoch 14: 0.23338857293128967
# Val loss for epoch 14: 0.2548321485519409
# Train loss for epoch 15: 0.2378346025943756
# Val loss for epoch 15: 0.25760987401008606
# Train loss for epoch 16: 0.23596583306789398
# Val loss for epoch 16: 0.28202664852142334
# Train loss for epoch 17: 0.22755064070224762
# Val loss for epoch 17: 0.2604328989982605
# Train loss for epoch 18: 0.22533445060253143
# Val loss for epoch 18: 0.30816951394081116
# Train loss for epoch 19: 0.22492383420467377
# Val loss for epoch 19: 0.2821926474571228
# Train loss for epoch 20: 0.2203279733657837
# Val loss for epoch 20: 0.2653651237487793
# Train loss for epoch 21: 0.2311040312051773
# Val loss for epoch 21: 0.3056504726409912
# Train loss for epoch 22: 0.22082847356796265
# Val loss for epoch 22: 0.2648436725139618
# Train loss for epoch 23: 0.22425545752048492
# Val loss for epoch 23: 0.27439671754837036
# Train loss for epoch 24: 0.21219594776630402
# Val loss for epoch 24: 0.26108333468437195
# Train loss for epoch 25: 0.20926633477210999
# Val loss for epoch 25: 0.2711316645145416
# Train loss for epoch 26: 0.20573696494102478
# Val loss for epoch 26: 0.2770399749279022
# Train loss for epoch 27: 0.2019290030002594
# Val loss for epoch 27: 0.2826530337333679
# Train loss for epoch 28: 0.19973228871822357
# Val loss for epoch 28: 0.3141896426677704
# Train loss for epoch 29: 0.201112762093544
# Val loss for epoch 29: 0.2779892385005951
# Train loss for epoch 30: 0.19331105053424835
# Val loss for epoch 30: 0.32304564118385315
# Train loss for epoch 31: 0.18996721506118774
# Val loss for epoch 31: 0.2815403938293457
# Train loss for epoch 32: 0.19160956144332886
# Val loss for epoch 32: 0.2817994952201843
# Train loss for epoch 33: 0.18221013247966766
# Val loss for epoch 33: 0.29252833127975464
# Train loss for epoch 34: 0.181207075715065
# Val loss for epoch 69: 0.6543017625808716
# Train loss for epoch 70: 0.035525694489479065
# Val loss for epoch 70: 0.7624133825302124
# Train loss for epoch 71: 0.03155037760734558
# Val loss for epoch 71: 0.804002046585083
# Train loss for epoch 72: 0.03200514242053032
# Val loss for epoch 72: 0.8950209617614746
# Train loss for epoch 73: 0.026340346783399582
# Val loss for epoch 73: 0.8500018119812012
# Train loss for epoch 74: 0.02455374225974083
# Val loss for epoch 74: 0.8828949332237244
# Train loss for epoch 75: 0.02594606764614582
# Val loss for epoch 75: 1.0253512859344482
# Train loss for epoch 76: 0.047700684517621994
# Val loss for epoch 76: 0.8711930513381958
# Train loss for epoch 77: 0.019947145134210587
# Val loss for epoch 77: 0.9159757494926453
# Train loss for epoch 78: 0.012653489597141743
# Val loss for epoch 78: 1.1410199403762817
# Train loss for epoch 79: 0.01382490899413824
# Val loss for epoch 79: 1.0250766277313232
# Train loss for epoch 80: 0.009541654027998447
# Val loss for epoch 80: 1.1214494705200195
# Train loss for epoch 81: 0.009463843889534473
# Val loss for epoch 81: 1.194861888885498
# Train loss for epoch 82: 0.016069428995251656
# Val loss for epoch 82: 1.232168197631836
# Train loss for epoch 83: 0.04167775809764862
# Val loss for epoch 83: 1.1229887008666992
# Train loss for epoch 84: 0.01938634179532528
# Val loss for epoch 84: 1.2908941507339478
# Train loss for epoch 85: 0.008324428461492062
# Val loss for epoch 85: 1.4288309812545776
# Train loss for epoch 86: 0.0038621805142611265
# Val loss for epoch 86: 1.2603169679641724
# Train loss for epoch 87: 0.0030253417789936066
# Val loss for epoch 87: 1.3968966007232666
# Train loss for epoch 88: 0.0024822531268000603
# Val loss for epoch 88: 1.4084516763687134
# Train loss for epoch 89: 0.0020971866324543953
# Val loss for epoch 89: 1.5062681436538696
# Train loss for epoch 90: 0.002138542477041483
# Val loss for epoch 90: 1.5595860481262207
# Train loss for epoch 91: 0.0026456264313310385
# Val loss for epoch 91: 1.5678231716156006
# Train loss for epoch 92: 0.00204521045088768
# Val loss for epoch 92: 1.6623939275741577
# Train loss for epoch 93: 0.001615819986909628
# Val loss for epoch 93: 1.6422884464263916
# Train loss for epoch 94: 0.06179185211658478
# Val loss for epoch 94: 2.004373550415039
# Train loss for epoch 95: 0.08043791353702545
# Val loss for epoch 95: 1.3962801694869995
# Train loss for epoch 96: 0.016615545377135277
# Val loss for epoch 96: 1.349692940711975
# Train loss for epoch 97: 0.004479433875530958
# Val loss for epoch 97: 1.4318393468856812
# Train loss for epoch 98: 0.002335641300305724
# Val loss for epoch 98: 1.5043045282363892
# Train loss for epoch 99: 0.0017249769298359752
# Val loss for epoch 99: 1.6147023439407349

# %%
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.title("4 layer CNN", fontsize = 15)
plt.plot(training_losses[:-1],linewidth = 1.5,label = 'train')
plt.plot(val_losses[:-1],linewidth = 1.5,label = 'valid')
plt.xlabel("Epoch",fontsize = 15)
plt.ylabel("Loss", fontsize = 15)
plt.legend()
plt.subplot(1,2,2)
plt.title("4 layer CNN", fontsize = 15)
plt.plot(training_acc[:-1],linewidth = 1.5,label = 'train')
plt.plot(val_acc[:-1],linewidth = 1.5,label = 'valid')
plt.xlabel("Epoch",fontsize = 15)
plt.ylabel("Accuracy", fontsize = 15)
plt.legend()
plt.show()

# %%
for batch_idx, (data, labels, date, rec, win) in enumerate(train_loader):
    data = data.to(device)
    x, conv1, conv2 = model(data)
    break

# %%
weights = conv1[0]
# plt.figure(figsize=(30,90))
for i in range(2):
    weights_sub = weights[i].detach().cpu()
    plt.subplot(1,2,i+1)
    plt.imshow(weights_sub)
    plt.colorbar(orientation='vertical')
plt.show()

# %%
weights = conv2[0]
# plt.figure(figsize=(30,90))
for i in range(4):
    weights_sub = weights[i].detach().cpu()
    plt.subplot(1,4,i+1)
    plt.imshow(weights_sub)
    plt.colorbar(orientation='vertical')
plt.show()

# %% [markdown]
# # Smaller 2 layer CNN

# %%
class CNNsmall(nn.Module):
    def __init__(self, in_channels = 1, num_classes = 1):
        super(CNNsmall, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=2, kernel_size=(3,3), stride = (1,1), padding = (1,1))
        self.conv2 = nn.Conv2d(in_channels=2, out_channels=4, kernel_size=(3,3), stride = (1,1), padding = (1,1))
#         self.conv3 = nn.Conv2d(in_channels=4, out_channels=8, kernel_size=(3,3), stride = (1,1), padding = (1,1))
#         self.conv4 = nn.Conv2d(in_channels=8, out_channels=16, kernel_size=(3,3), stride = (1,1), padding = (1,1))
#         self.fc1 = nn.Linear(16*10*100, num_classes)
        self.fc1 = nn.Linear(4*10*100, num_classes)
        self.sigmoid = nn.Sigmoid()
        
    def forward(self, x, verbose=True):
        x = x.float()
        x1 = relu(self.conv1(x))
        x2 = relu(self.conv2(x1))
#         x = relu(self.conv3(x2))
#         x = relu(self.conv4(x))
        x = x2.reshape(x2.shape[0], -1)
        x = self.fc1(x).flatten()
        x = self.sigmoid(x)
        return x, x1, x2

# %%
input_size = 1000 #(10x100)
num_classes = 1
learning_rate = 0.001
num_epochs = 100

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
model = CNNsmall().to(device)
# model.apply(weight_reset)

criterion = nn.BCELoss()
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)

training_losses = []
val_losses = []
training_acc = []
val_acc = []

train_predictions = []
validation_predictions = []
train_labels = []
validation_labels = []

for epoch in range(num_epochs):
    avg_train_loss, train_accuracy, train_preds, train_labs = train(train_loader, epoch)
    print('Train loss for epoch {}: {}'.format(epoch, avg_train_loss))
    val_loss, val_accuracy, val_preds, val_labels = test(val_loader, epoch)
    print('Val loss for epoch {}: {}'.format(epoch, val_loss))
    
    training_losses.append(avg_train_loss)
    training_acc.append(train_accuracy)
    val_losses.append(val_loss)
    val_acc.append(val_accuracy)
    
    train_predictions.append(train_preds)
    train_labels.append(train_labs)
    validation_predictions.append(val_preds)
    validation_labels.append(val_labels)
# Out:
# Train loss for epoch 0: 0.41937386989593506
# Val loss for epoch 0: 0.36998236179351807
# Train loss for epoch 1: 0.35178670287132263
# Val loss for epoch 1: 0.3731915056705475
# Train loss for epoch 2: 0.3268134593963623
# Val loss for epoch 2: 0.38732200860977173
# Train loss for epoch 3: 0.31799373030662537
# Val loss for epoch 3: 0.31373295187950134
# Train loss for epoch 4: 0.3134460151195526
# Val loss for epoch 4: 0.30514025688171387
# Train loss for epoch 5: 0.3067474067211151
# Val loss for epoch 5: 0.29864126443862915
# Train loss for epoch 6: 0.2998184561729431
# Val loss for epoch 6: 0.4020896255970001
# Train loss for epoch 7: 0.2949543297290802
# Val loss for epoch 7: 0.289341002702713
# Train loss for epoch 8: 0.28358030319213867
# Val loss for epoch 8: 0.36386343836784363
# Train loss for epoch 9: 0.2829623818397522
# Val loss for epoch 9: 0.33086061477661133
# Train loss for epoch 10: 0.27410849928855896
# Val loss for epoch 10: 0.3052598237991333
# Train loss for epoch 11: 0.2747226357460022
# Val loss for epoch 11: 0.2770199775695801
# Train loss for epoch 12: 0.27183905243873596
# Val loss for epoch 12: 0.2791360020637512
# Train loss for epoch 13: 0.26239192485809326
# Val loss for epoch 13: 0.3087387979030609
# Train loss for epoch 14: 0.2614888846874237
# Val loss for epoch 14: 0.2810143828392029
# Train loss for epoch 15: 0.2580316662788391
# Val loss for epoch 15: 0.27248743176460266
# Train loss for epoch 16: 0.2542802393436432
# Val loss for epoch 16: 0.2694045305252075
# Train loss for epoch 17: 0.25073370337486267
# Val loss for epoch 17: 0.29255080223083496
# Train loss for epoch 18: 0.24857047200202942
# Val loss for epoch 18: 0.26434648036956787
# Train loss for epoch 19: 0.24849021434783936
# Val loss for epoch 19: 0.377494752407074
# Train loss for epoch 20: 0.24570178985595703
# Val loss for epoch 20: 0.3195748031139374
# Train loss for epoch 21: 0.24513936042785645
# Val loss for epoch 21: 0.29144319891929626
# Train loss for epoch 22: 0.23886756598949432
# Val loss for epoch 22: 0.2714728116989136
# Train loss for epoch 23: 0.23589426279067993
# Val loss for epoch 23: 0.30982446670532227
# Train loss for epoch 24: 0.23680385947227478
# Val loss for epoch 24: 0.2854975461959839
# Train loss for epoch 25: 0.23425722122192383
# Val loss for epoch 25: 0.3082173764705658
# Train loss for epoch 26: 0.2312117964029312
# Val loss for epoch 26: 0.26951977610588074
# Train loss for epoch 27: 0.22930416464805603
# Val loss for epoch 27: 0.27130818367004395
# Train loss for epoch 28: 0.22801360487937927
# Val loss for epoch 28: 0.298249751329422
# Train loss for epoch 29: 0.22689472138881683
# Val loss for epoch 29: 0.2836051285266876
# Train loss for epoch 30: 0.22160957753658295
# Val loss for epoch 30: 0.28314703702926636
# Train loss for epoch 31: 0.2226080745458603
# Val loss for epoch 31: 0.27166399359703064
# Train loss for epoch 32: 0.2179623693227768
# Val loss for epoch 32: 0.2781888544559479
# Train loss for epoch 33: 0.21832948923110962
# Val loss for epoch 33: 0.30052265524864197
# Train loss for epoch 34: 0.21468761563301086
# Val loss for epoch 34: 0.27545419335365295
# Train loss for epoch 35: 0.2139872908592224
# Val loss for epoch 35: 0.3194604218006134
# Train loss for epoch 36: 0.2110496610403061
# Val loss for epoch 36: 0.2835109829902649
# Train loss for epoch 37: 0.21185201406478882
# Val loss for epoch 37: 0.3003557026386261
# Train loss for epoch 38: 0.2066788524389267
# Val loss for epoch 38: 0.29485276341438293
# Train loss for epoch 39: 0.20882496237754822
# Val loss for epoch 39: 0.2956387400627136
# Train loss for epoch 40: 0.20553767681121826
# Val loss for epoch 40: 0.34909528493881226
# Train loss for epoch 41: 0.20291075110435486
# Val loss for epoch 41: 0.28357958793640137
# Train loss for epoch 42: 0.20268572866916656
# Val loss for epoch 42: 0.2873164117336273
# Train loss for epoch 43: 0.20087844133377075
# Val loss for epoch 43: 0.29334115982055664
# Train loss for epoch 44: 0.19874979555606842
# Val loss for epoch 44: 0.3541598916053772
# Train loss for epoch 45: 0.19857650995254517
# Val loss for epoch 45: 0.33482471108436584
# Train loss for epoch 46: 0.19521987438201904
# Val loss for epoch 46: 0.31696686148643494
# Train loss for epoch 47: 0.1982734650373459
# Val loss for epoch 47: 0.29807111620903015
# Train loss for epoch 48: 0.1919352412223816
# Val loss for epoch 48: 0.31221482157707214
# Train loss for epoch 49: 0.18973349034786224
# Val loss for epoch 49: 0.35734304785728455
# Train loss for epoch 50: 0.1914278268814087
# Val loss for epoch 50: 0.3250158429145813
# Train loss for epoch 51: 0.18969415128231049
# Val loss for epoch 51: 0.3163268566131592
# Train loss for epoch 52: 0.18667280673980713
# Val loss for epoch 52: 0.3218473792076111
# Train loss for epoch 53: 0.18577603995800018
# Val loss for epoch 53: 0.33535024523735046
# Train loss for epoch 54: 0.1851816475391388
# Val loss for epoch 54: 0.3431619107723236
# Train loss for epoch 55: 0.18075120449066162
# Val loss for epoch 55: 0.3386852741241455
# Train loss for epoch 56: 0.17807485163211823
# Val loss for epoch 56: 0.38501831889152527
# Train loss for epoch 57: 0.1782088279724121
# Val loss for epoch 57: 0.33676114678382874
# Train loss for epoch 58: 0.1806579977273941
# Val loss for epoch 58: 0.34614697098731995
# Train loss for epoch 59: 0.1826123148202896
# Val loss for epoch 59: 0.3607628047466278
# Train loss for epoch 60: 0.1767556220293045
# Val loss for epoch 60: 0.3317670226097107
# Train loss for epoch 61: 0.17358869314193726
# Val loss for epoch 61: 0.3396526575088501
# Train loss for epoch 62: 0.1740458905696869
# Val loss for epoch 62: 0.33189550042152405
# Train loss for epoch 63: 0.17067714035511017
# Val loss for epoch 63: 0.3540474474430084
# Train loss for epoch 64: 0.17560964822769165
# Val loss for epoch 64: 0.32742542028427124
# Train loss for epoch 65: 0.1711554080247879
# Val loss for epoch 65: 0.3851775527000427
# Train loss for epoch 66: 0.18183869123458862
# Val loss for epoch 66: 0.3271329402923584
# Train loss for epoch 67: 0.16800326108932495
# Val loss for epoch 67: 0.32075151801109314
# Train loss for epoch 68: 0.1659824252128601
# Val loss for epoch 68: 0.32895979285240173
# Train loss for epoch 69: 0.16434741020202637
# Val loss for epoch 69: 0.32009971141815186
# Train loss for epoch 70: 0.1611376851797104
# Val loss for epoch 70: 0.3156154751777649
# Train loss for epoch 71: 0.1656304895877838
# Val loss for epoch 71: 0.3221481442451477
# Train loss for epoch 72: 0.163791686296463
# Val loss for epoch 72: 0.323796808719635
# Train loss for epoch 73: 0.1611783355474472
# Val loss for epoch 73: 0.33913153409957886
# Train loss for epoch 74: 0.16099177300930023
# Val loss for epoch 74: 0.36300739645957947
# Train loss for epoch 75: 0.1570257544517517
# Val loss for epoch 75: 0.36453279852867126
# Train loss for epoch 76: 0.15372873842716217
# Val loss for epoch 76: 0.32420554757118225
# Train loss for epoch 77: 0.15234293043613434
# Val loss for epoch 77: 0.3934558033943176
# Train loss for epoch 78: 0.15120427310466766
# Val loss for epoch 78: 0.34646275639533997
# Train loss for epoch 79: 0.15284870564937592
# Val loss for epoch 79: 0.3673340380191803
# Train loss for epoch 80: 0.1521650105714798
# Val loss for epoch 80: 0.40234577655792236
# Train loss for epoch 81: 0.15103349089622498
# Val loss for epoch 81: 0.34115996956825256
# Train loss for epoch 82: 0.1494533121585846
# Val loss for epoch 82: 0.3405766487121582
# Train loss for epoch 83: 0.14829842746257782
# Val loss for epoch 83: 0.3451691269874573
# Train loss for epoch 84: 0.1498105823993683
# Val loss for epoch 84: 0.3508501648902893
# Train loss for epoch 85: 0.14470265805721283
# Val loss for epoch 85: 0.3923994302749634
# Train loss for epoch 86: 0.1461898535490036
# Val loss for epoch 86: 0.37761178612709045
# Train loss for epoch 87: 0.13943377137184143
# Val loss for epoch 87: 0.42487671971321106
# Train loss for epoch 88: 0.13958832621574402
# Val loss for epoch 88: 0.37282881140708923
# Train loss for epoch 89: 0.13973204791545868
# Val loss for epoch 89: 0.40836119651794434
# Train loss for epoch 90: 0.1379065364599228
# Val loss for epoch 90: 0.41411182284355164
# Train loss for epoch 91: 0.13831022381782532
# Val loss for epoch 91: 0.4624841511249542
# Train loss for epoch 92: 0.1365046203136444
# Val loss for epoch 92: 0.38017475605010986
# Train loss for epoch 93: 0.14135509729385376
# Val loss for epoch 93: 0.3677158057689667
# Train loss for epoch 94: 0.1383826583623886
# Val loss for epoch 94: 0.4610651433467865
# Train loss for epoch 95: 0.13363191485404968
# Val loss for epoch 95: 0.3839316666126251
# Train loss for epoch 96: 0.13014379143714905
# Val loss for epoch 96: 0.3769066035747528
# Train loss for epoch 97: 0.13021999597549438
# Val loss for epoch 97: 0.4203518033027649
# Train loss for epoch 98: 0.1283012181520462
# Val loss for epoch 98: 0.37735122442245483
# Train loss for epoch 99: 0.12721173465251923
# Val loss for epoch 99: 0.43303120136260986

# %%
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.title("2 layer CNN", fontsize = 15)
plt.plot(training_losses[:-1],linewidth = 1.5,label = 'train')
plt.plot(val_losses[:-1],linewidth = 1.5,label = 'valid')
plt.xlabel("Epoch",fontsize = 15)
plt.ylabel("Loss", fontsize = 15)
plt.legend()
plt.subplot(1,2,2)
plt.title("2 layer CNN", fontsize = 15)
plt.plot(training_acc[:-1],linewidth = 1.5,label = 'train')
plt.plot(val_acc[:-1],linewidth = 1.5,label = 'valid')
plt.xlabel("Epoch",fontsize = 15)
plt.ylabel("Accuracy", fontsize = 15)
plt.legend()
plt.show()

# %%
for batch_idx, (data, labels, date, rec, win) in enumerate(train_loader):
    data = data.to(device)
    x, conv1, conv2 = model(data)
    break

# %%
weights = conv1[0]
# plt.figure(figsize=(30,90))
for i in range(2):
    weights_sub = weights[i].detach().cpu()
    plt.subplot(1,2,i+1)
    plt.imshow(weights_sub)
    plt.colorbar(orientation='vertical')
plt.show()

weights = conv2[0]
# plt.figure(figsize=(30,90))
for i in range(4):
    weights_sub = weights[i].detach().cpu()
    plt.subplot(1,4,i+1)
    plt.imshow(weights_sub)
    plt.colorbar(orientation='vertical')
plt.show()

# %% [markdown]
# # MLP

# %%
class MLP(nn.Module):
    def __init__(self, num_classes = 1):
        super(MLP, self).__init__()
        self.fc1 = nn.Linear(100*10, 200)
#         self.dropout = nn.Dropout(0.5)
        self.fc2 = nn.Linear(200, num_classes)
        self.sigmoid = nn.Sigmoid()
        
    def forward(self, x, verbose=True):
        x = x.float().reshape(x.shape[0], -1)
        x1 = relu(self.fc1(x))
#         x = self.dropout(x)
        x2 = self.fc2(x1).flatten()
        x = self.sigmoid(x2)
        return x, x1, x2

# %%
model = MLP().to(device)
# model.apply(weight_reset)

criterion = nn.BCELoss()
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)

training_losses = []
val_losses = []
training_acc = []
val_acc = []

train_predictions = []
validation_predictions = []
train_labels = []
validation_labels = []

for epoch in range(num_epochs):
    avg_train_loss, train_accuracy, train_preds, train_labs = train(train_loader, epoch)
    print('Train loss for epoch {}: {}'.format(epoch, avg_train_loss))
    val_loss, val_accuracy, val_preds, val_labels = test(val_loader, epoch)
    print('Val loss for epoch {}: {}'.format(epoch, val_loss))
    
    training_losses.append(avg_train_loss)
    training_acc.append(train_accuracy)
    val_losses.append(val_loss)
    val_acc.append(val_accuracy)
    
    train_predictions.append(train_preds)
    train_labels.append(train_labs)
    validation_predictions.append(val_preds)
    validation_labels.append(val_labels)
# Out:
# Train loss for epoch 0: 0.351389616727829
# Val loss for epoch 0: 0.35477524995803833
# Train loss for epoch 1: 0.2985493838787079
# Val loss for epoch 1: 0.2987966239452362
# Train loss for epoch 2: 0.2842399775981903
# Val loss for epoch 2: 0.27245521545410156
# Train loss for epoch 3: 0.27603593468666077
# Val loss for epoch 3: 0.2884346544742584
# Train loss for epoch 4: 0.266607403755188
# Val loss for epoch 4: 0.3210833966732025
# Train loss for epoch 5: 0.2604256272315979
# Val loss for epoch 5: 0.298595130443573
# Train loss for epoch 6: 0.2611907422542572
# Val loss for epoch 6: 0.31134048104286194
# Train loss for epoch 7: 0.25345611572265625
# Val loss for epoch 7: 0.256839394569397
# Train loss for epoch 8: 0.25571054220199585
# Val loss for epoch 8: 0.26954129338264465
# Train loss for epoch 9: 0.2525424361228943
# Val loss for epoch 9: 0.29652169346809387
# Train loss for epoch 10: 0.24801984429359436
# Val loss for epoch 10: 0.24762219190597534
# Train loss for epoch 11: 0.24303653836250305
# Val loss for epoch 11: 0.2690475583076477
# Train loss for epoch 12: 0.23901748657226562
# Val loss for epoch 12: 0.2724834084510803
# Train loss for epoch 13: 0.23978736996650696
# Val loss for epoch 13: 0.2774295508861542
# Train loss for epoch 14: 0.24167907238006592
# Val loss for epoch 14: 0.29089245200157166
# Train loss for epoch 15: 0.2351939082145691
# Val loss for epoch 15: 0.2989027798175812
# Train loss for epoch 16: 0.23483657836914062
# Val loss for epoch 16: 0.2834060788154602
# Train loss for epoch 17: 0.22984188795089722
# Val loss for epoch 17: 0.3624282479286194
# Train loss for epoch 18: 0.23290319740772247
# Val loss for epoch 18: 0.2678471803665161
# Train loss for epoch 19: 0.23080481588840485
# Val loss for epoch 19: 0.27993109822273254
# Train loss for epoch 20: 0.22888557612895966
# Val loss for epoch 20: 0.2655743658542633
# Train loss for epoch 21: 0.22993287444114685
# Val loss for epoch 21: 0.2660691738128662
# Train loss for epoch 22: 0.23301053047180176
# Val loss for epoch 22: 0.29334086179733276
# Train loss for epoch 23: 0.22453106939792633
# Val loss for epoch 23: 0.26010775566101074
# Train loss for epoch 24: 0.22734983265399933
# Val loss for epoch 24: 0.266713947057724
# Train loss for epoch 25: 0.22270649671554565
# Val loss for epoch 25: 0.2634788751602173
# Train loss for epoch 26: 0.2229325920343399
# Val loss for epoch 26: 0.26646360754966736
# Train loss for epoch 27: 0.2198467254638672
# Val loss for epoch 27: 0.27452418208122253
# Train loss for epoch 28: 0.22660624980926514
# Val loss for epoch 28: 0.3462893068790436
# Train loss for epoch 29: 0.221403107047081
# Val loss for epoch 29: 0.26681390404701233
# Train loss for epoch 30: 0.21650800108909607
# Val loss for epoch 30: 0.26202070713043213
# Train loss for epoch 31: 0.22311361134052277
# Val loss for epoch 31: 0.3002172112464905
# Train loss for epoch 32: 0.2231518030166626
# Val loss for epoch 32: 0.2734551727771759
# Train loss for epoch 33: 0.2192041277885437
# Val loss for epoch 33: 0.2611730992794037
# Train loss for epoch 34: 0.21777954697608948
# Val loss for epoch 34: 0.2643223702907562
# Train loss for epoch 35: 0.22076785564422607
# Val loss for epoch 35: 0.2953481376171112
# Train loss for epoch 36: 0.21228712797164917
# Val loss for epoch 36: 0.25769317150115967
# Train loss for epoch 37: 0.21252916753292084
# Val loss for epoch 37: 0.2707780599594116
# Train loss for epoch 38: 0.22285641729831696
# Val loss for epoch 38: 0.26723718643188477
# Train loss for epoch 39: 0.21914198994636536
# Val loss for epoch 39: 0.27500152587890625
# Train loss for epoch 40: 0.21496818959712982
# Val loss for epoch 40: 0.2635662257671356
# Train loss for epoch 41: 0.21227173507213593
# Val loss for epoch 41: 0.28227201104164124
# Train loss for epoch 42: 0.2107919305562973
# Val loss for epoch 42: 0.3970000147819519
# Train loss for epoch 43: 0.21429002285003662
# Val loss for epoch 43: 0.2547959089279175
# Train loss for epoch 44: 0.24528264999389648
# Val loss for epoch 44: 0.2611209750175476
# Train loss for epoch 45: 0.23513630032539368
# Val loss for epoch 45: 0.25109225511550903
# Train loss for epoch 46: 0.2306000292301178
# Val loss for epoch 46: 0.27375221252441406
# Train loss for epoch 47: 0.2287033051252365
# Val loss for epoch 47: 0.2789643108844757
# Train loss for epoch 48: 0.2363591194152832
# Val loss for epoch 48: 0.2698482871055603
# Train loss for epoch 49: 0.2361767292022705
# Val loss for epoch 49: 0.31324300169944763
# Train loss for epoch 50: 0.22990289330482483
# Val loss for epoch 50: 0.26017460227012634
# Train loss for epoch 51: 0.224116712808609
# Val loss for epoch 51: 0.266968309879303
# Train loss for epoch 52: 0.22772632539272308
# Val loss for epoch 52: 0.27169525623321533
# Train loss for epoch 53: 0.224180668592453
# Val loss for epoch 53: 0.28087082505226135
# Train loss for epoch 54: 0.22361119091510773
# Val loss for epoch 54: 0.2849022448062897
# Train loss for epoch 55: 0.22461889684200287
# Val loss for epoch 55: 0.2705908417701721
# Train loss for epoch 56: 0.2257816195487976
# Val loss for epoch 56: 0.26582878828048706
# Train loss for epoch 57: 0.22493886947631836
# Val loss for epoch 57: 0.26484420895576477
# Train loss for epoch 58: 0.22375763952732086
# Val loss for epoch 58: 0.27200058102607727
# Train loss for epoch 59: 0.22707140445709229
# Val loss for epoch 59: 0.27616170048713684
# Train loss for epoch 60: 0.22056791186332703
# Val loss for epoch 60: 0.2708166241645813
# Train loss for epoch 61: 0.2207569181919098
# Val loss for epoch 61: 0.31069615483283997
# Train loss for epoch 62: 0.22094373404979706
# Val loss for epoch 62: 0.2860110104084015
# Train loss for epoch 63: 0.22133466601371765
# Val loss for epoch 63: 0.2552497088909149
# Train loss for epoch 64: 0.21861551702022552
# %%
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.title("MLP", fontsize = 15)
plt.plot(training_losses[:-1],linewidth = 1.5,label = 'train')
plt.plot(val_losses[:-1],linewidth = 1.5,label = 'valid')
plt.xlabel("Epoch",fontsize = 15)
plt.ylabel("Loss", fontsize = 15)
plt.legend()
plt.subplot(1,2,2)
plt.title("MLP", fontsize = 15)
plt.plot(training_acc[:-1],linewidth = 1.5,label = 'train')
plt.plot(val_acc[:-1],linewidth = 1.5,label = 'valid')
plt.xlabel("Epoch",fontsize = 15)
plt.ylabel("Accuracy", fontsize = 15)
plt.legend()
plt.show()

# %%
for batch_idx, (data, labels, date, rec, win) in enumerate(train_loader):
    data = data.to(device)
    x, lin1, lin2 = model(data)
    break

# %%
lin1.shape
# Out:
# torch.Size([16, 200])

# %%
plt.imshow(lin1.detach().cpu())
plt.colorbar(orientation='vertical')
plt.show()

# %% [markdown]
# # MLP With Dropout Regularization

# %%
class MLPreg(nn.Module):
    def __init__(self, num_classes = 1):
        super(MLPreg, self).__init__()
        self.fc1 = nn.Linear(100*10, 200)
        self.dropout = nn.Dropout(0.5)
        self.fc2 = nn.Linear(200, num_classes)
        self.sigmoid = nn.Sigmoid()
        
    def forward(self, x, verbose=True):
        x = x.float().reshape(x.shape[0], -1)
        x1 = relu(self.fc1(x))
        x1 = self.dropout(x1)
        x2 = self.fc2(x1).flatten()
        x = self.sigmoid(x2)
        return x, x1, x2

# %%
model = MLPreg().to(device)
# model.apply(weight_reset)

criterion = nn.BCELoss()
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)

training_losses = []
val_losses = []
training_acc = []
val_acc = []

train_predictions = []
validation_predictions = []
train_labels = []
validation_labels = []

for epoch in range(num_epochs):
    avg_train_loss, train_accuracy, train_preds, train_labs = train(train_loader, epoch)
    print('Train loss for epoch {}: {}'.format(epoch, avg_train_loss))
    val_loss, val_accuracy, val_preds, val_labels = test(val_loader, epoch)
    print('Val loss for epoch {}: {}'.format(epoch, val_loss))
    
    training_losses.append(avg_train_loss)
    training_acc.append(train_accuracy)
    val_losses.append(val_loss)
    val_acc.append(val_accuracy)
    
    train_predictions.append(train_preds)
    train_labels.append(train_labs)
    validation_predictions.append(val_preds)
    validation_labels.append(val_labels)
# Out:
# Train loss for epoch 0: 0.3772211968898773
# Val loss for epoch 0: 0.3278123736381531
# Train loss for epoch 1: 0.3258798122406006
# Val loss for epoch 1: 0.30433499813079834
# Train loss for epoch 2: 0.3204501271247864
# Val loss for epoch 2: 0.29887983202934265
# Train loss for epoch 3: 0.3133679926395416
# Val loss for epoch 3: 0.31950506567955017
# Train loss for epoch 4: 0.31834959983825684
# Val loss for epoch 4: 0.34759625792503357
# Train loss for epoch 5: 0.30670642852783203
# Val loss for epoch 5: 0.3211531341075897
# Train loss for epoch 6: 0.2908598780632019
# Val loss for epoch 6: 0.28400465846061707
# Train loss for epoch 7: 0.30739960074424744
# Val loss for epoch 7: 0.32486963272094727
# Train loss for epoch 8: 0.29694539308547974
# Val loss for epoch 8: 0.28444939851760864
# Train loss for epoch 9: 0.2874487638473511
# Val loss for epoch 9: 0.3225998878479004
# Train loss for epoch 10: 0.2899821698665619
# Val loss for epoch 10: 0.2800253927707672
# Train loss for epoch 11: 0.28766584396362305
# Val loss for epoch 11: 0.287570595741272
# Train loss for epoch 12: 0.2853001654148102
# Val loss for epoch 12: 0.2633260190486908
# Train loss for epoch 13: 0.2778227925300598
# Val loss for epoch 13: 0.32963383197784424
# Train loss for epoch 14: 0.28291016817092896
# Val loss for epoch 14: 0.2652963399887085
# Train loss for epoch 15: 0.27595359086990356
# Val loss for epoch 15: 0.25902244448661804
# Train loss for epoch 16: 0.26983290910720825
# Val loss for epoch 16: 0.2900719940662384
# Train loss for epoch 17: 0.2761750817298889
# Val loss for epoch 17: 0.2588699460029602
# Train loss for epoch 18: 0.27404487133026123
# Val loss for epoch 18: 0.29133304953575134
# Train loss for epoch 19: 0.27112701535224915
# Val loss for epoch 19: 0.27095717191696167
# Train loss for epoch 20: 0.2763580083847046
# Val loss for epoch 20: 0.31240829825401306
# Train loss for epoch 21: 0.27161523699760437
# Val loss for epoch 21: 0.27395108342170715
# Train loss for epoch 22: 0.2674790620803833
# Val loss for epoch 22: 0.26558709144592285
# Train loss for epoch 23: 0.2726614475250244
# Val loss for epoch 23: 0.2705424129962921
# Train loss for epoch 24: 0.26218363642692566
# Val loss for epoch 24: 0.25475266575813293
# Train loss for epoch 25: 0.2713068425655365
# Val loss for epoch 25: 0.27282220125198364
# Train loss for epoch 26: 0.2724038064479828
# Val loss for epoch 26: 0.276425838470459
# Train loss for epoch 27: 0.26310545206069946
# Val loss for epoch 27: 0.2594231069087982
# Train loss for epoch 28: 0.26920264959335327
# Val loss for epoch 28: 0.2652241587638855
# Train loss for epoch 29: 0.2654860317707062
# Val loss for epoch 29: 0.2638813555240631
# Train loss for epoch 30: 0.26780131459236145
# Val loss for epoch 30: 0.3059012293815613
# Train loss for epoch 31: 0.2715650200843811
# Val loss for epoch 31: 0.3337826430797577
# Train loss for epoch 32: 0.29096803069114685
# Val loss for epoch 32: 0.2864396572113037
# Train loss for epoch 33: 0.26258450746536255
# Val loss for epoch 33: 0.2843937575817108
# Train loss for epoch 34: 0.2590039372444153
# Val loss for epoch 34: 0.27928417921066284
# Train loss for epoch 35: 0.254574716091156
# Val loss for epoch 35: 0.2554284334182739
# Train loss for epoch 36: 0.26193785667419434
# Val loss for epoch 36: 0.2500711977481842
# Train loss for epoch 37: 0.2611737847328186
# Val loss for epoch 37: 0.2729528546333313
# Train loss for epoch 38: 0.26198968291282654
# Val loss for epoch 38: 0.30208128690719604
# Train loss for epoch 39: 0.25863081216812134
# Val loss for epoch 39: 0.2722792625427246
# Train loss for epoch 40: 0.25813403725624084
# Val loss for epoch 40: 0.26656296849250793
# Train loss for epoch 41: 0.2723659574985504
# Val loss for epoch 41: 0.27429860830307007
# Train loss for epoch 42: 0.25751909613609314
# Val loss for epoch 42: 0.25717371702194214
# Train loss for epoch 43: 0.2528402507305145
# Val loss for epoch 43: 0.26357629895210266
# Train loss for epoch 44: 0.2575216591358185
# Val loss for epoch 44: 0.26212576031684875
# Train loss for epoch 45: 0.2546485364437103
# Val loss for epoch 45: 0.2787669897079468
# Train loss for epoch 46: 0.26306357979774475
# Val loss for epoch 46: 0.2722127139568329
# Train loss for epoch 47: 0.2520955502986908
# Val loss for epoch 47: 0.2784293591976166
# Train loss for epoch 48: 0.2549957036972046
# Val loss for epoch 48: 0.25344911217689514
# Train loss for epoch 49: 0.25414925813674927
# Val loss for epoch 49: 0.28545427322387695
# Train loss for epoch 50: 0.2525671124458313
# Val loss for epoch 85: 0.27670150995254517
# Train loss for epoch 86: 0.2443147450685501
# Val loss for epoch 86: 0.2854221761226654
# Train loss for epoch 87: 0.2488328069448471
# Val loss for epoch 87: 0.2553345263004303
# Train loss for epoch 88: 0.2490282952785492
# Val loss for epoch 88: 0.27778029441833496
# Train loss for epoch 89: 0.24062490463256836
# Val loss for epoch 89: 0.2719600200653076
# Train loss for epoch 90: 0.2435094565153122
# Val loss for epoch 90: 0.2656734883785248
# Train loss for epoch 91: 0.24107904732227325
# Val loss for epoch 91: 0.26819631457328796
# Train loss for epoch 92: 0.2425982505083084
# Val loss for epoch 92: 0.28005194664001465
# Train loss for epoch 93: 0.2363545000553131
# Val loss for epoch 93: 0.2513471841812134
# Train loss for epoch 94: 0.23689386248588562
# Val loss for epoch 94: 0.2915271818637848
# Train loss for epoch 95: 0.24067211151123047
# Val loss for epoch 95: 0.26960474252700806
# Train loss for epoch 96: 0.242121621966362
# Val loss for epoch 96: 0.2626241445541382
# Train loss for epoch 97: 0.24833190441131592
# Val loss for epoch 97: 0.2653689682483673
# Train loss for epoch 98: 0.24029910564422607
# Val loss for epoch 98: 0.2706611454486847
# Train loss for epoch 99: 0.24227745831012726
# Val loss for epoch 99: 0.25383538007736206

# %%
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.title("MLP Regularized", fontsize = 15)
plt.plot(training_losses[:-1],linewidth = 1.5,label = 'train')
plt.plot(val_losses[:-1],linewidth = 1.5,label = 'valid')
plt.xlabel("Epoch",fontsize = 15)
plt.ylabel("Loss", fontsize = 15)
plt.legend()
plt.subplot(1,2,2)
plt.title("MLP Regularized", fontsize = 15)
plt.plot(training_acc[:-1],linewidth = 1.5,label = 'train')
plt.plot(val_acc[:-1],linewidth = 1.5,label = 'valid')
plt.xlabel("Epoch",fontsize = 15)
plt.ylabel("Accuracy", fontsize = 15)
plt.legend()
plt.show()

# %%
for batch_idx, (data, labels, date, rec, win) in enumerate(train_loader):
    data = data.to(device)
    x, lin1, lin2 = model(data)
    break

# %%
plt.imshow(lin1.detach().cpu())
plt.colorbar(orientation='vertical')
plt.show()

# %% [markdown]
# # MLP with Batchnorm

# %%
class MLPbatchnorm(nn.Module):
    def __init__(self, num_classes = 1):
        super(MLPbatchnorm, self).__init__()
        self.fc1 = nn.Linear(100*10, 200)
        self.batchnorm = nn.BatchNorm1d(200)
        self.fc2 = nn.Linear(200, num_classes)
        self.sigmoid = nn.Sigmoid()
        
    def forward(self, x, verbose=True):
        x = x.float().reshape(x.shape[0], -1)
        x1 = relu(self.fc1(x))
        x1 = self.batchnorm(x1)
        x2 = self.fc2(x1).flatten()
        x = self.sigmoid(x2)
        return x, x1, x2

# %%
model = MLPbatchnorm().to(device)
# model.apply(weight_reset)

criterion = nn.BCELoss()
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)

training_losses = []
val_losses = []
training_acc = []
val_acc = []

train_predictions = []
validation_predictions = []
train_labels = []
validation_labels = []

for epoch in range(num_epochs):
    avg_train_loss, train_accuracy, train_preds, train_labs = train(train_loader, epoch)
    print('Train loss for epoch {}: {}'.format(epoch, avg_train_loss))
    val_loss, val_accuracy, val_preds, val_labels = test(val_loader, epoch)
    print('Val loss for epoch {}: {}'.format(epoch, val_loss))
    
    training_losses.append(avg_train_loss)
    training_acc.append(train_accuracy)
    val_losses.append(val_loss)
    val_acc.append(val_accuracy)
    
    train_predictions.append(train_preds)
    train_labels.append(train_labs)
    validation_predictions.append(val_preds)
    validation_labels.append(val_labels)
# Out:
# Train loss for epoch 0: 0.32257983088493347
# Val loss for epoch 0: 0.308698832988739
# Train loss for epoch 1: 0.2981615364551544
# Val loss for epoch 1: 0.3285014033317566
# Train loss for epoch 2: 0.2925729751586914
# Val loss for epoch 2: 0.3121621608734131
# Train loss for epoch 3: 0.2851932942867279
# Val loss for epoch 3: 0.3011229634284973
# Train loss for epoch 4: 0.28767284750938416
# Val loss for epoch 4: 0.28711456060409546
# Train loss for epoch 5: 0.28226056694984436
# Val loss for epoch 5: 0.27578747272491455
# Train loss for epoch 6: 0.28806957602500916
# Val loss for epoch 6: 0.3050876259803772
# Train loss for epoch 7: 0.27524349093437195
# Val loss for epoch 7: 0.2786574065685272
# Train loss for epoch 8: 0.27174705266952515
# Val loss for epoch 8: 0.2649642825126648
# Train loss for epoch 9: 0.2837471067905426
# Val loss for epoch 9: 0.35710597038269043
# Train loss for epoch 10: 0.2842882573604584
# Val loss for epoch 10: 0.2818637788295746
# Train loss for epoch 11: 0.2825322151184082
# Val loss for epoch 11: 0.2887338399887085
# Train loss for epoch 12: 0.27013421058654785
# Val loss for epoch 12: 0.2680167555809021
# Train loss for epoch 13: 0.2637593150138855
# Val loss for epoch 13: 0.3298149108886719
# Train loss for epoch 14: 0.26682519912719727
# Val loss for epoch 14: 0.3918841481208801
# Train loss for epoch 15: 0.2682826519012451
# Val loss for epoch 15: 0.3053087294101715
# Train loss for epoch 16: 0.26048362255096436
# Val loss for epoch 16: 0.39229634404182434
# Train loss for epoch 17: 0.2630299925804138
# Val loss for epoch 17: 0.2729910910129547
# Train loss for epoch 18: 0.2593901753425598
# Val loss for epoch 18: 0.2889758050441742
# Train loss for epoch 19: 0.2580030858516693
# Val loss for epoch 19: 0.2924496829509735
# Train loss for epoch 20: 0.25130000710487366
# Val loss for epoch 20: 0.26227954030036926
# Train loss for epoch 21: 0.2520436942577362
# Val loss for epoch 21: 0.30909910798072815
# Train loss for epoch 22: 0.2626326084136963
# Val loss for epoch 22: 0.37201598286628723
# Train loss for epoch 23: 0.25309595465660095
# Val loss for epoch 23: 0.479416161775589
# Train loss for epoch 24: 0.2560917139053345
# Val loss for epoch 24: 0.3022654056549072
# Train loss for epoch 25: 0.2549898326396942
# Val loss for epoch 25: 0.2768356204032898
# Train loss for epoch 26: 0.2554536461830139
# Val loss for epoch 26: 0.425534725189209
# Train loss for epoch 27: 0.2593410015106201
# Val loss for epoch 27: 0.2794686555862427
# Train loss for epoch 28: 0.2622697055339813
# Val loss for epoch 28: 0.34023216366767883
# Train loss for epoch 29: 0.25057390332221985
# Val loss for epoch 29: 0.2739829421043396
# Train loss for epoch 30: 0.2573208212852478
# Val loss for epoch 30: 0.2869139015674591
# Train loss for epoch 31: 0.2673167288303375
# Val loss for epoch 31: 0.26834824681282043
# Train loss for epoch 32: 0.2582225203514099
# Val loss for epoch 32: 0.3199883997440338
# Train loss for epoch 33: 0.24120411276817322
# Val loss for epoch 33: 0.6028669476509094
# Train loss for epoch 34: 0.24657440185546875
# Val loss for epoch 34: 0.28664401173591614
# Train loss for epoch 35: 0.2560518980026245
# Val loss for epoch 35: 0.3245621919631958
# Train loss for epoch 36: 0.245011568069458
# Val loss for epoch 36: 0.2670007348060608
# Train loss for epoch 37: 0.24409201741218567
# Val loss for epoch 37: 0.2678980529308319
# Train loss for epoch 38: 0.25686293840408325
# Val loss for epoch 38: 0.2723669409751892
# Train loss for epoch 39: 0.2510165274143219
# Val loss for epoch 39: 0.2709398567676544
# Train loss for epoch 40: 0.25389596819877625
# Val loss for epoch 40: 0.26021912693977356
# Train loss for epoch 41: 0.25404366850852966
# Val loss for epoch 41: 0.25081366300582886
# Train loss for epoch 42: 0.25279128551483154
# Val loss for epoch 42: 0.2678670883178711
# Train loss for epoch 43: 0.25392213463783264
# Val loss for epoch 43: 0.2608557641506195
# Train loss for epoch 44: 0.24743203818798065
# Val loss for epoch 44: 0.25375568866729736
# Train loss for epoch 45: 0.23976565897464752
# Val loss for epoch 45: 0.36882853507995605
# Train loss for epoch 46: 0.2472161054611206
# Val loss for epoch 46: 0.26230958104133606
# Train loss for epoch 47: 0.2564906179904938
# Val loss for epoch 47: 0.3826128840446472
# Train loss for epoch 48: 0.2528664469718933
# Val loss for epoch 48: 0.25430408120155334
# Train loss for epoch 49: 0.24931088089942932
# Val loss for epoch 49: 0.3155512511730194
# Train loss for epoch 50: 0.23899996280670166
# Val loss for epoch 50: 0.2615654170513153
# Train loss for epoch 51: 0.23821434378623962
# Val loss for epoch 51: 0.2735268175601959
# Train loss for epoch 52: 0.24647736549377441
# Val loss for epoch 52: 0.2652050256729126
# Train loss for epoch 53: 0.2528343200683594
# Val loss for epoch 53: 0.26957279443740845
# Train loss for epoch 54: 0.2596418559551239
# Val loss for epoch 54: 0.29633161425590515
# Train loss for epoch 55: 0.2560601830482483
# Val loss for epoch 55: 0.2860143780708313
# Train loss for epoch 56: 0.2572231590747833
# Val loss for epoch 56: 0.2895417809486389
# Train loss for epoch 57: 0.2575382888317108
# Val loss for epoch 57: 0.2699234187602997
# Train loss for epoch 58: 0.24499370157718658
# Val loss for epoch 58: 0.2685808837413788
# Train loss for epoch 59: 0.25726181268692017
# Val loss for epoch 59: 0.44421494007110596
# Train loss for epoch 60: 0.2511706054210663
# Val loss for epoch 60: 0.2795005738735199
# Train loss for epoch 61: 0.24753205478191376
# Val loss for epoch 61: 0.25736382603645325
# Train loss for epoch 62: 0.24237561225891113
# Val loss for epoch 62: 0.2548670768737793
# Train loss for epoch 63: 0.2442508190870285
# Val loss for epoch 63: 0.2756606638431549
# Train loss for epoch 64: 0.2525528073310852
# Val loss for epoch 64: 0.2829985022544861
# Train loss for epoch 65: 0.24713006615638733
# Val loss for epoch 65: 0.2592323124408722
# Train loss for epoch 66: 0.24184392392635345
# Val loss for epoch 66: 0.3486030399799347
# Train loss for epoch 67: 0.23663753271102905
# Val loss for epoch 67: 0.2631041407585144
# Train loss for epoch 68: 0.2365482747554779
# Val loss for epoch 68: 0.28299960494041443
# Train loss for epoch 69: 0.2403494417667389
# Val loss for epoch 69: 0.282271146774292
# Train loss for epoch 70: 0.23661132156848907
# Val loss for epoch 70: 0.3120707869529724
# Train loss for epoch 71: 0.23907575011253357
# Val loss for epoch 71: 0.26339128613471985
# Train loss for epoch 72: 0.2302122414112091
# Val loss for epoch 72: 0.2698594629764557
# Train loss for epoch 73: 0.23516930639743805
# Val loss for epoch 73: 0.2747473120689392
# Train loss for epoch 74: 0.233393132686615
# Val loss for epoch 74: 0.26679909229278564
# Train loss for epoch 75: 0.23576092720031738
# Val loss for epoch 75: 0.3141445517539978
# Train loss for epoch 76: 0.23523648083209991
# Val loss for epoch 76: 0.2608017325401306
# Train loss for epoch 77: 0.2444574534893036
# Val loss for epoch 77: 0.3314743936061859
# Train loss for epoch 78: 0.22134532034397125
# Val loss for epoch 78: 0.26291197538375854
# Train loss for epoch 79: 0.23872339725494385
# Val loss for epoch 79: 0.3286653757095337
# Train loss for epoch 80: 0.23149210214614868
# Val loss for epoch 80: 0.2598989009857178
# Train loss for epoch 81: 0.2330688089132309
# Val loss for epoch 81: 0.2565622925758362
# Train loss for epoch 82: 0.23507869243621826
# Val loss for epoch 82: 0.28973743319511414
# Train loss for epoch 83: 0.22361595928668976
# Val loss for epoch 83: 0.26322436332702637
# Train loss for epoch 84: 0.23041042685508728
# Val loss for epoch 84: 0.2674434185028076
# Train loss for epoch 85: 0.2388676106929779
# Val loss for epoch 85: 0.26722991466522217
# Train loss for epoch 86: 0.24710305035114288
# Val loss for epoch 86: 0.2478030025959015
# Train loss for epoch 87: 0.2400168925523758
# Val loss for epoch 87: 0.24236498773097992
# Train loss for epoch 88: 0.23511338233947754
# Val loss for epoch 88: 0.2634744942188263
# Train loss for epoch 89: 0.24280595779418945
# Val loss for epoch 89: 0.281317800283432
# Train loss for epoch 90: 0.22984808683395386
# Val loss for epoch 90: 0.29322704672813416
# Train loss for epoch 91: 0.22904367744922638
# Val loss for epoch 91: 0.3288589417934418
# Train loss for epoch 92: 0.23069685697555542
# Val loss for epoch 92: 0.2521575689315796
# Train loss for epoch 93: 0.23611463606357574
# Val loss for epoch 93: 0.24666936695575714
# Train loss for epoch 94: 0.22783011198043823
# Val loss for epoch 94: 0.24775300920009613
# Train loss for epoch 95: 0.2128487229347229
# Val loss for epoch 95: 0.3005782961845398
# Train loss for epoch 96: 0.23314054310321808
# Val loss for epoch 96: 0.2794048488140106
# Train loss for epoch 97: 0.22167731821537018
# Val loss for epoch 97: 0.25512048602104187
# Train loss for epoch 98: 0.2226632982492447
# Val loss for epoch 98: 0.27562955021858215
# Train loss for epoch 99: 0.2302456796169281
# Val loss for epoch 99: 0.27689534425735474

# %%
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.title("MLP BatchNorm", fontsize = 15)
plt.plot(training_losses[:-1],linewidth = 1.5,label = 'train')
plt.plot(val_losses[:-1],linewidth = 1.5,label = 'valid')
plt.xlabel("Epoch",fontsize = 15)
plt.ylabel("Loss", fontsize = 15)
plt.legend()
plt.subplot(1,2,2)
plt.title("MLP BatchNorm", fontsize = 15)
plt.plot(training_acc[:-1],linewidth = 1.5,label = 'train')
plt.plot(val_acc[:-1],linewidth = 1.5,label = 'valid')
plt.xlabel("Epoch",fontsize = 15)
plt.ylabel("Accuracy", fontsize = 15)
plt.legend()
plt.show()

# %%
for batch_idx, (data, labels, date, rec, win) in enumerate(train_loader):
    data = data.to(device)
    x, lin1, lin2 = model(data)
    break

# %%
plt.imshow(lin1.detach().cpu())
plt.colorbar(orientation='vertical')
plt.show()

# %% [markdown]
# # 4 Layer CNN with Dropout Reg

# %%
class CNNdropout(nn.Module):
    def __init__(self, in_channels = 1, num_classes = 1):
        super(CNNdropout, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=2, kernel_size=(3,3), stride = (1,1), padding = (1,1))
        self.conv2 = nn.Conv2d(in_channels=2, out_channels=4, kernel_size=(3,3), stride = (1,1), padding = (1,1))
        self.dropout = nn.Dropout(0.5)
        self.conv3 = nn.Conv2d(in_channels=4, out_channels=8, kernel_size=(3,3), stride = (1,1), padding = (1,1))
        self.conv4 = nn.Conv2d(in_channels=8, out_channels=16, kernel_size=(3,3), stride = (1,1), padding = (1,1))
        self.fc1 = nn.Linear(16*10*100, num_classes)
#         self.fc1 = nn.Linear(4*10*100, num_classes)
        self.sigmoid = nn.Sigmoid()
        
    def forward(self, x, verbose=True):
        x = x.float()
        x1 = relu(self.conv1(x))
        x2 = relu(self.conv2(x1))
        x2 = self.dropout(x2)
        x = relu(self.conv3(x2))
        x = relu(self.conv4(x))
        x = x.reshape(x.shape[0], -1)
        x = self.fc1(x).flatten()
        x = self.sigmoid(x)
        return x, x1, x2

# %%
model = CNNdropout().to(device)
# model.apply(weight_reset)

criterion = nn.BCELoss()
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)

training_losses = []
val_losses = []
training_acc = []
val_acc = []

train_predictions = []
validation_predictions = []
train_labels = []
validation_labels = []

for epoch in range(num_epochs):
    avg_train_loss, train_accuracy, train_preds, train_labs = train(train_loader, epoch)
    print('Train loss for epoch {}: {}'.format(epoch, avg_train_loss))
    val_loss, val_accuracy, val_preds, val_labels = test(val_loader, epoch)
    print('Val loss for epoch {}: {}'.format(epoch, val_loss))
    
    training_losses.append(avg_train_loss)
    training_acc.append(train_accuracy)
    val_losses.append(val_loss)
    val_acc.append(val_accuracy)
    
    train_predictions.append(train_preds)
    train_labels.append(train_labs)
    validation_predictions.append(val_preds)
    validation_labels.append(val_labels)
# Out:
# Train loss for epoch 0: 0.38912904262542725
# Val loss for epoch 0: 0.3250003457069397
# Train loss for epoch 1: 0.31515973806381226
# Val loss for epoch 1: 0.3058723509311676
# Train loss for epoch 2: 0.304548978805542
# Val loss for epoch 2: 0.3010948598384857
# Train loss for epoch 3: 0.29673415422439575
# Val loss for epoch 3: 0.3044283390045166
# Train loss for epoch 4: 0.2855878472328186
# Val loss for epoch 4: 0.32229235768318176
# Train loss for epoch 5: 0.2805328071117401
# Val loss for epoch 5: 0.3006100356578827
# Train loss for epoch 6: 0.2767184376716614
# Val loss for epoch 6: 0.2928425967693329
# Train loss for epoch 7: 0.2715020775794983
# Val loss for epoch 7: 0.28314098715782166
# Train loss for epoch 8: 0.27249839901924133
# Val loss for epoch 8: 0.30290380120277405
# Train loss for epoch 9: 0.2688707113265991
# Val loss for epoch 9: 0.3003004193305969
# Train loss for epoch 10: 0.2669561505317688
# Val loss for epoch 10: 0.2752572000026703
# Train loss for epoch 11: 0.2607920169830322
# Val loss for epoch 11: 0.306064248085022
# Train loss for epoch 12: 0.26591333746910095
# Val loss for epoch 12: 0.2827010452747345
# Train loss for epoch 13: 0.25953564047813416
# Val loss for epoch 13: 0.2758408188819885
# Train loss for epoch 14: 0.2602214217185974
# Val loss for epoch 14: 0.28003403544425964
# Train loss for epoch 15: 0.26073598861694336
# Val loss for epoch 15: 0.27587783336639404
# Train loss for epoch 16: 0.25825294852256775
# Val loss for epoch 16: 0.2788560390472412
# Train loss for epoch 17: 0.2601660192012787
# Val loss for epoch 17: 0.33731475472450256
# Train loss for epoch 18: 0.25993871688842773
# Val loss for epoch 18: 0.2745518088340759
# Train loss for epoch 19: 0.25465768575668335
# Val loss for epoch 19: 0.2684817314147949
# Train loss for epoch 20: 0.25131741166114807
# Val loss for epoch 20: 0.3022150993347168
# Train loss for epoch 21: 0.25256532430648804
# Val loss for epoch 21: 0.27670523524284363
# Train loss for epoch 22: 0.24746713042259216
# Val loss for epoch 22: 0.27721813321113586
# Train loss for epoch 23: 0.24959351122379303
# Val loss for epoch 23: 0.2646131217479706
# Train loss for epoch 24: 0.2486240565776825
# Val loss for epoch 24: 0.2627207040786743
# Train loss for epoch 25: 0.24941210448741913
# Val loss for epoch 25: 0.2775026261806488
# Train loss for epoch 26: 0.24572810530662537
# Val loss for epoch 26: 0.2748429775238037
# Train loss for epoch 27: 0.2431732714176178
# Val loss for epoch 27: 0.26286232471466064
# Train loss for epoch 28: 0.24683654308319092
# Val loss for epoch 28: 0.27161458134651184
# Train loss for epoch 29: 0.24174880981445312
# Val loss for epoch 29: 0.2662717401981354
# Train loss for epoch 30: 0.24254046380519867
# Val loss for epoch 30: 0.27617737650871277
# Train loss for epoch 31: 0.2347598820924759
# Val loss for epoch 31: 0.27576643228530884
# Train loss for epoch 32: 0.23435449600219727
# Val loss for epoch 32: 0.26711270213127136
# Train loss for epoch 33: 0.23443955183029175
# Val loss for epoch 33: 0.27500230073928833
# Train loss for epoch 34: 0.2391224503517151
# Val loss for epoch 34: 0.28799116611480713
# Train loss for epoch 35: 0.2359398603439331
# Val loss for epoch 35: 0.26768580079078674
# Train loss for epoch 36: 0.2345101684331894
# Val loss for epoch 36: 0.2715508043766022
# Train loss for epoch 37: 0.22969111800193787
# Val loss for epoch 37: 0.2782997190952301
# Train loss for epoch 38: 0.2326614111661911
# Val loss for epoch 38: 0.2675466239452362
# Train loss for epoch 39: 0.23351538181304932
# Val loss for epoch 39: 0.2699997127056122
# Train loss for epoch 40: 0.2291712760925293
# Val loss for epoch 40: 0.2831663489341736
# Train loss for epoch 41: 0.2259306013584137
# Val loss for epoch 41: 0.27260762453079224
# Train loss for epoch 42: 0.2281511276960373
# Val loss for epoch 42: 0.307104229927063
# Train loss for epoch 43: 0.2245400995016098
# Val loss for epoch 43: 0.2825658321380615
# Train loss for epoch 44: 0.22201448678970337
# Val loss for epoch 44: 0.2843391001224518
# Train loss for epoch 45: 0.22128577530384064
# Val loss for epoch 45: 0.2806580066680908
# Train loss for epoch 46: 0.22608700394630432
# Val loss for epoch 46: 0.28803905844688416
# Train loss for epoch 47: 0.2235371470451355
# Val loss for epoch 47: 0.2750290334224701
# Train loss for epoch 48: 0.2155545949935913
# Val loss for epoch 48: 0.26230388879776
# Train loss for epoch 49: 0.2216935008764267
# Val loss for epoch 49: 0.27596190571784973
# Train loss for epoch 50: 0.21997109055519104
# Val loss for epoch 50: 0.28049468994140625
# Train loss for epoch 51: 0.21615850925445557
# Val loss for epoch 51: 0.27164262533187866
# Train loss for epoch 52: 0.21595005691051483
# Val loss for epoch 52: 0.28031250834465027
# Train loss for epoch 53: 0.21435734629631042
# Val loss for epoch 53: 0.2859490215778351
# Train loss for epoch 89: 0.18386371433734894
# Val loss for epoch 89: 0.33002668619155884
# Train loss for epoch 90: 0.18055109679698944
# Val loss for epoch 90: 0.31216421723365784
# Train loss for epoch 91: 0.18597722053527832
# Val loss for epoch 91: 0.3226112425327301
# Train loss for epoch 92: 0.18640752136707306
# Val loss for epoch 92: 0.3518587052822113
# Train loss for epoch 93: 0.18019437789916992
# Val loss for epoch 93: 0.34455737471580505
# Train loss for epoch 94: 0.18229800462722778
# Val loss for epoch 94: 0.3431181311607361
# Train loss for epoch 95: 0.17794384062290192
# Val loss for epoch 95: 0.33110952377319336
# Train loss for epoch 96: 0.1825053095817566
# Val loss for epoch 96: 0.3255472779273987
# Train loss for epoch 97: 0.17106254398822784
# Val loss for epoch 97: 0.33541202545166016
# Train loss for epoch 98: 0.1781393438577652
# Val loss for epoch 98: 0.35285237431526184
# Train loss for epoch 99: 0.17478761076927185
# Val loss for epoch 99: 0.3326299786567688

# %%
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.title("4 layer CNN with dropout", fontsize = 15)
plt.plot(training_losses[:-1],linewidth = 1.5,label = 'train')
plt.plot(val_losses[:-1],linewidth = 1.5,label = 'valid')
plt.xlabel("Epoch",fontsize = 15)
plt.ylabel("Loss", fontsize = 15)
plt.legend()
plt.subplot(1,2,2)
plt.title("4 layer CNN with dropout", fontsize = 15)
plt.plot(training_acc[:-1],linewidth = 1.5,label = 'train')
plt.plot(val_acc[:-1],linewidth = 1.5,label = 'valid')
plt.xlabel("Epoch",fontsize = 15)
plt.ylabel("Accuracy", fontsize = 15)
plt.legend()
plt.show()

# %%
for batch_idx, (data, labels, date, rec, win) in enumerate(train_loader):
    data = data.to(device)
    x, conv1, conv2 = model(data)
    break

weights = conv1[0]
# plt.figure(figsize=(30,90))
for i in range(2):
    weights_sub = weights[i].detach().cpu()
    plt.subplot(1,2,i+1)
    plt.imshow(weights_sub)
    plt.colorbar(orientation='vertical')
plt.show()

# %%
weights = conv2[0]
# plt.figure(figsize=(30,90))
for i in range(4):
    weights_sub = weights[i].detach().cpu()
    plt.subplot(1,4,i+1)
    plt.imshow(weights_sub)
    plt.colorbar(orientation='vertical')
plt.show()

# %%
class CNNsmalldropout(nn.Module):
    def __init__(self, in_channels = 1, num_classes = 1):
        super(CNNsmalldropout, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=2, kernel_size=(3,3), stride = (1,1), padding = (1,1))
        self.conv2 = nn.Conv2d(in_channels=2, out_channels=4, kernel_size=(3,3), stride = (1,1), padding = (1,1))
        self.dropout = nn.Dropout(0.5)
#         self.conv3 = nn.Conv2d(in_channels=4, out_channels=8, kernel_size=(3,3), stride = (1,1), padding = (1,1))
#         self.conv4 = nn.Conv2d(in_channels=8, out_channels=16, kernel_size=(3,3), stride = (1,1), padding = (1,1))
#         self.fc1 = nn.Linear(16*10*100, num_classes)
        self.fc1 = nn.Linear(4*10*100, num_classes)
        self.sigmoid = nn.Sigmoid()
        
    def forward(self, x, verbose=True):
        x = x.float()
        x1 = relu(self.conv1(x))
        x2 = relu(self.conv2(x1))
#         x = relu(self.conv3(x2))
#         x = relu(self.conv4(x))
        x2 = self.dropout(x2)
        x = x2.reshape(x2.shape[0], -1)
        x = self.fc1(x).flatten()
        x = self.sigmoid(x)
        return x, x1, x2

# %%
model = CNNsmalldropout().to(device)
# model.apply(weight_reset)

criterion = nn.BCELoss()
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)

training_losses = []
val_losses = []
training_acc = []
val_acc = []

train_predictions = []
validation_predictions = []
train_labels = []
validation_labels = []

for epoch in range(num_epochs):
    avg_train_loss, train_accuracy, train_preds, train_labs = train(train_loader, epoch)
    print('Train loss for epoch {}: {}'.format(epoch, avg_train_loss))
    val_loss, val_accuracy, val_preds, val_labels = test(val_loader, epoch)
    print('Val loss for epoch {}: {}'.format(epoch, val_loss))
    
    training_losses.append(avg_train_loss)
    training_acc.append(train_accuracy)
    val_losses.append(val_loss)
    val_acc.append(val_accuracy)
    
    train_predictions.append(train_preds)
    train_labels.append(train_labs)
    validation_predictions.append(val_preds)
    validation_labels.append(val_labels)
# Out:
# Train loss for epoch 0: 0.3813263475894928
# Val loss for epoch 0: 0.325916588306427
# Train loss for epoch 1: 0.3172346353530884
# Val loss for epoch 1: 0.3147740364074707
# Train loss for epoch 2: 0.3000370264053345
# Val loss for epoch 2: 0.3935888409614563
# Train loss for epoch 3: 0.287943035364151
# Val loss for epoch 3: 0.2812771797180176
# Train loss for epoch 4: 0.28042465448379517
# Val loss for epoch 4: 0.28401342034339905
# Train loss for epoch 5: 0.28165167570114136
# Val loss for epoch 5: 0.2926454246044159
# Train loss for epoch 6: 0.27715620398521423
# Val loss for epoch 6: 0.28080740571022034
# Train loss for epoch 7: 0.26937392354011536
# Val loss for epoch 7: 0.28298941254615784
# Train loss for epoch 8: 0.27365466952323914
# Val loss for epoch 8: 0.2859864830970764
# Train loss for epoch 9: 0.2705610990524292
# Val loss for epoch 9: 0.2913927435874939
# Train loss for epoch 10: 0.2647704482078552
# Val loss for epoch 10: 0.2644355595111847
# Train loss for epoch 11: 0.263284295797348
# Val loss for epoch 11: 0.2667894661426544
# Train loss for epoch 12: 0.26456889510154724
# Val loss for epoch 12: 0.27958086133003235
# Train loss for epoch 13: 0.2629416882991791
# Val loss for epoch 13: 0.280259370803833
# Train loss for epoch 14: 0.2642691731452942
# Val loss for epoch 14: 0.2711664140224457
# Train loss for epoch 15: 0.25954607129096985
# Val loss for epoch 15: 0.2698277235031128
# Train loss for epoch 16: 0.2564954459667206
# Val loss for epoch 16: 0.2716750502586365
# Train loss for epoch 17: 0.2645418047904968
# Val loss for epoch 17: 0.26370543241500854
# Train loss for epoch 18: 0.2564672827720642
# Val loss for epoch 18: 0.28544220328330994
# Train loss for epoch 19: 0.25374841690063477
# Val loss for epoch 19: 0.2671363353729248
# Train loss for epoch 20: 0.2534477412700653
# Val loss for epoch 20: 0.29096153378486633
# Train loss for epoch 21: 0.2549906075000763
# Val loss for epoch 21: 0.2817590832710266
# Train loss for epoch 22: 0.2531174421310425
# Val loss for epoch 22: 0.26531004905700684
# Train loss for epoch 23: 0.2500569820404053
# Val loss for epoch 23: 0.28034648299217224
# Train loss for epoch 24: 0.249141126871109
# Val loss for epoch 24: 0.26475396752357483
# Train loss for epoch 25: 0.2485792189836502
# Val loss for epoch 25: 0.2730425000190735
# Train loss for epoch 26: 0.2501126825809479
# Val loss for epoch 26: 0.30033785104751587
# Train loss for epoch 27: 0.2535693645477295
# Val loss for epoch 27: 0.2704069912433624
# Train loss for epoch 28: 0.24830378592014313
# Val loss for epoch 28: 0.27346381545066833
# Train loss for epoch 29: 0.24730925261974335
# Val loss for epoch 29: 0.27128517627716064
# Train loss for epoch 30: 0.2454630434513092
# Val loss for epoch 30: 0.30010008811950684
# Train loss for epoch 31: 0.25086522102355957
# Val loss for epoch 66: 0.2922094464302063
# Train loss for epoch 67: 0.2278941422700882
# Val loss for epoch 67: 0.2747056186199188
# Train loss for epoch 68: 0.23195551335811615
# Val loss for epoch 68: 0.2745700776576996
# Train loss for epoch 69: 0.23341503739356995
# Val loss for epoch 69: 0.2850591838359833
# Train loss for epoch 70: 0.23032188415527344
# Val loss for epoch 70: 0.26092278957366943
# Train loss for epoch 71: 0.2281007319688797
# Val loss for epoch 71: 0.29625070095062256
# Train loss for epoch 72: 0.22782942652702332
# Val loss for epoch 72: 0.2661786377429962
# Train loss for epoch 73: 0.22990180552005768
# Val loss for epoch 73: 0.2677634656429291
# Train loss for epoch 74: 0.22565463185310364
# Val loss for epoch 74: 0.2663058042526245
# Train loss for epoch 75: 0.23377063870429993
# Val loss for epoch 75: 0.263833224773407
# Train loss for epoch 76: 0.22751416265964508
# Val loss for epoch 76: 0.2934734523296356
# Train loss for epoch 77: 0.23126563429832458
# Val loss for epoch 77: 0.26155877113342285
# Train loss for epoch 78: 0.22875657677650452
# Val loss for epoch 78: 0.28051653504371643
# Train loss for epoch 79: 0.22942475974559784
# Val loss for epoch 79: 0.2664850354194641
# Train loss for epoch 80: 0.22852057218551636
# Val loss for epoch 80: 0.2845315635204315
# Train loss for epoch 81: 0.22832727432250977
# Val loss for epoch 81: 0.2714262306690216
# Train loss for epoch 82: 0.22567971050739288
# Val loss for epoch 82: 0.26030001044273376
# Train loss for epoch 83: 0.22400681674480438
# Val loss for epoch 83: 0.2688852548599243
# Train loss for epoch 84: 0.22601985931396484
# Val loss for epoch 84: 0.26169154047966003
# Train loss for epoch 85: 0.22419728338718414
# Val loss for epoch 85: 0.2896089553833008
# Train loss for epoch 86: 0.22632838785648346
# Val loss for epoch 86: 0.27676859498023987
# Train loss for epoch 87: 0.22591717541217804
# Val loss for epoch 87: 0.28500282764434814
# Train loss for epoch 88: 0.22030779719352722
# Val loss for epoch 88: 0.2678903341293335
# Train loss for epoch 89: 0.22335073351860046
# Val loss for epoch 89: 0.27110740542411804
# Train loss for epoch 90: 0.22408488392829895
# Val loss for epoch 90: 0.2964175045490265
# Train loss for epoch 91: 0.22741323709487915
# Val loss for epoch 91: 0.26904454827308655
# Train loss for epoch 92: 0.2227480411529541
# Val loss for epoch 92: 0.2729478180408478
# Train loss for epoch 93: 0.22493693232536316
# Val loss for epoch 93: 0.2695368230342865
# Train loss for epoch 94: 0.22549904882907867
# Val loss for epoch 94: 0.29055485129356384
# Train loss for epoch 95: 0.2225596308708191
# Val loss for epoch 95: 0.2896064519882202
# Train loss for epoch 96: 0.22375573217868805
# Val loss for epoch 96: 0.26722466945648193
# Train loss for epoch 97: 0.22162605822086334
# Val loss for epoch 97: 0.2641749978065491
# Train loss for epoch 98: 0.2285253405570984
# Val loss for epoch 98: 0.2826462686061859
# Train loss for epoch 99: 0.22590474784374237
# Val loss for epoch 99: 0.2705751061439514

# %%
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.title("2 layer CNN with dropout", fontsize = 15)
plt.plot(training_losses[:-1],linewidth = 1.5,label = 'train')
plt.plot(val_losses[:-1],linewidth = 1.5,label = 'valid')
plt.xlabel("Epoch",fontsize = 15)
plt.ylabel("Loss", fontsize = 15)
plt.legend()
plt.subplot(1,2,2)
plt.title("2 layer CNN with dropout", fontsize = 15)
plt.plot(training_acc[:-1],linewidth = 1.5,label = 'train')
plt.plot(val_acc[:-1],linewidth = 1.5,label = 'valid')
plt.xlabel("Epoch",fontsize = 15)
plt.ylabel("Accuracy", fontsize = 15)
plt.legend()
plt.show()

# %%
for batch_idx, (data, labels, date, rec, win) in enumerate(train_loader):
    data = data.to(device)
    x, conv1, conv2 = model(data)
    break

weights = conv1[0]
# plt.figure(figsize=(30,90))
for i in range(2):
    weights_sub = weights[i].detach().cpu()
    plt.subplot(1,2,i+1)
    plt.imshow(weights_sub)
    plt.colorbar(orientation='vertical')
plt.show()

# %%
weights = conv2[0]
# plt.figure(figsize=(30,90))
for i in range(4):
    weights_sub = weights[i].detach().cpu()
    plt.subplot(1,4,i+1)
    plt.imshow(weights_sub)
    plt.colorbar(orientation='vertical')
plt.show()

# %% [markdown]
# # 4 layer CNN with batchnorm2d

# %%
class CNNbatchnorm(nn.Module):
    def __init__(self, in_channels = 1, num_classes = 1):
        super(CNNbatchnorm, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=2, kernel_size=(3,3), stride = (1,1), padding = (1,1))
        self.conv2 = nn.Conv2d(in_channels=2, out_channels=4, kernel_size=(3,3), stride = (1,1), padding = (1,1))
        self.dropout = nn.BatchNorm2d(4)
        self.conv3 = nn.Conv2d(in_channels=4, out_channels=8, kernel_size=(3,3), stride = (1,1), padding = (1,1))
        self.conv4 = nn.Conv2d(in_channels=8, out_channels=16, kernel_size=(3,3), stride = (1,1), padding = (1,1))
        self.fc1 = nn.Linear(16*10*100, num_classes)
#         self.fc1 = nn.Linear(4*10*100, num_classes)
        self.sigmoid = nn.Sigmoid()
        
    def forward(self, x, verbose=True):
        x = x.float()
        x1 = relu(self.conv1(x))
        x2 = relu(self.conv2(x1))
        x2 = self.dropout(x2)
        x = relu(self.conv3(x2))
        x = relu(self.conv4(x))
        x = x.reshape(x.shape[0], -1)
        x = self.fc1(x).flatten()
        x = self.sigmoid(x)
        return x, x1, x2

# %%
model = CNNbatchnorm().to(device)
# model.apply(weight_reset)

criterion = nn.BCELoss()
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)

training_losses = []
val_losses = []
training_acc = []
val_acc = []

train_predictions = []
validation_predictions = []
train_labels = []
validation_labels = []

for epoch in range(num_epochs):
    avg_train_loss, train_accuracy, train_preds, train_labs = train(train_loader, epoch)
    print('Train loss for epoch {}: {}'.format(epoch, avg_train_loss))
    val_loss, val_accuracy, val_preds, val_labels = test(val_loader, epoch)
    print('Val loss for epoch {}: {}'.format(epoch, val_loss))
    
    training_losses.append(avg_train_loss)
    training_acc.append(train_accuracy)
    val_losses.append(val_loss)
    val_acc.append(val_accuracy)
    
    train_predictions.append(train_preds)
    train_labels.append(train_labs)
    validation_predictions.append(val_preds)
    validation_labels.append(val_labels)
# Out:
# Train loss for epoch 0: 0.430553138256073
# Val loss for epoch 0: 0.41060250997543335
# Train loss for epoch 1: 0.3477221429347992
# Val loss for epoch 1: 0.38094407320022583
# Train loss for epoch 2: 0.3355570435523987
# Val loss for epoch 2: 0.3435440957546234
# Train loss for epoch 3: 0.31170564889907837
# Val loss for epoch 3: 0.3286226689815521
# Train loss for epoch 4: 0.289164274930954
# Val loss for epoch 4: 0.30129870772361755
# Train loss for epoch 5: 0.2740776240825653
# Val loss for epoch 5: 0.32515332102775574
# Train loss for epoch 6: 0.2605830729007721
# Val loss for epoch 6: 0.34628230333328247
# Train loss for epoch 7: 0.246947780251503
# Val loss for epoch 7: 0.2842245399951935
# Train loss for epoch 8: 0.24204720556735992
# Val loss for epoch 8: 0.3246677815914154
# Train loss for epoch 9: 0.23216179013252258
# Val loss for epoch 9: 0.3443690538406372
# Train loss for epoch 10: 0.2188340574502945
# Val loss for epoch 10: 0.3038100600242615
# Train loss for epoch 11: 0.20920854806900024
# Val loss for epoch 11: 0.2934549152851105
# Train loss for epoch 12: 0.19680310785770416
# Val loss for epoch 12: 0.3022628128528595
# Train loss for epoch 13: 0.18561400473117828
# Val loss for epoch 13: 0.3716132640838623
# Train loss for epoch 14: 0.18123073875904083
# Val loss for epoch 14: 0.3386470079421997
# Train loss for epoch 15: 0.1652808040380478
# Val loss for epoch 15: 0.3445614278316498
# Train loss for epoch 16: 0.15088503062725067
# Val loss for epoch 16: 0.38962531089782715
# Train loss for epoch 17: 0.13138079643249512
# Val loss for epoch 17: 0.4053155481815338
# Train loss for epoch 18: 0.12163907289505005
# Val loss for epoch 18: 0.3932705521583557
# Train loss for epoch 19: 0.11108934879302979
# Val loss for epoch 19: 0.4239179491996765
# Train loss for epoch 20: 0.09363441169261932
# Val loss for epoch 20: 0.4783880114555359
# Train loss for epoch 21: 0.07710742205381393
# Val loss for epoch 21: 0.5359233617782593
# Train loss for epoch 22: 0.05702819302678108
# Val loss for epoch 22: 0.5282235741615295
# Train loss for epoch 23: 0.054039642214775085
# Val loss for epoch 23: 0.5746665596961975
# Train loss for epoch 24: 0.05093630030751228
# Val loss for epoch 24: 0.6436172127723694
# Train loss for epoch 25: 0.039472416043281555
# Val loss for epoch 25: 0.716871976852417
# Train loss for epoch 26: 0.03094269149005413
# Val loss for epoch 26: 0.6985252499580383
# Train loss for epoch 27: 0.07046546041965485
# Val loss for epoch 27: 0.7615239024162292
# Train loss for epoch 28: 0.01868744008243084
# Val loss for epoch 28: 0.8218241930007935
# Train loss for epoch 29: 0.0174497552216053
# Val loss for epoch 29: 0.7984826564788818
# Train loss for epoch 30: 0.008375863544642925
# Val loss for epoch 30: 0.9316855072975159
# Train loss for epoch 31: 0.006899693049490452
# Val loss for epoch 31: 0.9865041375160217
# Train loss for epoch 32: 0.0202958807349205
# Val loss for epoch 32: 1.07230544090271
# Train loss for epoch 33: 0.022968903183937073
# Val loss for epoch 33: 1.1636923551559448
# Train loss for epoch 34: 0.029221199452877045
# Val loss for epoch 34: 1.2632744312286377
# Train loss for epoch 35: 0.011841862462460995
# Val loss for epoch 35: 0.982387900352478
# Train loss for epoch 36: 0.026516608893871307
# Val loss for epoch 36: 1.3707871437072754
# Train loss for epoch 37: 0.0907084122300148
# Val loss for epoch 37: 0.9924718737602234
# Train loss for epoch 38: 0.012760481797158718
# Val loss for epoch 38: 0.9506415128707886
# Train loss for epoch 39: 0.0057222964242100716
# Val loss for epoch 39: 1.121769666671753
# Train loss for epoch 40: 0.001872326130978763
# Val loss for epoch 40: 1.2289245128631592
# Train loss for epoch 41: 0.0023310650140047073
# Val loss for epoch 41: 1.1756455898284912
# Train loss for epoch 42: 0.002909710630774498
# Val loss for epoch 42: 1.2645139694213867
# Train loss for epoch 43: 0.001541652949526906
# Val loss for epoch 43: 1.3182882070541382
# Train loss for epoch 44: 0.0018606067169457674
# Val loss for epoch 44: 1.430044412612915
# Train loss for epoch 80: 0.0002307825197931379
# Val loss for epoch 80: 1.9383095502853394
# Train loss for epoch 81: 0.007653080392628908
# Val loss for epoch 81: 1.6604371070861816
# Train loss for epoch 82: 0.0070419758558273315
# Val loss for epoch 82: 1.6080113649368286
# Train loss for epoch 83: 0.004139687400311232
# Val loss for epoch 83: 1.861693263053894
# Train loss for epoch 84: 0.012275397777557373
# Val loss for epoch 84: 1.5944246053695679
# Train loss for epoch 85: 0.03524237871170044
# Val loss for epoch 85: 2.0927398204803467
# Train loss for epoch 86: 0.011776821687817574
# Val loss for epoch 86: 1.8334176540374756
# Train loss for epoch 87: 0.005362346768379211
# Val loss for epoch 87: 1.7023615837097168
# Train loss for epoch 88: 0.0006514149717986584
# Val loss for epoch 88: 1.7877236604690552
# Train loss for epoch 89: 0.0002550128847360611
# Val loss for epoch 89: 1.8199228048324585
# Train loss for epoch 90: 0.001985918264836073
# Val loss for epoch 90: 1.6460368633270264
# Train loss for epoch 91: 0.0006344647263176739
# Val loss for epoch 91: 1.4231866598129272
# Train loss for epoch 92: 0.001055617700330913
# Val loss for epoch 92: 2.0306665897369385
# Train loss for epoch 93: 0.0003289901651442051
# Val loss for epoch 93: 2.2620654106140137
# Train loss for epoch 94: 0.0001038270493154414
# Val loss for epoch 94: 2.2264626026153564
# Train loss for epoch 95: 0.0003348934988025576
# Val loss for epoch 95: 2.2232117652893066
# Train loss for epoch 96: 0.00011981552961515263
# Val loss for epoch 96: 2.361034631729126
# Train loss for epoch 97: 0.037781309336423874
# Val loss for epoch 97: 1.8351606130599976
# Train loss for epoch 98: 0.03154606372117996
# Val loss for epoch 98: 1.6895161867141724
# Train loss for epoch 99: 0.011911206878721714
# Val loss for epoch 99: 1.7771592140197754

# %%
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.title("4 layer CNN with batchnorm", fontsize = 15)
plt.plot(training_losses[:-1],linewidth = 1.5,label = 'train')
plt.plot(val_losses[:-1],linewidth = 1.5,label = 'valid')
plt.xlabel("Epoch",fontsize = 15)
plt.ylabel("Loss", fontsize = 15)
plt.legend()
plt.subplot(1,2,2)
plt.title("4 layer CNN with batchnorm", fontsize = 15)
plt.plot(training_acc[:-1],linewidth = 1.5,label = 'train')
plt.plot(val_acc[:-1],linewidth = 1.5,label = 'valid')
plt.xlabel("Epoch",fontsize = 15)
plt.ylabel("Accuracy", fontsize = 15)
plt.legend()
plt.show()

# %%
for batch_idx, (data, labels, date, rec, win) in enumerate(train_loader):
    data = data.to(device)
    x, conv1, conv2 = model(data)
    break

weights = conv1[0]
# plt.figure(figsize=(30,90))
for i in range(2):
    weights_sub = weights[i].detach().cpu()
    plt.subplot(1,2,i+1)
    plt.imshow(weights_sub)
    plt.colorbar(orientation='vertical')
plt.show()

# %%
weights = conv2[0]
# plt.figure(figsize=(30,90))
for i in range(4):
    weights_sub = weights[i].detach().cpu()
    plt.subplot(1,4,i+1)
    plt.imshow(weights_sub)
    plt.colorbar(orientation='vertical')
plt.show()

# %% [markdown]
# # 2 layer CNN with Batchnorm

# %%
class CNNsmallbatchnorm(nn.Module):
    def __init__(self, in_channels = 1, num_classes = 1):
        super(CNNsmallbatchnorm, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=2, kernel_size=(3,3), stride = (1,1), padding = (1,1))
        self.conv2 = nn.Conv2d(in_channels=2, out_channels=4, kernel_size=(3,3), stride = (1,1), padding = (1,1))
        self.dropout = nn.Batchnorm(4)
#         self.conv3 = nn.Conv2d(in_channels=4, out_channels=8, kernel_size=(3,3), stride = (1,1), padding = (1,1))
#         self.conv4 = nn.Conv2d(in_channels=8, out_channels=16, kernel_size=(3,3), stride = (1,1), padding = (1,1))
#         self.fc1 = nn.Linear(16*10*100, num_classes)
        self.fc1 = nn.Linear(4*10*100, num_classes)
        self.sigmoid = nn.Sigmoid()
        
    def forward(self, x, verbose=True):
        x = x.float()
        x1 = relu(self.conv1(x))
        x2 = relu(self.conv2(x1))
#         x = relu(self.conv3(x2))
#         x = relu(self.conv4(x))
        x2 = self.dropout(x2)
        x = x2.reshape(x2.shape[0], -1)
        x = self.fc1(x).flatten()
        x = self.sigmoid(x)
        return x, x1, x2

# %%
model = CNNbatchnorm().to(device)
# model.apply(weight_reset)

criterion = nn.BCELoss()
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)

training_losses = []
val_losses = []
training_acc = []
val_acc = []

train_predictions = []
validation_predictions = []
train_labels = []
validation_labels = []

for epoch in range(num_epochs):
    avg_train_loss, train_accuracy, train_preds, train_labs = train(train_loader, epoch)
    print('Train loss for epoch {}: {}'.format(epoch, avg_train_loss))
    val_loss, val_accuracy, val_preds, val_labels = test(val_loader, epoch)
    print('Val loss for epoch {}: {}'.format(epoch, val_loss))
    
    training_losses.append(avg_train_loss)
    training_acc.append(train_accuracy)
    val_losses.append(val_loss)
    val_acc.append(val_accuracy)
    
    train_predictions.append(train_preds)
    train_labels.append(train_labs)
    validation_predictions.append(val_preds)
    validation_labels.append(val_labels)
# Out:
# Train loss for epoch 0: 0.3904516100883484
# Val loss for epoch 0: 0.37954652309417725
# Train loss for epoch 1: 0.33092591166496277
# Val loss for epoch 1: 0.3800124228000641
# Train loss for epoch 2: 0.30130475759506226
# Val loss for epoch 2: 0.28867200016975403
# Train loss for epoch 3: 0.28482601046562195
# Val loss for epoch 3: 0.2960590422153473
# Train loss for epoch 4: 0.2751152217388153
# Val loss for epoch 4: 0.2841906249523163
# Train loss for epoch 5: 0.26600348949432373
# Val loss for epoch 5: 0.31010907888412476
# Train loss for epoch 6: 0.26013731956481934
# Val loss for epoch 6: 0.27137190103530884
# Train loss for epoch 7: 0.2559688091278076
# Val loss for epoch 7: 0.30985549092292786
# Train loss for epoch 8: 0.2506241500377655
# Val loss for epoch 8: 0.32006019353866577
# Train loss for epoch 9: 0.2395159751176834
# Val loss for epoch 9: 0.32638388872146606
# Train loss for epoch 10: 0.23970048129558563
# Val loss for epoch 10: 0.2719000279903412
# Train loss for epoch 11: 0.23235715925693512
# Val loss for epoch 11: 0.2785990834236145
# Train loss for epoch 12: 0.22778576612472534
# Val loss for epoch 12: 0.3016416132450104
# Train loss for epoch 13: 0.21702712774276733
# Val loss for epoch 13: 0.30506837368011475
# Train loss for epoch 14: 0.20731055736541748
# Val loss for epoch 14: 0.3119896650314331
# Train loss for epoch 15: 0.20080223679542542
# Val loss for epoch 15: 0.3272104859352112
# Train loss for epoch 16: 0.19065216183662415
# Val loss for epoch 16: 0.3076035976409912
# Train loss for epoch 17: 0.17854395508766174
# Val loss for epoch 17: 0.3412432074546814
# Train loss for epoch 18: 0.16973702609539032
# Val loss for epoch 18: 0.3281944692134857
# Train loss for epoch 19: 0.16319335997104645
# Val loss for epoch 19: 0.341074675321579
# Train loss for epoch 20: 0.14114682376384735
# Val loss for epoch 20: 0.45494765043258667
# Train loss for epoch 21: 0.12533968687057495
# Val loss for epoch 21: 0.39375102519989014
# Train loss for epoch 22: 0.11156100779771805
# Val loss for epoch 22: 0.3903154134750366
# Train loss for epoch 23: 0.09614256769418716
# Val loss for epoch 23: 0.47825387120246887
# Train loss for epoch 24: 0.0802290141582489
# Val loss for epoch 24: 0.5029523372650146
# Train loss for epoch 25: 0.0675572082400322
# Val loss for epoch 25: 0.5009539127349854
# Train loss for epoch 26: 0.05734040588140488
# Val loss for epoch 26: 0.5683055520057678
# Train loss for epoch 27: 0.0501825287938118
# Val loss for epoch 27: 0.6009657382965088
# Train loss for epoch 28: 0.04043683409690857
# Val loss for epoch 28: 0.709498941898346
# Train loss for epoch 29: 0.03436194360256195
# Val loss for epoch 29: 0.7253426909446716
# Train loss for epoch 30: 0.02901882864534855
# Val loss for epoch 30: 0.7198349833488464
# Train loss for epoch 31: 0.032194625586271286
# Val loss for epoch 31: 0.6734446883201599
# Train loss for epoch 32: 0.030816849321126938
# Val loss for epoch 32: 0.8181747794151306
# Train loss for epoch 33: 0.018519191071391106
# Val loss for epoch 33: 0.8584070801734924
# Train loss for epoch 34: 0.02649076282978058
# Val loss for epoch 34: 0.673167884349823
# Train loss for epoch 35: 0.014968237839639187
# Val loss for epoch 35: 0.9674691557884216
# Train loss for epoch 36: 0.010389186441898346
# Val loss for epoch 36: 0.9902061223983765
# Train loss for epoch 37: 0.009427634999155998
# Val loss for epoch 37: 1.068291187286377
# Train loss for epoch 38: 0.052100811153650284
# Val loss for epoch 38: 0.8803542852401733
# Train loss for epoch 39: 0.01595962420105934
# Val loss for epoch 39: 0.9347500205039978
# Train loss for epoch 40: 0.007562937214970589
# Val loss for epoch 40: 1.1324480772018433
# Train loss for epoch 41: 0.00343592232093215
# Val loss for epoch 41: 1.3515650033950806
# Train loss for epoch 42: 0.028946464881300926
# Val loss for epoch 42: 1.1975454092025757
# Train loss for epoch 43: 0.01478145644068718
# Val loss for epoch 43: 1.3242292404174805
# Train loss for epoch 44: 0.00908715184777975
# Val loss for epoch 44: 1.4053795337677002
# Train loss for epoch 45: 0.03941122442483902
# Val loss for epoch 45: 0.9867985248565674
# Train loss for epoch 46: 0.029546678066253662
# Val loss for epoch 46: 1.3419376611709595
# Train loss for epoch 47: 0.006230498664081097
# Val loss for epoch 47: 1.4129252433776855
# Train loss for epoch 48: 0.004772236570715904
# Val loss for epoch 48: 1.5697654485702515
# Train loss for epoch 49: 0.0014190830988809466
# Val loss for epoch 49: 1.5929114818572998
# Train loss for epoch 50: 0.02269941195845604
# Val loss for epoch 50: 1.3573142290115356
# Train loss for epoch 51: 0.016285572201013565
# Val loss for epoch 51: 1.3838731050491333
# Train loss for epoch 52: 0.006489809136837721
# Val loss for epoch 52: 1.348592758178711
# Train loss for epoch 53: 0.015438578091561794
# Val loss for epoch 53: 1.2962322235107422
# Train loss for epoch 54: 0.021198106929659843
# Val loss for epoch 54: 1.4413267374038696
# Train loss for epoch 90: 0.06414924561977386
# Val loss for epoch 90: 1.1988648176193237
# Train loss for epoch 91: 0.013671161606907845
# Val loss for epoch 91: 1.4941917657852173
# Train loss for epoch 92: 0.0036706249229609966
# Val loss for epoch 92: 1.4767338037490845
# Train loss for epoch 93: 0.007331695407629013
# Val loss for epoch 93: 1.3808470964431763
# Train loss for epoch 94: 0.0034044950734823942
# Val loss for epoch 94: 1.6119205951690674
# Train loss for epoch 95: 0.0005320724449120462
# Val loss for epoch 95: 2.0687854290008545
# Train loss for epoch 96: 0.0012497681891545653
# Val loss for epoch 96: 2.046644926071167
# Train loss for epoch 97: 0.0021698204800486565
# Val loss for epoch 97: 1.6792073249816895
# Train loss for epoch 98: 0.04148110747337341
# Val loss for epoch 98: 1.294152855873108
# Train loss for epoch 99: 0.019964730367064476
# Val loss for epoch 99: 1.4338304996490479

# %%
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.title("2 layer CNN with batchnorm", fontsize = 15)
plt.plot(training_losses[:-1],linewidth = 1.5,label = 'train')
plt.plot(val_losses[:-1],linewidth = 1.5,label = 'valid')
plt.xlabel("Epoch",fontsize = 15)
plt.ylabel("Loss", fontsize = 15)
plt.legend()
plt.subplot(1,2,2)
plt.title("2 layer CNN with batchnorm", fontsize = 15)
plt.plot(training_acc[:-1],linewidth = 1.5,label = 'train')
plt.plot(val_acc[:-1],linewidth = 1.5,label = 'valid')
plt.xlabel("Epoch",fontsize = 15)
plt.ylabel("Accuracy", fontsize = 15)
plt.legend()
plt.show()

# %%
for batch_idx, (data, labels, date, rec, win) in enumerate(train_loader):
    data = data.to(device)
    x, conv1, conv2 = model(data)
    break

weights = conv1[0]
# plt.figure(figsize=(30,90))
for i in range(2):
    weights_sub = weights[i].detach().cpu()
    plt.subplot(1,2,i+1)
    plt.imshow(weights_sub)
    plt.colorbar(orientation='vertical')
plt.show()

weights = conv2[0]
# plt.figure(figsize=(30,90))
for i in range(4):
    weights_sub = weights[i].detach().cpu()
    plt.subplot(1,4,i+1)
    plt.imshow(weights_sub)
    plt.colorbar(orientation='vertical')
plt.show()

# %% [markdown]
# # Checking models can learn single example

# %%
# def __init__(self, mode='train',moving_files_train=moving_files_train,sleeping_files_train=sleeping_files_train,moving_files_val=moving_files_val,sleeping_files_val=sleeping_files_val):
train_dataset_single = NoahSpectrogramDataset(mode='train', moving_files_train=moving_files_train[:1], sleeping_files_train=[], moving_files_val=moving_files_train[:1], sleeping_files_val=[])
valid_dataset_single = NoahSpectrogramDataset(mode='valid', moving_files_train=moving_files_train[:1], sleeping_files_train=[], moving_files_val=moving_files_train[:1], sleeping_files_val=[])

# %%
train_loader_single = DataLoader(dataset = train_dataset_single, batch_size = 1, shuffle = True)
val_loader_single = DataLoader(dataset = valid_dataset_single, batch_size = 1, shuffle = False)

# %%
model = CNNsplit().to(device)
# model.apply(weight_reset)

criterion = nn.BCELoss()
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)

training_losses = []
val_losses = []
training_acc = []
val_acc = []

train_predictions = []
validation_predictions = []
train_labels = []
validation_labels = []

for epoch in range(num_epochs):
    avg_train_loss, train_accuracy, train_preds, train_labs = train(train_loader_single, epoch)
    print('Train loss for epoch {}: {}'.format(epoch, avg_train_loss))
    val_loss, val_accuracy, val_preds, val_labels = test(val_loader_single, epoch)
    print('Val loss for epoch {}: {}'.format(epoch, val_loss))
    
    training_losses.append(avg_train_loss)
    training_acc.append(train_accuracy)
    val_losses.append(val_loss)
    val_acc.append(val_accuracy)
    
    train_predictions.append(train_preds)
    train_labels.append(train_labs)
    validation_predictions.append(val_preds)
    validation_labels.append(val_labels)
# Out:
# Train loss for epoch 0: 0.7039603590965271
# Val loss for epoch 0: 0.42136335372924805
# Train loss for epoch 1: 0.42136335372924805
# Val loss for epoch 1: 0.22744160890579224
# Train loss for epoch 2: 0.22744160890579224
# Val loss for epoch 2: 0.11093311011791229
# Train loss for epoch 3: 0.11093311011791229
# Val loss for epoch 3: 0.05015068128705025
# Train loss for epoch 4: 0.05015068128705025
# Val loss for epoch 4: 0.021632274612784386
# Train loss for epoch 5: 0.021632274612784386
# Val loss for epoch 5: 0.009121827781200409
# Train loss for epoch 6: 0.009121827781200409
# Val loss for epoch 6: 0.003833898575976491
# Train loss for epoch 7: 0.003833898575976491
# Val loss for epoch 7: 0.0016287709586322308
# Train loss for epoch 8: 0.0016287709586322308
# Val loss for epoch 8: 0.0007062663789838552
# Train loss for epoch 9: 0.0007062663789838552
# Val loss for epoch 9: 0.000314702425384894
# Train loss for epoch 10: 0.000314702425384894
# Val loss for epoch 10: 0.00014473055489361286
# Train loss for epoch 11: 0.00014473055489361286
# Val loss for epoch 11: 6.88457366777584e-05
# Train loss for epoch 12: 6.88457366777584e-05
# Val loss for epoch 12: 3.3975225960602984e-05
# Train loss for epoch 13: 3.3975225960602984e-05
# Val loss for epoch 13: 1.7404707250534557e-05
# Train loss for epoch 14: 1.7404707250534557e-05
# Val loss for epoch 14: 9.23876268643653e-06
# Train loss for epoch 15: 9.23876268643653e-06
# Val loss for epoch 15: 5.066407538834028e-06
# Train loss for epoch 16: 5.066407538834028e-06
# Val loss for epoch 16: 2.920631914093974e-06
# Train loss for epoch 17: 2.920631914093974e-06
# Val loss for epoch 17: 1.7285361764152185e-06
# Train loss for epoch 18: 1.7285361764152185e-06
# Val loss for epoch 18: 1.0728841743912199e-06
# Train loss for epoch 19: 1.0728841743912199e-06
# Val loss for epoch 19: 6.556513199029723e-07
# Train loss for epoch 20: 6.556513199029723e-07
# Val loss for epoch 20: 4.1723259869286267e-07
# Train loss for epoch 21: 4.1723259869286267e-07
# Val loss for epoch 21: 2.98023280720372e-07
# Train loss for epoch 22: 2.98023280720372e-07
# Val loss for epoch 22: 1.788139485370266e-07
# Train loss for epoch 23: 1.788139485370266e-07
# Val loss for epoch 23: 1.1920930376163597e-07
# Train loss for epoch 24: 1.1920930376163597e-07
# Val loss for epoch 24: 1.1920930376163597e-07
# Train loss for epoch 25: 1.1920930376163597e-07
# Val loss for epoch 25: 5.960464477539063e-08
# Train loss for epoch 26: 5.960464477539063e-08
# Val loss for epoch 26: 5.960464477539063e-08
# Train loss for epoch 27: 5.960464477539063e-08
# Val loss for epoch 27: 5.960464477539063e-08
# Train loss for epoch 28: 5.960464477539063e-08
# Val loss for epoch 28: 5.960464477539063e-08
# Train loss for epoch 29: 5.960464477539063e-08
# Val loss for epoch 29: 5.960464477539063e-08
# Train loss for epoch 30: 5.960464477539063e-08
# Val loss for epoch 30: 0.0
# Train loss for epoch 31: 0.0
# Val loss for epoch 31: 0.0
# Train loss for epoch 32: 0.0
# Val loss for epoch 32: 0.0
# Train loss for epoch 33: 0.0
# Val loss for epoch 33: 0.0
# Train loss for epoch 34: 0.0
# Val loss for epoch 34: 0.0
# Train loss for epoch 35: 0.0
# Val loss for epoch 35: 0.0
# Train loss for epoch 36: 0.0
# Val loss for epoch 36: 0.0
# Train loss for epoch 37: 0.0
# Val loss for epoch 37: 0.0
# Train loss for epoch 38: 0.0
# Val loss for epoch 38: 0.0
# Train loss for epoch 39: 0.0
# Val loss for epoch 39: 0.0
# Train loss for epoch 40: 0.0
# Val loss for epoch 40: 0.0
# Train loss for epoch 41: 0.0
# Val loss for epoch 41: 0.0
# Train loss for epoch 42: 0.0
# Val loss for epoch 42: 0.0
# Train loss for epoch 43: 0.0
# Val loss for epoch 43: 0.0
# Train loss for epoch 44: 0.0
# Val loss for epoch 44: 0.0
# Train loss for epoch 45: 0.0
# Val loss for epoch 45: 0.0
# Train loss for epoch 46: 0.0
# Val loss for epoch 46: 0.0
# Train loss for epoch 47: 0.0
# Val loss for epoch 47: 0.0
# Train loss for epoch 48: 0.0
# Val loss for epoch 48: 0.0
# Train loss for epoch 49: 0.0
# Val loss for epoch 49: 0.0
# Train loss for epoch 50: 0.0
# Val loss for epoch 50: 0.0
# Train loss for epoch 51: 0.0
# Val loss for epoch 51: 0.0
# Train loss for epoch 52: 0.0
# Val loss for epoch 52: 0.0
# Train loss for epoch 53: 0.0
# Val loss for epoch 53: 0.0
# Train loss for epoch 54: 0.0
# Val loss for epoch 54: 0.0
# Train loss for epoch 55: 0.0
# Val loss for epoch 55: 0.0
# Train loss for epoch 56: 0.0
# Val loss for epoch 56: 0.0
# Train loss for epoch 57: 0.0
# Val loss for epoch 57: 0.0
# Train loss for epoch 58: 0.0
# Val loss for epoch 58: 0.0
# Train loss for epoch 59: 0.0
# Val loss for epoch 59: 0.0
# Train loss for epoch 60: 0.0
# Val loss for epoch 60: 0.0
# Train loss for epoch 61: 0.0
# Val loss for epoch 61: 0.0
# Train loss for epoch 62: 0.0
# Val loss for epoch 62: 0.0
# Train loss for epoch 63: 0.0
# Val loss for epoch 63: 0.0
# Train loss for epoch 64: 0.0
# Val loss for epoch 64: 0.0
# Train loss for epoch 65: 0.0
# Val loss for epoch 65: 0.0
# Train loss for epoch 66: 0.0
# Val loss for epoch 66: 0.0
# Train loss for epoch 67: 0.0
# Val loss for epoch 67: 0.0
# Train loss for epoch 68: 0.0
# Val loss for epoch 68: 0.0
# Train loss for epoch 69: 0.0
# Val loss for epoch 69: 0.0
# Train loss for epoch 70: 0.0
# Val loss for epoch 70: 0.0
# Train loss for epoch 71: 0.0
# Val loss for epoch 71: 0.0
# Train loss for epoch 72: 0.0
# Val loss for epoch 72: 0.0
# Train loss for epoch 73: 0.0
# Val loss for epoch 73: 0.0
# Train loss for epoch 74: 0.0
# Val loss for epoch 74: 0.0
# Train loss for epoch 75: 0.0
# Val loss for epoch 75: 0.0
# Train loss for epoch 76: 0.0
# Val loss for epoch 76: 0.0
# Train loss for epoch 77: 0.0
# Val loss for epoch 77: 0.0
# Train loss for epoch 78: 0.0
# Val loss for epoch 78: 0.0
# Train loss for epoch 79: 0.0
# Val loss for epoch 79: 0.0
# Train loss for epoch 80: 0.0
# Val loss for epoch 80: 0.0
# Train loss for epoch 81: 0.0
# Val loss for epoch 81: 0.0
# Train loss for epoch 82: 0.0
# Val loss for epoch 82: 0.0
# Train loss for epoch 83: 0.0
# Val loss for epoch 83: 0.0
# Train loss for epoch 84: 0.0
# Val loss for epoch 84: 0.0
# Train loss for epoch 85: 0.0
# Val loss for epoch 85: 0.0
# Train loss for epoch 86: 0.0
# Val loss for epoch 86: 0.0
# Train loss for epoch 87: 0.0
# Val loss for epoch 87: 0.0
# Train loss for epoch 88: 0.0
# Val loss for epoch 88: 0.0
# Train loss for epoch 89: 0.0
# Val loss for epoch 89: 0.0
# Train loss for epoch 90: 0.0
# Val loss for epoch 90: 0.0
# Train loss for epoch 91: 0.0
# Val loss for epoch 91: 0.0
# Train loss for epoch 92: 0.0
# Val loss for epoch 92: 0.0
# Train loss for epoch 93: 0.0
# Val loss for epoch 93: 0.0
# Train loss for epoch 94: 0.0
# Val loss for epoch 94: 0.0
# Train loss for epoch 95: 0.0
# Val loss for epoch 95: 0.0
# Train loss for epoch 96: 0.0
# Val loss for epoch 96: 0.0
# Train loss for epoch 97: 0.0
# Val loss for epoch 97: 0.0
# Train loss for epoch 98: 0.0
# Val loss for epoch 98: 0.0
# Train loss for epoch 99: 0.0
# Val loss for epoch 99: 0.0

# %%
model = MLP().to(device)
# model.apply(weight_reset)

criterion = nn.BCELoss()
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)

training_losses = []
val_losses = []
training_acc = []
val_acc = []

train_predictions = []
validation_predictions = []
train_labels = []
validation_labels = []

for epoch in range(num_epochs):
    avg_train_loss, train_accuracy, train_preds, train_labs = train(train_loader_single, epoch)
    print('Train loss for epoch {}: {}'.format(epoch, avg_train_loss))
    val_loss, val_accuracy, val_preds, val_labels = test(val_loader_single, epoch)
    print('Val loss for epoch {}: {}'.format(epoch, val_loss))
    
    training_losses.append(avg_train_loss)
    training_acc.append(train_accuracy)
    val_losses.append(val_loss)
    val_acc.append(val_accuracy)
    
    train_predictions.append(train_preds)
    train_labels.append(train_labs)
    validation_predictions.append(val_preds)
    validation_labels.append(val_labels)
# Out:
# Train loss for epoch 0: 0.6323049068450928
# Val loss for epoch 0: 0.12737344205379486
# Train loss for epoch 1: 0.12737344205379486
# Val loss for epoch 1: 0.038932040333747864
# Train loss for epoch 2: 0.038932040333747864
# Val loss for epoch 2: 0.015314060263335705
# Train loss for epoch 3: 0.015314060263335705
# Val loss for epoch 3: 0.00675048865377903
# Train loss for epoch 4: 0.00675048865377903
# Val loss for epoch 4: 0.003244113177061081
# Train loss for epoch 5: 0.003244113177061081
# Val loss for epoch 5: 0.001679220236837864
# Train loss for epoch 6: 0.001679220236837864
# Val loss for epoch 6: 0.0009269240545108914
# Train loss for epoch 7: 0.0009269240545108914
# Val loss for epoch 70: 1.9669553239509696e-06
# Train loss for epoch 71: 1.9669553239509696e-06
# Val loss for epoch 71: 1.9669553239509696e-06
# Train loss for epoch 72: 1.9669553239509696e-06
# Val loss for epoch 72: 1.9669553239509696e-06
# Train loss for epoch 73: 1.9669553239509696e-06
# Val loss for epoch 73: 1.9669553239509696e-06
# Train loss for epoch 74: 1.9669553239509696e-06
# Val loss for epoch 74: 1.9669553239509696e-06
# Train loss for epoch 75: 1.9669553239509696e-06
# Val loss for epoch 75: 1.9669553239509696e-06
# Train loss for epoch 76: 1.9669553239509696e-06
# Val loss for epoch 76: 1.9669553239509696e-06
# Train loss for epoch 77: 1.9669553239509696e-06
# Val loss for epoch 77: 1.9669553239509696e-06
# Train loss for epoch 78: 1.9669553239509696e-06
# Val loss for epoch 78: 1.9669553239509696e-06
# Train loss for epoch 79: 1.9669553239509696e-06
# Val loss for epoch 79: 1.9669553239509696e-06
# Train loss for epoch 80: 1.9669553239509696e-06
# Val loss for epoch 80: 1.9669553239509696e-06
# Train loss for epoch 81: 1.9669553239509696e-06
# Val loss for epoch 81: 1.9669553239509696e-06
# Train loss for epoch 82: 1.9669553239509696e-06
# Val loss for epoch 82: 1.9669553239509696e-06
# Train loss for epoch 83: 1.9669553239509696e-06
# Val loss for epoch 83: 1.9669553239509696e-06
# Train loss for epoch 84: 1.9669553239509696e-06
# Val loss for epoch 84: 1.9669553239509696e-06
# Train loss for epoch 85: 1.9669553239509696e-06
# Val loss for epoch 85: 1.9669553239509696e-06
# Train loss for epoch 86: 1.9669553239509696e-06
# Val loss for epoch 86: 1.9669553239509696e-06
# Train loss for epoch 87: 1.9669553239509696e-06
# Val loss for epoch 87: 1.9669553239509696e-06
# Train loss for epoch 88: 1.9669553239509696e-06
# Val loss for epoch 88: 1.9669553239509696e-06
# Train loss for epoch 89: 1.9669553239509696e-06
# Val loss for epoch 89: 1.9669553239509696e-06
# Train loss for epoch 90: 1.9669553239509696e-06
# Val loss for epoch 90: 1.9669553239509696e-06
# Train loss for epoch 91: 1.9669553239509696e-06
# Val loss for epoch 91: 1.9669553239509696e-06
# Train loss for epoch 92: 1.9669553239509696e-06
# Val loss for epoch 92: 1.9669553239509696e-06
# Train loss for epoch 93: 1.9669553239509696e-06
# Val loss for epoch 93: 1.9669553239509696e-06
# Train loss for epoch 94: 1.9669553239509696e-06
# Val loss for epoch 94: 1.9669553239509696e-06
# Train loss for epoch 95: 1.9669553239509696e-06
# Val loss for epoch 95: 1.9669553239509696e-06
# Train loss for epoch 96: 1.9669553239509696e-06
# Val loss for epoch 96: 1.9669553239509696e-06
# Train loss for epoch 97: 1.9669553239509696e-06
# Val loss for epoch 97: 1.9669553239509696e-06
# Train loss for epoch 98: 1.9669553239509696e-06
# Val loss for epoch 98: 1.9669553239509696e-06
# Train loss for epoch 99: 1.9669553239509696e-06
# Val loss for epoch 99: 1.9669553239509696e-06

# %%
model
# Out:
# MLP(
#   (fc1): Linear(in_features=1000, out_features=200, bias=True)
#   (fc2): Linear(in_features=200, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
# )

# %%
model.fc1.weight.shape
# Out:
# torch.Size([200, 1000])
