# %% [markdown]
# # Make a faster version of spectrogram generation code, using notes from Monday's meeting such as
#
# 1) Load in all video files to start
#
# 2) Save all channels simultaneously
#
# 3) badtimes based on index in mat file
#
# 4) ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import torch
import os
from scipy.stats import zscore
import scipy
from scipy.io import loadmat

# %%
save_path = '../../data/'
total_nonmvmt_samples = len(os.listdir(save_path + 'sleep')) 
total_mvmt_samples = len(os.listdir(save_path + 'move')) 

print("Total non-movement = ", total_nonmvmt_samples, ' and total movement = ', total_mvmt_samples)
# Out:
# Total non-movement =  0  and total movement =  0

# %%
# first, load in util function used if there are no transitions in the currently loaded in NE file


def no_transitions_iterative(file,night,rec,spec_path):
    """
    
    Iterate through previous recordings, using those to determine whether or not vid is all movement or all non-movement. 
    
    """
    # At most 10 files
    try:
        for i in range(1,2): 
            try: 
                prev_file = 'N10W1dn1_'+night+'_rec'+ '00' + str(int(rec) - i)+'.mat'    

                # load in prev file, check transitions
               # if os.path.exists(spec_path + prev_file):
                prev_spec_data = loadmat(spec_path + prev_file)
                ti = prev_spec_data['Spec_per_Ch']['Ch1'][0][0]['ti'][0][0]
                vid_stop = ti[0][-1]/ 1000
                m_stop = prev_spec_data['Spec_per_Ch']['Ch1'][0][0]['m_stop'][0][0][0][-1] #[0][0][6]

                if m_stop < vid_stop:
                    print('Monkey is sleeping for the entire recording!')
                    return np.array([100000]), np.array([100000])
                else:
                    print("Monkey is moving for the entire recording!")
                    return np.array([0]), np.array([100000]) # movement for entire rec. 
            except:
                print("Unable to extract movements from recording ", int(rec) - i,'. Trying one prior.')

    except:
        print("Unable to return ")
                

def CameraFell(spec,times,ztotSpecs):
    """
    Checks for camera fall indicator, making all points following it discarded. 
    """
    
    camerafell = spec['Spec_per_Ch']['Ch1'][0][0]['CameraFell'][0][0]

    if camerafell.shape[0] <=1:
        print("cam does not fall :-) ")
        return ztotSpecs
    else:
        print("camera fell! discarding")


    idx = np.abs(times - camerafell[0][0]).argmin()
    
    ztotSpecs[:,idx,:] = np.nan
    
    return ztotSpecs
        
def OutOfFrame(spec,times,ztotSpecs):
    """
    Checks for out of frame indicators, and for all points within that interval, turns points to NaN, discarding
    """
    
    return2frame = spec['Spec_per_Ch']['Ch1'][0][0]['BackInFrame'][0][0]
    if return2frame.shape[0] <=1:
        print("monkey does not leave frame :-) ")
        return ztotSpecs
    
    
    leftframe = []
    oof_lm =  spec['Spec_per_Ch']['Ch1'][0][0]['OutOfFrame_LikelyMovement'][0][0]
    if oof_lm.shape[0] > 1:
        leftframe.append(oof_lm[0])
        
    oof_lnm = spec['Spec_per_Ch']['Ch1'][0][0]['OutOfFrame_LikelyNoMovement'][0][0]
    if oof_lnm.shape[0] > 1:
        leftframe.append(oof_lnm[0])
        
    oos_nsi = spec['Spec_per_Ch']['Ch1'][0][0]['OutOfFrame_NoStateIndications'][0][0]
    if oof_nsi.shape[0] > 1:
        leftframe.append(oof_nsi[0])

    
        
    leftframe = np.array(list(set(leftframe).flatten()))

   
    
    OOF_start_idx = []  
    for start in leftframe:
        idx = (np.abs(times-start)).argmin()
        OOF_start_idx.append(idx)

    OOF_stop_idx = []
    for stop in return2frame[0]:
        idx = (np.abs(times-stop)).argmin()
        OOF_stop_idx.append(idx)
        
    for start_idx, stop_idx in zip(OOF_start_idx,OOF_stop_idx):
        print(start_idx,stop_idx)

        ztotSpecs[:,start_idx:stop_idx,:]
        
    return ztotSpecs

# %%
len(os.listdir('../../../Spectrogram_mat_data/'))
# Out:
# 140

# %%
# main script. Runs over all specs of all recordings, saving into separate files the movement and non-movement info. 

def create_spec_dataset(spec_path = '../../../Spectrogram_mat_data/', save_path = '../../data/', task='movement',window = 10):
    """

    Loads in, the night event files, and uses those to then split into whatever designated window size is 
    used to then save in separate folders the corresponding input and output pairs for the movement vs non-movement classification task. 


    Would definitely be worth including as an attribute what the downstream task is, so as
    to allow this method to be used for saving any form of the data. 




    """



    #TODO: load in specs


    for file in os.listdir(spec_path)[:]:
        if file[-4:] != '.mat': # only consider .mat files 
            continue
        # sort of a metadata collection, read in what night and rec # this file corresponds to. 
        night = file.split('_')[1]
        rec = file.split('_')[2].split('.')[0][-3:]
        print("currently reading in ",file)

        ch = 0
        # TODO: Read spec main data
        spec_data = loadmat(spec_path + file)
        #return spec_data

        try:
            ti = spec_data['Spec_per_Ch']['Ch1'][0][0]['ti'][0][0]
        except Exception as e: 
            print("Error when trying to load in ti file. Something's wrong with ", file)
            print(e)
            continue

        # load in the other attributes. 
        f = spec_data['Spec_per_Ch']['Ch1'][0][0]['f'][0][0]#[0][0][ch][0][0][1]
        times = ti[0][:] // 1000
        try:
            test = spec_data['Spec_per_Ch']['Ch2']
        except:
            print("wrong format! cannot read. ")
            continue
        #badtimes = spec_data['Spec_per_Ch']['Ch1'][0][0]['badtimes'][0][0]#[0][0][ch][0][0][3]
        m_start = spec_data['Spec_per_Ch']['Ch1'][0][0]['m_start'][0][0]
        m_stop = spec_data['Spec_per_Ch']['Ch1'][0][0]['m_stop'][0][0]#[0][0][6]
        if m_start.shape[0] == 0: #check to see if there is movement info as part of this rec. 
            print(file, " has no transitions. ")
            #continue
           # print("Skipping ", file, " (no mstart)")
            print("This spec is either entirely moving or not moving. So let's check the prior rec. ")
            try:
                
                m_start, m_stop = no_transitions_iterative(file,night,rec,spec_path)  #TODO: add night before too, in case both are no transition. 
                print("Was able to use prior rec, saving.")
            except Exception as e:
                print(e)
                print("Unable to read ", file)
                continue
        else:
            m_start = m_start[0]
            m_stop = m_stop[0]


        all_badtimes = np.array([])
        specs = []
        for ch in range(1,63): #iterate over the 62 channels saved, stack together and proceed with that. 
            ztotSpec = spec_data['Spec_per_Ch']['Ch'+str(ch)][0][0]['ztotSpec'][0][0]
            # TODO: NaN check 
            specs.append(ztotSpec)
            
            badtimes = spec_data['Spec_per_Ch']['Ch'+str(ch)][0][0]['badtimes'][0][0]
            all_badtimes = np.concatenate([all_badtimes, badtimes.flatten()])
        
        all_badtimes = np.array(list(set(all_badtimes))) #method 1 
        ztotSpecs = np.stack(specs) # 62 x 100 x 7000

        ## Check for camera falling and out of frame indicators, remove all points after. 
        
        ztotSpecs = OutOfFrame(spec_data,times,ztotSpecs)
        ztotSpecs = CameraFell(spec_data,times,ztotSpecs)
        
        # transforms the movement start and stop times into the corresponding index on the 
        # spectrogram. 

        m_start_idx = []  
        for start in m_start:
            idx = (np.abs(times-start)).argmin()
            m_start_idx.append(idx)

        m_stop_idx = []
        for stop in m_stop:
            idx = (np.abs(times-stop)).argmin()
            m_stop_idx.append(idx)
            
        if m_start_idx[0] > m_stop_idx[0]:
            m_start_idx.insert(0,0)
            print('save 1')
        
        if len(m_start_idx) > len(m_stop_idx):
            m_stop_idx.append(-1) # now same 
            print("Saved the project. 2 ")
        
 
            

        # transforms the badtime time into corresponding index on spectrogram. In doing so, converts
        # that entire col to NaN values to ensure that window is discarded during saving. 
        badtime_idx = []    
        # TODO: apparently these are the bad times only for 1 channel? Add all badtime indices 
        # for every channel next. 
        for badtime in all_badtimes:
            idx = (np.abs(times-badtime)).argmin()
            badtime_idx.append(idx)

        for idx in badtime_idx:
            ztotSpecs[:,idx,:] = np.nan



        prior_mvmt_idx = 0 #initialize to 0, saves everything preceeding mvmt start idx to be non-movement
        for start_idx, stop_idx in zip(m_start_idx,m_stop_idx):
            print(start_idx,stop_idx)
            asleep = torch.from_numpy(ztotSpecs[:,int(round(prior_mvmt_idx)):int(round(start_idx)),:])
            moving = torch.from_numpy(ztotSpecs[:,int(round(start_idx)):int(round(stop_idx)),:])
            prior_mvmt_idx = stop_idx


            asleeps = torch.split(asleep,split_size_or_sections=window,dim=1)
            movings = torch.split(moving,split_size_or_sections=window,dim=1)

            print("Total # of non-movement windows saved: ", len(asleeps)-1) #not exact, but still a good indicator for this phase. 
            print("Total # of movement windows saved: ", len(movings)-1)

            # Now of these two arrays, split and save, assuming it does not include a badtime index

                                # loop over these windows and save 
            for i, arr in enumerate(asleeps):
                if not torch.isnan(arr.sum()) and arr.shape[1] == window:
                    np.save(save_path + 'sleep/' + night + '_' + rec + '_' + str(ch) + '_win'+str(i) +'_sleep.npy',arr.numpy()) 
            for i, arr in enumerate(movings):
                if not torch.isnan(arr.sum()) and arr.shape[1] == window:
                    np.save(save_path + 'move/' + night + '_' + rec + '_' + str(ch) + '_win'+str(i) +'_move.npy',arr.numpy()) 

    total_nonmvmt_samples = len(os.listdir(save_path + 'sleep')) 
    total_mvmt_samples = len(os.listdir(save_path + 'move')) 
           	
    print("Done! Total non-movement = ", total_nonmvmt_samples, ' and total movement = ', total_mvmt_samples)


if __name__ == '__main__':
    spec = create_spec_dataset()
# Out:
# currently reading in  N10W1dn1_180326_rec008.mat
# N10W1dn1_180326_rec008.mat  has no transitions.
# This spec is either entirely moving or not moving. So let's check the prior rec.
# Unable to extract movements from recording  7 . Trying one prior.
# cannot unpack non-iterable NoneType object
# Unable to read  N10W1dn1_180326_rec008.mat
# currently reading in  N10W1dn1_180323_rec001.mat
# monkey does not leave frame :-)
# cam does not fall :-)
# 0 3911
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  391
# 3913 3917
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  0
# 3980 6162
# Total # of non-movement windows saved:  6
# Total # of movement windows saved:  218
# 6180 6184
# Total # of non-movement windows saved:  1
# Total # of movement windows saved:  0
# 6369 6373
# Total # of non-movement windows saved:  18
# Total # of movement windows saved:  0
# 6480 6484
# Total # of non-movement windows saved:  10
# Total # of movement windows saved:  0
# 6487 6491
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  0
# 7100 7106
# Total # of non-movement windows saved:  60
# Total # of movement windows saved:  0
# currently reading in  N10W1dn1_180331_rec003.mat
# monkey does not leave frame :-)
# cam does not fall :-)
# 15 45
# Total # of non-movement windows saved:  1
# Total # of movement windows saved:  2
# 51 56
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  0
# 80 85
# Total # of non-movement windows saved:  2
# Total # of movement windows saved:  0
# 95 234
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  13
# 1695 1745
# Total # of non-movement windows saved:  146
# Total # of movement windows saved:  4
# 3042 3065
# Total # of non-movement windows saved:  129
# Total # of movement windows saved:  2
# 3068 3070
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  0
# 3161 3172
# Total # of non-movement windows saved:  9
# Total # of movement windows saved:  1
# 3823 3887
# Total # of non-movement windows saved:  65
# Total # of movement windows saved:  6
# 4028 4045
# Total # of non-movement windows saved:  14
# Total # of movement windows saved:  1
# 4114 4171
# Total # of non-movement windows saved:  6
# Total # of movement windows saved:  5
# 6005 6047
# Total # of non-movement windows saved:  183
# Total # of movement windows saved:  4
# 6072 6090
# Total # of non-movement windows saved:  2
# Total # of movement windows saved:  1
# 6111 6120
# Total # of non-movement windows saved:  2
# Total # of movement windows saved:  0
# 6580 6583
# Total # of non-movement windows saved:  45
# Total # of movement windows saved:  0
# 6714 6754
# Total # of non-movement windows saved:  13
# Total # of movement windows saved:  3
# 6810 6817
# Total # of non-movement windows saved:  5
# Total # of movement windows saved:  0
# 6864 6920
# Total # of non-movement windows saved:  4
# Total # of movement windows saved:  5
# currently reading in  N10W1dn1_180323_rec006.mat
# monkey does not leave frame :-)
# cam does not fall :-)
# save 1
# Saved the project. 2
# 0 1480
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  147
# 2129 4233
# Total # of non-movement windows saved:  64
# Total # of movement windows saved:  210
# 4847 6913
# Total # of non-movement windows saved:  61
# Total # of movement windows saved:  206
# 6920 6923
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  0
# 6977 6987
# Total # of non-movement windows saved:  5
# Total # of movement windows saved:  0
# 6995 7002
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  0
# 7008 7030
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  2
# 7045 7047
# Total # of non-movement windows saved:  1
# Total # of movement windows saved:  0
# 7065 7081
# Total # of non-movement windows saved:  1
# Total # of movement windows saved:  1
# 7097 -1
# Total # of non-movement windows saved:  1
# Total # of movement windows saved:  9
# currently reading in  N10W1dn1_180329_rec008.mat
# N10W1dn1_180329_rec008.mat  has no transitions.
# This spec is either entirely moving or not moving. So let's check the prior rec.
# Unable to extract movements from recording  7 . Trying one prior.
# cannot unpack non-iterable NoneType object
# Unable to read  N10W1dn1_180329_rec008.mat
# currently reading in  N10W1dn1_180326_rec004.mat
# monkey does not leave frame :-)
# cam does not fall :-)
# 42 52
# Total # of non-movement windows saved:  4
# Total # of movement windows saved:  0
# 196 217
# Total # of non-movement windows saved:  14
# Total # of movement windows saved:  2
# 705 764
# Total # of non-movement windows saved:  48
# Total # of movement windows saved:  5
# 1255 1283
# Total # of non-movement windows saved:  49
# Total # of movement windows saved:  2
# 3042 3071
# Total # of non-movement windows saved:  175
# Total # of movement windows saved:  2
# 3774 3781
# Total # of non-movement windows saved:  70
# Total # of movement windows saved:  0
# 3890 3898
# Total # of non-movement windows saved:  10
# Total # of movement windows saved:  0
# 3902 4021
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  11
# 4295 4319
# Total # of non-movement windows saved:  27
# Total # of movement windows saved:  2
# 4323 4339
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  1
# 6231 6245
# Total # of non-movement windows saved:  189
# Total # of movement windows saved:  1
# 6748 6783
# Total # of non-movement windows saved:  50
# Total # of movement windows saved:  3
# currently reading in  N10W1dn1_180326_rec010.mat
# N10W1dn1_180326_rec010.mat  has no transitions.
# This spec is either entirely moving or not moving. So let's check the prior rec.
# Unable to extract movements from recording  9 . Trying one prior.
# cannot unpack non-iterable NoneType object
# Unable to read  N10W1dn1_180326_rec010.mat
# currently reading in  N10W1dn1_180324_rec003.mat
# wrong format! cannot read.
# currently reading in  N10W1dn1_180409_rec005.mat
# monkey does not leave frame :-)
# cam does not fall :-)
# 1712 1740
# Total # of non-movement windows saved:  171
# Total # of movement windows saved:  2
# 3717 3734
# Total # of non-movement windows saved:  197
# Total # of movement windows saved:  1
# 4816 4848
# Total # of non-movement windows saved:  108
# Total # of movement windows saved:  3
# 4945 4949
# Total # of non-movement windows saved:  9
# Total # of movement windows saved:  0
# 5014 5017
# Total # of non-movement windows saved:  6
# Total # of movement windows saved:  0
# 5042 5862
# Total # of non-movement windows saved:  2
# Total # of movement windows saved:  81
# 5905 5936
# Total # of non-movement windows saved:  4
# Total # of movement windows saved:  3
# currently reading in  N10W1dn1_180322_rec009.mat
# N10W1dn1_180322_rec009.mat  has no transitions.
# This spec is either entirely moving or not moving. So let's check the prior rec.
# Unable to extract movements from recording  8 . Trying one prior.
# cannot unpack non-iterable NoneType object
# Unable to read  N10W1dn1_180322_rec009.mat
# currently reading in  N10W1dn1_180323_rec009.mat
# wrong format! cannot read.
# currently reading in  N10W1dn1_180326_rec002.mat
# N10W1dn1_180326_rec002.mat  has no transitions.
# This spec is either entirely moving or not moving. So let's check the prior rec.
# Unable to extract movements from recording  1 . Trying one prior.
# cannot unpack non-iterable NoneType object
# Unable to read  N10W1dn1_180326_rec002.mat
# currently reading in  N10W1dn1_180325_rec003.mat
# wrong format! cannot read.
# currently reading in  N10W1dn1_180326_rec003.mat
# monkey does not leave frame :-)
# cam does not fall :-)
# 522 553
# Total # of non-movement windows saved:  52
# Total # of movement windows saved:  3
# 1817 1838
# Total # of non-movement windows saved:  126
# Total # of movement windows saved:  2
# 2394 2413
# Total # of non-movement windows saved:  55
# Total # of movement windows saved:  1
# 3746 3754
# Total # of non-movement windows saved:  133
# Total # of movement windows saved:  0
# 3757 3778
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  2
# 4620 4806
# Total # of non-movement windows saved:  84
# Total # of movement windows saved:  18
# 4936 5226
# Total # of non-movement windows saved:  12
# Total # of movement windows saved:  28
# 6109 6126
# Total # of non-movement windows saved:  88
# Total # of movement windows saved:  1
# 6622 6623
# Total # of non-movement windows saved:  49
# Total # of movement windows saved:  0
# currently reading in  N10W1dn1_180326_rec005.mat
# monkey does not leave frame :-)
# cam does not fall :-)
# 1084 1096
# Total # of non-movement windows saved:  108
# Total # of movement windows saved:  1
# 2242 2285
# Total # of non-movement windows saved:  114
# Total # of movement windows saved:  4
# currently reading in  N10W1dn1_180326_rec006.mat
# N10W1dn1_180326_rec006.mat  has no transitions.
# This spec is either entirely moving or not moving. So let's check the prior rec.
# Monkey is sleeping for the entire recording!
# Was able to use prior rec, saving.
# monkey does not leave frame :-)
# cam does not fall :-)
# 7196 7196
# Total # of non-movement windows saved:  719
# Total # of movement windows saved:  0
# currently reading in  N10W1dn1_180410_rec005.mat
# monkey does not leave frame :-)
# cam does not fall :-)
# 25 30
# Total # of non-movement windows saved:  2
# Total # of movement windows saved:  0
# 1437 1451
# Total # of non-movement windows saved:  140
# Total # of movement windows saved:  1
# 1463 1466
# Total # of non-movement windows saved:  1
# Total # of movement windows saved:  0
# 1497 1929
# Total # of non-movement windows saved:  3
# Total # of movement windows saved:  43
# 1938 1956
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  1
# 2516 2538
# Total # of non-movement windows saved:  55
# Total # of movement windows saved:  2
# 2559 2563
# Total # of non-movement windows saved:  2
# Total # of movement windows saved:  0
# 3161 3168
# Total # of non-movement windows saved:  59
# Total # of movement windows saved:  0
# 4179 4190
# Total # of non-movement windows saved:  101
# Total # of movement windows saved:  1
# 4847 4855
# Total # of non-movement windows saved:  65
# Total # of movement windows saved:  0
# 6232 6240
# Total # of non-movement windows saved:  137
# Total # of movement windows saved:  0
# 6822 6847
# Total # of non-movement windows saved:  58
# Total # of movement windows saved:  2
# currently reading in  N10W1dn1_180331_rec001.mat
# monkey does not leave frame :-)
# cam does not fall :-)
# 0 2584
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  258
# 2603 2633
# Total # of non-movement windows saved:  1
# Total # of movement windows saved:  2
# 2696 2714
# Total # of non-movement windows saved:  6
# Total # of movement windows saved:  1
# 2720 2783
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  6
# 2796 2799
# Total # of non-movement windows saved:  1
# Total # of movement windows saved:  0
# 2804 2813
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  0
# 2971 2975
# Total # of non-movement windows saved:  15
# Total # of movement windows saved:  0
# 3722 3760
# Total # of non-movement windows saved:  74
# Total # of movement windows saved:  3
# 3822 3899
# Total # of non-movement windows saved:  6
# Total # of movement windows saved:  7
# 3914 3926
# Total # of non-movement windows saved:  1
# Total # of movement windows saved:  1
# 5050 5167
# Total # of non-movement windows saved:  112
# Total # of movement windows saved:  11
# 6491 6555
# Total # of non-movement windows saved:  132
# Total # of movement windows saved:  6
# 7088 7104
# Total # of non-movement windows saved:  53
# Total # of movement windows saved:  1
# currently reading in  N10W1dn1_180330_rec002.mat
# N10W1dn1_180330_rec002.mat  has no transitions.
# This spec is either entirely moving or not moving. So let's check the prior rec.
# Monkey is sleeping for the entire recording!
# Was able to use prior rec, saving.
# monkey does not leave frame :-)
# cam does not fall :-)
# 301 301
# Total # of non-movement windows saved:  30
# Total # of movement windows saved:  0
# currently reading in  N10W1dn1_180411_rec003.mat
# monkey does not leave frame :-)
# cam does not fall :-)
# 70 80
# Total # of non-movement windows saved:  6
# Total # of movement windows saved:  0
# 1296 1354
# Total # of non-movement windows saved:  121
# Total # of movement windows saved:  5
# 2119 2126
# Total # of non-movement windows saved:  76
# Total # of movement windows saved:  0
# 3407 3413
# Total # of non-movement windows saved:  128
# Total # of movement windows saved:  0
# 3812 3826
# Total # of non-movement windows saved:  39
# Total # of movement windows saved:  1
# 4020 4025
# Total # of non-movement windows saved:  19
# Total # of movement windows saved:  0
# 4409 4429
# Total # of non-movement windows saved:  38
# Total # of movement windows saved:  1
# 4432 4438
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  0
# 5167 5173
# Total # of non-movement windows saved:  72
# Total # of movement windows saved:  0
# 5560 5564
# Total # of non-movement windows saved:  38
# Total # of movement windows saved:  0
# 5586 5587
# Total # of non-movement windows saved:  2
# Total # of movement windows saved:  0
# 5595 5606
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  1
# 5611 5623
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  1
# 5668 5678
# Total # of non-movement windows saved:  4
# Total # of movement windows saved:  0
# 5830 5847
# Total # of non-movement windows saved:  15
# Total # of movement windows saved:  1
# 5867 5871
# Total # of non-movement windows saved:  1
# Total # of movement windows saved:  0
# 6294 6300
# Total # of non-movement windows saved:  42
# Total # of movement windows saved:  0
# currently reading in  N10W1dn1_180322_rec003.mat
# monkey does not leave frame :-)
# cam does not fall :-)
# 302 322
# Total # of non-movement windows saved:  30
# Total # of movement windows saved:  1
# 1877 1935
# Total # of non-movement windows saved:  155
# Total # of movement windows saved:  5
# 2417 2439
# Total # of non-movement windows saved:  48
# Total # of movement windows saved:  2
# 2455 2457
# Total # of non-movement windows saved:  1
# Total # of movement windows saved:  0
# 3614 3637
# Total # of non-movement windows saved:  115
# Total # of movement windows saved:  2
# 4051 4058
# Total # of non-movement windows saved:  41
# Total # of movement windows saved:  0
# 4323 4359
# Total # of non-movement windows saved:  26
# Total # of movement windows saved:  3
# 4418 4429
# Total # of non-movement windows saved:  5
# Total # of movement windows saved:  1
# 4690 4697
# Total # of non-movement windows saved:  26
# Total # of movement windows saved:  0
# 5025 5032
# Total # of non-movement windows saved:  32
# Total # of movement windows saved:  0
# 5454 5455
# Total # of non-movement windows saved:  42
# Total # of movement windows saved:  0
# 7106 7118
# Total # of non-movement windows saved:  165
# Total # of movement windows saved:  1
# 7133 7150
# Total # of non-movement windows saved:  1
# Total # of movement windows saved:  1
# currently reading in  N10W1dn1_180327_rec004.mat
# monkey does not leave frame :-)
# cam does not fall :-)
# 1776 1799
# Total # of non-movement windows saved:  177
# Total # of movement windows saved:  2
# 1948 2888
# Total # of non-movement windows saved:  14
# Total # of movement windows saved:  93
# 3980 3998
# Total # of non-movement windows saved:  109
# Total # of movement windows saved:  1
# 5555 5587
# Total # of non-movement windows saved:  155
# Total # of movement windows saved:  3
# 6654 6673
# Total # of non-movement windows saved:  106
# Total # of movement windows saved:  1
# 6723 6727
# Total # of non-movement windows saved:  4
# Total # of movement windows saved:  0
# 6989 7050
# Total # of non-movement windows saved:  26
# Total # of movement windows saved:  6
# currently reading in  N10W1dn1_180322_rec005.mat
# monkey does not leave frame :-)
# cam does not fall :-)
# 526 540
# Total # of non-movement windows saved:  52
# Total # of movement windows saved:  1
# 553 562
# Total # of non-movement windows saved:  1
# Total # of movement windows saved:  0
# 831 837
# Total # of non-movement windows saved:  26
# Total # of movement windows saved:  0
# 1189 1194
# Total # of non-movement windows saved:  35
# Total # of movement windows saved:  0
# 1208 1223
# Total # of non-movement windows saved:  1
# Total # of movement windows saved:  1
# 1259 1284
# Total # of non-movement windows saved:  3
# Total # of movement windows saved:  2
# 2268 2275
# Total # of non-movement windows saved:  98
# Total # of movement windows saved:  0
# 2290 2292
# Total # of non-movement windows saved:  1
# Total # of movement windows saved:  0
# 2610 2620
# Total # of non-movement windows saved:  31
# Total # of movement windows saved:  0
# 3196 3220
# Total # of non-movement windows saved:  57
# Total # of movement windows saved:  2
# 3251 3251
# Total # of non-movement windows saved:  3
# Total # of movement windows saved:  0
# 3270 3275
# Total # of non-movement windows saved:  1
# Total # of movement windows saved:  0
# 3289 3291
# Total # of non-movement windows saved:  1
# Total # of movement windows saved:  0
# 3311 5842
# Total # of non-movement windows saved:  1
# Total # of movement windows saved:  253
# 6789 6807
# Total # of non-movement windows saved:  94
# Total # of movement windows saved:  1
# currently reading in  N10W1dn1_180413_rec006.mat
# monkey does not leave frame :-)
# cam does not fall :-)
# 1879 1887
# Total # of non-movement windows saved:  187
# Total # of movement windows saved:  0
# 1898 1907
# Total # of non-movement windows saved:  1
# Total # of movement windows saved:  0
# 2429 2445
# Total # of non-movement windows saved:  52
# Total # of movement windows saved:  1
# 2451 2454
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  0
# 2472 2479
# Total # of non-movement windows saved:  1
# Total # of movement windows saved:  0
# 2484 2497
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  1
# 2578 2593
# Total # of non-movement windows saved:  8
# Total # of movement windows saved:  1
# 2603 2613
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  0
# 2658 2664
# Total # of non-movement windows saved:  4
# Total # of movement windows saved:  0
# 3866 3876
# Total # of non-movement windows saved:  120
# Total # of movement windows saved:  0
# 4128 4131
# Total # of non-movement windows saved:  25
# Total # of movement windows saved:  0
# 4144 4147
# Total # of non-movement windows saved:  1
# Total # of movement windows saved:  0
# 4163 4165
# Total # of non-movement windows saved:  1
# Total # of movement windows saved:  0
# 4815 4833
# Total # of non-movement windows saved:  64
# Total # of movement windows saved:  1
# 5732 5737
# Total # of non-movement windows saved:  89
# Total # of movement windows saved:  0
# 6253 6273
# Total # of non-movement windows saved:  51
# Total # of movement windows saved:  1
# currently reading in  N10W1dn1_180412_rec003.mat
# monkey does not leave frame :-)
# cam does not fall :-)
# 372 376
# Total # of non-movement windows saved:  37
# Total # of movement windows saved:  0
# 1128 1136
# Total # of non-movement windows saved:  75
# Total # of movement windows saved:  0
# 1243 1244
# Total # of non-movement windows saved:  10
# Total # of movement windows saved:  0
# 1776 1803
# Total # of non-movement windows saved:  53
# Total # of movement windows saved:  2
# 1834 1836
# Total # of non-movement windows saved:  3
# Total # of movement windows saved:  0
# 2886 2901
# Total # of non-movement windows saved:  104
# Total # of movement windows saved:  1
# 3547 3554
# Total # of non-movement windows saved:  64
# Total # of movement windows saved:  0
# 4020 4026
# Total # of non-movement windows saved:  46
# Total # of movement windows saved:  0
# 4409 4422
# Total # of non-movement windows saved:  38
# Total # of movement windows saved:  1
# 4999 5009
# Total # of non-movement windows saved:  57
# Total # of movement windows saved:  0
# 5047 5058
# Total # of non-movement windows saved:  3
# Total # of movement windows saved:  1
# 5065 5070
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  0
# 6044 6048
# Total # of non-movement windows saved:  97
# Total # of movement windows saved:  0
# currently reading in  N10W1dn1_180330_rec011.mat
# monkey does not leave frame :-)
# cam does not fall :-)
# save 1
# Saved the project. 2
# 0 0
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  0
# 15 -1
# Total # of non-movement windows saved:  1
# Total # of movement windows saved:  131
# currently reading in  N10W1dn1_180325_rec007.mat
# wrong format! cannot read.
# currently reading in  N10W1dn1_180329_rec001.mat
# monkey does not leave frame :-)
# cam does not fall :-)
# 0 1526
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  152
# 1587 1597
# Total # of non-movement windows saved:  6
# Total # of movement windows saved:  0
# 1624 1749
# Total # of non-movement windows saved:  2
# Total # of movement windows saved:  12
# 1834 1839
# Total # of non-movement windows saved:  8
# Total # of movement windows saved:  0
# 2305 2325
# Total # of non-movement windows saved:  46
# Total # of movement windows saved:  1
# 2349 2443
# Total # of non-movement windows saved:  2
# Total # of movement windows saved:  9
# 2657 2667
# Total # of non-movement windows saved:  21
# Total # of movement windows saved:  0
# 2673 2774
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  10
# 3206 3221
# Total # of non-movement windows saved:  43
# Total # of movement windows saved:  1
# 4194 4201
# Total # of non-movement windows saved:  97
# Total # of movement windows saved:  0
# 5117 5129
# Total # of non-movement windows saved:  91
# Total # of movement windows saved:  1
# 5295 5323
# Total # of non-movement windows saved:  16
# Total # of movement windows saved:  2
# 5375 5478
# Total # of non-movement windows saved:  5
# Total # of movement windows saved:  10
# 6168 6190
# Total # of non-movement windows saved:  68
# Total # of movement windows saved:  2
# currently reading in  N10W1dn1_180322_rec002.mat
# monkey does not leave frame :-)
# cam does not fall :-)
# 311 3488
# Total # of non-movement windows saved:  31
# Total # of movement windows saved:  317
# 5104 5134
# Total # of non-movement windows saved:  161
# Total # of movement windows saved:  2
# 5313 5315
# Total # of non-movement windows saved:  17
# Total # of movement windows saved:  0
# 5422 5424
# Total # of non-movement windows saved:  10
# Total # of movement windows saved:  0
# 5914 5930
# Total # of non-movement windows saved:  48
# Total # of movement windows saved:  1
# 5953 5961
# Total # of non-movement windows saved:  2
# Total # of movement windows saved:  0
# 6602 6616
# Total # of non-movement windows saved:  64
# Total # of movement windows saved:  1
# 6637 6648
# Total # of non-movement windows saved:  2
# Total # of movement windows saved:  1
# 6652 6654
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  0
# currently reading in  N10W1dn1_180401_rec002.mat
# wrong format! cannot read.
# currently reading in  N10W1dn1_180412_rec004.mat
# monkey does not leave frame :-)
# cam does not fall :-)
# 224 258
# Total # of non-movement windows saved:  22
# Total # of movement windows saved:  3
# 513 525
# Total # of non-movement windows saved:  25
# Total # of movement windows saved:  1
# 706 722
# Total # of non-movement windows saved:  18
# Total # of movement windows saved:  1
# 1238 1262
# Total # of non-movement windows saved:  51
# Total # of movement windows saved:  2
# 2507 2515
# Total # of non-movement windows saved:  124
# Total # of movement windows saved:  0
# 2693 2697
# Total # of non-movement windows saved:  17
# Total # of movement windows saved:  0
# 2784 2811
# Total # of non-movement windows saved:  8
# Total # of movement windows saved:  2
# 3034 3046
# Total # of non-movement windows saved:  22
# Total # of movement windows saved:  1
# 3140 3220
# Total # of non-movement windows saved:  9
# Total # of movement windows saved:  7
# 3257 4217
# Total # of non-movement windows saved:  3
# Total # of movement windows saved:  95
# 4344 4358
# Total # of non-movement windows saved:  12
# Total # of movement windows saved:  1
# 4436 4446
# Total # of non-movement windows saved:  7
# Total # of movement windows saved:  0
# 4478 4482
# Total # of non-movement windows saved:  3
# Total # of movement windows saved:  0
# 4626 4629
# Total # of non-movement windows saved:  14
# Total # of movement windows saved:  0
# 4645 4660
# Total # of non-movement windows saved:  1
# Total # of movement windows saved:  1
# 4680 4692
# Total # of non-movement windows saved:  1
# Total # of movement windows saved:  1
# 4839 4843
# Total # of non-movement windows saved:  14
# Total # of movement windows saved:  0
# 5181 5191
# Total # of non-movement windows saved:  33
# Total # of movement windows saved:  0
# 5915 5950
# Total # of non-movement windows saved:  72
# Total # of movement windows saved:  3
# 7079 7081
# Total # of non-movement windows saved:  112
# Total # of movement windows saved:  0
# currently reading in  N10W1dn1_180330_rec008.mat
# monkey does not leave frame :-)
# cam does not fall :-)
# save 1
# 0 0
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  0
# 109 1852
# Total # of non-movement windows saved:  10
# Total # of movement windows saved:  174
# 2044 4881
# Total # of non-movement windows saved:  19
# Total # of movement windows saved:  283
# 4910 4953
# Total # of non-movement windows saved:  2
# Total # of movement windows saved:  4
# 5492 7107
# Total # of non-movement windows saved:  53
# Total # of movement windows saved:  161
# currently reading in  N10W1dn1_180330_rec010.mat
# monkey does not leave frame :-)
# cam does not fall :-)
# save 1
# Saved the project. 2
# 0 3786
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  378
# 4024 4359
# Total # of non-movement windows saved:  23
# Total # of movement windows saved:  33
# 4664 -1
# Total # of non-movement windows saved:  30
# Total # of movement windows saved:  252
# currently reading in  N10W1dn1_180401_rec007.mat
# wrong format! cannot read.
# currently reading in  N10W1dn1_180331_rec006.mat
# monkey does not leave frame :-)
# cam does not fall :-)
# 412 438
# Total # of non-movement windows saved:  41
# Total # of movement windows saved:  2
# 472 504
# Total # of non-movement windows saved:  3
# Total # of movement windows saved:  3
# 2033 2051
# Total # of non-movement windows saved:  152
# Total # of movement windows saved:  1
# 3473 3489
# Total # of non-movement windows saved:  142
# Total # of movement windows saved:  1
# 3501 3506
# Total # of non-movement windows saved:  1
# Total # of movement windows saved:  0
# 4187 4211
# Total # of non-movement windows saved:  68
# Total # of movement windows saved:  2
# 4814 4822
# Total # of non-movement windows saved:  60
# Total # of movement windows saved:  0
# 5610 5631
# Total # of non-movement windows saved:  78
# Total # of movement windows saved:  2
# 6187 6210
# Total # of non-movement windows saved:  55
# Total # of movement windows saved:  2
# 6663 6677
# Total # of non-movement windows saved:  45
# Total # of movement windows saved:  1
# 6993 7007
# Total # of non-movement windows saved:  31
# Total # of movement windows saved:  1
# currently reading in  N10W1dn1_180323_rec002.mat
# monkey does not leave frame :-)
# cam does not fall :-)
# 1060 1080
# Total # of non-movement windows saved:  105
# Total # of movement windows saved:  1
# 1086 1098
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  1
# 2002 2008
# Total # of non-movement windows saved:  90
# Total # of movement windows saved:  0
# 3162 3163
# Total # of non-movement windows saved:  115
# Total # of movement windows saved:  0
# 3648 3671
# Total # of non-movement windows saved:  48
# Total # of movement windows saved:  2
# 4193 4201
# Total # of non-movement windows saved:  52
# Total # of movement windows saved:  0
# 4221 4228
# Total # of non-movement windows saved:  1
# Total # of movement windows saved:  0
# 4844 4857
# Total # of non-movement windows saved:  61
# Total # of movement windows saved:  1
# 6262 6264
# Total # of non-movement windows saved:  140
# Total # of movement windows saved:  0
# 6269 6291
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  2
# 6307 6321
# Total # of non-movement windows saved:  1
# Total # of movement windows saved:  1
# 6815 6839
# Total # of non-movement windows saved:  49
# Total # of movement windows saved:  2
# currently reading in  N10W1dn1_180323_rec008.mat
# N10W1dn1_180323_rec008.mat  has no transitions.
# This spec is either entirely moving or not moving. So let's check the prior rec.
# Monkey is sleeping for the entire recording!
# Was able to use prior rec, saving.
# monkey does not leave frame :-)
# cam does not fall :-)
# 7196 7196
# Total # of non-movement windows saved:  719
# Total # of movement windows saved:  0
# currently reading in  N10W1dn1_180330_rec005.mat
# monkey does not leave frame :-)
# cam does not fall :-)
# 344 381
# Total # of non-movement windows saved:  34
# Total # of movement windows saved:  3
# 689 695
# Total # of non-movement windows saved:  30
# Total # of movement windows saved:  0
# 2113 2140
# Total # of non-movement windows saved:  141
# Total # of movement windows saved:  2
# 2832 2855
# Total # of non-movement windows saved:  69
# Total # of movement windows saved:  2
# 3181 3185
# Total # of non-movement windows saved:  32
# Total # of movement windows saved:  0
# 3564 3584
# Total # of non-movement windows saved:  37
# Total # of movement windows saved:  1
# 3787 3793
# Total # of non-movement windows saved:  20
# Total # of movement windows saved:  0
# 3994 3996
# Total # of non-movement windows saved:  20
# Total # of movement windows saved:  0
# 4210 4254
# Total # of non-movement windows saved:  21
# Total # of movement windows saved:  4
# 4769 4778
# Total # of non-movement windows saved:  51
# Total # of movement windows saved:  0
# 5807 5819
# Total # of non-movement windows saved:  102
# Total # of movement windows saved:  1
# 6454 6481
# Total # of non-movement windows saved:  63
# Total # of movement windows saved:  2
# 6956 6985
# Total # of non-movement windows saved:  47
# Total # of movement windows saved:  2
# currently reading in  N10W1dn1_180331_rec008.mat
# N10W1dn1_180331_rec008.mat  has no transitions.
# This spec is either entirely moving or not moving. So let's check the prior rec.
# Monkey is sleeping for the entire recording!
# Was able to use prior rec, saving.
# monkey does not leave frame :-)
# cam does not fall :-)
# 4349 4349
# Total # of non-movement windows saved:  434
# Total # of movement windows saved:  0
# currently reading in  N10W1dn1_180324_rec005.mat
# wrong format! cannot read.
# currently reading in  N10W1dn1_180326_rec009.mat
# N10W1dn1_180326_rec009.mat  has no transitions.
# This spec is either entirely moving or not moving. So let's check the prior rec.
# Unable to extract movements from recording  8 . Trying one prior.
# cannot unpack non-iterable NoneType object
# Unable to read  N10W1dn1_180326_rec009.mat
# currently reading in  N10W1dn1_180322_rec006.mat
# monkey does not leave frame :-)
# cam does not fall :-)
# Saved the project. 2
# 1280 1286
# Total # of non-movement windows saved:  127
# Total # of movement windows saved:  0
# 2713 2720
# Total # of non-movement windows saved:  142
# Total # of movement windows saved:  0
# 2813 2862
# Total # of non-movement windows saved:  9
# Total # of movement windows saved:  4
# 2914 2954
# Total # of non-movement windows saved:  5
# Total # of movement windows saved:  3
# 2968 2974
# Total # of non-movement windows saved:  1
# Total # of movement windows saved:  0
# 3074 3098
# Total # of non-movement windows saved:  9
# Total # of movement windows saved:  2
# 3105 3107
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  0
# 3111 3114
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  0
# 3121 -1
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  406
# currently reading in  N10W1dn1_180324_rec001.mat
# wrong format! cannot read.
# currently reading in  N10W1dn1_180325_rec002.mat
# wrong format! cannot read.
# currently reading in  N10W1dn1_180327_rec001.mat
# monkey does not leave frame :-)
# cam does not fall :-)
# 0 2334
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  233
# 2829 2831
# Total # of non-movement windows saved:  49
# Total # of movement windows saved:  0
# 3393 3423
# Total # of non-movement windows saved:  56
# Total # of movement windows saved:  2
# 3996 3998
# Total # of non-movement windows saved:  57
# Total # of movement windows saved:  0
# 4022 4028
# Total # of non-movement windows saved:  2
# Total # of movement windows saved:  0
# 4090 4152
# Total # of non-movement windows saved:  6
# Total # of movement windows saved:  6
# 4196 4203
# Total # of non-movement windows saved:  4
# Total # of movement windows saved:  0
# 4220 4270
# Total # of non-movement windows saved:  1
# Total # of movement windows saved:  4
# 4764 4783
# Total # of non-movement windows saved:  49
# Total # of movement windows saved:  1
# 6565 6575
# Total # of non-movement windows saved:  178
# Total # of movement windows saved:  0
# 6660 7135
# Total # of non-movement windows saved:  8
# Total # of movement windows saved:  47
# currently reading in  N10W1dn1_180325_rec006.mat
# wrong format! cannot read.
# currently reading in  N10W1dn1_180413_rec002.mat
# monkey does not leave frame :-)
# cam does not fall :-)
# save 1
# Saved the project. 2
# 0 2063
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  206
# 2146 2154
# Total # of non-movement windows saved:  8
# Total # of movement windows saved:  0
# 2263 2267
# Total # of non-movement windows saved:  10
# Total # of movement windows saved:  0
# 2277 2286
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  0
# 2420 2423
# Total # of non-movement windows saved:  13
# Total # of movement windows saved:  0
# 2806 2830
# Total # of non-movement windows saved:  38
# Total # of movement windows saved:  2
# 2905 2907
# Total # of non-movement windows saved:  7
# Total # of movement windows saved:  0
# 3144 3150
# Total # of non-movement windows saved:  23
# Total # of movement windows saved:  0
# 3187 3189
# Total # of non-movement windows saved:  3
# Total # of movement windows saved:  0
# 3402 -1
# Total # of non-movement windows saved:  21
# Total # of movement windows saved:  378
# currently reading in  N10W1dn1_180325_rec001.mat
# wrong format! cannot read.
# currently reading in  N10W1dn1_180411_rec006.mat
# monkey does not leave frame :-)
# cam does not fall :-)
# Saved the project. 2
# 318 327
# Total # of non-movement windows saved:  31
# Total # of movement windows saved:  0
# 500 515
# Total # of non-movement windows saved:  17
# Total # of movement windows saved:  1
# 1389 1402
# Total # of non-movement windows saved:  87
# Total # of movement windows saved:  1
# 1710 1725
# Total # of non-movement windows saved:  30
# Total # of movement windows saved:  1
# 2070 2076
# Total # of non-movement windows saved:  34
# Total # of movement windows saved:  0
# 2492 2495
# Total # of non-movement windows saved:  41
# Total # of movement windows saved:  0
# 2510 2521
# Total # of non-movement windows saved:  1
# Total # of movement windows saved:  1
# 2903 2912
# Total # of non-movement windows saved:  38
# Total # of movement windows saved:  0
# 3664 3685
# Total # of non-movement windows saved:  75
# Total # of movement windows saved:  2
# 3707 3755
# Total # of non-movement windows saved:  2
# Total # of movement windows saved:  4
# 3764 3774
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  0
# 3782 3785
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  0
# 4219 4236
# Total # of non-movement windows saved:  43
# Total # of movement windows saved:  1
# 4257 4259
# Total # of non-movement windows saved:  2
# Total # of movement windows saved:  0
# 4665 4689
# Total # of non-movement windows saved:  40
# Total # of movement windows saved:  2
# 5179 5184
# Total # of non-movement windows saved:  48
# Total # of movement windows saved:  0
# 5223 5247
# Total # of non-movement windows saved:  3
# Total # of movement windows saved:  2
# 5254 5256
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  0
# 5385 5788
# Total # of non-movement windows saved:  12
# Total # of movement windows saved:  40
# 5908 5934
# Total # of non-movement windows saved:  11
# Total # of movement windows saved:  2
# 6133 6145
# Total # of non-movement windows saved:  19
# Total # of movement windows saved:  1
# 6207 6216
# Total # of non-movement windows saved:  6
# Total # of movement windows saved:  0
# 6317 -1
# Total # of non-movement windows saved:  10
# Total # of movement windows saved:  87
# currently reading in  N10W1dn1_180323_rec007.mat
# monkey does not leave frame :-)
# cam does not fall :-)
# save 1
# Saved the project. 2
# 0 0
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  0
# 57 78
# Total # of non-movement windows saved:  5
# Total # of movement windows saved:  2
# 108 -1
# Total # of non-movement windows saved:  2
# Total # of movement windows saved:  708
# currently reading in  N10W1dn1_180409_rec004.mat
# monkey does not leave frame :-)
# cam does not fall :-)
# 980 991
# Total # of non-movement windows saved:  97
# Total # of movement windows saved:  1
# 1106 1114
# Total # of non-movement windows saved:  11
# Total # of movement windows saved:  0
# 1475 1484
# Total # of non-movement windows saved:  36
# Total # of movement windows saved:  0
# 1625 1713
# Total # of non-movement windows saved:  14
# Total # of movement windows saved:  8
# 2538 2547
# Total # of non-movement windows saved:  82
# Total # of movement windows saved:  0
# 2822 2831
# Total # of non-movement windows saved:  27
# Total # of movement windows saved:  0
# 2896 2909
# Total # of non-movement windows saved:  6
# Total # of movement windows saved:  1
# 4052 4092
# Total # of non-movement windows saved:  114
# Total # of movement windows saved:  3
# 4655 4668
# Total # of non-movement windows saved:  56
# Total # of movement windows saved:  1
# 6739 6778
# Total # of non-movement windows saved:  207
# Total # of movement windows saved:  3
# currently reading in  N10W1dn1_180411_rec007.mat
# monkey does not leave frame :-)
# cam does not fall :-)
# save 1
# Saved the project. 2
# 0 1329
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  132
# 1456 1483
# Total # of non-movement windows saved:  12
# Total # of movement windows saved:  2
# 1622 -1
# Total # of non-movement windows saved:  13
# Total # of movement windows saved:  64
# currently reading in  N10W1dn1_180409_rec003.mat
# monkey does not leave frame :-)
# cam does not fall :-)
# 1119 1125
# Total # of non-movement windows saved:  111
# Total # of movement windows saved:  0
# 1143 1147
# Total # of non-movement windows saved:  1
# Total # of movement windows saved:  0
# 1149 1231
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  8
# 1256 1274
# Total # of non-movement windows saved:  2
# Total # of movement windows saved:  1
# 1724 1746
# Total # of non-movement windows saved:  44
# Total # of movement windows saved:  2
# 2212 2222
# Total # of non-movement windows saved:  46
# Total # of movement windows saved:  0
# 3504 3521
# Total # of non-movement windows saved:  128
# Total # of movement windows saved:  1
# 3529 3538
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  0
# 3783 3817
# Total # of non-movement windows saved:  24
# Total # of movement windows saved:  3
# 4712 4731
# Total # of non-movement windows saved:  89
# Total # of movement windows saved:  1
# 4741 4747
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  0
# 4977 4989
# Total # of non-movement windows saved:  22
# Total # of movement windows saved:  1
# 6457 6470
# Total # of non-movement windows saved:  146
# Total # of movement windows saved:  1
# currently reading in  N10W1dn1_180330_rec003.mat
# monkey does not leave frame :-)
# cam does not fall :-)
# 617 670
# Total # of non-movement windows saved:  61
# Total # of movement windows saved:  5
# 1172 1182
# Total # of non-movement windows saved:  50
# Total # of movement windows saved:  0
# 1204 1223
# Total # of non-movement windows saved:  2
# Total # of movement windows saved:  1
# 1554 1560
# Total # of non-movement windows saved:  33
# Total # of movement windows saved:  0
# 1644 1651
# Total # of non-movement windows saved:  8
# Total # of movement windows saved:  0
# 2379 2428
# Total # of non-movement windows saved:  72
# Total # of movement windows saved:  4
# 2608 2617
# Total # of non-movement windows saved:  17
# Total # of movement windows saved:  0
# 3085 3104
# Total # of non-movement windows saved:  46
# Total # of movement windows saved:  1
# 3130 3140
# Total # of non-movement windows saved:  2
# Total # of movement windows saved:  0
# 3285 3303
# Total # of non-movement windows saved:  14
# Total # of movement windows saved:  1
# 3319 3324
# Total # of non-movement windows saved:  1
# Total # of movement windows saved:  0
# 3383 3391
# Total # of non-movement windows saved:  5
# Total # of movement windows saved:  0
# 3565 3571
# Total # of non-movement windows saved:  17
# Total # of movement windows saved:  0
# 3601 3612
# Total # of non-movement windows saved:  2
# Total # of movement windows saved:  1
# 3616 3623
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  0
# 4439 4442
# Total # of non-movement windows saved:  81
# Total # of movement windows saved:  0
# 5462 5471
# Total # of non-movement windows saved:  101
# Total # of movement windows saved:  0
# 5489 5501
# Total # of non-movement windows saved:  1
# Total # of movement windows saved:  1
# 5701 5706
# Total # of non-movement windows saved:  19
# Total # of movement windows saved:  0
# 5749 5763
# Total # of non-movement windows saved:  4
# Total # of movement windows saved:  1
# 6083 6092
# Total # of non-movement windows saved:  31
# Total # of movement windows saved:  0
# 6389 6411
# Total # of non-movement windows saved:  29
# Total # of movement windows saved:  2
# 6739 6739
# Total # of non-movement windows saved:  32
# Total # of movement windows saved:  0
# 6809 6814
# Total # of non-movement windows saved:  6
# Total # of movement windows saved:  0
# 6898 6902
# Total # of non-movement windows saved:  8
# Total # of movement windows saved:  0
# 6914 6987
# Total # of non-movement windows saved:  1
# Total # of movement windows saved:  7
# currently reading in  N10W1dn1_180330_rec004.mat
# monkey does not leave frame :-)
# cam does not fall :-)
# 1004 1016
# Total # of non-movement windows saved:  100
# Total # of movement windows saved:  1
# 2124 2144
# Total # of non-movement windows saved:  110
# Total # of movement windows saved:  1
# 2190 2204
# Total # of non-movement windows saved:  4
# Total # of movement windows saved:  1
# 2814 2830
# Total # of non-movement windows saved:  60
# Total # of movement windows saved:  1
# 2961 2985
# Total # of non-movement windows saved:  13
# Total # of movement windows saved:  2
# 3940 3987
# Total # of non-movement windows saved:  95
# Total # of movement windows saved:  4
# 4052 4056
# Total # of non-movement windows saved:  6
# Total # of movement windows saved:  0
# 4628 4643
# Total # of non-movement windows saved:  57
# Total # of movement windows saved:  1
# 4856 4866
# Total # of non-movement windows saved:  21
# Total # of movement windows saved:  0
# 5414 5419
# Total # of non-movement windows saved:  54
# Total # of movement windows saved:  0
# 5487 5500
# Total # of non-movement windows saved:  6
# Total # of movement windows saved:  1
# 5833 5855
# Total # of non-movement windows saved:  33
# Total # of movement windows saved:  2
# 6094 6113
# Total # of non-movement windows saved:  23
# Total # of movement windows saved:  1
# 6145 6161
# Total # of non-movement windows saved:  3
# Total # of movement windows saved:  1
# 6276 6279
# Total # of non-movement windows saved:  11
# Total # of movement windows saved:  0
# 6589 6685
# Total # of non-movement windows saved:  30
# Total # of movement windows saved:  9
# 6718 6721
# Total # of non-movement windows saved:  3
# Total # of movement windows saved:  0
# 7012 7026
# Total # of non-movement windows saved:  29
# Total # of movement windows saved:  1
# currently reading in  N10W1dn1_180413_rec009.mat
# monkey does not leave frame :-)
# cam does not fall :-)
# 0 0
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  0
# 44 49
# Total # of non-movement windows saved:  4
# Total # of movement windows saved:  0
# 403 413
# Total # of non-movement windows saved:  35
# Total # of movement windows saved:  0
# 543 547
# Total # of non-movement windows saved:  12
# Total # of movement windows saved:  0
# 716 721
# Total # of non-movement windows saved:  16
# Total # of movement windows saved:  0
# 726 735
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  0
# 2118 2128
# Total # of non-movement windows saved:  138
# Total # of movement windows saved:  0
# 2347 2353
# Total # of non-movement windows saved:  21
# Total # of movement windows saved:  0
# 2373 2374
# Total # of non-movement windows saved:  1
# Total # of movement windows saved:  0
# 2873 2881
# Total # of non-movement windows saved:  49
# Total # of movement windows saved:  0
# 2885 2900
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  1
# 3807 3820
# Total # of non-movement windows saved:  90
# Total # of movement windows saved:  1
# 3849 3880
# Total # of non-movement windows saved:  2
# Total # of movement windows saved:  3
# 4170 4173
# Total # of non-movement windows saved:  28
# Total # of movement windows saved:  0
# 4203 4219
# Total # of non-movement windows saved:  2
# Total # of movement windows saved:  1
# 4338 4709
# Total # of non-movement windows saved:  11
# Total # of movement windows saved:  37
# 5437 7013
# Total # of non-movement windows saved:  72
# Total # of movement windows saved:  157
# currently reading in  N10W1dn1_180325_rec008.mat
# wrong format! cannot read.
# currently reading in  N10W1dn1_180329_rec003.mat
# monkey does not leave frame :-)
# cam does not fall :-)
# 135 141
# Total # of non-movement windows saved:  13
# Total # of movement windows saved:  0
# 179 185
# Total # of non-movement windows saved:  3
# Total # of movement windows saved:  0
# 206 217
# Total # of non-movement windows saved:  2
# Total # of movement windows saved:  1
# 468 473
# Total # of non-movement windows saved:  25
# Total # of movement windows saved:  0
# 487 501
# Total # of non-movement windows saved:  1
# Total # of movement windows saved:  1
# 1523 1532
# Total # of non-movement windows saved:  102
# Total # of movement windows saved:  0
# 1929 1938
# Total # of non-movement windows saved:  39
# Total # of movement windows saved:  0
# 2551 2560
# Total # of non-movement windows saved:  61
# Total # of movement windows saved:  0
# 3431 3465
# Total # of non-movement windows saved:  87
# Total # of movement windows saved:  3
# 3522 3539
# Total # of non-movement windows saved:  5
# Total # of movement windows saved:  1
# 3946 4020
# Total # of non-movement windows saved:  40
# Total # of movement windows saved:  7
# 4077 4088
# Total # of non-movement windows saved:  5
# Total # of movement windows saved:  1
# 4090 4099
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  0
# 4154 4158
# Total # of non-movement windows saved:  5
# Total # of movement windows saved:  0
# 4464 4472
# Total # of non-movement windows saved:  30
# Total # of movement windows saved:  0
# 5333 5572
# Total # of non-movement windows saved:  86
# Total # of movement windows saved:  23
# 5612 5619
# Total # of non-movement windows saved:  3
# Total # of movement windows saved:  0
# 6770 6783
# Total # of non-movement windows saved:  115
# Total # of movement windows saved:  1
# currently reading in  N10W1dn1_180414_rec003.mat
# monkey does not leave frame :-)
# cam does not fall :-)
# 65 77
# Total # of non-movement windows saved:  6
# Total # of movement windows saved:  1
# 376 385
# Total # of non-movement windows saved:  29
# Total # of movement windows saved:  0
# 755 781
# Total # of non-movement windows saved:  36
# Total # of movement windows saved:  2
# 936 983
# Total # of non-movement windows saved:  15
# Total # of movement windows saved:  4
# 1784 1801
# Total # of non-movement windows saved:  80
# Total # of movement windows saved:  1
# 2444 2457
# Total # of non-movement windows saved:  64
# Total # of movement windows saved:  1
# 2466 2472
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  0
# 2479 2488
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  0
# 2504 2512
# Total # of non-movement windows saved:  1
# Total # of movement windows saved:  0
# 3138 3150
# Total # of non-movement windows saved:  62
# Total # of movement windows saved:  1
# 3746 3757
# Total # of non-movement windows saved:  59
# Total # of movement windows saved:  1
# 4412 4429
# Total # of non-movement windows saved:  65
# Total # of movement windows saved:  1
# 5796 5801
# Total # of non-movement windows saved:  136
# ...
# Total # of movement windows saved:  0
# 4935 4941
# Total # of non-movement windows saved:  1
# Total # of movement windows saved:  0
# 4965 4967
# Total # of non-movement windows saved:  2
# Total # of movement windows saved:  0
# 5441 5448
# Total # of non-movement windows saved:  47
# Total # of movement windows saved:  0
# 6260 6278
# Total # of non-movement windows saved:  81
# Total # of movement windows saved:  1
# 6325 6333
# Total # of non-movement windows saved:  4
# Total # of movement windows saved:  0
# 6353 6371
# Total # of non-movement windows saved:  1
# Total # of movement windows saved:  1
# 6832 6851
# Total # of non-movement windows saved:  46
# Total # of movement windows saved:  1
# currently reading in  N10W1dn1_180329_rec009.mat
# N10W1dn1_180329_rec009.mat  has no transitions.
# This spec is either entirely moving or not moving. So let's check the prior rec.
# Unable to extract movements from recording  8 . Trying one prior.
# cannot unpack non-iterable NoneType object
# Unable to read  N10W1dn1_180329_rec009.mat
# currently reading in  N10W1dn1_180329_rec004.mat
# monkey does not leave frame :-)
# cam does not fall :-)
# Saved the project. 2
# 1185 1238
# Total # of non-movement windows saved:  118
# Total # of movement windows saved:  5
# 1299 1400
# Total # of non-movement windows saved:  6
# Total # of movement windows saved:  10
# 1494 1507
# Total # of non-movement windows saved:  9
# Total # of movement windows saved:  1
# 1894 1968
# Total # of non-movement windows saved:  38
# Total # of movement windows saved:  7
# 2566 2588
# Total # of non-movement windows saved:  59
# Total # of movement windows saved:  2
# 4587 4630
# Total # of non-movement windows saved:  199
# Total # of movement windows saved:  4
# 4654 4669
# Total # of non-movement windows saved:  2
# Total # of movement windows saved:  1
# 4768 4778
# Total # of non-movement windows saved:  9
# Total # of movement windows saved:  0
# 5148 5155
# Total # of non-movement windows saved:  36
# Total # of movement windows saved:  0
# 6191 6203
# Total # of non-movement windows saved:  103
# Total # of movement windows saved:  1
# 6568 6589
# Total # of non-movement windows saved:  36
# Total # of movement windows saved:  2
# 6834 6909
# Total # of non-movement windows saved:  24
# Total # of movement windows saved:  7
# 7032 -1
# Total # of non-movement windows saved:  12
# Total # of movement windows saved:  16
# currently reading in  N10W1dn1_180413_rec004.mat
# monkey does not leave frame :-)
# cam does not fall :-)
# save 1
# 0 1293
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  129
# 1446 1451
# Total # of non-movement windows saved:  15
# Total # of movement windows saved:  0
# 1530 1540
# Total # of non-movement windows saved:  7
# Total # of movement windows saved:  0
# 2154 2160
# Total # of non-movement windows saved:  61
# Total # of movement windows saved:  0
# 2248 2258
# Total # of non-movement windows saved:  8
# Total # of movement windows saved:  0
# 3224 3278
# Total # of non-movement windows saved:  96
# Total # of movement windows saved:  5
# 4190 4291
# Total # of non-movement windows saved:  91
# Total # of movement windows saved:  10
# 4316 4328
# Total # of non-movement windows saved:  2
# Total # of movement windows saved:  1
# 4385 4389
# Total # of non-movement windows saved:  5
# Total # of movement windows saved:  0
# 4432 4454
# Total # of non-movement windows saved:  4
# Total # of movement windows saved:  2
# 4488 4500
# Total # of non-movement windows saved:  3
# Total # of movement windows saved:  1
# 4567 4574
# Total # of non-movement windows saved:  6
# Total # of movement windows saved:  0
# 6450 6452
# Total # of non-movement windows saved:  187
# Total # of movement windows saved:  0
# 6559 6565
# Total # of non-movement windows saved:  10
# Total # of movement windows saved:  0
# currently reading in  N10W1dn1_180329_rec007.mat
# N10W1dn1_180329_rec007.mat  has no transitions.
# This spec is either entirely moving or not moving. So let's check the prior rec.
# Monkey is sleeping for the entire recording!
# Was able to use prior rec, saving.
# monkey does not leave frame :-)
# cam does not fall :-)
# 7177 7177
# Total # of non-movement windows saved:  717
# Total # of movement windows saved:  0
# currently reading in  N10W1dn1_180414_rec005.mat
# monkey does not leave frame :-)
# cam does not fall :-)
# Saved the project. 2
# 685 697
# Total # of non-movement windows saved:  68
# Total # of movement windows saved:  1
# 702 711
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  0
# 1031 1035
# Total # of non-movement windows saved:  31
# Total # of movement windows saved:  0
# 1235 1277
# Total # of non-movement windows saved:  19
# Total # of movement windows saved:  4
# 1463 1469
# Total # of non-movement windows saved:  18
# Total # of movement windows saved:  0
# 1682 1696
# Total # of non-movement windows saved:  21
# Total # of movement windows saved:  1
# 1700 1704
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  0
# 1716 1723
# Total # of non-movement windows saved:  1
# Total # of movement windows saved:  0
# 2250 2320
# Total # of non-movement windows saved:  52
# Total # of movement windows saved:  6
# 2444 2512
# Total # of non-movement windows saved:  12
# Total # of movement windows saved:  6
# 2579 2583
# Total # of non-movement windows saved:  6
# Total # of movement windows saved:  0
# 2597 2602
# Total # of non-movement windows saved:  1
# Total # of movement windows saved:  0
# 2605 3185
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  57
# 3221 3238
# Total # of non-movement windows saved:  3
# Total # of movement windows saved:  1
# 3255 3265
# Total # of non-movement windows saved:  1
# Total # of movement windows saved:  0
# 3643 3658
# Total # of non-movement windows saved:  37
# Total # of movement windows saved:  1
# 4056 4070
# Total # of non-movement windows saved:  39
# Total # of movement windows saved:  1
# 4545 4578
# Total # of non-movement windows saved:  47
# Total # of movement windows saved:  3
# 6277 6296
# Total # of non-movement windows saved:  169
# Total # of movement windows saved:  1
# 6305 6313
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  0
# 6322 6325
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  0
# 6330 6336
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  0
# 6555 6611
# Total # of non-movement windows saved:  21
# Total # of movement windows saved:  5
# 6625 6632
# Total # of non-movement windows saved:  1
# Total # of movement windows saved:  0
# 6840 6847
# Total # of non-movement windows saved:  20
# Total # of movement windows saved:  0
# 7170 -1
# Total # of non-movement windows saved:  32
# Total # of movement windows saved:  1
# currently reading in  N10W1dn1_180401_rec003.mat
# wrong format! cannot read.
# currently reading in  N10W1dn1_180401_rec004.mat
# wrong format! cannot read.
# currently reading in  N10W1dn1_180413_rec005.mat
# monkey does not leave frame :-)
# cam does not fall :-)
# 127 142
# Total # of non-movement windows saved:  12
# Total # of movement windows saved:  1
# 1476 1482
# Total # of non-movement windows saved:  133
# Total # of movement windows saved:  0
# 2531 2549
# Total # of non-movement windows saved:  104
# Total # of movement windows saved:  1
# 2571 2578
# Total # of non-movement windows saved:  2
# Total # of movement windows saved:  0
# 2587 2594
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  0
# 2987 3012
# Total # of non-movement windows saved:  39
# Total # of movement windows saved:  2
# 4384 4390
# Total # of non-movement windows saved:  137
# Total # of movement windows saved:  0
# 5189 5199
# Total # of non-movement windows saved:  79
# Total # of movement windows saved:  0
# 5208 5210
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  0
# 5992 6001
# Total # of non-movement windows saved:  78
# Total # of movement windows saved:  0
# 6009 6016
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  0
# 6022 6023
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  0
# 6513 6531
# Total # of non-movement windows saved:  48
# Total # of movement windows saved:  1
# 6560 6572
# Total # of non-movement windows saved:  2
# Total # of movement windows saved:  1
# 7174 7181
# Total # of non-movement windows saved:  60
# Total # of movement windows saved:  0
# currently reading in  N10W1dn1_180324_rec002.mat
# wrong format! cannot read.
# currently reading in  N10W1dn1_180322_rec008.mat
# N10W1dn1_180322_rec008.mat  has no transitions.
# This spec is either entirely moving or not moving. So let's check the prior rec.
# Monkey is sleeping for the entire recording!
# Was able to use prior rec, saving.
# monkey does not leave frame :-)
# cam does not fall :-)
# 7190 7190
# Total # of non-movement windows saved:  718
# Total # of movement windows saved:  0
# currently reading in  N10W1dn1_180410_rec002.mat
# monkey does not leave frame :-)
# cam does not fall :-)
# 506 695
# Total # of non-movement windows saved:  50
# Total # of movement windows saved:  18
# 773 777
# Total # of non-movement windows saved:  7
# Total # of movement windows saved:  0
# 800 802
# Total # of non-movement windows saved:  2
# Total # of movement windows saved:  0
# 1360 1373
# Total # of non-movement windows saved:  55
# Total # of movement windows saved:  1
# 1394 1397
# Total # of non-movement windows saved:  2
# Total # of movement windows saved:  0
# 2669 2675
# Total # of non-movement windows saved:  127
# Total # of movement windows saved:  0
# 3324 3396
# Total # of non-movement windows saved:  64
# Total # of movement windows saved:  7
# 3609 3613
# Total # of non-movement windows saved:  21
# Total # of movement windows saved:  0
# 3696 3728
# Total # of non-movement windows saved:  8
# Total # of movement windows saved:  3
# 3814 3819
# Total # of non-movement windows saved:  8
# Total # of movement windows saved:  0
# 4418 4431
# Total # of non-movement windows saved:  59
# Total # of movement windows saved:  1
# 5811 5888
# Total # of non-movement windows saved:  137
# Total # of movement windows saved:  7
# 6218 6259
# Total # of non-movement windows saved:  32
# Total # of movement windows saved:  4
# currently reading in  N10W1dn1_180410_rec007.mat
# N10W1dn1_180410_rec007.mat  has no transitions.
# This spec is either entirely moving or not moving. So let's check the prior rec.
# Monkey is sleeping for the entire recording!
# Was able to use prior rec, saving.
# monkey does not leave frame :-)
# cam does not fall :-)
# 2524 2524
# Total # of non-movement windows saved:  252
# Total # of movement windows saved:  0
# currently reading in  N10W1dn1_180324_rec009.mat
# wrong format! cannot read.
# currently reading in  N10W1dn1_180329_rec002.mat
# monkey does not leave frame :-)
# cam does not fall :-)
# 59 72
# Total # of non-movement windows saved:  5
# Total # of movement windows saved:  1
# 575 590
# Total # of non-movement windows saved:  50
# Total # of movement windows saved:  1
# 618 638
# Total # of non-movement windows saved:  2
# Total # of movement windows saved:  1
# 659 663
# Total # of non-movement windows saved:  2
# Total # of movement windows saved:  0
# 677 688
# Total # of non-movement windows saved:  1
# Total # of movement windows saved:  1
# 1761 1782
# Total # of non-movement windows saved:  107
# Total # of movement windows saved:  2
# 2290 2305
# Total # of non-movement windows saved:  50
# Total # of movement windows saved:  1
# 3869 3915
# Total # of non-movement windows saved:  156
# Total # of movement windows saved:  4
# 4406 4448
# Total # of non-movement windows saved:  49
# Total # of movement windows saved:  4
# 6048 6060
# Total # of non-movement windows saved:  159
# Total # of movement windows saved:  1
# 6095 6115
# Total # of non-movement windows saved:  3
# Total # of movement windows saved:  1
# currently reading in  N10W1dn1_180322_rec011.mat
# N10W1dn1_180322_rec011.mat  has no transitions.
# This spec is either entirely moving or not moving. So let's check the prior rec.
# Unable to extract movements from recording  10 . Trying one prior.
# cannot unpack non-iterable NoneType object
# Unable to read  N10W1dn1_180322_rec011.mat
# currently reading in  N10W1dn1_180323_rec003.mat
# monkey does not leave frame :-)
# cam does not fall :-)
# Saved the project. 2
# 456 458
# Total # of non-movement windows saved:  45
# Total # of movement windows saved:  0
# 462 474
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  1
# 491 500
# Total # of non-movement windows saved:  1
# Total # of movement windows saved:  0
# 1518 1528
# Total # of non-movement windows saved:  101
# Total # of movement windows saved:  0
# 1773 1780
# Total # of non-movement windows saved:  24
# Total # of movement windows saved:  0
# 2108 2123
# Total # of non-movement windows saved:  32
# Total # of movement windows saved:  1
# 2291 2293
# Total # of non-movement windows saved:  16
# Total # of movement windows saved:  0
# 2651 2674
# Total # of non-movement windows saved:  35
# Total # of movement windows saved:  2
# 3688 3690
# Total # of non-movement windows saved:  101
# Total # of movement windows saved:  0
# 3695 3715
# Total # of non-movement windows saved:  0
# Total # of movement windows saved:  1
# 3947 3953
# Total # of non-movement windows saved:  23
# Total # of movement windows saved:  0
# 4163 4180
# Total # of non-movement windows saved:  20
# Total # of movement windows saved:  1
# 4731 4734
# Total # of non-movement windows saved:  55
# Total # of movement windows saved:  0
# 4812 4824
# Total # of non-movement windows saved:  7
# Total # of movement windows saved:  1
# 6090 6141
# Total # of non-movement windows saved:  126
# Total # of movement windows saved:  5
# 6312 6339
# Total # of non-movement windows saved:  17
# Total # of movement windows saved:  2
# 6809 6863
# Total # of non-movement windows saved:  46
# Total # of movement windows saved:  5
# 6908 -1
# Total # of non-movement windows saved:  4
# Total # of movement windows saved:  28
# currently reading in  N10W1dn1_180327_rec003.mat
# monkey does not leave frame :-)
# cam does not fall :-)
# 474 658
# Total # of non-movement windows saved:  47
# Total # of movement windows saved:  18
# 843 847
# Total # of non-movement windows saved:  18
# Total # of movement windows saved:  0
# 859 1136
# Total # of non-movement windows saved:  1
# Total # of movement windows saved:  27
# 2733 2740
# Total # of non-movement windows saved:  159
# Total # of movement windows saved:  0
# 3709 3718
# Total # of non-movement windows saved:  96
# Total # of movement windows saved:  0
# 3816 4759
# Total # of non-movement windows saved:  9
# Total # of movement windows saved:  94
# 4774 4784
# Total # of non-movement windows saved:  1
# Total # of movement windows saved:  0
# 4844 4856
# Total # of non-movement windows saved:  5
# Total # of movement windows saved:  1
# 5326 5339
# Total # of non-movement windows saved:  46
# Total # of movement windows saved:  1
# 6079 6156
# Total # of non-movement windows saved:  73
# Total # of movement windows saved:  7
# 6546 6562
# Total # of non-movement windows saved:  38
# Total # of movement windows saved:  1
# 6648 6868
# Total # of non-movement windows saved:  8
# Total # of movement windows saved:  21
# 6940 6947
# Total # of non-movement windows saved:  7
# Total # of movement windows saved:  0
# currently reading in  N10W1dn1_180322_rec004.mat
# monkey does not leave frame :-)
# cam does not fall :-)
# 19 36
# Total # of non-movement windows saved:  1
# Total # of movement windows saved:  1
# 69 103
# Total # of non-movement windows saved:  3
# Total # of movement windows saved:  3
# 143 232
# Total # of non-movement windows saved:  3
# Total # of movement windows saved:  8
# 330 3718
# Total # of non-movement windows saved:  9
# Total # of movement windows saved:  338
# 3992 3999
# Total # of non-movement windows saved:  27
# Total # of movement windows saved:  0
# 5171 5175
# Total # of non-movement windows saved:  117
# Total # of movement windows saved:  0
# 5903 5911
# Total # of non-movement windows saved:  72
# Total # of movement windows saved:  0
# 6358 6365
# Total # of non-movement windows saved:  44
# Total # of movement windows saved:  0
# 6829 6831
# Total # of non-movement windows saved:  46
# Total # of movement windows saved:  0
# currently reading in  N10W1dn1_180325_rec004.mat
# wrong format! cannot read.
# Done! Total non-movement =  12952  and total movement =  9739

# %%
# !pwd

# %%
spec_f = []
for f in os.listdir('../../data2/sleep'):
    night, rec = f.split('_')[:2]
    night_rec = night + "_" + rec
    spec_f.append(night_rec)

# %%
len(list(set(spec_f)))

# %%
all_badtimes = np.array([])
for ch in range(1,63): #iterate over the 62 channels saved, stack together and proceed with that. 
    badtimes = spec['Spec_per_Ch']['Ch'+str(ch)][0][0]['badtimes'][0][0]
    all_badtimes = np.concatenate([all_badtimes, badtimes.flatten()])

# %%
plt.hist(all_badtimes)

# %%
all_badtimes = np.array(list(set(all_badtimes)))

# %%
badtimes.shape

# %%
# load in a few sample inputs to see if they make sense?

# %%
sample_sleep = np.load('../../data/sleep/180326_003_62_win119_sleep.npy')

# %%
plt.imshow(sample_sleep[0].T)

# %%
sample_move = np.load('../../data/move/180326_003_62_win12_move.npy')

# %%
plt.imshow(sample_move[0].T)
